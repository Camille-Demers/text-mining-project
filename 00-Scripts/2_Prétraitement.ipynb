# %% [markdown]
# ## **2. Prétraitement**
# - Segmentation (phrases)
# - Tokenization (mots)
# - Étiquetage morphosyntaxique (POS Tagging)
# - Filtrage (stopwords)
# - Extraction de termes complexes (MWE / n-grammes / segments répétés)
# - Chunking / Filtrage par patrons syntaxiques (basés sur les patrons fréquents dans les MeSH)
# - Extraction de collocations significatives (en fonction du Log-likelihood ratio)
# - Extraction de concordances (KWIC) pour un ensemble de mots-clés d'intérêt
# - Extraction de termes MeSH présents dans les données / Termes de la taxonomie présents dans les données

# %% [markdown]
# ### **Lire le corpus**

# %%
import shutil, re, random
from os import listdir, chdir, path
from pathlib import Path
from pandas import *
import glob

import nltk
#nltk.download(['popular'])
from nltk.tokenize import RegexpTokenizer
tokenizer_re = RegexpTokenizer(r"\w\'|\w+")
from nltk import bigrams, trigrams, ngrams, everygrams
from nltk.probability import FreqDist


import treetaggerwrapper
tagger = treetaggerwrapper.TreeTagger(TAGLANG='fr')


from collections import Counter
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.stats import binom, chi2
# Out:
# c:\Users\p1115145\AppData\Local\Programs\Python\Python310\lib\site-packages\treetaggerwrapper.py:739: FutureWarning: Possible nested set at position 8
#   punct2find_re = re.compile("([^ ])([[" + ALONEMARKS + "])",
# c:\Users\p1115145\AppData\Local\Programs\Python\Python310\lib\site-packages\treetaggerwrapper.py:2043: FutureWarning: Possible nested set at position 152
#   DnsHostMatch_re = re.compile("(" + DnsHost_expression + ")",
# c:\Users\p1115145\AppData\Local\Programs\Python\Python310\lib\site-packages\treetaggerwrapper.py:2067: FutureWarning: Possible nested set at position 409
#   UrlMatch_re = re.compile(UrlMatch_expression, re.VERBOSE | re.IGNORECASE)
# c:\Users\p1115145\AppData\Local\Programs\Python\Python310\lib\site-packages\treetaggerwrapper.py:2079: FutureWarning: Possible nested set at position 192
#   EmailMatch_re = re.compile(EmailMatch_expression, re.VERBOSE | re.IGNORECASE)

# %%
lng = 'fr'
acteur = '' # Paramètre à indiquer avant de rouler le script

if lng == 'fr':
    file = acteur +'.csv'
if lng == 'en':
    file = acteur + '_en.csv'

# %%
def lire_corpus(acteur = acteur, langue=lng):
    base_path = '../01-corpus/2-data/'
    
    folder_path = path.join(base_path, '1-' + langue, acteur)
    all_files = glob.glob(path.join(folder_path, "*.csv"))
    tags = [f.split('_')[1][:-4] for f in listdir(folder_path)]

    df = DataFrame()
    for f, tag in zip(all_files, tags):
        csv = read_csv(f, encoding='utf-8', sep=',')
        csv = csv[~csv["Address"].str.contains('pdf')] #  Problèmes 

        df = concat([df, csv]) [['Corpus', 'Sous-corpus', 'Address', 'Title', 'Type', 'text']]
    return df

def lire_corpus_csv(acteur):
    base_path = '../01-corpus/2-data/1-fr/'
    with open(base_path + acteur + '.csv', encoding='utf-8') as f:
        df = read_csv(f, encoding='utf-8', sep=',')
    return df

# %%
data = lire_corpus_csv(acteur) 
nb_docs = len(data)
print("On a un corpus de {} documents.".format(nb_docs))
# Out:
# On a un corpus de 3568 documents.

# %%
base_path = '../01-corpus/2-data/'
folder_path = path.join(base_path, '1-' + lng, acteur)

data.to_csv(folder_path + '.csv')
data
# Out:
#       Unnamed: 0 Corpus             Sous-corpus  \
# 0              0   chum  Aide médicale à mourir
# 1              1   chum  Aide médicale à mourir
# 2              2   chum  Aide médicale à mourir
# 3              3   chum  Aide médicale à mourir
# 4              0   chum              Audiologie
# ...          ...    ...                     ...
# 3563          44   chum       Soins et services
# 3564           0   chum             Toxicomanie
# 3565           1   chum             Toxicomanie
# 3566           2   chum             Toxicomanie
# 3567           3   chum             Toxicomanie
#
#                                                 Address  \
# 0     https:////www.chumontreal.qc.ca//patients//aid...
# 1     https:////www.chumontreal.qc.ca//patients//aid...
# 2     https:////www.chumontreal.qc.ca//patients//aid...
# 3     https:////www.chumontreal.qc.ca//patients//aid...
# 4     https:////www.chumontreal.qc.ca//patients//aud...
# ...                                                 ...
# 3563  https:////www.chumontreal.qc.ca//fiche//preven...
# 3564  https:////www.chumontreal.qc.ca//patients//med...
# 3565  https:////www.chumontreal.qc.ca//patients//med...
# 3566  https:////www.chumontreal.qc.ca//patients//med...
# 3567  https:////www.chumontreal.qc.ca//patients//med...
#
#                                                   Title        Type  \
# 0       Aide médicale à mourir - Je suis patient | CHUM  text//html
# 1     Aide médicale à mourir - Je suis un proche | CHUM  text//html
# 2     Aide médicale à mourir - Don d’organes et don ...  text//html
# 3     Aide médicale à mourir - Groupes de soutien | ...  text//html
# 4                      CHUM | Audiologie - Nos services  text//html
# ...                                                 ...         ...
# 3563  Prévenir les chutes lors de mon rendez-vous à ...  text//html
# 3564                                     Soins de santé  text//html
# 3565                                       Enseignement  text//html
# 3566             Soutien aux professionnels de la santé  text//html
# 3567                                          Recherche  text//html
#
#                                                    text
# 0     Demander l'aide médicale à mourir Faire une de...
# 1     Accompagner un proche qui demande l'aide médic...
# 2     Don d’organes et don de tissus Le don d’organe...
# 3     Groupes de soutien Des groupes qui pourront vo...
# 4     Nos services Troubles d'audition Vertiges et d...
# ...                                                 ...
# 3563  Prévenir les chutes lors de mon rendez-vous à ...
# 3564  Soins de santé NOS PROGRAMMES Hospitalisation ...
# 3565  Enseignement Programme de formation avancée en...
# 3566  Soutien aux professionnels de la santé N’hésit...
# 3567  Recherche ÉTUDES EN COURS DE RECRUTEMENT Utili...
#
# [3568 rows x 7 columns]

# %% [markdown]
# ### **Nettoyage**

# %%
punct = '[!#$%&•►*+,;\/\\<=>?@[\]^_{|}~©«»—“”–—]'
spaces = '\s+'
postals = '([a-zA-Z]+\d+|\d+[a-zA-Z]+)+'

text = [str(t).strip('\n').lower().replace('’', '\'') for t in data['text'].tolist()]
text = [re.sub(spaces, ' ', t) for t in text]
text = [re.sub(postals, ' STOP ', t) for t in text]
text = [re.sub(punct, ' STOP ', t) for t in text]
text = [t.replace("  ", " " ) for t in text]

# %% [markdown]
# ### **Extraire un échantillon aléatoire**
#
# Au besoin, si on n'arrive pas à traiter la totalité du corpus pour des raisons de performance, on peut prendre un échantillon aléatoire en spécifiant un ratio souhaité.

# %%
def sample_corpus(corpus, ratio):
    n = round(ratio * len(corpus))
    corpus = random.sample(text, n)
    print("On va travailler sur un échantillon correspondant à environ " + str(ratio * 100) + " % des documents du corpus, soit {} documents". format(len(corpus)))
    return " ".join(corpus)
    
corpus = sample_corpus(text, 1) # Ratio à modifier au besoin
# Out:
# On va travailler sur un échantillon correspondant à environ 100 % des documents du corpus, soit 3568 documents

# %% [markdown]
# ### **Filtrage**
# On va filtrer tout de suite filtrer certaines expressions relatives à l'architecture d'information / navigation Web

# %%
def filter_mwesw(corpus):
    file_mwesw = '../02-filtrage/mwe_stopwords.txt'
    with open (file_mwesw, 'r', encoding='utf-8') as f:
        mwe_sw = [t.lower().strip('\n') for t in f.readlines()]
    for mwe in mwe_sw:
        corpus = corpus.replace(mwe, ' STOP ').replace('  ', " ")
    return corpus

# %%
corpus = filter_mwesw(corpus)

# %% [markdown]
# ### **Tokenisation / POS tagging** (TreeTagger)
# https://github.com/miotto/treetagger-python/blob/master/README.rst
# https://treetaggerwrapper.readthedocs.io/en/latest/

# %%
# Ici, on tokenise une première fois avec le Regex Tokenizer de NLTK pour voir combien de temps ça devrait 
# prendre au Tree Tagger pour tokeniser et tagger notre corpus ; en théorie, le Tree Tagger est capable d'étiquetter
# environ 15 000 tokens / seconde. 
def tok(corpus):
    # Seulement les caractères alphabétiques
    tokens = tokenizer_re.tokenize(corpus)
    print("Avec le RegExpTokenizer, notre corpus contient {} tokens.".format(len(tokens)))
    temps = round(len(tokens) / 15000 / 60)
    print('Le POS tagging devrait prendre environ {} minutes.'.format(temps))
    return tokens

tok(corpus)[:10]
# Out:
# Avec le RegExpTokenizer, notre corpus contient 973306 tokens.
# Le POS tagging devrait prendre environ 1 minutes.
# ['axe',
#  'imagerie',
#  'et',
#  'ingénierie',
#  'responsable',
#  'de',
#  "l'",
#  'axe',
#  'gilles',
#  'soulez']

# %%
def tagging(corpus):
    output = []
    for t in tagger.tag_text(corpus):
        try: 
            output.append([t.split('\t')[0], t.split('\t')[1]])
        except Exception as e:
            output.append(('STOP', 'NAM'))

    return output

# %%
tagged = tagging(corpus)
tokens = [t[0] for t in tagged]

# %%
tagged
# Out:
# [['axe', 'VER:pres'],
#  ['imagerie', 'NOM'],
#  ['et', 'KON'],
#  ['ingénierie', 'NOM'],
#  ['responsable', 'ADJ'],
#  ['de', 'PRP'],
#  ["l'", 'DET:ART'],
#  ['axe', 'NOM'],
#  [':', 'PUN'],
#  ['gilles', 'NOM'],
#  ['soulez', 'VER:pres'],
#  ['STOP', 'NOM'],
#  ['m.d.', 'VER:subi'],
#  ['STOP', 'NOM'],
#  ['m', 'NOM'],
#  ['.', 'SENT'],
#  ['sc', 'NOM'],
#  ['.', 'SENT'],
#  ['STOP', 'INT'],
#  ['frcpc', 'NOM'],
#  ['STOP', 'INT'],
#  ['publications', 'NOM'],
#  ['des', 'PRP:det'],
#  ['chercheurs', 'NOM'],
#  ["l'", 'DET:ART'],
#  ['axe', 'NOM'],
#  ['imagerie', 'NOM'],
#  ['et', 'KON'],
#  ['ingénierie', 'NOM'],
#  ['du', 'PRP:det'],
#  ['crchum', 'NOM'],
#  ['se', 'PRO:PER'],
#  ['donne', 'VER:pres'],
#  ['pour', 'PRP'],
#  ['mission', 'NOM'],
#  ['principale', 'ADJ'],
#  ['de', 'PRP'],
#  ['mettre', 'VER:infi'],
#  ['le', 'DET:ART'],
#  ['génie', 'NOM'],
#  ['au', 'PRP:det'],
#  ['service', 'NOM'],
#  ['de', 'PRP'],
#  ['la', 'DET:ART'],
#  ['santé', 'NOM'],
#  ['.', 'SENT'],
#  ['il', 'PRO:PER'],
#  ['regroupe', 'VER:pres'],
#  ['des', 'PRP:det'],
#  ['chercheurs', 'NOM'],
#  ['issus', 'ADJ'],
#  ['de', 'PRP'],
#  ['plusieurs', 'PRO:IND'],
#  ['domaines', 'NOM'],
#  ["d'", 'PRP'],
#  ['expertise', 'NOM'],
#  ['dans', 'PRP'],
#  ['le', 'DET:ART'],
#  ['but', 'NOM'],
#  ['de', 'PRP'],
#  ['favoriser', 'VER:infi'],
#  ['les', 'DET:ART'],
#  ['interactions', 'NOM'],
#  ['et', 'KON'],
#  ['la', 'DET:ART'],
#  ['mise', 'NOM'],
#  ['en', 'PRP'],
#  ['commun', 'NOM'],
#  ['des', 'PRP:det'],
#  ['compétences', 'NOM'],
#  ['.', 'SENT'],
#  ["l'", 'DET:ART'],
#  ['axe', 'NOM'],
#  ['imagerie', 'NOM'],
#  ['et', 'KON'],
#  ['ingénierie', 'NOM'],
#  ['du', 'PRP:det'],
#  ['crchum', 'NOM'],
#  ['abrite', 'VER:pres'],
#  ['cinq', 'NUM'],
#  ['laboratoires', 'NOM'],
#  ['STOP', 'NOM'],
#  ['en', 'PRP'],
#  ['lien', 'NOM'],
#  ['avec', 'PRP'],
#  ['trois', 'NUM'],
#  ['thématiques', 'NOM'],
#  [':', 'PUN'],
#  ['imagerie', 'NOM'],
#  ['et', 'KON'],
#  ['modélisation', 'NOM'],
#  ['morpho-fonctionnelle', 'ADJ'],
#  ['et', 'KON'],
#  ['physique', 'ADJ'],
#  ['des', 'PRP:det'],
#  ['systèmes', 'NOM'],
#  ['biologiques', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['gestes', 'NOM'],
#  ['médicaux', 'ADJ'],
#  ['guidés', 'VER:pper'],
#  ['par', 'PRP'],
#  ["l'", 'DET:ART'],
#  ['image', 'NOM'],
#  ['STOP', 'INT'],
#  ['conception', 'NOM'],
#  ['STOP', 'INT'],
#  ['développement', 'NOM'],
#  ['et', 'KON'],
#  ['validation', 'NOM'],
#  ['de', 'PRP'],
#  ['nouveaux', 'ADJ'],
#  ['biomatériaux', 'NOM'],
#  ['et', 'KON'],
#  ['implants', 'NOM'],
#  ['.', 'SENT'],
#  ['laboratoire', 'NOM'],
#  ['de', 'PRP'],
#  ['recherche', 'NOM'],
#  ['en', 'PRP'],
#  ['imagerie', 'NOM'],
#  ['et', 'KON'],
#  ['orthopédie', 'NOM'],
#  ['(', 'PUN'],
#  ['lio', 'NOM'],
#  [')', 'PUN'],
#  ['le', 'DET:ART'],
#  ['laboratoire', 'NOM'],
#  ['de', 'PRP'],
#  ['recherche', 'NOM'],
#  ['en', 'PRP'],
#  ['imagerie', 'NOM'],
#  ['et', 'KON'],
#  ['orthopédie', 'NOM'],
#  ['(', 'PUN'],
#  ['lio', 'NOM'],
#  [')', 'PUN'],
#  ['est', 'VER:pres'],
#  ['un', 'DET:ART'],
#  ['laboratoire', 'NOM'],
#  ['multidisciplinaire', 'ADJ'],
#  ['accrédité', 'VER:pper'],
#  ['de', 'PRP'],
#  ["l'", 'DET:ART'],
#  ['école', 'NOM'],
#  ['de', 'PRP'],
#  ['technologie', 'NOM'],
#  ['supérieure', 'ADJ'],
#  ['dont', 'PRO:REL'],
#  ['la', 'DET:ART'],
#  ['sphère', 'NOM'],
#  ["d'", 'PRP'],
#  ['activités', 'NOM'],
#  ["s'", 'PRO:PER'],
#  ['étend', 'VER:pres'],
#  ['autour', 'ADV'],
#  ['de', 'PRP'],
#  ["l'", 'DET:ART'],
#  ['imagerie', 'NOM'],
#  ['médicale', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['de', 'PRP'],
#  ['la', 'DET:ART'],
#  ['biomécanique', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['des', 'PRP:det'],
#  ['dispositifs', 'NOM'],
#  ['médicaux', 'ADJ'],
#  ['et', 'KON'],
#  ['des', 'PRP:det'],
#  ['aides', 'NOM'],
#  ['techniques', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['des', 'PRP:det'],
#  ['systèmes', 'NOM'],
#  ["d'", 'PRP'],
#  ['aide', 'NOM'],
#  ['à', 'PRP'],
#  ['la', 'DET:ART'],
#  ['décision', 'NOM'],
#  ['assistés', 'VER:pper'],
#  ['par', 'PRP'],
#  ['ordinateur', 'NOM'],
#  ['et', 'KON'],
#  ['des', 'PRP:det'],
#  ['biomatériaux', 'NOM'],
#  ['.', 'SENT'],
#  ['les', 'DET:ART'],
#  ['chercheurs', 'NOM'],
#  ['du', 'PRP:det'],
#  ['lio', 'NOM'],
#  ['STOP', 'NOM'],
#  ['ingénieurs', 'NOM'],
#  ['et', 'KON'],
#  ['cliniciens', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['travaillent', 'VER:pres'],
#  ['en', 'PRP'],
#  ['étroite', 'ADJ'],
#  ['collaboration', 'NOM'],
#  ['à', 'PRP'],
#  ["l'", 'DET:ART'],
#  ['analyse', 'NOM'],
#  ['morpho-fonctionnelle', 'ADJ'],
#  ['des', 'PRP:det'],
#  ['systèmes', 'NOM'],
#  ['biologiques', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['à', 'PRP'],
#  ['la', 'DET:ART'],
#  ['modélisation', 'NOM'],
#  ['géométrique', 'ADJ'],
#  ['et', 'KON'],
#  ['fonctionnelle', 'ADJ'],
#  ['des', 'PRP:det'],
#  ['organes', 'NOM'],
#  ['et', 'KON'],
#  ['des', 'PRP:det'],
#  ['articulations', 'NOM'],
#  ['STOP', 'NOM'],
#  ['ainsi', 'ADV'],
#  ["qu'", 'KON'],
#  ['à', 'PRP'],
#  ['la', 'DET:ART'],
#  ['conception', 'NOM'],
#  ['et', 'KON'],
#  ['à', 'PRP'],
#  ["l'", 'DET:ART'],
#  ['évaluation', 'NOM'],
#  ['de', 'PRP'],
#  ['méthodes', 'NOM'],
#  ['de', 'PRP'],
#  ['traitement', 'NOM'],
#  ['et', 'KON'],
#  ["d'", 'PRP'],
#  ['analyse', 'NOM'],
#  ["d'", 'PRP'],
#  ['images', 'NOM'],
#  ['STOP', 'NOM'],
#  ['de', 'PRP'],
#  ['dispositifs', 'NOM'],
#  ['médicaux', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['de', 'PRP'],
#  ['prothèses', 'NOM'],
#  ['et', 'KON'],
#  ["d'", 'PRP'],
#  ['orthèses', 'NOM'],
#  ['STOP', 'NOM'],
#  ["d'", 'PRP'],
#  ['instruments', 'NOM'],
#  ['chirurgicaux', 'ADJ'],
#  ['et', 'KON'],
#  ['de', 'PRP'],
#  ['robots', 'NOM'],
#  ['médicaux', 'ADJ'],
#  ['.', 'SENT'],
#  ['STOP', 'INT'],
#  ['site', 'NOM'],
#  ['du', 'PRP:det'],
#  ['lio', 'NOM'],
#  ['laboratoire', 'NOM'],
#  ['de', 'PRP'],
#  ['biomatériaux', 'NOM'],
#  ['endovasculaires', 'ADJ'],
#  ['(', 'PUN'],
#  ['lbev', 'ADJ'],
#  [')', 'PUN'],
#  ['le', 'DET:ART'],
#  ['laboratoire', 'NOM'],
#  ['de', 'PRP'],
#  ['biomatériaux', 'NOM'],
#  ['endovasculaires', 'ADJ'],
#  ['(', 'PUN'],
#  ['lbev', 'ADJ'],
#  [')', 'PUN'],
#  ["s'", 'PRO:PER'],
#  ['intéresse', 'VER:pres'],
#  ['aux', 'PRP:det'],
#  ['biomatériaux', 'NOM'],
#  ['et', 'KON'],
#  ['implants', 'NOM'],
#  ['biomédicaux', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['à', 'PRP'],
#  ['leur', 'DET:POS'],
#  ['caractérisation', 'NOM'],
#  ['et', 'KON'],
#  ['à', 'PRP'],
#  ['leurs', 'DET:POS'],
#  ['modifications', 'NOM'],
#  ['de', 'PRP'],
#  ['surface', 'NOM'],
#  ['STOP', 'NOM'],
#  ['en', 'PRP'],
#  ['particulier', 'NOM'],
#  ['pour', 'PRP'],
#  ['les', 'DET:ART'],
#  ['applications', 'NOM'],
#  ['cardiovasculaires', 'ADJ'],
#  ['.', 'SENT'],
#  ['entre', 'PRP'],
#  ['autres', 'ADJ'],
#  ['activités', 'NOM'],
#  ['STOP', 'NOM'],
#  ['le', 'DET:ART'],
#  ['laboratoire', 'NOM'],
#  ['étudie', 'VER:pres'],
#  ['les', 'DET:ART'],
#  ['mécanismes', 'NOM'],
#  ["d'", 'PRP'],
#  ['échec', 'NOM'],
#  ['des', 'PRP:det'],
#  ['implants', 'NOM'],
#  ['endovasculaires', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['conçoit', 'VER:pres'],
#  ['des', 'PRP:det'],
#  ['revêtements', 'NOM'],
#  ['bioactifs', 'ADJ'],
#  ['et', 'KON'],
#  ['des', 'PRP:det'],
#  ['hydrogels', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['et', 'KON'],
#  ['évalue', 'VER:pres'],
#  ['la', 'DET:ART'],
#  ['biocompatibilité', 'NOM'],
#  ['de', 'PRP'],
#  ['nouveaux', 'ADJ'],
#  ['biomatériaux', 'NOM'],
#  ['in', 'ADJ'],
#  ['vitro', 'NOM'],
#  ['et', 'KON'],
#  ['in', 'ADJ'],
#  ['vivo', 'ADV'],
#  ['.', 'SENT'],
#  ['STOP', 'INT'],
#  ['site', 'NOM'],
#  ['du', 'PRP:det'],
#  ['lbev', 'ADJ'],
#  ['laboratoire', 'NOM'],
#  ['de', 'PRP'],
#  ['biorhéologie', 'NOM'],
#  ['et', 'KON'],
#  ["d'", 'PRP'],
#  ['ultrasonographie', 'NOM'],
#  ['médicale', 'ADJ'],
#  ['(', 'PUN'],
#  ['lbum', 'NOM'],
#  [')', 'PUN'],
#  ['le', 'DET:ART'],
#  ['laboratoire', 'NOM'],
#  ['de', 'PRP'],
#  ['biorhéologie', 'NOM'],
#  ['et', 'KON'],
#  ["d'", 'PRP'],
#  ['ultrasonographie', 'NOM'],
#  ['médicale', 'ADJ'],
#  ['(', 'PUN'],
#  ['lbum', 'NOM'],
#  [')', 'PUN'],
#  ['concentre', 'VER:pres'],
#  ['ses', 'DET:POS'],
#  ['activités', 'NOM'],
#  ['autour', 'ADV'],
#  ['de', 'PRP'],
#  ["l'", 'DET:ART'],
#  ['imagerie', 'NOM'],
#  ['médicale', 'ADJ'],
#  ['ultrasonore', 'ADJ'],
#  ['.', 'SENT'],
#  ['les', 'DET:ART'],
#  ['chercheurs', 'NOM'],
#  ['utilisent', 'VER:pres'],
#  ['les', 'DET:ART'],
#  ['nouvelles', 'ADJ'],
#  ['techniques', 'NOM'],
#  ["d'", 'PRP'],
#  ['imagerie', 'NOM'],
#  ['pour', 'PRP'],
#  ['optimiser', 'VER:infi'],
#  ['le', 'DET:ART'],
#  ['diagnostic', 'NOM'],
#  ['et', 'KON'],
#  ['le', 'DET:ART'],
#  ['suivi', 'NOM'],
#  ['thérapeutique', 'ADJ'],
#  ['de', 'PRP'],
#  ["l'", 'DET:ART'],
#  ['artériosclérose', 'NOM'],
#  ['STOP', 'NOM'],
#  ['des', 'PRP:det'],
#  ['tumeurs', 'NOM'],
#  ['cancéreuses', 'ADJ'],
#  ['du', 'PRP:det'],
#  ['sein', 'NOM'],
#  ['ainsi', 'KON'],
#  ['que', 'KON'],
#  ['des', 'PRP:det'],
#  ['troubles', 'NOM'],
#  ['vasculaires', 'ADJ'],
#  ['tels', 'PRO:DEM'],
#  ['que', 'PRO:REL'],
#  ['les', 'DET:ART'],
#  ['sténoses', 'NOM'],
#  ['STOP', 'INT'],
#  ['les', 'DET:ART'],
#  ['anévrismes', 'NOM'],
#  ['ou', 'KON'],
#  ['les', 'DET:ART'],
#  ['thromboses', 'NOM'],
#  ['veineuses', 'ADJ'],
#  ['.', 'SENT'],
#  ['ils', 'PRO:PER'],
#  ['utilisent', 'VER:pres'],
#  ['également', 'ADV'],
#  ["l'", 'DET:ART'],
#  ['élastographie', 'NOM'],
#  ['ultrasonore', 'ADJ'],
#  ['pour', 'PRP'],
#  ['étudier', 'VER:infi'],
#  ['les', 'DET:ART'],
#  ['propriétés', 'NOM'],
#  ['biomécaniques', 'ADJ'],
#  ['associées', 'VER:pper'],
#  ['à', 'PRP'],
#  ['ces', 'PRO:DEM'],
#  ['pathologies', 'NOM'],
#  ['.', 'SENT'],
#  ['STOP', 'INT'],
#  ['site', 'NOM'],
#  ['du', 'PRP:det'],
#  ['lbum', 'NOM'],
#  ['laboratoire', 'NOM'],
#  ['central', 'ADJ'],
#  ['de', 'PRP'],
#  ['traitement', 'NOM'],
#  ['de', 'PRP'],
#  ["l'", 'DET:ART'],
#  ['image', 'NOM'],
#  ['(', 'PUN'],
#  ['lcti', 'VER:pper'],
#  [')', 'PUN'],
#  ['le', 'DET:ART'],
#  ['laboratoire', 'NOM'],
#  ['central', 'ADJ'],
#  ['de', 'PRP'],
#  ['traitement', 'NOM'],
#  ['de', 'PRP'],
#  ["l'", 'DET:ART'],
#  ['image', 'NOM'],
#  ['(', 'PUN'],
#  ['lcti', 'VER:pper'],
#  [')', 'PUN'],
#  ['STOP', 'NOM'],
#  ['de', 'PRP'],
#  ['vocation', 'NOM'],
#  ['multidisciplinaire', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['est', 'VER:pres'],
#  ['impliqué', 'VER:pper'],
#  ['à', 'PRP'],
#  ['différents', 'ADJ'],
#  ['niveaux', 'NOM'],
#  ['du', 'PRP:det'],
#  ['processus', 'NOM'],
#  ['radiologique', 'ADJ'],
#  ['allant', 'VER:ppre'],
#  ['de', 'PRP'],
#  ["l'", 'DET:ART'],
#  ['acquisition', 'NOM'],
#  ['des', 'PRP:det'],
#  ['images', 'NOM'],
#  ['à', 'PRP'],
#  ['leur', 'DET:POS'],
#  ['archivage', 'NOM'],
#  ['en', 'PRP'],
#  ['passant', 'VER:ppre'],
#  ['par', 'PRP'],
#  ['le', 'DET:ART'],
#  ['développement', 'NOM'],
#  ["d'", 'PRP'],
#  ['outils', 'NOM'],
#  ['informatiques', 'ADJ'],
#  ['pour', 'PRP'],
#  ["l'", 'DET:ART'],
#  ['aide', 'NOM'],
#  ['au', 'PRP:det'],
#  ['diagnostic', 'NOM'],
#  ['STOP', 'NOM'],
#  ['la', 'DET:ART'],
#  ['planification', 'NOM'],
#  ['interventionnelle', 'ADJ'],
#  ['et', 'KON'],
#  ['le', 'DET:ART'],
#  ['suivi', 'NOM'],
#  ['quantitatif', 'ADJ'],
#  ['des', 'PRP:det'],
#  ['pathologies', 'NOM'],
#  ['.', 'SENT'],
#  ['les', 'DET:ART'],
#  ['principaux', 'ADJ'],
#  ['champs', 'NOM'],
#  ["d'", 'PRP'],
#  ['intérêts', 'NOM'],
#  ['des', 'PRP:det'],
#  ['chercheurs', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['ingénieurs', 'NOM'],
#  ['STOP', 'INT'],
#  ['physiciens', 'NOM'],
#  ['STOP', 'INT'],
#  ['radiologues', 'NOM'],
#  ['et', 'KON'],
#  ['cliniciens', 'NOM'],
#  ['du', 'PRP:det'],
#  ['laboratoire', 'NOM'],
#  ['sont', 'VER:pres'],
#  ['le', 'DET:ART'],
#  ['suivi', 'ADJ'],
#  ['pré-', 'NOM'],
#  ['STOP', 'NOM'],
#  ['per-', 'ADJ'],
#  ['et', 'KON'],
#  ['postopératoire', 'ADJ'],
#  ['des', 'PRP:det'],
#  ['pathologies', 'NOM'],
#  ['vasculaires', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['la', 'DET:ART'],
#  ['segmentation', 'NOM'],
#  ['tridimensionnelle', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['la', 'DET:ART'],
#  ['fusion', 'NOM'],
#  ['multimodale', 'ADJ'],
#  ['STOP', 'NOM'],
#  ["l'", 'DET:ART'],
#  ['optimisation', 'NOM'],
#  ['des', 'PRP:det'],
#  ['acquisitions', 'NOM'],
#  ['irm', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['ainsi', 'KON'],
#  ['que', 'KON'],
#  ['la', 'DET:ART'],
#  ['modélisation', 'NOM'],
#  ['hémodynamique', 'ADJ'],
#  ['et', 'KON'],
#  ['mécanique', 'ADJ'],
#  ['réaliste', 'NOM'],
#  ['des', 'PRP:det'],
#  ['structures', 'NOM'],
#  ['vasculaires', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['des', 'PRP:det'],
#  ['prothèses', 'NOM'],
#  ['endovasculaires', 'ADJ'],
#  ['et', 'KON'],
#  ['du', 'PRP:det'],
#  ['processus', 'NOM'],
#  ['interventionnel', 'ADJ'],
#  ['.', 'SENT'],
#  ['laboratoire', 'NOM'],
#  ['de', 'PRP'],
#  ['recherche', 'NOM'],
#  ['en', 'PRP'],
#  ['neuroradiologie', 'NOM'],
#  ['interventionnelle', 'ADJ'],
#  ['(', 'PUN'],
#  ['nri', 'VER:pper'],
#  [')', 'PUN'],
#  ['le', 'DET:ART'],
#  ['laboratoire', 'NOM'],
#  ['de', 'PRP'],
#  ['recherche', 'NOM'],
#  ['en', 'PRP'],
#  ['neuroradiologie', 'NOM'],
#  ['interventionnelle', 'ADJ'],
#  ['(', 'PUN'],
#  ['nri', 'VER:pper'],
#  [')', 'PUN'],
#  ['a', 'VER:pres'],
#  ['pour', 'PRP'],
#  ['objectif', 'ADJ'],
#  ["d'", 'PRP'],
#  ['améliorer', 'VER:infi'],
#  ['les', 'DET:ART'],
#  ['connaissances', 'NOM'],
#  ['en', 'PRP'],
#  ['imagerie', 'NOM'],
#  ['et', 'KON'],
#  ['en', 'PRP'],
#  ['thérapeutique', 'ADJ'],
#  ['endovasculaire', 'NOM'],
#  ['pour', 'PRP'],
#  ['le', 'DET:ART'],
#  ['traitement', 'NOM'],
#  ['des', 'PRP:det'],
#  ['pathologies', 'NOM'],
#  ['vasculaires', 'ADJ'],
#  ['artérielles', 'ADJ'],
#  ['ou', 'KON'],
#  ['veineuses', 'ADJ'],
#  ['.', 'SENT'],
#  ['notre', 'DET:POS'],
#  ['laboratoire', 'NOM'],
#  ['est', 'VER:pres'],
#  ['constitué', 'VER:pper'],
#  ["d'", 'PRP'],
#  ['une', 'DET:ART'],
#  ['unité', 'NOM'],
#  ['de', 'PRP'],
#  ['recherche', 'NOM'],
#  ['fondamentale', 'ADJ'],
#  ['(', 'PUN'],
#  ['nrif', 'ADJ'],
#  [')', 'PUN'],
#  ['et', 'KON'],
#  ["d'", 'PRP'],
#  ['une', 'DET:ART'],
#  ['unité', 'NOM'],
#  ['de', 'PRP'],
#  ['recherche', 'NOM'],
#  ['clinique', 'ADJ'],
#  ['(', 'PUN'],
#  ['nric', 'NOM'],
#  [')', 'PUN'],
#  ['.', 'SENT'],
#  ['le', 'DET:ART'],
#  ['nrif', 'NOM'],
#  ['possède', 'VER:pres'],
#  ['une', 'DET:ART'],
#  ['expertise', 'NOM'],
#  ['unique', 'ADJ'],
#  ['dans', 'PRP'],
#  ['la', 'DET:ART'],
#  ['construction', 'NOM'],
#  ['de', 'PRP'],
#  ['modèles', 'NOM'],
#  ["d'", 'PRP'],
#  ['anévrismes', 'NOM'],
#  ['et', 'KON'],
#  ['dans', 'PRP'],
#  ['le', 'DET:ART'],
#  ['développement', 'NOM'],
#  ['des', 'PRP:det'],
#  ['dispositifs', 'NOM'],
#  ['et', 'KON'],
#  ['techniques', 'ADJ'],
#  ['endovasculaires', 'NOM'],
#  ['.', 'SENT'],
#  ['les', 'DET:ART'],
#  ['efforts', 'NOM'],
#  ['de', 'PRP'],
#  ['recherche', 'NOM'],
#  ['sont', 'VER:pres'],
#  ['principalement', 'ADV'],
#  ['tournés', 'VER:pper'],
#  ['vers', 'PRP'],
#  ['la', 'DET:ART'],
#  ['diminution', 'NOM'],
#  ['du', 'PRP:det'],
#  ['taux', 'NOM'],
#  ['de', 'PRP'],
#  ['récidive', 'NOM'],
#  ['des', 'PRP:det'],
#  ['anévrismes', 'NOM'],
#  ['suite', 'NOM'],
#  ['au', 'PRP:det'],
#  ['traitement', 'NOM'],
#  ['endovasculaire', 'ADJ'],
#  ['mais', 'KON'],
#  ['aussi', 'ADV'],
#  ['vers', 'PRP'],
#  ["l'", 'DET:ART'],
#  ['innocuité', 'NOM'],
#  ['et', 'KON'],
#  ["l'", 'DET:ART'],
#  ['efficacité', 'NOM'],
#  ['des', 'PRP:det'],
#  ['stents', 'NOM'],
#  ['et', 'KON'],
#  ['STOP', 'NOM'],
#  ['flow', 'NOM'],
#  ['diverters', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['STOP', 'NOM'],
#  ['nouveaux', 'ADJ'],
#  ['outils', 'NOM'],
#  ['utilisés', 'VER:pper'],
#  ['pour', 'PRP'],
#  ['traiter', 'VER:infi'],
#  ['les', 'DET:ART'],
#  ['anévrismes', 'NOM'],
#  ['STOP', 'INT'],
#  ['dans', 'PRP'],
#  ['les', 'DET:ART'],
#  ['modèles', 'NOM'],
#  ['animaux', 'ADJ'],
#  ['.', 'SENT'],
#  ["l'", 'DET:ART'],
#  ['unité', 'NOM'],
#  ['de', 'PRP'],
#  ['recherche', 'NOM'],
#  ['clinique', 'ADJ'],
#  ['du', 'PRP:det'],
#  ['nri', 'NOM'],
#  ['(', 'PUN'],
#  ['nric', 'NOM'],
#  [')', 'PUN'],
#  ['offre', 'VER:pres'],
#  ['une', 'DET:ART'],
#  ['infrastructure', 'NOM'],
#  ['appropriée', 'VER:pper'],
#  ['pour', 'PRP'],
#  ['le', 'DET:ART'],
#  ['développement', 'NOM'],
#  ['et', 'KON'],
#  ['la', 'DET:ART'],
#  ['réalisation', 'NOM'],
#  ["d'", 'PRP'],
#  ['études', 'NOM'],
#  ['cliniques', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['principalement', 'ADV'],
#  ['les', 'DET:ART'],
#  ['études', 'NOM'],
#  ['initiées', 'VER:pper'],
#  ['par', 'PRP'],
#  ['le', 'DET:ART'],
#  ['chercheur', 'NOM'],
#  ['.', 'SENT'],
#  ['le', 'DET:ART'],
#  ['cœur', 'NOM'],
#  ['de', 'PRP'],
#  ['notre', 'DET:POS'],
#  ['expertise', 'NOM'],
#  ['repose', 'VER:pres'],
#  ['sur', 'PRP'],
#  ['la', 'DET:ART'],
#  ['gestion', 'NOM'],
#  ['de', 'PRP'],
#  ['projets', 'NOM'],
#  ["d'", 'PRP'],
#  ['études', 'NOM'],
#  ['et', 'KON'],
#  ['de', 'PRP'],
#  ['centres', 'NOM'],
#  ['cliniques', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['la', 'DET:ART'],
#  ['gestion', 'NOM'],
#  ['des', 'PRP:det'],
#  ['données', 'NOM'],
#  ['STOP', 'NOM'],
#  ['les', 'DET:ART'],
#  ['biostatistiques', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['et', 'KON'],
#  ['les', 'DET:ART'],
#  ['méthodes', 'NOM'],
#  ['de', 'PRP'],
#  ['transfert', 'NOM'],
#  ['STOP', 'NOM'],
#  ['STOP', 'INT'],
#  ['conservation', 'NOM'],
#  ['des', 'PRP:det'],
#  ['images', 'NOM'],
#  ['électroniques', 'ADJ'],
#  ['et', 'KON'],
#  ['ce', 'PRO:DEM'],
#  ['STOP', 'NOM'],
#  ['à', 'PRP'],
#  ['budget', 'NOM'],
#  ['minime', 'ADJ'],
#  ['(', 'PUN'],
#  ['concept', 'NOM'],
#  ['de', 'PRP'],
#  ['standard', 'NOM'],
#  ['de', 'PRP'],
#  ['soin', 'NOM'],
#  [')', 'PUN'],
#  ['.', 'SENT'],
#  ['recherche', 'NOM'],
#  ['merci', 'NOM'],
#  ["d'", 'PRP'],
#  ['être', 'VER:infi'],
#  ['toujours', 'ADV'],
#  ['là', 'ADV'],
#  ['STOP', 'NOM'],
#  ['15', 'NUM'],
#  ['février', 'NOM'],
#  ['2021', 'NUM'],
#  ['à', 'PRP'],
#  ['vous', 'PRO:PER'],
#  ['STOP', 'NOM'],
#  ['préposés.ées', 'VER:pper'],
#  ['en', 'PRP'],
#  ['retraitement', 'NOM'],
#  ['des', 'PRP:det'],
#  ['dispositifs', 'NOM'],
#  ['médicaux', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['qui', 'PRO:REL'],
#  ['avez', 'VER:pres'],
#  ['un', 'DET:ART'],
#  ['rôle', 'NOM'],
#  ['méconnu', 'VER:pper'],
#  ['STOP', 'NOM'],
#  ['mais', 'KON'],
#  ['essentiel', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['merci', 'NOM'],
#  ['de', 'PRP'],
#  ['contribuer', 'VER:infi'],
#  ['à', 'PRP'],
#  ['ce', 'PRO:DEM'],
#  ['que', 'KON'],
#  ['nos', 'DET:POS'],
#  ['patients', 'NOM'],
#  ['reçoivent', 'VER:pres'],
#  ['des', 'PRP:det'],
#  ['soins', 'NOM'],
#  ['de', 'PRP'],
#  ['qualité', 'NOM'],
#  ['en', 'PRP'],
#  ['toute', 'PRO:IND'],
#  ['sécurité', 'NOM'],
#  ['STOP', 'NOM'],
#  ['particulièrement', 'ADV'],
#  ['en', 'PRP'],
#  ['cette', 'PRO:DEM'],
#  ['période', 'NOM'],
#  ['de', 'PRP'],
#  ['pandémie', 'NOM'],
#  ['.', 'SENT'],
#  ['plusieurs', 'PRO:IND'],
#  ['départements', 'NOM'],
#  ['ne', 'ADV'],
#  ['pourraient', 'VER:cond'],
#  ['fonctionner', 'VER:infi'],
#  ['sans', 'PRP'],
#  ['votre', 'DET:POS'],
#  ['bon', 'ADJ'],
#  ['travail', 'NOM'],
#  ['.', 'SENT'],
#  ['merci', 'NOM'],
#  ["d'", 'PRP'],
#  ['être', 'VER:infi'],
#  ['toujours', 'ADV'],
#  ['là', 'ADV'],
#  ['STOP', 'NOM'],
#  ['de', 'PRP'],
#  ['escouade', 'NOM'],
#  ['reconnaissance', 'NOM'],
#  ['pour', 'PRP'],
#  ['préposé.es', 'NOM'],
#  ['en', 'PRP'],
#  ['retraitement', 'NOM'],
#  ['des', 'PRP:det'],
#  ['dispositifs', 'NOM'],
#  ['médicaux', 'ADJ'],
#  ['facebook', 'ADJ'],
#  ['twitter', 'NOM'],
#  ['linkedin', 'ADJ'],
#  ['print', 'ADJ'],
#  ['recherche', 'NOM'],
#  ['STOP', 'NOM'],
#  ['STOP', 'NOM'],
#  ['prendre', 'VER:infi'],
#  ['rendez', 'VER:pres'],
#  ['-vous', 'PRO:PER'],
#  ['centre', 'VER:pres'],
#  ['de', 'PRP'],
#  ['prélèvement', 'NOM'],
#  ['guide', 'VER:pres'],
#  ['de', 'PRP'],
#  ['votre', 'DET:POS'],
#  ['séjour', 'NOM'],
#  ['STOP', 'NOM'],
#  ['plan', 'ADJ'],
#  ['du', 'PRP:det'],
#  ['chum', 'NOM'],
#  ['STOP', 'NOM'],
#  ['pour', 'PRP'],
#  ['vous', 'PRO:PER'],
#  ['retrouver', 'VER:infi'],
#  ['dans', 'PRP'],
#  ["l'", 'DET:ART'],
#  ['hôpital', 'NOM'],
#  ['avant', 'PRP'],
#  ['de', 'PRP'],
#  ['vous', 'PRO:PER'],
#  ['rendre', 'VER:infi'],
#  ['à', 'PRP'],
#  ["l'", 'DET:ART'],
#  ['urgence', 'NOM'],
#  ['1000', 'NUM'],
#  ['merci', 'NOM'],
#  ['à', 'PRP'],
#  ['la', 'DET:ART'],
#  ['radiologie', 'NOM'],
#  ['en', 'PRP'],
#  ['imagerie', 'NOM'],
#  ['du', 'PRP:det'],
#  ['sein', 'NOM'],
#  ['19', 'NUM'],
#  ['octobre', 'NOM'],
#  ['2021', 'NUM'],
#  ['ce', 'PRO:DEM'],
#  ['fut', 'VER:simp'],
#  ['ma', 'DET:POS'],
#  ['première', 'NUM'],
#  ['visite', 'NOM'],
#  ['ce', 'PRO:DEM'],
#  ['jour', 'NOM'],
#  ['dans', 'PRP'],
#  ['votre', 'DET:POS'],
#  ['ch', 'NOM'],
#  ['pour', 'KON'],
#  ['des', 'PRP:det'],
#  ['biopsies', 'NOM'],
#  ['du', 'PRP:det'],
#  ['sein', 'NOM'],
#  ['.', 'SENT'],
#  ['malgré', 'PRP'],
#  ['les', 'DET:ART'],
#  ['circonstances', 'NOM'],
#  ['STOP', 'INT'],
#  ['cela', 'PRO:DEM'],
#  ['fut', 'VER:simp'],
#  ['une', 'DET:ART'],
#  ['très', 'ADV'],
#  ['belle', 'ADJ'],
#  ['expérience', 'NOM'],
#  ['humaine', 'ADJ'],
#  ['.', 'SENT'],
#  ['une', 'DET:ART'],
#  ['équipe', 'NOM'],
#  ['fantastique', 'ADJ'],
#  ['avec', 'PRP'],
#  ['des', 'PRP:det'],
#  ['intervenants', 'NOM'],
#  ['ultra', 'ADJ'],
#  [':', 'PUN'],
#  ['pros', 'NOM'],
#  ['STOP', 'NOM'],
#  ['chaleureux', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['dévoués', 'VER:pper'],
#  ['STOP', 'NOM'],
#  ['engagés', 'VER:pper'],
#  ['STOP', 'NOM'],
#  ['vraiment', 'ADV'],
#  ['tournés', 'VER:pper'],
#  ['vers', 'PRP'],
#  ['le', 'DET:ART'],
#  ['patient', 'NOM'],
#  ['et', 'KON'],
#  ['son', 'DET:POS'],
#  ['bien-être', 'NOM'],
#  ['STOP', 'INT'],
#  ['merci', 'NOM'],
#  ['de', 'PRP'],
#  ['ne', 'ADV'],
#  ['pas', 'ADV'],
#  ['avoir', 'VER:infi'],
#  ['baissé', 'VER:pper'],
#  ['les', 'DET:ART'],
#  ['bras', 'NOM'],
#  ['quand', 'KON'],
#  ['la', 'DET:ART'],
#  ['technologie', 'NOM'],
#  ['vous', 'PRO:PER'],
#  ['joue', 'VER:pres'],
#  ['des', 'PRP:det'],
#  ['tours', 'NOM'],
#  [':', 'PUN'],
#  [')', 'PUN'],
#  ['.', 'SENT'],
#  ['merci', 'NOM'],
#  ['pour', 'PRP'],
#  ['vos', 'DET:POS'],
#  ['sourires', 'NOM'],
#  ['et', 'KON'],
#  ['vos', 'DET:POS'],
#  ['encouragements', 'NOM'],
#  [':', 'PUN'],
#  [')', 'PUN'],
#  ['.', 'SENT'],
#  ['merci', 'NOM'],
#  ['de', 'PRP'],
#  ['ne', 'ADV'],
#  ['jamais', 'ADV'],
#  ['oublier', 'VER:infi'],
#  ["l'", 'DET:ART'],
#  ['être', 'NOM'],
#  ['humain', 'ADJ'],
#  ...]

# %% [markdown]
# ### **Collocations / Phrases / N-Grammes (MWE)**
# https://www.kaggle.com/code/alvations/n-gram-language-model-with-nltk/notebook

# %%
def extr_ngrams(tagged):
    ngrammes= list(everygrams(tagged, min_len=2, max_len=8))
    print("Avant filtrage, on a {} ngrammes.".format(len(ngrammes)))
    return ngrammes

# %%
ngrammes = extr_ngrams(tagged)
#ngrammes_lem = extr_ngrams(tagged_lem)
# Out:
# Avant filtrage, on a 7058226 ngrammes.

# %%
ngrammes
# Out:
# [(['axe', 'VER:pres'], ['imagerie', 'NOM']),
#  (['axe', 'VER:pres'], ['imagerie', 'NOM'], ['et', 'KON']),
#  (['axe', 'VER:pres'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM']),
#  (['axe', 'VER:pres'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['responsable', 'ADJ']),
#  (['axe', 'VER:pres'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['responsable', 'ADJ'],
#   ['de', 'PRP']),
#  (['axe', 'VER:pres'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['responsable', 'ADJ'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART']),
#  (['axe', 'VER:pres'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['responsable', 'ADJ'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM']),
#  (['imagerie', 'NOM'], ['et', 'KON']),
#  (['imagerie', 'NOM'], ['et', 'KON'], ['ingénierie', 'NOM']),
#  (['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['responsable', 'ADJ']),
#  (['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['responsable', 'ADJ'],
#   ['de', 'PRP']),
#  (['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['responsable', 'ADJ'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART']),
#  (['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['responsable', 'ADJ'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM']),
#  (['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['responsable', 'ADJ'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   [':', 'PUN']),
#  (['et', 'KON'], ['ingénierie', 'NOM']),
#  (['et', 'KON'], ['ingénierie', 'NOM'], ['responsable', 'ADJ']),
#  (['et', 'KON'], ['ingénierie', 'NOM'], ['responsable', 'ADJ'], ['de', 'PRP']),
#  (['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['responsable', 'ADJ'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART']),
#  (['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['responsable', 'ADJ'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM']),
#  (['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['responsable', 'ADJ'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   [':', 'PUN']),
#  (['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['responsable', 'ADJ'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   [':', 'PUN'],
#   ['gilles', 'NOM']),
#  (['ingénierie', 'NOM'], ['responsable', 'ADJ']),
#  (['ingénierie', 'NOM'], ['responsable', 'ADJ'], ['de', 'PRP']),
#  (['ingénierie', 'NOM'],
#   ['responsable', 'ADJ'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART']),
#  (['ingénierie', 'NOM'],
#   ['responsable', 'ADJ'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM']),
#  (['ingénierie', 'NOM'],
#   ['responsable', 'ADJ'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   [':', 'PUN']),
#  (['ingénierie', 'NOM'],
#   ['responsable', 'ADJ'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   [':', 'PUN'],
#   ['gilles', 'NOM']),
#  (['ingénierie', 'NOM'],
#   ['responsable', 'ADJ'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   [':', 'PUN'],
#   ['gilles', 'NOM'],
#   ['soulez', 'VER:pres']),
#  (['responsable', 'ADJ'], ['de', 'PRP']),
#  (['responsable', 'ADJ'], ['de', 'PRP'], ["l'", 'DET:ART']),
#  (['responsable', 'ADJ'], ['de', 'PRP'], ["l'", 'DET:ART'], ['axe', 'NOM']),
#  (['responsable', 'ADJ'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   [':', 'PUN']),
#  (['responsable', 'ADJ'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   [':', 'PUN'],
#   ['gilles', 'NOM']),
#  (['responsable', 'ADJ'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   [':', 'PUN'],
#   ['gilles', 'NOM'],
#   ['soulez', 'VER:pres']),
#  (['responsable', 'ADJ'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   [':', 'PUN'],
#   ['gilles', 'NOM'],
#   ['soulez', 'VER:pres'],
#   ['STOP', 'NOM']),
#  (['de', 'PRP'], ["l'", 'DET:ART']),
#  (['de', 'PRP'], ["l'", 'DET:ART'], ['axe', 'NOM']),
#  (['de', 'PRP'], ["l'", 'DET:ART'], ['axe', 'NOM'], [':', 'PUN']),
#  (['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   [':', 'PUN'],
#   ['gilles', 'NOM']),
#  (['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   [':', 'PUN'],
#   ['gilles', 'NOM'],
#   ['soulez', 'VER:pres']),
#  (['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   [':', 'PUN'],
#   ['gilles', 'NOM'],
#   ['soulez', 'VER:pres'],
#   ['STOP', 'NOM']),
#  (['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   [':', 'PUN'],
#   ['gilles', 'NOM'],
#   ['soulez', 'VER:pres'],
#   ['STOP', 'NOM'],
#   ['m.d.', 'VER:subi']),
#  (["l'", 'DET:ART'], ['axe', 'NOM']),
#  (["l'", 'DET:ART'], ['axe', 'NOM'], [':', 'PUN']),
#  (["l'", 'DET:ART'], ['axe', 'NOM'], [':', 'PUN'], ['gilles', 'NOM']),
#  (["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   [':', 'PUN'],
#   ['gilles', 'NOM'],
#   ['soulez', 'VER:pres']),
#  (["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   [':', 'PUN'],
#   ['gilles', 'NOM'],
#   ['soulez', 'VER:pres'],
#   ['STOP', 'NOM']),
#  (["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   [':', 'PUN'],
#   ['gilles', 'NOM'],
#   ['soulez', 'VER:pres'],
#   ['STOP', 'NOM'],
#   ['m.d.', 'VER:subi']),
#  (["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   [':', 'PUN'],
#   ['gilles', 'NOM'],
#   ['soulez', 'VER:pres'],
#   ['STOP', 'NOM'],
#   ['m.d.', 'VER:subi'],
#   ['STOP', 'NOM']),
#  (['axe', 'NOM'], [':', 'PUN']),
#  (['axe', 'NOM'], [':', 'PUN'], ['gilles', 'NOM']),
#  (['axe', 'NOM'], [':', 'PUN'], ['gilles', 'NOM'], ['soulez', 'VER:pres']),
#  (['axe', 'NOM'],
#   [':', 'PUN'],
#   ['gilles', 'NOM'],
#   ['soulez', 'VER:pres'],
#   ['STOP', 'NOM']),
#  (['axe', 'NOM'],
#   [':', 'PUN'],
#   ['gilles', 'NOM'],
#   ['soulez', 'VER:pres'],
#   ['STOP', 'NOM'],
#   ['m.d.', 'VER:subi']),
#  (['axe', 'NOM'],
#   [':', 'PUN'],
#   ['gilles', 'NOM'],
#   ['soulez', 'VER:pres'],
#   ['STOP', 'NOM'],
#   ['m.d.', 'VER:subi'],
#   ['STOP', 'NOM']),
#  (['axe', 'NOM'],
#   [':', 'PUN'],
#   ['gilles', 'NOM'],
#   ['soulez', 'VER:pres'],
#   ['STOP', 'NOM'],
#   ['m.d.', 'VER:subi'],
#   ['STOP', 'NOM'],
#   ['m', 'NOM']),
#  ([':', 'PUN'], ['gilles', 'NOM']),
#  ([':', 'PUN'], ['gilles', 'NOM'], ['soulez', 'VER:pres']),
#  ([':', 'PUN'], ['gilles', 'NOM'], ['soulez', 'VER:pres'], ['STOP', 'NOM']),
#  ([':', 'PUN'],
#   ['gilles', 'NOM'],
#   ['soulez', 'VER:pres'],
#   ['STOP', 'NOM'],
#   ['m.d.', 'VER:subi']),
#  ([':', 'PUN'],
#   ['gilles', 'NOM'],
#   ['soulez', 'VER:pres'],
#   ['STOP', 'NOM'],
#   ['m.d.', 'VER:subi'],
#   ['STOP', 'NOM']),
#  ([':', 'PUN'],
#   ['gilles', 'NOM'],
#   ['soulez', 'VER:pres'],
#   ['STOP', 'NOM'],
#   ['m.d.', 'VER:subi'],
#   ['STOP', 'NOM'],
#   ['m', 'NOM']),
#  ([':', 'PUN'],
#   ['gilles', 'NOM'],
#   ['soulez', 'VER:pres'],
#   ['STOP', 'NOM'],
#   ['m.d.', 'VER:subi'],
#   ['STOP', 'NOM'],
#   ['m', 'NOM'],
#   ['.', 'SENT']),
#  (['gilles', 'NOM'], ['soulez', 'VER:pres']),
#  (['gilles', 'NOM'], ['soulez', 'VER:pres'], ['STOP', 'NOM']),
#  (['gilles', 'NOM'],
#   ['soulez', 'VER:pres'],
#   ['STOP', 'NOM'],
#   ['m.d.', 'VER:subi']),
#  (['gilles', 'NOM'],
#   ['soulez', 'VER:pres'],
#   ['STOP', 'NOM'],
#   ['m.d.', 'VER:subi'],
#   ['STOP', 'NOM']),
#  (['gilles', 'NOM'],
#   ['soulez', 'VER:pres'],
#   ['STOP', 'NOM'],
#   ['m.d.', 'VER:subi'],
#   ['STOP', 'NOM'],
#   ['m', 'NOM']),
#  (['gilles', 'NOM'],
#   ['soulez', 'VER:pres'],
#   ['STOP', 'NOM'],
#   ['m.d.', 'VER:subi'],
#   ['STOP', 'NOM'],
#   ['m', 'NOM'],
#   ['.', 'SENT']),
#  (['gilles', 'NOM'],
#   ['soulez', 'VER:pres'],
#   ['STOP', 'NOM'],
#   ['m.d.', 'VER:subi'],
#   ['STOP', 'NOM'],
#   ['m', 'NOM'],
#   ['.', 'SENT'],
#   ['sc', 'NOM']),
#  (['soulez', 'VER:pres'], ['STOP', 'NOM']),
#  (['soulez', 'VER:pres'], ['STOP', 'NOM'], ['m.d.', 'VER:subi']),
#  (['soulez', 'VER:pres'],
#   ['STOP', 'NOM'],
#   ['m.d.', 'VER:subi'],
#   ['STOP', 'NOM']),
#  (['soulez', 'VER:pres'],
#   ['STOP', 'NOM'],
#   ['m.d.', 'VER:subi'],
#   ['STOP', 'NOM'],
#   ['m', 'NOM']),
#  (['soulez', 'VER:pres'],
#   ['STOP', 'NOM'],
#   ['m.d.', 'VER:subi'],
#   ['STOP', 'NOM'],
#   ['m', 'NOM'],
#   ['.', 'SENT']),
#  (['soulez', 'VER:pres'],
#   ['STOP', 'NOM'],
#   ['m.d.', 'VER:subi'],
#   ['STOP', 'NOM'],
#   ['m', 'NOM'],
#   ['.', 'SENT'],
#   ['sc', 'NOM']),
#  (['soulez', 'VER:pres'],
#   ['STOP', 'NOM'],
#   ['m.d.', 'VER:subi'],
#   ['STOP', 'NOM'],
#   ['m', 'NOM'],
#   ['.', 'SENT'],
#   ['sc', 'NOM'],
#   ['.', 'SENT']),
#  (['STOP', 'NOM'], ['m.d.', 'VER:subi']),
#  (['STOP', 'NOM'], ['m.d.', 'VER:subi'], ['STOP', 'NOM']),
#  (['STOP', 'NOM'], ['m.d.', 'VER:subi'], ['STOP', 'NOM'], ['m', 'NOM']),
#  (['STOP', 'NOM'],
#   ['m.d.', 'VER:subi'],
#   ['STOP', 'NOM'],
#   ['m', 'NOM'],
#   ['.', 'SENT']),
#  (['STOP', 'NOM'],
#   ['m.d.', 'VER:subi'],
#   ['STOP', 'NOM'],
#   ['m', 'NOM'],
#   ['.', 'SENT'],
#   ['sc', 'NOM']),
#  (['STOP', 'NOM'],
#   ['m.d.', 'VER:subi'],
#   ['STOP', 'NOM'],
#   ['m', 'NOM'],
#   ['.', 'SENT'],
#   ['sc', 'NOM'],
#   ['.', 'SENT']),
#  (['STOP', 'NOM'],
#   ['m.d.', 'VER:subi'],
#   ['STOP', 'NOM'],
#   ['m', 'NOM'],
#   ['.', 'SENT'],
#   ['sc', 'NOM'],
#   ['.', 'SENT'],
#   ['STOP', 'INT']),
#  (['m.d.', 'VER:subi'], ['STOP', 'NOM']),
#  (['m.d.', 'VER:subi'], ['STOP', 'NOM'], ['m', 'NOM']),
#  (['m.d.', 'VER:subi'], ['STOP', 'NOM'], ['m', 'NOM'], ['.', 'SENT']),
#  (['m.d.', 'VER:subi'],
#   ['STOP', 'NOM'],
#   ['m', 'NOM'],
#   ['.', 'SENT'],
#   ['sc', 'NOM']),
#  (['m.d.', 'VER:subi'],
#   ['STOP', 'NOM'],
#   ['m', 'NOM'],
#   ['.', 'SENT'],
#   ['sc', 'NOM'],
#   ['.', 'SENT']),
#  (['m.d.', 'VER:subi'],
#   ['STOP', 'NOM'],
#   ['m', 'NOM'],
#   ['.', 'SENT'],
#   ['sc', 'NOM'],
#   ['.', 'SENT'],
#   ['STOP', 'INT']),
#  (['m.d.', 'VER:subi'],
#   ['STOP', 'NOM'],
#   ['m', 'NOM'],
#   ['.', 'SENT'],
#   ['sc', 'NOM'],
#   ['.', 'SENT'],
#   ['STOP', 'INT'],
#   ['frcpc', 'NOM']),
#  (['STOP', 'NOM'], ['m', 'NOM']),
#  (['STOP', 'NOM'], ['m', 'NOM'], ['.', 'SENT']),
#  (['STOP', 'NOM'], ['m', 'NOM'], ['.', 'SENT'], ['sc', 'NOM']),
#  (['STOP', 'NOM'], ['m', 'NOM'], ['.', 'SENT'], ['sc', 'NOM'], ['.', 'SENT']),
#  (['STOP', 'NOM'],
#   ['m', 'NOM'],
#   ['.', 'SENT'],
#   ['sc', 'NOM'],
#   ['.', 'SENT'],
#   ['STOP', 'INT']),
#  (['STOP', 'NOM'],
#   ['m', 'NOM'],
#   ['.', 'SENT'],
#   ['sc', 'NOM'],
#   ['.', 'SENT'],
#   ['STOP', 'INT'],
#   ['frcpc', 'NOM']),
#  (['STOP', 'NOM'],
#   ['m', 'NOM'],
#   ['.', 'SENT'],
#   ['sc', 'NOM'],
#   ['.', 'SENT'],
#   ['STOP', 'INT'],
#   ['frcpc', 'NOM'],
#   ['STOP', 'INT']),
#  (['m', 'NOM'], ['.', 'SENT']),
#  (['m', 'NOM'], ['.', 'SENT'], ['sc', 'NOM']),
#  (['m', 'NOM'], ['.', 'SENT'], ['sc', 'NOM'], ['.', 'SENT']),
#  (['m', 'NOM'], ['.', 'SENT'], ['sc', 'NOM'], ['.', 'SENT'], ['STOP', 'INT']),
#  (['m', 'NOM'],
#   ['.', 'SENT'],
#   ['sc', 'NOM'],
#   ['.', 'SENT'],
#   ['STOP', 'INT'],
#   ['frcpc', 'NOM']),
#  (['m', 'NOM'],
#   ['.', 'SENT'],
#   ['sc', 'NOM'],
#   ['.', 'SENT'],
#   ['STOP', 'INT'],
#   ['frcpc', 'NOM'],
#   ['STOP', 'INT']),
#  (['m', 'NOM'],
#   ['.', 'SENT'],
#   ['sc', 'NOM'],
#   ['.', 'SENT'],
#   ['STOP', 'INT'],
#   ['frcpc', 'NOM'],
#   ['STOP', 'INT'],
#   ['publications', 'NOM']),
#  (['.', 'SENT'], ['sc', 'NOM']),
#  (['.', 'SENT'], ['sc', 'NOM'], ['.', 'SENT']),
#  (['.', 'SENT'], ['sc', 'NOM'], ['.', 'SENT'], ['STOP', 'INT']),
#  (['.', 'SENT'],
#   ['sc', 'NOM'],
#   ['.', 'SENT'],
#   ['STOP', 'INT'],
#   ['frcpc', 'NOM']),
#  (['.', 'SENT'],
#   ['sc', 'NOM'],
#   ['.', 'SENT'],
#   ['STOP', 'INT'],
#   ['frcpc', 'NOM'],
#   ['STOP', 'INT']),
#  (['.', 'SENT'],
#   ['sc', 'NOM'],
#   ['.', 'SENT'],
#   ['STOP', 'INT'],
#   ['frcpc', 'NOM'],
#   ['STOP', 'INT'],
#   ['publications', 'NOM']),
#  (['.', 'SENT'],
#   ['sc', 'NOM'],
#   ['.', 'SENT'],
#   ['STOP', 'INT'],
#   ['frcpc', 'NOM'],
#   ['STOP', 'INT'],
#   ['publications', 'NOM'],
#   ['des', 'PRP:det']),
#  (['sc', 'NOM'], ['.', 'SENT']),
#  (['sc', 'NOM'], ['.', 'SENT'], ['STOP', 'INT']),
#  (['sc', 'NOM'], ['.', 'SENT'], ['STOP', 'INT'], ['frcpc', 'NOM']),
#  (['sc', 'NOM'],
#   ['.', 'SENT'],
#   ['STOP', 'INT'],
#   ['frcpc', 'NOM'],
#   ['STOP', 'INT']),
#  (['sc', 'NOM'],
#   ['.', 'SENT'],
#   ['STOP', 'INT'],
#   ['frcpc', 'NOM'],
#   ['STOP', 'INT'],
#   ['publications', 'NOM']),
#  (['sc', 'NOM'],
#   ['.', 'SENT'],
#   ['STOP', 'INT'],
#   ['frcpc', 'NOM'],
#   ['STOP', 'INT'],
#   ['publications', 'NOM'],
#   ['des', 'PRP:det']),
#  (['sc', 'NOM'],
#   ['.', 'SENT'],
#   ['STOP', 'INT'],
#   ['frcpc', 'NOM'],
#   ['STOP', 'INT'],
#   ['publications', 'NOM'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM']),
#  (['.', 'SENT'], ['STOP', 'INT']),
#  (['.', 'SENT'], ['STOP', 'INT'], ['frcpc', 'NOM']),
#  (['.', 'SENT'], ['STOP', 'INT'], ['frcpc', 'NOM'], ['STOP', 'INT']),
#  (['.', 'SENT'],
#   ['STOP', 'INT'],
#   ['frcpc', 'NOM'],
#   ['STOP', 'INT'],
#   ['publications', 'NOM']),
#  (['.', 'SENT'],
#   ['STOP', 'INT'],
#   ['frcpc', 'NOM'],
#   ['STOP', 'INT'],
#   ['publications', 'NOM'],
#   ['des', 'PRP:det']),
#  (['.', 'SENT'],
#   ['STOP', 'INT'],
#   ['frcpc', 'NOM'],
#   ['STOP', 'INT'],
#   ['publications', 'NOM'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM']),
#  (['.', 'SENT'],
#   ['STOP', 'INT'],
#   ['frcpc', 'NOM'],
#   ['STOP', 'INT'],
#   ['publications', 'NOM'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ["l'", 'DET:ART']),
#  (['STOP', 'INT'], ['frcpc', 'NOM']),
#  (['STOP', 'INT'], ['frcpc', 'NOM'], ['STOP', 'INT']),
#  (['STOP', 'INT'], ['frcpc', 'NOM'], ['STOP', 'INT'], ['publications', 'NOM']),
#  (['STOP', 'INT'],
#   ['frcpc', 'NOM'],
#   ['STOP', 'INT'],
#   ['publications', 'NOM'],
#   ['des', 'PRP:det']),
#  (['STOP', 'INT'],
#   ['frcpc', 'NOM'],
#   ['STOP', 'INT'],
#   ['publications', 'NOM'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM']),
#  (['STOP', 'INT'],
#   ['frcpc', 'NOM'],
#   ['STOP', 'INT'],
#   ['publications', 'NOM'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ["l'", 'DET:ART']),
#  (['STOP', 'INT'],
#   ['frcpc', 'NOM'],
#   ['STOP', 'INT'],
#   ['publications', 'NOM'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM']),
#  (['frcpc', 'NOM'], ['STOP', 'INT']),
#  (['frcpc', 'NOM'], ['STOP', 'INT'], ['publications', 'NOM']),
#  (['frcpc', 'NOM'],
#   ['STOP', 'INT'],
#   ['publications', 'NOM'],
#   ['des', 'PRP:det']),
#  (['frcpc', 'NOM'],
#   ['STOP', 'INT'],
#   ['publications', 'NOM'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM']),
#  (['frcpc', 'NOM'],
#   ['STOP', 'INT'],
#   ['publications', 'NOM'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ["l'", 'DET:ART']),
#  (['frcpc', 'NOM'],
#   ['STOP', 'INT'],
#   ['publications', 'NOM'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM']),
#  (['frcpc', 'NOM'],
#   ['STOP', 'INT'],
#   ['publications', 'NOM'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   ['imagerie', 'NOM']),
#  (['STOP', 'INT'], ['publications', 'NOM']),
#  (['STOP', 'INT'], ['publications', 'NOM'], ['des', 'PRP:det']),
#  (['STOP', 'INT'],
#   ['publications', 'NOM'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM']),
#  (['STOP', 'INT'],
#   ['publications', 'NOM'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ["l'", 'DET:ART']),
#  (['STOP', 'INT'],
#   ['publications', 'NOM'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM']),
#  (['STOP', 'INT'],
#   ['publications', 'NOM'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   ['imagerie', 'NOM']),
#  (['STOP', 'INT'],
#   ['publications', 'NOM'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON']),
#  (['publications', 'NOM'], ['des', 'PRP:det']),
#  (['publications', 'NOM'], ['des', 'PRP:det'], ['chercheurs', 'NOM']),
#  (['publications', 'NOM'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ["l'", 'DET:ART']),
#  (['publications', 'NOM'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM']),
#  (['publications', 'NOM'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   ['imagerie', 'NOM']),
#  (['publications', 'NOM'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON']),
#  (['publications', 'NOM'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM']),
#  (['des', 'PRP:det'], ['chercheurs', 'NOM']),
#  (['des', 'PRP:det'], ['chercheurs', 'NOM'], ["l'", 'DET:ART']),
#  (['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM']),
#  (['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   ['imagerie', 'NOM']),
#  (['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON']),
#  (['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM']),
#  (['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['du', 'PRP:det']),
#  (['chercheurs', 'NOM'], ["l'", 'DET:ART']),
#  (['chercheurs', 'NOM'], ["l'", 'DET:ART'], ['axe', 'NOM']),
#  (['chercheurs', 'NOM'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   ['imagerie', 'NOM']),
#  (['chercheurs', 'NOM'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON']),
#  (['chercheurs', 'NOM'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM']),
#  (['chercheurs', 'NOM'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['du', 'PRP:det']),
#  (['chercheurs', 'NOM'],
#   ["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['du', 'PRP:det'],
#   ['crchum', 'NOM']),
#  (["l'", 'DET:ART'], ['axe', 'NOM']),
#  (["l'", 'DET:ART'], ['axe', 'NOM'], ['imagerie', 'NOM']),
#  (["l'", 'DET:ART'], ['axe', 'NOM'], ['imagerie', 'NOM'], ['et', 'KON']),
#  (["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM']),
#  (["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['du', 'PRP:det']),
#  (["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['du', 'PRP:det'],
#   ['crchum', 'NOM']),
#  (["l'", 'DET:ART'],
#   ['axe', 'NOM'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['du', 'PRP:det'],
#   ['crchum', 'NOM'],
#   ['se', 'PRO:PER']),
#  (['axe', 'NOM'], ['imagerie', 'NOM']),
#  (['axe', 'NOM'], ['imagerie', 'NOM'], ['et', 'KON']),
#  (['axe', 'NOM'], ['imagerie', 'NOM'], ['et', 'KON'], ['ingénierie', 'NOM']),
#  (['axe', 'NOM'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['du', 'PRP:det']),
#  (['axe', 'NOM'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['du', 'PRP:det'],
#   ['crchum', 'NOM']),
#  (['axe', 'NOM'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['du', 'PRP:det'],
#   ['crchum', 'NOM'],
#   ['se', 'PRO:PER']),
#  (['axe', 'NOM'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['du', 'PRP:det'],
#   ['crchum', 'NOM'],
#   ['se', 'PRO:PER'],
#   ['donne', 'VER:pres']),
#  (['imagerie', 'NOM'], ['et', 'KON']),
#  (['imagerie', 'NOM'], ['et', 'KON'], ['ingénierie', 'NOM']),
#  (['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['du', 'PRP:det']),
#  (['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['du', 'PRP:det'],
#   ['crchum', 'NOM']),
#  (['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['du', 'PRP:det'],
#   ['crchum', 'NOM'],
#   ['se', 'PRO:PER']),
#  (['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['du', 'PRP:det'],
#   ['crchum', 'NOM'],
#   ['se', 'PRO:PER'],
#   ['donne', 'VER:pres']),
#  (['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['du', 'PRP:det'],
#   ['crchum', 'NOM'],
#   ['se', 'PRO:PER'],
#   ['donne', 'VER:pres'],
#   ['pour', 'PRP']),
#  (['et', 'KON'], ['ingénierie', 'NOM']),
#  (['et', 'KON'], ['ingénierie', 'NOM'], ['du', 'PRP:det']),
#  (['et', 'KON'], ['ingénierie', 'NOM'], ['du', 'PRP:det'], ['crchum', 'NOM']),
#  (['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['du', 'PRP:det'],
#   ['crchum', 'NOM'],
#   ['se', 'PRO:PER']),
#  (['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['du', 'PRP:det'],
#   ['crchum', 'NOM'],
#   ['se', 'PRO:PER'],
#   ['donne', 'VER:pres']),
#  (['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['du', 'PRP:det'],
#   ['crchum', 'NOM'],
#   ['se', 'PRO:PER'],
#   ['donne', 'VER:pres'],
#   ['pour', 'PRP']),
#  (['et', 'KON'],
#   ['ingénierie', 'NOM'],
#   ['du', 'PRP:det'],
#   ['crchum', 'NOM'],
#   ['se', 'PRO:PER'],
#   ['donne', 'VER:pres'],
#   ['pour', 'PRP'],
#   ['mission', 'NOM']),
#  (['ingénierie', 'NOM'], ['du', 'PRP:det']),
#  (['ingénierie', 'NOM'], ['du', 'PRP:det'], ['crchum', 'NOM']),
#  (['ingénierie', 'NOM'],
#   ['du', 'PRP:det'],
#   ['crchum', 'NOM'],
#   ['se', 'PRO:PER']),
#  (['ingénierie', 'NOM'],
#   ['du', 'PRP:det'],
#   ['crchum', 'NOM'],
#   ['se', 'PRO:PER'],
#   ['donne', 'VER:pres']),
#  (['ingénierie', 'NOM'],
#   ['du', 'PRP:det'],
#   ['crchum', 'NOM'],
#   ['se', 'PRO:PER'],
#   ['donne', 'VER:pres'],
#   ['pour', 'PRP']),
#  (['ingénierie', 'NOM'],
#   ['du', 'PRP:det'],
#   ['crchum', 'NOM'],
#   ['se', 'PRO:PER'],
#   ['donne', 'VER:pres'],
#   ['pour', 'PRP'],
#   ['mission', 'NOM']),
#  (['ingénierie', 'NOM'],
#   ['du', 'PRP:det'],
#   ['crchum', 'NOM'],
#   ['se', 'PRO:PER'],
#   ['donne', 'VER:pres'],
#   ['pour', 'PRP'],
#   ['mission', 'NOM'],
#   ['principale', 'ADJ']),
#  (['du', 'PRP:det'], ['crchum', 'NOM']),
#  (['du', 'PRP:det'], ['crchum', 'NOM'], ['se', 'PRO:PER']),
#  (['du', 'PRP:det'],
#   ['crchum', 'NOM'],
#   ['se', 'PRO:PER'],
#   ['donne', 'VER:pres']),
#  (['du', 'PRP:det'],
#   ['crchum', 'NOM'],
#   ['se', 'PRO:PER'],
#   ['donne', 'VER:pres'],
#   ['pour', 'PRP']),
#  (['du', 'PRP:det'],
#   ['crchum', 'NOM'],
#   ['se', 'PRO:PER'],
#   ['donne', 'VER:pres'],
#   ['pour', 'PRP'],
#   ['mission', 'NOM']),
#  (['du', 'PRP:det'],
#   ['crchum', 'NOM'],
#   ['se', 'PRO:PER'],
#   ['donne', 'VER:pres'],
#   ['pour', 'PRP'],
#   ['mission', 'NOM'],
#   ['principale', 'ADJ']),
#  (['du', 'PRP:det'],
#   ['crchum', 'NOM'],
#   ['se', 'PRO:PER'],
#   ['donne', 'VER:pres'],
#   ['pour', 'PRP'],
#   ['mission', 'NOM'],
#   ['principale', 'ADJ'],
#   ['de', 'PRP']),
#  (['crchum', 'NOM'], ['se', 'PRO:PER']),
#  (['crchum', 'NOM'], ['se', 'PRO:PER'], ['donne', 'VER:pres']),
#  (['crchum', 'NOM'],
#   ['se', 'PRO:PER'],
#   ['donne', 'VER:pres'],
#   ['pour', 'PRP']),
#  (['crchum', 'NOM'],
#   ['se', 'PRO:PER'],
#   ['donne', 'VER:pres'],
#   ['pour', 'PRP'],
#   ['mission', 'NOM']),
#  (['crchum', 'NOM'],
#   ['se', 'PRO:PER'],
#   ['donne', 'VER:pres'],
#   ['pour', 'PRP'],
#   ['mission', 'NOM'],
#   ['principale', 'ADJ']),
#  (['crchum', 'NOM'],
#   ['se', 'PRO:PER'],
#   ['donne', 'VER:pres'],
#   ['pour', 'PRP'],
#   ['mission', 'NOM'],
#   ['principale', 'ADJ'],
#   ['de', 'PRP']),
#  (['crchum', 'NOM'],
#   ['se', 'PRO:PER'],
#   ['donne', 'VER:pres'],
#   ['pour', 'PRP'],
#   ['mission', 'NOM'],
#   ['principale', 'ADJ'],
#   ['de', 'PRP'],
#   ['mettre', 'VER:infi']),
#  (['se', 'PRO:PER'], ['donne', 'VER:pres']),
#  (['se', 'PRO:PER'], ['donne', 'VER:pres'], ['pour', 'PRP']),
#  (['se', 'PRO:PER'],
#   ['donne', 'VER:pres'],
#   ['pour', 'PRP'],
#   ['mission', 'NOM']),
#  (['se', 'PRO:PER'],
#   ['donne', 'VER:pres'],
#   ['pour', 'PRP'],
#   ['mission', 'NOM'],
#   ['principale', 'ADJ']),
#  (['se', 'PRO:PER'],
#   ['donne', 'VER:pres'],
#   ['pour', 'PRP'],
#   ['mission', 'NOM'],
#   ['principale', 'ADJ'],
#   ['de', 'PRP']),
#  (['se', 'PRO:PER'],
#   ['donne', 'VER:pres'],
#   ['pour', 'PRP'],
#   ['mission', 'NOM'],
#   ['principale', 'ADJ'],
#   ['de', 'PRP'],
#   ['mettre', 'VER:infi']),
#  (['se', 'PRO:PER'],
#   ['donne', 'VER:pres'],
#   ['pour', 'PRP'],
#   ['mission', 'NOM'],
#   ['principale', 'ADJ'],
#   ['de', 'PRP'],
#   ['mettre', 'VER:infi'],
#   ['le', 'DET:ART']),
#  (['donne', 'VER:pres'], ['pour', 'PRP']),
#  (['donne', 'VER:pres'], ['pour', 'PRP'], ['mission', 'NOM']),
#  (['donne', 'VER:pres'],
#   ['pour', 'PRP'],
#   ['mission', 'NOM'],
#   ['principale', 'ADJ']),
#  (['donne', 'VER:pres'],
#   ['pour', 'PRP'],
#   ['mission', 'NOM'],
#   ['principale', 'ADJ'],
#   ['de', 'PRP']),
#  (['donne', 'VER:pres'],
#   ['pour', 'PRP'],
#   ['mission', 'NOM'],
#   ['principale', 'ADJ'],
#   ['de', 'PRP'],
#   ['mettre', 'VER:infi']),
#  (['donne', 'VER:pres'],
#   ['pour', 'PRP'],
#   ['mission', 'NOM'],
#   ['principale', 'ADJ'],
#   ['de', 'PRP'],
#   ['mettre', 'VER:infi'],
#   ['le', 'DET:ART']),
#  (['donne', 'VER:pres'],
#   ['pour', 'PRP'],
#   ['mission', 'NOM'],
#   ['principale', 'ADJ'],
#   ['de', 'PRP'],
#   ['mettre', 'VER:infi'],
#   ['le', 'DET:ART'],
#   ['génie', 'NOM']),
#  (['pour', 'PRP'], ['mission', 'NOM']),
#  (['pour', 'PRP'], ['mission', 'NOM'], ['principale', 'ADJ']),
#  (['pour', 'PRP'], ['mission', 'NOM'], ['principale', 'ADJ'], ['de', 'PRP']),
#  (['pour', 'PRP'],
#   ['mission', 'NOM'],
#   ['principale', 'ADJ'],
#   ['de', 'PRP'],
#   ['mettre', 'VER:infi']),
#  (['pour', 'PRP'],
#   ['mission', 'NOM'],
#   ['principale', 'ADJ'],
#   ['de', 'PRP'],
#   ['mettre', 'VER:infi'],
#   ['le', 'DET:ART']),
#  (['pour', 'PRP'],
#   ['mission', 'NOM'],
#   ['principale', 'ADJ'],
#   ['de', 'PRP'],
#   ['mettre', 'VER:infi'],
#   ['le', 'DET:ART'],
#   ['génie', 'NOM']),
#  (['pour', 'PRP'],
#   ['mission', 'NOM'],
#   ['principale', 'ADJ'],
#   ['de', 'PRP'],
#   ['mettre', 'VER:infi'],
#   ['le', 'DET:ART'],
#   ['génie', 'NOM'],
#   ['au', 'PRP:det']),
#  (['mission', 'NOM'], ['principale', 'ADJ']),
#  (['mission', 'NOM'], ['principale', 'ADJ'], ['de', 'PRP']),
#  (['mission', 'NOM'],
#   ['principale', 'ADJ'],
#   ['de', 'PRP'],
#   ['mettre', 'VER:infi']),
#  (['mission', 'NOM'],
#   ['principale', 'ADJ'],
#   ['de', 'PRP'],
#   ['mettre', 'VER:infi'],
#   ['le', 'DET:ART']),
#  (['mission', 'NOM'],
#   ['principale', 'ADJ'],
#   ['de', 'PRP'],
#   ['mettre', 'VER:infi'],
#   ['le', 'DET:ART'],
#   ['génie', 'NOM']),
#  (['mission', 'NOM'],
#   ['principale', 'ADJ'],
#   ['de', 'PRP'],
#   ['mettre', 'VER:infi'],
#   ['le', 'DET:ART'],
#   ['génie', 'NOM'],
#   ['au', 'PRP:det']),
#  (['mission', 'NOM'],
#   ['principale', 'ADJ'],
#   ['de', 'PRP'],
#   ['mettre', 'VER:infi'],
#   ['le', 'DET:ART'],
#   ['génie', 'NOM'],
#   ['au', 'PRP:det'],
#   ['service', 'NOM']),
#  (['principale', 'ADJ'], ['de', 'PRP']),
#  (['principale', 'ADJ'], ['de', 'PRP'], ['mettre', 'VER:infi']),
#  (['principale', 'ADJ'],
#   ['de', 'PRP'],
#   ['mettre', 'VER:infi'],
#   ['le', 'DET:ART']),
#  (['principale', 'ADJ'],
#   ['de', 'PRP'],
#   ['mettre', 'VER:infi'],
#   ['le', 'DET:ART'],
#   ['génie', 'NOM']),
#  (['principale', 'ADJ'],
#   ['de', 'PRP'],
#   ['mettre', 'VER:infi'],
#   ['le', 'DET:ART'],
#   ['génie', 'NOM'],
#   ['au', 'PRP:det']),
#  (['principale', 'ADJ'],
#   ['de', 'PRP'],
#   ['mettre', 'VER:infi'],
#   ['le', 'DET:ART'],
#   ['génie', 'NOM'],
#   ['au', 'PRP:det'],
#   ['service', 'NOM']),
#  (['principale', 'ADJ'],
#   ['de', 'PRP'],
#   ['mettre', 'VER:infi'],
#   ['le', 'DET:ART'],
#   ['génie', 'NOM'],
#   ['au', 'PRP:det'],
#   ['service', 'NOM'],
#   ['de', 'PRP']),
#  (['de', 'PRP'], ['mettre', 'VER:infi']),
#  (['de', 'PRP'], ['mettre', 'VER:infi'], ['le', 'DET:ART']),
#  (['de', 'PRP'], ['mettre', 'VER:infi'], ['le', 'DET:ART'], ['génie', 'NOM']),
#  (['de', 'PRP'],
#   ['mettre', 'VER:infi'],
#   ['le', 'DET:ART'],
#   ['génie', 'NOM'],
#   ['au', 'PRP:det']),
#  (['de', 'PRP'],
#   ['mettre', 'VER:infi'],
#   ['le', 'DET:ART'],
#   ['génie', 'NOM'],
#   ['au', 'PRP:det'],
#   ['service', 'NOM']),
#  (['de', 'PRP'],
#   ['mettre', 'VER:infi'],
#   ['le', 'DET:ART'],
#   ['génie', 'NOM'],
#   ['au', 'PRP:det'],
#   ['service', 'NOM'],
#   ['de', 'PRP']),
#  (['de', 'PRP'],
#   ['mettre', 'VER:infi'],
#   ['le', 'DET:ART'],
#   ['génie', 'NOM'],
#   ['au', 'PRP:det'],
#   ['service', 'NOM'],
#   ['de', 'PRP'],
#   ['la', 'DET:ART']),
#  (['mettre', 'VER:infi'], ['le', 'DET:ART']),
#  (['mettre', 'VER:infi'], ['le', 'DET:ART'], ['génie', 'NOM']),
#  (['mettre', 'VER:infi'],
#   ['le', 'DET:ART'],
#   ['génie', 'NOM'],
#   ['au', 'PRP:det']),
#  (['mettre', 'VER:infi'],
#   ['le', 'DET:ART'],
#   ['génie', 'NOM'],
#   ['au', 'PRP:det'],
#   ['service', 'NOM']),
#  (['mettre', 'VER:infi'],
#   ['le', 'DET:ART'],
#   ['génie', 'NOM'],
#   ['au', 'PRP:det'],
#   ['service', 'NOM'],
#   ['de', 'PRP']),
#  (['mettre', 'VER:infi'],
#   ['le', 'DET:ART'],
#   ['génie', 'NOM'],
#   ['au', 'PRP:det'],
#   ['service', 'NOM'],
#   ['de', 'PRP'],
#   ['la', 'DET:ART']),
#  (['mettre', 'VER:infi'],
#   ['le', 'DET:ART'],
#   ['génie', 'NOM'],
#   ['au', 'PRP:det'],
#   ['service', 'NOM'],
#   ['de', 'PRP'],
#   ['la', 'DET:ART'],
#   ['santé', 'NOM']),
#  (['le', 'DET:ART'], ['génie', 'NOM']),
#  (['le', 'DET:ART'], ['génie', 'NOM'], ['au', 'PRP:det']),
#  (['le', 'DET:ART'], ['génie', 'NOM'], ['au', 'PRP:det'], ['service', 'NOM']),
#  (['le', 'DET:ART'],
#   ['génie', 'NOM'],
#   ['au', 'PRP:det'],
#   ['service', 'NOM'],
#   ['de', 'PRP']),
#  (['le', 'DET:ART'],
#   ['génie', 'NOM'],
#   ['au', 'PRP:det'],
#   ['service', 'NOM'],
#   ['de', 'PRP'],
#   ['la', 'DET:ART']),
#  (['le', 'DET:ART'],
#   ['génie', 'NOM'],
#   ['au', 'PRP:det'],
#   ['service', 'NOM'],
#   ['de', 'PRP'],
#   ['la', 'DET:ART'],
#   ['santé', 'NOM']),
#  (['le', 'DET:ART'],
#   ['génie', 'NOM'],
#   ['au', 'PRP:det'],
#   ['service', 'NOM'],
#   ['de', 'PRP'],
#   ['la', 'DET:ART'],
#   ['santé', 'NOM'],
#   ['.', 'SENT']),
#  (['génie', 'NOM'], ['au', 'PRP:det']),
#  (['génie', 'NOM'], ['au', 'PRP:det'], ['service', 'NOM']),
#  (['génie', 'NOM'], ['au', 'PRP:det'], ['service', 'NOM'], ['de', 'PRP']),
#  (['génie', 'NOM'],
#   ['au', 'PRP:det'],
#   ['service', 'NOM'],
#   ['de', 'PRP'],
#   ['la', 'DET:ART']),
#  (['génie', 'NOM'],
#   ['au', 'PRP:det'],
#   ['service', 'NOM'],
#   ['de', 'PRP'],
#   ['la', 'DET:ART'],
#   ['santé', 'NOM']),
#  (['génie', 'NOM'],
#   ['au', 'PRP:det'],
#   ['service', 'NOM'],
#   ['de', 'PRP'],
#   ['la', 'DET:ART'],
#   ['santé', 'NOM'],
#   ['.', 'SENT']),
#  (['génie', 'NOM'],
#   ['au', 'PRP:det'],
#   ['service', 'NOM'],
#   ['de', 'PRP'],
#   ['la', 'DET:ART'],
#   ['santé', 'NOM'],
#   ['.', 'SENT'],
#   ['il', 'PRO:PER']),
#  (['au', 'PRP:det'], ['service', 'NOM']),
#  (['au', 'PRP:det'], ['service', 'NOM'], ['de', 'PRP']),
#  (['au', 'PRP:det'], ['service', 'NOM'], ['de', 'PRP'], ['la', 'DET:ART']),
#  (['au', 'PRP:det'],
#   ['service', 'NOM'],
#   ['de', 'PRP'],
#   ['la', 'DET:ART'],
#   ['santé', 'NOM']),
#  (['au', 'PRP:det'],
#   ['service', 'NOM'],
#   ['de', 'PRP'],
#   ['la', 'DET:ART'],
#   ['santé', 'NOM'],
#   ['.', 'SENT']),
#  (['au', 'PRP:det'],
#   ['service', 'NOM'],
#   ['de', 'PRP'],
#   ['la', 'DET:ART'],
#   ['santé', 'NOM'],
#   ['.', 'SENT'],
#   ['il', 'PRO:PER']),
#  (['au', 'PRP:det'],
#   ['service', 'NOM'],
#   ['de', 'PRP'],
#   ['la', 'DET:ART'],
#   ['santé', 'NOM'],
#   ['.', 'SENT'],
#   ['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres']),
#  (['service', 'NOM'], ['de', 'PRP']),
#  (['service', 'NOM'], ['de', 'PRP'], ['la', 'DET:ART']),
#  (['service', 'NOM'], ['de', 'PRP'], ['la', 'DET:ART'], ['santé', 'NOM']),
#  (['service', 'NOM'],
#   ['de', 'PRP'],
#   ['la', 'DET:ART'],
#   ['santé', 'NOM'],
#   ['.', 'SENT']),
#  (['service', 'NOM'],
#   ['de', 'PRP'],
#   ['la', 'DET:ART'],
#   ['santé', 'NOM'],
#   ['.', 'SENT'],
#   ['il', 'PRO:PER']),
#  (['service', 'NOM'],
#   ['de', 'PRP'],
#   ['la', 'DET:ART'],
#   ['santé', 'NOM'],
#   ['.', 'SENT'],
#   ['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres']),
#  (['service', 'NOM'],
#   ['de', 'PRP'],
#   ['la', 'DET:ART'],
#   ['santé', 'NOM'],
#   ['.', 'SENT'],
#   ['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres'],
#   ['des', 'PRP:det']),
#  (['de', 'PRP'], ['la', 'DET:ART']),
#  (['de', 'PRP'], ['la', 'DET:ART'], ['santé', 'NOM']),
#  (['de', 'PRP'], ['la', 'DET:ART'], ['santé', 'NOM'], ['.', 'SENT']),
#  (['de', 'PRP'],
#   ['la', 'DET:ART'],
#   ['santé', 'NOM'],
#   ['.', 'SENT'],
#   ['il', 'PRO:PER']),
#  (['de', 'PRP'],
#   ['la', 'DET:ART'],
#   ['santé', 'NOM'],
#   ['.', 'SENT'],
#   ['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres']),
#  (['de', 'PRP'],
#   ['la', 'DET:ART'],
#   ['santé', 'NOM'],
#   ['.', 'SENT'],
#   ['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres'],
#   ['des', 'PRP:det']),
#  (['de', 'PRP'],
#   ['la', 'DET:ART'],
#   ['santé', 'NOM'],
#   ['.', 'SENT'],
#   ['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM']),
#  (['la', 'DET:ART'], ['santé', 'NOM']),
#  (['la', 'DET:ART'], ['santé', 'NOM'], ['.', 'SENT']),
#  (['la', 'DET:ART'], ['santé', 'NOM'], ['.', 'SENT'], ['il', 'PRO:PER']),
#  (['la', 'DET:ART'],
#   ['santé', 'NOM'],
#   ['.', 'SENT'],
#   ['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres']),
#  (['la', 'DET:ART'],
#   ['santé', 'NOM'],
#   ['.', 'SENT'],
#   ['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres'],
#   ['des', 'PRP:det']),
#  (['la', 'DET:ART'],
#   ['santé', 'NOM'],
#   ['.', 'SENT'],
#   ['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM']),
#  (['la', 'DET:ART'],
#   ['santé', 'NOM'],
#   ['.', 'SENT'],
#   ['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ['issus', 'ADJ']),
#  (['santé', 'NOM'], ['.', 'SENT']),
#  (['santé', 'NOM'], ['.', 'SENT'], ['il', 'PRO:PER']),
#  (['santé', 'NOM'],
#   ['.', 'SENT'],
#   ['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres']),
#  (['santé', 'NOM'],
#   ['.', 'SENT'],
#   ['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres'],
#   ['des', 'PRP:det']),
#  (['santé', 'NOM'],
#   ['.', 'SENT'],
#   ['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM']),
#  (['santé', 'NOM'],
#   ['.', 'SENT'],
#   ['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ['issus', 'ADJ']),
#  (['santé', 'NOM'],
#   ['.', 'SENT'],
#   ['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ['issus', 'ADJ'],
#   ['de', 'PRP']),
#  (['.', 'SENT'], ['il', 'PRO:PER']),
#  (['.', 'SENT'], ['il', 'PRO:PER'], ['regroupe', 'VER:pres']),
#  (['.', 'SENT'],
#   ['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres'],
#   ['des', 'PRP:det']),
#  (['.', 'SENT'],
#   ['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM']),
#  (['.', 'SENT'],
#   ['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ['issus', 'ADJ']),
#  (['.', 'SENT'],
#   ['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ['issus', 'ADJ'],
#   ['de', 'PRP']),
#  (['.', 'SENT'],
#   ['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ['issus', 'ADJ'],
#   ['de', 'PRP'],
#   ['plusieurs', 'PRO:IND']),
#  (['il', 'PRO:PER'], ['regroupe', 'VER:pres']),
#  (['il', 'PRO:PER'], ['regroupe', 'VER:pres'], ['des', 'PRP:det']),
#  (['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM']),
#  (['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ['issus', 'ADJ']),
#  (['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ['issus', 'ADJ'],
#   ['de', 'PRP']),
#  (['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ['issus', 'ADJ'],
#   ['de', 'PRP'],
#   ['plusieurs', 'PRO:IND']),
#  (['il', 'PRO:PER'],
#   ['regroupe', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ['issus', 'ADJ'],
#   ['de', 'PRP'],
#   ['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM']),
#  (['regroupe', 'VER:pres'], ['des', 'PRP:det']),
#  (['regroupe', 'VER:pres'], ['des', 'PRP:det'], ['chercheurs', 'NOM']),
#  (['regroupe', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ['issus', 'ADJ']),
#  (['regroupe', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ['issus', 'ADJ'],
#   ['de', 'PRP']),
#  (['regroupe', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ['issus', 'ADJ'],
#   ['de', 'PRP'],
#   ['plusieurs', 'PRO:IND']),
#  (['regroupe', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ['issus', 'ADJ'],
#   ['de', 'PRP'],
#   ['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM']),
#  (['regroupe', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ['issus', 'ADJ'],
#   ['de', 'PRP'],
#   ['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM'],
#   ["d'", 'PRP']),
#  (['des', 'PRP:det'], ['chercheurs', 'NOM']),
#  (['des', 'PRP:det'], ['chercheurs', 'NOM'], ['issus', 'ADJ']),
#  (['des', 'PRP:det'], ['chercheurs', 'NOM'], ['issus', 'ADJ'], ['de', 'PRP']),
#  (['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ['issus', 'ADJ'],
#   ['de', 'PRP'],
#   ['plusieurs', 'PRO:IND']),
#  (['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ['issus', 'ADJ'],
#   ['de', 'PRP'],
#   ['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM']),
#  (['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ['issus', 'ADJ'],
#   ['de', 'PRP'],
#   ['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM'],
#   ["d'", 'PRP']),
#  (['des', 'PRP:det'],
#   ['chercheurs', 'NOM'],
#   ['issus', 'ADJ'],
#   ['de', 'PRP'],
#   ['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM'],
#   ["d'", 'PRP'],
#   ['expertise', 'NOM']),
#  (['chercheurs', 'NOM'], ['issus', 'ADJ']),
#  (['chercheurs', 'NOM'], ['issus', 'ADJ'], ['de', 'PRP']),
#  (['chercheurs', 'NOM'],
#   ['issus', 'ADJ'],
#   ['de', 'PRP'],
#   ['plusieurs', 'PRO:IND']),
#  (['chercheurs', 'NOM'],
#   ['issus', 'ADJ'],
#   ['de', 'PRP'],
#   ['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM']),
#  (['chercheurs', 'NOM'],
#   ['issus', 'ADJ'],
#   ['de', 'PRP'],
#   ['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM'],
#   ["d'", 'PRP']),
#  (['chercheurs', 'NOM'],
#   ['issus', 'ADJ'],
#   ['de', 'PRP'],
#   ['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM'],
#   ["d'", 'PRP'],
#   ['expertise', 'NOM']),
#  (['chercheurs', 'NOM'],
#   ['issus', 'ADJ'],
#   ['de', 'PRP'],
#   ['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM'],
#   ["d'", 'PRP'],
#   ['expertise', 'NOM'],
#   ['dans', 'PRP']),
#  (['issus', 'ADJ'], ['de', 'PRP']),
#  (['issus', 'ADJ'], ['de', 'PRP'], ['plusieurs', 'PRO:IND']),
#  (['issus', 'ADJ'],
#   ['de', 'PRP'],
#   ['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM']),
#  (['issus', 'ADJ'],
#   ['de', 'PRP'],
#   ['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM'],
#   ["d'", 'PRP']),
#  (['issus', 'ADJ'],
#   ['de', 'PRP'],
#   ['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM'],
#   ["d'", 'PRP'],
#   ['expertise', 'NOM']),
#  (['issus', 'ADJ'],
#   ['de', 'PRP'],
#   ['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM'],
#   ["d'", 'PRP'],
#   ['expertise', 'NOM'],
#   ['dans', 'PRP']),
#  (['issus', 'ADJ'],
#   ['de', 'PRP'],
#   ['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM'],
#   ["d'", 'PRP'],
#   ['expertise', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART']),
#  (['de', 'PRP'], ['plusieurs', 'PRO:IND']),
#  (['de', 'PRP'], ['plusieurs', 'PRO:IND'], ['domaines', 'NOM']),
#  (['de', 'PRP'], ['plusieurs', 'PRO:IND'], ['domaines', 'NOM'], ["d'", 'PRP']),
#  (['de', 'PRP'],
#   ['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM'],
#   ["d'", 'PRP'],
#   ['expertise', 'NOM']),
#  (['de', 'PRP'],
#   ['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM'],
#   ["d'", 'PRP'],
#   ['expertise', 'NOM'],
#   ['dans', 'PRP']),
#  (['de', 'PRP'],
#   ['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM'],
#   ["d'", 'PRP'],
#   ['expertise', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART']),
#  (['de', 'PRP'],
#   ['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM'],
#   ["d'", 'PRP'],
#   ['expertise', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['but', 'NOM']),
#  (['plusieurs', 'PRO:IND'], ['domaines', 'NOM']),
#  (['plusieurs', 'PRO:IND'], ['domaines', 'NOM'], ["d'", 'PRP']),
#  (['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM'],
#   ["d'", 'PRP'],
#   ['expertise', 'NOM']),
#  (['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM'],
#   ["d'", 'PRP'],
#   ['expertise', 'NOM'],
#   ['dans', 'PRP']),
#  (['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM'],
#   ["d'", 'PRP'],
#   ['expertise', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART']),
#  (['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM'],
#   ["d'", 'PRP'],
#   ['expertise', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['but', 'NOM']),
#  (['plusieurs', 'PRO:IND'],
#   ['domaines', 'NOM'],
#   ["d'", 'PRP'],
#   ['expertise', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['but', 'NOM'],
#   ['de', 'PRP']),
#  (['domaines', 'NOM'], ["d'", 'PRP']),
#  (['domaines', 'NOM'], ["d'", 'PRP'], ['expertise', 'NOM']),
#  (['domaines', 'NOM'], ["d'", 'PRP'], ['expertise', 'NOM'], ['dans', 'PRP']),
#  (['domaines', 'NOM'],
#   ["d'", 'PRP'],
#   ['expertise', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART']),
#  (['domaines', 'NOM'],
#   ["d'", 'PRP'],
#   ['expertise', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['but', 'NOM']),
#  (['domaines', 'NOM'],
#   ["d'", 'PRP'],
#   ['expertise', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['but', 'NOM'],
#   ['de', 'PRP']),
#  (['domaines', 'NOM'],
#   ["d'", 'PRP'],
#   ['expertise', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['but', 'NOM'],
#   ['de', 'PRP'],
#   ['favoriser', 'VER:infi']),
#  (["d'", 'PRP'], ['expertise', 'NOM']),
#  (["d'", 'PRP'], ['expertise', 'NOM'], ['dans', 'PRP']),
#  (["d'", 'PRP'], ['expertise', 'NOM'], ['dans', 'PRP'], ['le', 'DET:ART']),
#  (["d'", 'PRP'],
#   ['expertise', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['but', 'NOM']),
#  (["d'", 'PRP'],
#   ['expertise', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['but', 'NOM'],
#   ['de', 'PRP']),
#  (["d'", 'PRP'],
#   ['expertise', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['but', 'NOM'],
#   ['de', 'PRP'],
#   ['favoriser', 'VER:infi']),
#  (["d'", 'PRP'],
#   ['expertise', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['but', 'NOM'],
#   ['de', 'PRP'],
#   ['favoriser', 'VER:infi'],
#   ['les', 'DET:ART']),
#  (['expertise', 'NOM'], ['dans', 'PRP']),
#  (['expertise', 'NOM'], ['dans', 'PRP'], ['le', 'DET:ART']),
#  (['expertise', 'NOM'], ['dans', 'PRP'], ['le', 'DET:ART'], ['but', 'NOM']),
#  (['expertise', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['but', 'NOM'],
#   ['de', 'PRP']),
#  (['expertise', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['but', 'NOM'],
#   ['de', 'PRP'],
#   ['favoriser', 'VER:infi']),
#  (['expertise', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['but', 'NOM'],
#   ['de', 'PRP'],
#   ['favoriser', 'VER:infi'],
#   ['les', 'DET:ART']),
#  (['expertise', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['but', 'NOM'],
#   ['de', 'PRP'],
#   ['favoriser', 'VER:infi'],
#   ['les', 'DET:ART'],
#   ['interactions', 'NOM']),
#  (['dans', 'PRP'], ['le', 'DET:ART']),
#  (['dans', 'PRP'], ['le', 'DET:ART'], ['but', 'NOM']),
#  (['dans', 'PRP'], ['le', 'DET:ART'], ['but', 'NOM'], ['de', 'PRP']),
#  (['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['but', 'NOM'],
#   ['de', 'PRP'],
#   ['favoriser', 'VER:infi']),
#  (['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['but', 'NOM'],
#   ['de', 'PRP'],
#   ['favoriser', 'VER:infi'],
#   ['les', 'DET:ART']),
#  (['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['but', 'NOM'],
#   ['de', 'PRP'],
#   ['favoriser', 'VER:infi'],
#   ['les', 'DET:ART'],
#   ['interactions', 'NOM']),
#  (['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['but', 'NOM'],
#   ['de', 'PRP'],
#   ['favoriser', 'VER:infi'],
#   ['les', 'DET:ART'],
#   ['interactions', 'NOM'],
#   ['et', 'KON']),
#  (['le', 'DET:ART'], ['but', 'NOM']),
#  (['le', 'DET:ART'], ['but', 'NOM'], ['de', 'PRP']),
#  (['le', 'DET:ART'], ['but', 'NOM'], ['de', 'PRP'], ['favoriser', 'VER:infi']),
#  (['le', 'DET:ART'],
#   ['but', 'NOM'],
#   ['de', 'PRP'],
#   ['favoriser', 'VER:infi'],
#   ['les', 'DET:ART']),
#  (['le', 'DET:ART'],
#   ['but', 'NOM'],
#   ['de', 'PRP'],
#   ['favoriser', 'VER:infi'],
#   ['les', 'DET:ART'],
#   ['interactions', 'NOM']),
#  (['le', 'DET:ART'],
#   ['but', 'NOM'],
#   ['de', 'PRP'],
#   ['favoriser', 'VER:infi'],
#   ['les', 'DET:ART'],
#   ['interactions', 'NOM'],
#   ['et', 'KON']),
#  (['le', 'DET:ART'],
#   ['but', 'NOM'],
#   ['de', 'PRP'],
#   ['favoriser', 'VER:infi'],
#   ['les', 'DET:ART'],
#   ['interactions', 'NOM'],
#   ['et', 'KON'],
#   ['la', 'DET:ART']),
#  (['but', 'NOM'], ['de', 'PRP']),
#  (['but', 'NOM'], ['de', 'PRP'], ['favoriser', 'VER:infi']),
#  (['but', 'NOM'],
#   ['de', 'PRP'],
#   ['favoriser', 'VER:infi'],
#   ['les', 'DET:ART']),
#  (['but', 'NOM'],
#   ['de', 'PRP'],
#   ['favoriser', 'VER:infi'],
#   ['les', 'DET:ART'],
#   ['interactions', 'NOM']),
#  (['but', 'NOM'],
#   ['de', 'PRP'],
#   ['favoriser', 'VER:infi'],
#   ['les', 'DET:ART'],
#   ['interactions', 'NOM'],
#   ['et', 'KON']),
#  (['but', 'NOM'],
#   ['de', 'PRP'],
#   ['favoriser', 'VER:infi'],
#   ['les', 'DET:ART'],
#   ['interactions', 'NOM'],
#   ['et', 'KON'],
#   ['la', 'DET:ART']),
#  (['but', 'NOM'],
#   ['de', 'PRP'],
#   ['favoriser', 'VER:infi'],
#   ['les', 'DET:ART'],
#   ['interactions', 'NOM'],
#   ['et', 'KON'],
#   ['la', 'DET:ART'],
#   ['mise', 'NOM']),
#  (['de', 'PRP'], ['favoriser', 'VER:infi']),
#  (['de', 'PRP'], ['favoriser', 'VER:infi'], ['les', 'DET:ART']),
#  (['de', 'PRP'],
#   ['favoriser', 'VER:infi'],
#   ['les', 'DET:ART'],
#   ['interactions', 'NOM']),
#  (['de', 'PRP'],
#   ['favoriser', 'VER:infi'],
#   ['les', 'DET:ART'],
#   ['interactions', 'NOM'],
#   ['et', 'KON']),
#  (['de', 'PRP'],
#   ['favoriser', 'VER:infi'],
#   ['les', 'DET:ART'],
#   ['interactions', 'NOM'],
#   ['et', 'KON'],
#   ['la', 'DET:ART']),
#  (['de', 'PRP'],
#   ['favoriser', 'VER:infi'],
#   ['les', 'DET:ART'],
#   ['interactions', 'NOM'],
#   ['et', 'KON'],
#   ['la', 'DET:ART'],
#   ['mise', 'NOM']),
#  (['de', 'PRP'],
#   ['favoriser', 'VER:infi'],
#   ['les', 'DET:ART'],
#   ['interactions', 'NOM'],
#   ['et', 'KON'],
#   ['la', 'DET:ART'],
#   ['mise', 'NOM'],
#   ['en', 'PRP']),
#  (['favoriser', 'VER:infi'], ['les', 'DET:ART']),
#  (['favoriser', 'VER:infi'], ['les', 'DET:ART'], ['interactions', 'NOM']),
#  (['favoriser', 'VER:infi'],
#   ['les', 'DET:ART'],
#   ['interactions', 'NOM'],
#   ['et', 'KON']),
#  (['favoriser', 'VER:infi'],
#   ['les', 'DET:ART'],
#   ['interactions', 'NOM'],
#   ['et', 'KON'],
#   ['la', 'DET:ART']),
#  (['favoriser', 'VER:infi'],
#   ['les', 'DET:ART'],
#   ['interactions', 'NOM'],
#   ['et', 'KON'],
#   ['la', 'DET:ART'],
#   ['mise', 'NOM']),
#  (['favoriser', 'VER:infi'],
#   ['les', 'DET:ART'],
#   ['interactions', 'NOM'],
#   ['et', 'KON'],
#   ['la', 'DET:ART'],
#   ['mise', 'NOM'],
#   ['en', 'PRP']),
#  (['favoriser', 'VER:infi'],
#   ['les', 'DET:ART'],
#   ['interactions', 'NOM'],
#   ['et', 'KON'],
#   ['la', 'DET:ART'],
#   ['mise', 'NOM'],
#   ['en', 'PRP'],
#   ['commun', 'NOM']),
#  (['les', 'DET:ART'], ['interactions', 'NOM']),
#  (['les', 'DET:ART'], ['interactions', 'NOM'], ['et', 'KON']),
#  (['les', 'DET:ART'],
#   ['interactions', 'NOM'],
#   ['et', 'KON'],
#   ['la', 'DET:ART']),
#  (['les', 'DET:ART'],
#   ['interactions', 'NOM'],
#   ['et', 'KON'],
#   ['la', 'DET:ART'],
#   ['mise', 'NOM']),
#  (['les', 'DET:ART'],
#   ['interactions', 'NOM'],
#   ['et', 'KON'],
#   ['la', 'DET:ART'],
#   ['mise', 'NOM'],
#   ['en', 'PRP']),
#  (['les', 'DET:ART'],
#   ['interactions', 'NOM'],
#   ['et', 'KON'],
#   ['la', 'DET:ART'],
#   ['mise', 'NOM'],
#   ['en', 'PRP'],
#   ['commun', 'NOM']),
#  (['les', 'DET:ART'],
#   ['interactions', 'NOM'],
#   ['et', 'KON'],
#   ['la', 'DET:ART'],
#   ['mise', 'NOM'],
#   ['en', 'PRP'],
#   ['commun', 'NOM'],
#   ['des', 'PRP:det']),
#  (['interactions', 'NOM'], ['et', 'KON']),
#  (['interactions', 'NOM'], ['et', 'KON'], ['la', 'DET:ART']),
#  (['interactions', 'NOM'], ['et', 'KON'], ['la', 'DET:ART'], ['mise', 'NOM']),
#  (['interactions', 'NOM'],
#   ['et', 'KON'],
#   ['la', 'DET:ART'],
#   ['mise', 'NOM'],
#   ['en', 'PRP']),
#  (['interactions', 'NOM'],
#   ['et', 'KON'],
#   ['la', 'DET:ART'],
#   ['mise', 'NOM'],
#   ['en', 'PRP'],
#   ['commun', 'NOM']),
#  (['interactions', 'NOM'],
#   ['et', 'KON'],
#   ['la', 'DET:ART'],
#   ['mise', 'NOM'],
#   ['en', 'PRP'],
#   ['commun', 'NOM'],
#   ['des', 'PRP:det']),
#  (['interactions', 'NOM'],
#   ['et', 'KON'],
#   ['la', 'DET:ART'],
#   ['mise', 'NOM'],
#   ['en', 'PRP'],
#   ['commun', 'NOM'],
#   ['des', 'PRP:det'],
#   ['compétences', 'NOM']),
#  (['et', 'KON'], ['la', 'DET:ART']),
#  (['et', 'KON'], ['la', 'DET:ART'], ['mise', 'NOM']),
#  (['et', 'KON'], ['la', 'DET:ART'], ['mise', 'NOM'], ['en', 'PRP']),
#  (['et', 'KON'],
#   ['la', 'DET:ART'],
#   ['mise', 'NOM'],
#   ['en', 'PRP'],
#   ['commun', 'NOM']),
#  (['et', 'KON'],
#   ['la', 'DET:ART'],
#   ['mise', 'NOM'],
#   ['en', 'PRP'],
#   ['commun', 'NOM'],
#   ['des', 'PRP:det']),
#  (['et', 'KON'],
#   ['la', 'DET:ART'],
#   ['mise', 'NOM'],
#   ['en', 'PRP'],
#   ['commun', 'NOM'],
#   ['des', 'PRP:det'],
#   ['compétences', 'NOM']),
#  (['et', 'KON'],
#   ['la', 'DET:ART'],
#   ['mise', 'NOM'],
#   ['en', 'PRP'],
#   ['commun', 'NOM'],
#   ['des', 'PRP:det'],
#   ['compétences', 'NOM'],
#   ['.', 'SENT']),
#  (['la', 'DET:ART'], ['mise', 'NOM']),
#  (['la', 'DET:ART'], ['mise', 'NOM'], ['en', 'PRP']),
#  (['la', 'DET:ART'], ['mise', 'NOM'], ['en', 'PRP'], ['commun', 'NOM']),
#  (['la', 'DET:ART'],
#   ['mise', 'NOM'],
#   ['en', 'PRP'],
#   ['commun', 'NOM'],
#   ['des', 'PRP:det']),
#  (['la', 'DET:ART'],
#   ['mise', 'NOM'],
#   ['en', 'PRP'],
#   ['commun', 'NOM'],
#   ['des', 'PRP:det'],
#   ['compétences', 'NOM']),
#  (['la', 'DET:ART'],
#   ['mise', 'NOM'],
#   ['en', 'PRP'],
#   ['commun', 'NOM'],
#   ['des', 'PRP:det'],
#   ['compétences', 'NOM'],
#   ['.', 'SENT']),
#  (['la', 'DET:ART'],
#   ['mise', 'NOM'],
#   ['en', 'PRP'],
#   ['commun', 'NOM'],
#   ['des', 'PRP:det'],
#   ['compétences', 'NOM'],
#   ['.', 'SENT'],
#   ["l'", 'DET:ART']),
#  (['mise', 'NOM'], ['en', 'PRP']),
#  (['mise', 'NOM'], ['en', 'PRP'], ['commun', 'NOM']),
#  (['mise', 'NOM'], ['en', 'PRP'], ['commun', 'NOM'], ['des', 'PRP:det']),
#  (['mise', 'NOM'],
#   ['en', 'PRP'],
#   ['commun', 'NOM'],
#   ['des', 'PRP:det'],
#   ['compétences', 'NOM']),
#  (['mise', 'NOM'],
#   ['en', 'PRP'],
#   ['commun', 'NOM'],
#   ['des', 'PRP:det'],
#   ['compétences', 'NOM'],
#   ['.', 'SENT']),
#  (['mise', 'NOM'],
# ...
#  (['et', 'KON'], ['orthopédie', 'NOM'], ['(', 'PUN'], ['lio', 'NOM']),
#  (['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN']),
#  (['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['le', 'DET:ART']),
#  (['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['le', 'DET:ART'],
#   ['laboratoire', 'NOM']),
#  (['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['le', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['de', 'PRP']),
#  (['orthopédie', 'NOM'], ['(', 'PUN']),
#  (['orthopédie', 'NOM'], ['(', 'PUN'], ['lio', 'NOM']),
#  (['orthopédie', 'NOM'], ['(', 'PUN'], ['lio', 'NOM'], [')', 'PUN']),
#  (['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['le', 'DET:ART']),
#  (['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['le', 'DET:ART'],
#   ['laboratoire', 'NOM']),
#  (['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['le', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['de', 'PRP']),
#  (['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['le', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['de', 'PRP'],
#   ['recherche', 'NOM']),
#  (['(', 'PUN'], ['lio', 'NOM']),
#  (['(', 'PUN'], ['lio', 'NOM'], [')', 'PUN']),
#  (['(', 'PUN'], ['lio', 'NOM'], [')', 'PUN'], ['le', 'DET:ART']),
#  (['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['le', 'DET:ART'],
#   ['laboratoire', 'NOM']),
#  (['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['le', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['de', 'PRP']),
#  (['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['le', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['de', 'PRP'],
#   ['recherche', 'NOM']),
#  (['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['le', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['de', 'PRP'],
#   ['recherche', 'NOM'],
#   ['en', 'PRP']),
#  (['lio', 'NOM'], [')', 'PUN']),
#  (['lio', 'NOM'], [')', 'PUN'], ['le', 'DET:ART']),
#  (['lio', 'NOM'], [')', 'PUN'], ['le', 'DET:ART'], ['laboratoire', 'NOM']),
#  (['lio', 'NOM'],
#   [')', 'PUN'],
#   ['le', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['de', 'PRP']),
#  (['lio', 'NOM'],
#   [')', 'PUN'],
#   ['le', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['de', 'PRP'],
#   ['recherche', 'NOM']),
#  (['lio', 'NOM'],
#   [')', 'PUN'],
#   ['le', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['de', 'PRP'],
#   ['recherche', 'NOM'],
#   ['en', 'PRP']),
#  (['lio', 'NOM'],
#   [')', 'PUN'],
#   ['le', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['de', 'PRP'],
#   ['recherche', 'NOM'],
#   ['en', 'PRP'],
#   ['imagerie', 'NOM']),
#  ([')', 'PUN'], ['le', 'DET:ART']),
#  ([')', 'PUN'], ['le', 'DET:ART'], ['laboratoire', 'NOM']),
#  ([')', 'PUN'], ['le', 'DET:ART'], ['laboratoire', 'NOM'], ['de', 'PRP']),
#  ([')', 'PUN'],
#   ['le', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['de', 'PRP'],
#   ['recherche', 'NOM']),
#  ([')', 'PUN'],
#   ['le', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['de', 'PRP'],
#   ['recherche', 'NOM'],
#   ['en', 'PRP']),
#  ([')', 'PUN'],
#   ['le', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['de', 'PRP'],
#   ['recherche', 'NOM'],
#   ['en', 'PRP'],
#   ['imagerie', 'NOM']),
#  ([')', 'PUN'],
#   ['le', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['de', 'PRP'],
#   ['recherche', 'NOM'],
#   ['en', 'PRP'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON']),
#  (['le', 'DET:ART'], ['laboratoire', 'NOM']),
#  (['le', 'DET:ART'], ['laboratoire', 'NOM'], ['de', 'PRP']),
#  (['le', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['de', 'PRP'],
#   ['recherche', 'NOM']),
#  (['le', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['de', 'PRP'],
#   ['recherche', 'NOM'],
#   ['en', 'PRP']),
#  (['le', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['de', 'PRP'],
#   ['recherche', 'NOM'],
#   ['en', 'PRP'],
#   ['imagerie', 'NOM']),
#  (['le', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['de', 'PRP'],
#   ['recherche', 'NOM'],
#   ['en', 'PRP'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON']),
#  (['le', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['de', 'PRP'],
#   ['recherche', 'NOM'],
#   ['en', 'PRP'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['orthopédie', 'NOM']),
#  (['laboratoire', 'NOM'], ['de', 'PRP']),
#  (['laboratoire', 'NOM'], ['de', 'PRP'], ['recherche', 'NOM']),
#  (['laboratoire', 'NOM'], ['de', 'PRP'], ['recherche', 'NOM'], ['en', 'PRP']),
#  (['laboratoire', 'NOM'],
#   ['de', 'PRP'],
#   ['recherche', 'NOM'],
#   ['en', 'PRP'],
#   ['imagerie', 'NOM']),
#  (['laboratoire', 'NOM'],
#   ['de', 'PRP'],
#   ['recherche', 'NOM'],
#   ['en', 'PRP'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON']),
#  (['laboratoire', 'NOM'],
#   ['de', 'PRP'],
#   ['recherche', 'NOM'],
#   ['en', 'PRP'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['orthopédie', 'NOM']),
#  (['laboratoire', 'NOM'],
#   ['de', 'PRP'],
#   ['recherche', 'NOM'],
#   ['en', 'PRP'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN']),
#  (['de', 'PRP'], ['recherche', 'NOM']),
#  (['de', 'PRP'], ['recherche', 'NOM'], ['en', 'PRP']),
#  (['de', 'PRP'], ['recherche', 'NOM'], ['en', 'PRP'], ['imagerie', 'NOM']),
#  (['de', 'PRP'],
#   ['recherche', 'NOM'],
#   ['en', 'PRP'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON']),
#  (['de', 'PRP'],
#   ['recherche', 'NOM'],
#   ['en', 'PRP'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['orthopédie', 'NOM']),
#  (['de', 'PRP'],
#   ['recherche', 'NOM'],
#   ['en', 'PRP'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN']),
#  (['de', 'PRP'],
#   ['recherche', 'NOM'],
#   ['en', 'PRP'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM']),
#  (['recherche', 'NOM'], ['en', 'PRP']),
#  (['recherche', 'NOM'], ['en', 'PRP'], ['imagerie', 'NOM']),
#  (['recherche', 'NOM'], ['en', 'PRP'], ['imagerie', 'NOM'], ['et', 'KON']),
#  (['recherche', 'NOM'],
#   ['en', 'PRP'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['orthopédie', 'NOM']),
#  (['recherche', 'NOM'],
#   ['en', 'PRP'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN']),
#  (['recherche', 'NOM'],
#   ['en', 'PRP'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM']),
#  (['recherche', 'NOM'],
#   ['en', 'PRP'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN']),
#  (['en', 'PRP'], ['imagerie', 'NOM']),
#  (['en', 'PRP'], ['imagerie', 'NOM'], ['et', 'KON']),
#  (['en', 'PRP'], ['imagerie', 'NOM'], ['et', 'KON'], ['orthopédie', 'NOM']),
#  (['en', 'PRP'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN']),
#  (['en', 'PRP'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM']),
#  (['en', 'PRP'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN']),
#  (['en', 'PRP'],
#   ['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['est', 'VER:pres']),
#  (['imagerie', 'NOM'], ['et', 'KON']),
#  (['imagerie', 'NOM'], ['et', 'KON'], ['orthopédie', 'NOM']),
#  (['imagerie', 'NOM'], ['et', 'KON'], ['orthopédie', 'NOM'], ['(', 'PUN']),
#  (['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM']),
#  (['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN']),
#  (['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['est', 'VER:pres']),
#  (['imagerie', 'NOM'],
#   ['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['est', 'VER:pres'],
#   ['un', 'DET:ART']),
#  (['et', 'KON'], ['orthopédie', 'NOM']),
#  (['et', 'KON'], ['orthopédie', 'NOM'], ['(', 'PUN']),
#  (['et', 'KON'], ['orthopédie', 'NOM'], ['(', 'PUN'], ['lio', 'NOM']),
#  (['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN']),
#  (['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['est', 'VER:pres']),
#  (['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['est', 'VER:pres'],
#   ['un', 'DET:ART']),
#  (['et', 'KON'],
#   ['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['est', 'VER:pres'],
#   ['un', 'DET:ART'],
#   ['laboratoire', 'NOM']),
#  (['orthopédie', 'NOM'], ['(', 'PUN']),
#  (['orthopédie', 'NOM'], ['(', 'PUN'], ['lio', 'NOM']),
#  (['orthopédie', 'NOM'], ['(', 'PUN'], ['lio', 'NOM'], [')', 'PUN']),
#  (['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['est', 'VER:pres']),
#  (['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['est', 'VER:pres'],
#   ['un', 'DET:ART']),
#  (['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['est', 'VER:pres'],
#   ['un', 'DET:ART'],
#   ['laboratoire', 'NOM']),
#  (['orthopédie', 'NOM'],
#   ['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['est', 'VER:pres'],
#   ['un', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ']),
#  (['(', 'PUN'], ['lio', 'NOM']),
#  (['(', 'PUN'], ['lio', 'NOM'], [')', 'PUN']),
#  (['(', 'PUN'], ['lio', 'NOM'], [')', 'PUN'], ['est', 'VER:pres']),
#  (['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['est', 'VER:pres'],
#   ['un', 'DET:ART']),
#  (['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['est', 'VER:pres'],
#   ['un', 'DET:ART'],
#   ['laboratoire', 'NOM']),
#  (['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['est', 'VER:pres'],
#   ['un', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ']),
#  (['(', 'PUN'],
#   ['lio', 'NOM'],
#   [')', 'PUN'],
#   ['est', 'VER:pres'],
#   ['un', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper']),
#  (['lio', 'NOM'], [')', 'PUN']),
#  (['lio', 'NOM'], [')', 'PUN'], ['est', 'VER:pres']),
#  (['lio', 'NOM'], [')', 'PUN'], ['est', 'VER:pres'], ['un', 'DET:ART']),
#  (['lio', 'NOM'],
#   [')', 'PUN'],
#   ['est', 'VER:pres'],
#   ['un', 'DET:ART'],
#   ['laboratoire', 'NOM']),
#  (['lio', 'NOM'],
#   [')', 'PUN'],
#   ['est', 'VER:pres'],
#   ['un', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ']),
#  (['lio', 'NOM'],
#   [')', 'PUN'],
#   ['est', 'VER:pres'],
#   ['un', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper']),
#  (['lio', 'NOM'],
#   [')', 'PUN'],
#   ['est', 'VER:pres'],
#   ['un', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper'],
#   ['de', 'PRP']),
#  ([')', 'PUN'], ['est', 'VER:pres']),
#  ([')', 'PUN'], ['est', 'VER:pres'], ['un', 'DET:ART']),
#  ([')', 'PUN'],
#   ['est', 'VER:pres'],
#   ['un', 'DET:ART'],
#   ['laboratoire', 'NOM']),
#  ([')', 'PUN'],
#   ['est', 'VER:pres'],
#   ['un', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ']),
#  ([')', 'PUN'],
#   ['est', 'VER:pres'],
#   ['un', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper']),
#  ([')', 'PUN'],
#   ['est', 'VER:pres'],
#   ['un', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper'],
#   ['de', 'PRP']),
#  ([')', 'PUN'],
#   ['est', 'VER:pres'],
#   ['un', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART']),
#  (['est', 'VER:pres'], ['un', 'DET:ART']),
#  (['est', 'VER:pres'], ['un', 'DET:ART'], ['laboratoire', 'NOM']),
#  (['est', 'VER:pres'],
#   ['un', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ']),
#  (['est', 'VER:pres'],
#   ['un', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper']),
#  (['est', 'VER:pres'],
#   ['un', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper'],
#   ['de', 'PRP']),
#  (['est', 'VER:pres'],
#   ['un', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART']),
#  (['est', 'VER:pres'],
#   ['un', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['école', 'NOM']),
#  (['un', 'DET:ART'], ['laboratoire', 'NOM']),
#  (['un', 'DET:ART'], ['laboratoire', 'NOM'], ['multidisciplinaire', 'ADJ']),
#  (['un', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper']),
#  (['un', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper'],
#   ['de', 'PRP']),
#  (['un', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART']),
#  (['un', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['école', 'NOM']),
#  (['un', 'DET:ART'],
#   ['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['école', 'NOM'],
#   ['de', 'PRP']),
#  (['laboratoire', 'NOM'], ['multidisciplinaire', 'ADJ']),
#  (['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper']),
#  (['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper'],
#   ['de', 'PRP']),
#  (['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART']),
#  (['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['école', 'NOM']),
#  (['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['école', 'NOM'],
#   ['de', 'PRP']),
#  (['laboratoire', 'NOM'],
#   ['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['école', 'NOM'],
#   ['de', 'PRP'],
#   ['technologie', 'NOM']),
#  (['multidisciplinaire', 'ADJ'], ['accrédité', 'VER:pper']),
#  (['multidisciplinaire', 'ADJ'], ['accrédité', 'VER:pper'], ['de', 'PRP']),
#  (['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART']),
#  (['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['école', 'NOM']),
#  (['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['école', 'NOM'],
#   ['de', 'PRP']),
#  (['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['école', 'NOM'],
#   ['de', 'PRP'],
#   ['technologie', 'NOM']),
#  (['multidisciplinaire', 'ADJ'],
#   ['accrédité', 'VER:pper'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['école', 'NOM'],
#   ['de', 'PRP'],
#   ['technologie', 'NOM'],
#   ['supérieure', 'ADJ']),
#  (['accrédité', 'VER:pper'], ['de', 'PRP']),
#  (['accrédité', 'VER:pper'], ['de', 'PRP'], ["l'", 'DET:ART']),
#  (['accrédité', 'VER:pper'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['école', 'NOM']),
#  (['accrédité', 'VER:pper'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['école', 'NOM'],
#   ['de', 'PRP']),
#  (['accrédité', 'VER:pper'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['école', 'NOM'],
#   ['de', 'PRP'],
#   ['technologie', 'NOM']),
#  (['accrédité', 'VER:pper'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['école', 'NOM'],
#   ['de', 'PRP'],
#   ['technologie', 'NOM'],
#   ['supérieure', 'ADJ']),
#  (['accrédité', 'VER:pper'],
#   ['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['école', 'NOM'],
#   ['de', 'PRP'],
#   ['technologie', 'NOM'],
#   ['supérieure', 'ADJ'],
#   ['dont', 'PRO:REL']),
#  (['de', 'PRP'], ["l'", 'DET:ART']),
#  (['de', 'PRP'], ["l'", 'DET:ART'], ['école', 'NOM']),
#  (['de', 'PRP'], ["l'", 'DET:ART'], ['école', 'NOM'], ['de', 'PRP']),
#  (['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['école', 'NOM'],
#   ['de', 'PRP'],
#   ['technologie', 'NOM']),
#  (['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['école', 'NOM'],
#   ['de', 'PRP'],
#   ['technologie', 'NOM'],
#   ['supérieure', 'ADJ']),
#  (['de', 'PRP'],
#   ["l'", 'DET:ART'],
#   ['école', 'NOM'],
#   ['de', 'PRP'],
#   ['technologie', 'NOM'],
#   ['supérieure', 'ADJ'],
#   ['dont', 'PRO:REL']),
#  ...]

# %% [markdown]
# ### **Extraction des patrons syntaxiques**

# %%
def extract_patterns(ngrammes):
    patterns = []
    for ng in ngrammes:
        phrase = tuple([t[0] for t in ng])
        pattern = [t[1] for t in ng]
        patterns.append([phrase, pattern])
    return patterns

# %%
phrases = extract_patterns(ngrammes)

# %%
frequencies = FreqDist(everygrams(tokens, min_len=1, max_len=8))

# %%
frequencies
# Out:
# FreqDist({('STOP',): 68484, ('de',): 55655, ('.',): 27777, ('la',): 21837, ('et',): 21314, ("l'",): 18482, ('le',): 17328, ('à',): 15197, ('du',): 15041, ('des',): 14624, ...})

# %% [markdown]
# ### **Filtrage**
# On retire les n-grammes qui débutent ou se terminent par un stopword (antidictionnaire)

# %%
# Importer l'antidictionnaire pour filtrer les données

# Stopwords fréquents en français (non lemmatisés)
file_path = "../02-filtrage/stopwords.txt"
with open(file_path, 'r', encoding="utf-8") as f:
    stopwords = [t.lower().strip('\n') for t in f.readlines()]


# Stopwords fréquents en anglais (non lemmatisés)
file_path = '../02-filtrage/stop_words_english.txt'
with open(file_path, 'r', encoding="utf-8") as f:
    stopwords += [t.lower().strip('\n') for t in f.readlines()]

# %%
def filtrer_stopwords(x): # On s'assure aussi que le premier terme du ngramme est un NOM pour avoir des syntagmes nominaux
    if lng == 'en':
        nom = 'NN'
    if lng == 'fr':
        nom = 'NOM'
    return [term for term in x if not 'STOP' in term[0] and not term[0][0] in stopwords and not term[0][-1] in stopwords \
        and not 'NUM' in term[1] and term[1][0] == nom and not '.' in term[0] and not '-' in term[0] and not ':' in term[0]\
        
        # Une parenthèse fermante peut juste se trouver comme dernier token
        # Si une parenthèse est ouverte, elle doit aussi être fermée (et vice versa)
        and not ')' in term[0][:-1] and not ('(' in term[0] and not ')' in term[0]) \
        and not (')' in term[0] and not '(' in term[0])]

# %%
phrases = filtrer_stopwords(phrases)

# %% [markdown]
# On retire les n-grammes qui débutent ou se terminent par un token dont la longueur est inférieure à 2 caractères ou supérieure à 18 caractères

# %%
def filter_len(x):
    return [term for term in x if \
        (len(term[0][0]) > 2 or term[0][0] == '(')  and (len(term[0][-1]) > 2 or term[0][-1] == ')') and \
        len(term[0][0]) < 18 and len(term[0][-1]) < 18]

phrases = filter_len(phrases)

# %% [markdown]
# On retire les n-grammes qui apparaissent moins de 5 fois dans le corpus

# %%
def filter_freq(x):
    return [term for term in x if frequencies[tuple(term[0])] > 5]

phrases = filter_freq(phrases)

# %%
phrases
# Out:
# [[('imagerie', 'et', 'ingénierie'), ['NOM', 'KON', 'NOM']],
#  [('axe', 'imagerie'), ['NOM', 'NOM']],
#  [('axe', 'imagerie', 'et', 'ingénierie'), ['NOM', 'NOM', 'KON', 'NOM']],
#  [('imagerie', 'et', 'ingénierie'), ['NOM', 'KON', 'NOM']],
#  [('axe', 'imagerie'), ['NOM', 'NOM']],
#  [('axe', 'imagerie', 'et', 'ingénierie'), ['NOM', 'NOM', 'KON', 'NOM']],
#  [('imagerie', 'et', 'ingénierie'), ['NOM', 'KON', 'NOM']],
#  [('crchum', 'abrite'), ['NOM', 'VER:pres']],
#  [('systèmes', 'biologiques'), ['NOM', 'ADJ']],
#  [('développement', 'et', 'validation'), ['NOM', 'KON', 'NOM']],
#  [('laboratoire', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('laboratoire', 'de', 'recherche', 'en', 'imagerie'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'NOM']],
#  [('laboratoire', 'de', 'recherche', 'en', 'imagerie', 'et', 'orthopédie'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'NOM', 'KON', 'NOM']],
#  [('recherche', 'en', 'imagerie'), ['NOM', 'PRP', 'NOM']],
#  [('recherche', 'en', 'imagerie', 'et', 'orthopédie'),
#   ['NOM', 'PRP', 'NOM', 'KON', 'NOM']],
#  [('recherche', 'en', 'imagerie', 'et', 'orthopédie', '(', 'lio', ')'),
#   ['NOM', 'PRP', 'NOM', 'KON', 'NOM', 'PUN', 'NOM', 'PUN']],
#  [('imagerie', 'et', 'orthopédie'), ['NOM', 'KON', 'NOM']],
#  [('imagerie', 'et', 'orthopédie', '(', 'lio', ')'),
#   ['NOM', 'KON', 'NOM', 'PUN', 'NOM', 'PUN']],
#  [('orthopédie', '(', 'lio', ')'), ['NOM', 'PUN', 'NOM', 'PUN']],
#  [('laboratoire', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('laboratoire', 'de', 'recherche', 'en', 'imagerie'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'NOM']],
#  [('laboratoire', 'de', 'recherche', 'en', 'imagerie', 'et', 'orthopédie'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'NOM', 'KON', 'NOM']],
#  [('recherche', 'en', 'imagerie'), ['NOM', 'PRP', 'NOM']],
#  [('recherche', 'en', 'imagerie', 'et', 'orthopédie'),
#   ['NOM', 'PRP', 'NOM', 'KON', 'NOM']],
#  [('recherche', 'en', 'imagerie', 'et', 'orthopédie', '(', 'lio', ')'),
#   ['NOM', 'PRP', 'NOM', 'KON', 'NOM', 'PUN', 'NOM', 'PUN']],
#  [('imagerie', 'et', 'orthopédie'), ['NOM', 'KON', 'NOM']],
#  [('imagerie', 'et', 'orthopédie', '(', 'lio', ')'),
#   ['NOM', 'KON', 'NOM', 'PUN', 'NOM', 'PUN']],
#  [('orthopédie', '(', 'lio', ')'), ['NOM', 'PUN', 'NOM', 'PUN']],
#  [('école', 'de', 'technologie'), ['NOM', 'PRP', 'NOM']],
#  [('école', 'de', 'technologie', 'supérieure'), ['NOM', 'PRP', 'NOM', 'ADJ']],
#  [('technologie', 'supérieure'), ['NOM', 'ADJ']],
#  [('imagerie', 'médicale'), ['NOM', 'ADJ']],
#  [('dispositifs', 'médicaux'), ['NOM', 'ADJ']],
#  [('aides', 'techniques'), ['NOM', 'ADJ']],
#  [('aide', 'à', 'la', 'décision'), ['NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('systèmes', 'biologiques'), ['NOM', 'ADJ']],
#  [('analyse', "d'", 'images'), ['NOM', 'PRP', 'NOM']],
#  [('dispositifs', 'médicaux'), ['NOM', 'ADJ']],
#  [('laboratoire', 'de', 'biomatériaux'), ['NOM', 'PRP', 'NOM']],
#  [('laboratoire', 'de', 'biomatériaux', 'endovasculaires'),
#   ['NOM', 'PRP', 'NOM', 'ADJ']],
#  [('laboratoire', 'de', 'biomatériaux', 'endovasculaires', '(', 'lbev', ')'),
#   ['NOM', 'PRP', 'NOM', 'ADJ', 'PUN', 'ADJ', 'PUN']],
#  [('biomatériaux', 'endovasculaires'), ['NOM', 'ADJ']],
#  [('biomatériaux', 'endovasculaires', '(', 'lbev', ')'),
#   ['NOM', 'ADJ', 'PUN', 'ADJ', 'PUN']],
#  [('laboratoire', 'de', 'biomatériaux'), ['NOM', 'PRP', 'NOM']],
#  [('laboratoire', 'de', 'biomatériaux', 'endovasculaires'),
#   ['NOM', 'PRP', 'NOM', 'ADJ']],
#  [('laboratoire', 'de', 'biomatériaux', 'endovasculaires', '(', 'lbev', ')'),
#   ['NOM', 'PRP', 'NOM', 'ADJ', 'PUN', 'ADJ', 'PUN']],
#  [('biomatériaux', 'endovasculaires'), ['NOM', 'ADJ']],
#  [('biomatériaux', 'endovasculaires', '(', 'lbev', ')'),
#   ['NOM', 'ADJ', 'PUN', 'ADJ', 'PUN']],
#  [('laboratoire', 'étudie'), ['NOM', 'VER:pres']],
#  [('vitro', 'et', 'in', 'vivo'), ['NOM', 'KON', 'ADJ', 'ADV']],
#  [('laboratoire', 'de', 'biorhéologie'), ['NOM', 'PRP', 'NOM']],
#  [('laboratoire', 'de', 'biorhéologie', 'et', "d'", 'ultrasonographie'),
#   ['NOM', 'PRP', 'NOM', 'KON', 'PRP', 'NOM']],
#  [('laboratoire',
#    'de',
#    'biorhéologie',
#    'et',
#    "d'",
#    'ultrasonographie',
#    'médicale'),
#   ['NOM', 'PRP', 'NOM', 'KON', 'PRP', 'NOM', 'ADJ']],
#  [('biorhéologie', 'et', "d'", 'ultrasonographie'),
#   ['NOM', 'KON', 'PRP', 'NOM']],
#  [('biorhéologie', 'et', "d'", 'ultrasonographie', 'médicale'),
#   ['NOM', 'KON', 'PRP', 'NOM', 'ADJ']],
#  [('biorhéologie',
#    'et',
#    "d'",
#    'ultrasonographie',
#    'médicale',
#    '(',
#    'lbum',
#    ')'),
#   ['NOM', 'KON', 'PRP', 'NOM', 'ADJ', 'PUN', 'NOM', 'PUN']],
#  [('ultrasonographie', 'médicale'), ['NOM', 'ADJ']],
#  [('ultrasonographie', 'médicale', '(', 'lbum', ')'),
#   ['NOM', 'ADJ', 'PUN', 'NOM', 'PUN']],
#  [('laboratoire', 'de', 'biorhéologie'), ['NOM', 'PRP', 'NOM']],
#  [('laboratoire', 'de', 'biorhéologie', 'et', "d'", 'ultrasonographie'),
#   ['NOM', 'PRP', 'NOM', 'KON', 'PRP', 'NOM']],
#  [('laboratoire',
#    'de',
#    'biorhéologie',
#    'et',
#    "d'",
#    'ultrasonographie',
#    'médicale'),
#   ['NOM', 'PRP', 'NOM', 'KON', 'PRP', 'NOM', 'ADJ']],
#  [('biorhéologie', 'et', "d'", 'ultrasonographie'),
#   ['NOM', 'KON', 'PRP', 'NOM']],
#  [('biorhéologie', 'et', "d'", 'ultrasonographie', 'médicale'),
#   ['NOM', 'KON', 'PRP', 'NOM', 'ADJ']],
#  [('biorhéologie',
#    'et',
#    "d'",
#    'ultrasonographie',
#    'médicale',
#    '(',
#    'lbum',
#    ')'),
#   ['NOM', 'KON', 'PRP', 'NOM', 'ADJ', 'PUN', 'NOM', 'PUN']],
#  [('ultrasonographie', 'médicale'), ['NOM', 'ADJ']],
#  [('ultrasonographie', 'médicale', '(', 'lbum', ')'),
#   ['NOM', 'ADJ', 'PUN', 'NOM', 'PUN']],
#  [('imagerie', 'médicale'), ['NOM', 'ADJ']],
#  [('techniques', "d'", 'imagerie'), ['NOM', 'PRP', 'NOM']],
#  [('traitement', 'de', "l'", 'image'), ['NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('traitement', 'de', "l'", 'image'), ['NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('champs', "d'", 'intérêts'), ['NOM', 'PRP', 'NOM']],
#  [('pathologies', 'vasculaires'), ['NOM', 'ADJ']],
#  [('laboratoire', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('laboratoire', 'de', 'recherche', 'en', 'neuroradiologie'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'NOM']],
#  [('laboratoire',
#    'de',
#    'recherche',
#    'en',
#    'neuroradiologie',
#    'interventionnelle'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'NOM', 'ADJ']],
#  [('recherche', 'en', 'neuroradiologie'), ['NOM', 'PRP', 'NOM']],
#  [('recherche', 'en', 'neuroradiologie', 'interventionnelle'),
#   ['NOM', 'PRP', 'NOM', 'ADJ']],
#  [('recherche', 'en', 'neuroradiologie', 'interventionnelle', '(', 'nri', ')'),
#   ['NOM', 'PRP', 'NOM', 'ADJ', 'PUN', 'VER:pper', 'PUN']],
#  [('neuroradiologie', 'interventionnelle'), ['NOM', 'ADJ']],
#  [('neuroradiologie', 'interventionnelle', '(', 'nri', ')'),
#   ['NOM', 'ADJ', 'PUN', 'VER:pper', 'PUN']],
#  [('laboratoire', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('laboratoire', 'de', 'recherche', 'en', 'neuroradiologie'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'NOM']],
#  [('laboratoire',
#    'de',
#    'recherche',
#    'en',
#    'neuroradiologie',
#    'interventionnelle'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'NOM', 'ADJ']],
#  [('recherche', 'en', 'neuroradiologie'), ['NOM', 'PRP', 'NOM']],
#  [('recherche', 'en', 'neuroradiologie', 'interventionnelle'),
#   ['NOM', 'PRP', 'NOM', 'ADJ']],
#  [('recherche', 'en', 'neuroradiologie', 'interventionnelle', '(', 'nri', ')'),
#   ['NOM', 'PRP', 'NOM', 'ADJ', 'PUN', 'VER:pper', 'PUN']],
#  [('neuroradiologie', 'interventionnelle'), ['NOM', 'ADJ']],
#  [('neuroradiologie', 'interventionnelle', '(', 'nri', ')'),
#   ['NOM', 'ADJ', 'PUN', 'VER:pper', 'PUN']],
#  [('pathologies', 'vasculaires'), ['NOM', 'ADJ']],
#  [('unité', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('recherche', 'fondamentale'), ['NOM', 'ADJ']],
#  [('unité', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('recherche', 'clinique'), ['NOM', 'ADJ']],
#  [('efforts', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('traitement', 'endovasculaire'), ['NOM', 'ADJ']],
#  [('modèles', 'animaux'), ['NOM', 'ADJ']],
#  [('unité', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('recherche', 'clinique'), ['NOM', 'ADJ']],
#  [('études', 'cliniques'), ['NOM', 'ADJ']],
#  [('gestion', 'des', 'données'), ['NOM', 'PRP:det', 'NOM']],
#  [('retraitement', 'des', 'dispositifs'), ['NOM', 'PRP:det', 'NOM']],
#  [('retraitement', 'des', 'dispositifs', 'médicaux'),
#   ['NOM', 'PRP:det', 'NOM', 'ADJ']],
#  [('dispositifs', 'médicaux'), ['NOM', 'ADJ']],
#  [('rôle', 'méconnu'), ['NOM', 'VER:pper']],
#  [('patients', 'reçoivent'), ['NOM', 'VER:pres']],
#  [('soins', 'de', 'qualité'), ['NOM', 'PRP', 'NOM']],
#  [('période', 'de', 'pandémie'), ['NOM', 'PRP', 'NOM']],
#  [('escouade', 'reconnaissance'), ['NOM', 'NOM']],
#  [('retraitement', 'des', 'dispositifs'), ['NOM', 'PRP:det', 'NOM']],
#  [('retraitement', 'des', 'dispositifs', 'médicaux'),
#   ['NOM', 'PRP:det', 'NOM', 'ADJ']],
#  [('dispositifs', 'médicaux'), ['NOM', 'ADJ']],
#  [('prélèvement', 'guide'), ['NOM', 'VER:pres']],
#  [('prélèvement', 'guide', 'de', 'votre', 'séjour'),
#   ['NOM', 'VER:pres', 'PRP', 'DET:POS', 'NOM']],
#  [('hôpital', 'avant', 'de', 'vous', 'rendre', 'à', "l'", 'urgence'),
#   ['NOM', 'PRP', 'PRP', 'PRO:PER', 'VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('radiologie', 'en', 'imagerie'), ['NOM', 'PRP', 'NOM']],
#  [('visite', 'ce', 'jour'), ['NOM', 'PRO:DEM', 'NOM']],
#  [('jour', 'dans', 'votre', 'ch', 'pour', 'des', 'biopsies'),
#   ['NOM', 'PRP', 'DET:POS', 'NOM', 'KON', 'PRP:det', 'NOM']],
#  [('prélèvement', 'guide'), ['NOM', 'VER:pres']],
#  [('prélèvement', 'guide', 'de', 'votre', 'séjour'),
#   ['NOM', 'VER:pres', 'PRP', 'DET:POS', 'NOM']],
#  [('hôpital', 'avant', 'de', 'vous', 'rendre', 'à', "l'", 'urgence'),
#   ['NOM', 'PRP', 'PRP', 'PRO:PER', 'VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('traitement', 'intraveineux'), ['NOM', 'ADJ']],
#  [('fuite', "d'", 'un', 'médicament'), ['NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('fuite', "d'", 'un', 'médicament', 'hors', 'des', 'veines'),
#   ['NOM', 'PRP', 'DET:ART', 'NOM', 'PRP', 'PRP:det', 'NOM']],
#  [('médicament', 'hors', 'des', 'veines'), ['NOM', 'PRP', 'PRP:det', 'NOM']],
#  [('fiche', 'vous', 'explique'), ['NOM', 'PRO:PER', 'VER:pres']],
#  [('fiche', 'vous', 'explique', 'ce', "qu'"),
#   ['NOM', 'PRO:PER', 'VER:pres', 'PRO:DEM', 'PRO:REL']],
#  [('signes', 'et', 'symptômes'), ['NOM', 'KON', 'NOM']],
#  [('symptômes', 'à', 'surveiller'), ['NOM', 'PRP', 'VER:infi']],
#  [('fiche', 'recherche'), ['NOM', 'VER:pres']],
#  [('prélèvement', 'guide'), ['NOM', 'VER:pres']],
#  [('prélèvement', 'guide', 'de', 'votre', 'séjour'),
#   ['NOM', 'VER:pres', 'PRP', 'DET:POS', 'NOM']],
#  [('hôpital', 'avant', 'de', 'vous', 'rendre', 'à', "l'", 'urgence'),
#   ['NOM', 'PRP', 'PRP', 'PRO:PER', 'VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('ans', 'nellie'), ['NOM', 'VER:pper']],
#  [('ans', 'axelle'), ['NOM', 'VER:pres']],
#  [('ans', 'à', 'chaque', 'soir'), ['NOM', 'PRP', 'PRO:IND', 'NOM']],
#  [('prélèvement', 'guide'), ['NOM', 'VER:pres']],
#  [('prélèvement', 'guide', 'de', 'votre', 'séjour'),
#   ['NOM', 'VER:pres', 'PRP', 'DET:POS', 'NOM']],
#  [('hôpital', 'avant', 'de', 'vous', 'rendre', 'à', "l'", 'urgence'),
#   ['NOM', 'PRP', 'PRP', 'PRO:PER', 'VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('prélèvement', 'guide'), ['NOM', 'VER:pres']],
#  [('prélèvement', 'guide', 'de', 'votre', 'séjour'),
#   ['NOM', 'VER:pres', 'PRP', 'DET:POS', 'NOM']],
#  [('hôpital', 'avant', 'de', 'vous', 'rendre', 'à', "l'", 'urgence'),
#   ['NOM', 'PRP', 'PRP', 'PRO:PER', 'VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('mccpm', 'chercheur'), ['NOM', 'ADJ']],
#  [('santé', 'centre'), ['NOM', 'NOM']],
#  [('santé', 'centre', 'de', 'recherche'), ['NOM', 'NOM', 'PRP', 'NOM']],
#  [('santé', 'centre', 'de', 'recherche', 'du', 'chum'),
#   ['NOM', 'NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('santé', 'centre', 'de', 'recherche', 'du', 'chum', 'axe'),
#   ['NOM', 'NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'NOM']],
#  [('centre', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('centre', 'de', 'recherche', 'du', 'chum'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('centre', 'de', 'recherche', 'du', 'chum', 'axe'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'NOM']],
#  [('centre', 'de', 'recherche', 'du', 'chum', 'axe', 'de', 'recherche'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'NOM', 'PRP', 'NOM']],
#  [('recherche', 'du', 'chum'), ['NOM', 'PRP:det', 'NOM']],
#  [('recherche', 'du', 'chum', 'axe'), ['NOM', 'PRP:det', 'NOM', 'NOM']],
#  [('recherche', 'du', 'chum', 'axe', 'de', 'recherche'),
#   ['NOM', 'PRP:det', 'NOM', 'NOM', 'PRP', 'NOM']],
#  [('recherche', 'du', 'chum', 'axe', 'de', 'recherche', 'imagerie'),
#   ['NOM', 'PRP:det', 'NOM', 'NOM', 'PRP', 'NOM', 'NOM']],
#  [('chum', 'axe'), ['NOM', 'NOM']],
#  [('chum', 'axe', 'de', 'recherche'), ['NOM', 'NOM', 'PRP', 'NOM']],
#  [('chum', 'axe', 'de', 'recherche', 'imagerie'),
#   ['NOM', 'NOM', 'PRP', 'NOM', 'NOM']],
#  [('chum', 'axe', 'de', 'recherche', 'imagerie', 'et', 'ingénierie'),
#   ['NOM', 'NOM', 'PRP', 'NOM', 'NOM', 'KON', 'NOM']],
#  [('chum',
#    'axe',
#    'de',
#    'recherche',
#    'imagerie',
#    'et',
#    'ingénierie',
#    'physicien'),
#   ['NOM', 'NOM', 'PRP', 'NOM', 'NOM', 'KON', 'NOM', 'NOM']],
#  [('axe', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('axe', 'de', 'recherche', 'imagerie'), ['NOM', 'PRP', 'NOM', 'NOM']],
#  [('axe', 'de', 'recherche', 'imagerie', 'et', 'ingénierie'),
#   ['NOM', 'PRP', 'NOM', 'NOM', 'KON', 'NOM']],
#  [('axe', 'de', 'recherche', 'imagerie', 'et', 'ingénierie', 'physicien'),
#   ['NOM', 'PRP', 'NOM', 'NOM', 'KON', 'NOM', 'NOM']],
#  [('recherche', 'imagerie'), ['NOM', 'NOM']],
#  [('recherche', 'imagerie', 'et', 'ingénierie'), ['NOM', 'NOM', 'KON', 'NOM']],
#  [('recherche', 'imagerie', 'et', 'ingénierie', 'physicien'),
#   ['NOM', 'NOM', 'KON', 'NOM', 'NOM']],
#  [('imagerie', 'et', 'ingénierie'), ['NOM', 'KON', 'NOM']],
#  [('imagerie', 'et', 'ingénierie', 'physicien'), ['NOM', 'KON', 'NOM', 'NOM']],
#  [('ingénierie', 'physicien'), ['NOM', 'NOM']],
#  [('patient', 'qui', 'a', 'besoin'), ['NOM', 'PRO:REL', 'VER:pres', 'NOM']],
#  [('patient', 'qui', 'a', 'besoin', "d'", 'assistance'),
#   ['NOM', 'PRO:REL', 'VER:pres', 'NOM', 'PRP', 'NOM']],
#  [('patient', 'qui', 'a', 'besoin', "d'", 'assistance', 'immédiate'),
#   ['NOM', 'PRO:REL', 'VER:pres', 'NOM', 'PRP', 'NOM', 'ADJ']],
#  [('besoin', "d'", 'assistance'), ['NOM', 'PRP', 'NOM']],
#  [('besoin', "d'", 'assistance', 'immédiate'), ['NOM', 'PRP', 'NOM', 'ADJ']],
#  [('besoin',
#    "d'",
#    'assistance',
#    'immédiate',
#    'ne',
#    'doit',
#    'pas',
#    'communiquer'),
#   ['NOM', 'PRP', 'NOM', 'ADJ', 'ADV', 'VER:pres', 'ADV', 'VER:infi']],
#  [('assistance', 'immédiate'), ['NOM', 'ADJ']],
#  [('assistance', 'immédiate', 'ne', 'doit', 'pas', 'communiquer'),
#   ['NOM', 'ADJ', 'ADV', 'VER:pres', 'ADV', 'VER:infi']],
#  [('cabinet', 'du', 'médecin'), ['NOM', 'PRP:det', 'NOM']],
#  [('cabinet', 'du', 'médecin', 'ou', 'prendre'),
#   ['NOM', 'PRP:det', 'NOM', 'KON', 'VER:infi']],
#  [('cabinet', 'du', 'médecin', 'ou', 'prendre', "d'", 'autres', 'mesures'),
#   ['NOM', 'PRP:det', 'NOM', 'KON', 'VER:infi', 'PRP', 'ADJ', 'NOM']],
#  [('médecin', 'ou', 'prendre'), ['NOM', 'KON', 'VER:infi']],
#  [('médecin', 'ou', 'prendre', "d'", 'autres', 'mesures'),
#   ['NOM', 'KON', 'VER:infi', 'PRP', 'ADJ', 'NOM']],
#  [('médecin', 'ou', 'prendre', "d'", 'autres', 'mesures', 'appropriées'),
#   ['NOM', 'KON', 'VER:infi', 'PRP', 'ADJ', 'NOM', 'ADJ']],
#  [('mesures', 'appropriées'), ['NOM', 'ADJ']],
#  [('service', "d'", 'urgence'), ['NOM', 'PRP', 'NOM']],
#  [('intérêts', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('intérêts', 'de', 'recherche', 'développement'),
#   ['NOM', 'PRP', 'NOM', 'NOM']],
#  [('recherche', 'développement'), ['NOM', 'NOM']],
#  [('développement', 'de', 'techniques'), ['NOM', 'PRP', 'NOM']],
#  [('recherche', 'préclinique'), ['NOM', 'ADJ']],
#  [('scholar', 'recherche'), ['NOM', 'NOM']],
#  [('prélèvement', 'guide'), ['NOM', 'VER:pres']],
#  [('prélèvement', 'guide', 'de', 'votre', 'séjour'),
#   ['NOM', 'VER:pres', 'PRP', 'DET:POS', 'NOM']],
#  [('hôpital', 'avant', 'de', 'vous', 'rendre', 'à', "l'", 'urgence'),
#   ['NOM', 'PRP', 'PRP', 'PRO:PER', 'VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('travail', 'exceptionnel'), ['NOM', 'ADJ']],
#  [('biologiste', 'moléculaire'), ['NOM', 'ADJ']],
#  [('biologiste', 'moléculaire', 'au', 'laboratoire'),
#   ['NOM', 'ADJ', 'PRP:det', 'NOM']],
#  [('biologiste', 'moléculaire', 'au', 'laboratoire', 'de', 'biologie'),
#   ['NOM', 'ADJ', 'PRP:det', 'NOM', 'PRP', 'NOM']],
#  [('biologiste',
#    'moléculaire',
#    'au',
#    'laboratoire',
#    'de',
#    'biologie',
#    'moléculaire'),
#   ['NOM', 'ADJ', 'PRP:det', 'NOM', 'PRP', 'NOM', 'ADJ']],
#  [('laboratoire', 'de', 'biologie'), ['NOM', 'PRP', 'NOM']],
#  [('laboratoire', 'de', 'biologie', 'moléculaire'),
#   ['NOM', 'PRP', 'NOM', 'ADJ']],
#  [('laboratoire', 'de', 'biologie', 'moléculaire', 'du', 'chum'),
#   ['NOM', 'PRP', 'NOM', 'ADJ', 'PRP:det', 'NOM']],
#  [('biologie', 'moléculaire'), ['NOM', 'ADJ']],
#  [('biologie', 'moléculaire', 'du', 'chum'), ['NOM', 'ADJ', 'PRP:det', 'NOM']],
#  [('population', 'du', 'québec'), ['NOM', 'PRP:det', 'NOM']],
#  [('prélèvement', 'guide'), ['NOM', 'VER:pres']],
#  [('prélèvement', 'guide', 'de', 'votre', 'séjour'),
#   ['NOM', 'VER:pres', 'PRP', 'DET:POS', 'NOM']],
#  [('hôpital', 'avant', 'de', 'vous', 'rendre', 'à', "l'", 'urgence'),
#   ['NOM', 'PRP', 'PRP', 'PRO:PER', 'VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('urgence', 'salle'), ['NOM', 'NOM']],
#  [('urgence', 'salle', 'de', 'formation'), ['NOM', 'NOM', 'PRP', 'NOM']],
#  [('salle', 'de', 'formation'), ['NOM', 'PRP', 'NOM']],
#  [('projection', 'ordinateur'), ['NOM', 'ADJ']],
#  [('projection', 'ordinateur', 'au', 'lutrin'),
#   ['NOM', 'ADJ', 'PRP:det', 'NOM']],
#  [('projection', 'ordinateur', 'au', 'lutrin', 'avec', 'possibilité'),
#   ['NOM', 'ADJ', 'PRP:det', 'NOM', 'PRP', 'NOM']],
#  [('projection',
#    'ordinateur',
#    'au',
#    'lutrin',
#    'avec',
#    'possibilité',
#    'de',
#    'brancher'),
#   ['NOM', 'ADJ', 'PRP:det', 'NOM', 'PRP', 'NOM', 'PRP', 'VER:infi']],
#  [('lutrin', 'avec', 'possibilité'), ['NOM', 'PRP', 'NOM']],
#  [('lutrin', 'avec', 'possibilité', 'de', 'brancher'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'VER:infi']],
#  [('lutrin', 'avec', 'possibilité', 'de', 'brancher', 'un', 'portable'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'VER:infi', 'DET:ART', 'ADJ']],
#  [('lutrin',
#    'avec',
#    'possibilité',
#    'de',
#    'brancher',
#    'un',
#    'portable',
#    'internet'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'VER:infi', 'DET:ART', 'ADJ', 'NOM']],
#  [('possibilité', 'de', 'brancher'), ['NOM', 'PRP', 'VER:infi']],
#  [('possibilité', 'de', 'brancher', 'un', 'portable'),
#   ['NOM', 'PRP', 'VER:infi', 'DET:ART', 'ADJ']],
#  [('possibilité', 'de', 'brancher', 'un', 'portable', 'internet'),
#   ['NOM', 'PRP', 'VER:infi', 'DET:ART', 'ADJ', 'NOM']],
#  [('possibilité',
#    'de',
#    'brancher',
#    'un',
#    'portable',
#    'internet',
#    'sans',
#    'fil'),
#   ['NOM', 'PRP', 'VER:infi', 'DET:ART', 'ADJ', 'NOM', 'PRP', 'NOM']],
#  [('internet', 'sans', 'fil'), ['NOM', 'PRP', 'NOM']],
#  [('internet', 'sans', 'fil', '(', 'île', 'sans-fil', 'chum', ')'),
#   ['NOM', 'PRP', 'NOM', 'PUN', 'NOM', 'NOM', 'NOM', 'PUN']],
#  [('fil', '(', 'île', 'sans-fil', 'chum', ')'),
#   ['NOM', 'PUN', 'NOM', 'NOM', 'NOM', 'PUN']],
#  [('île', 'sans-fil'), ['NOM', 'NOM']],
#  [('île', 'sans-fil', 'chum'), ['NOM', 'NOM', 'NOM']],
#  [('sans-fil', 'chum'), ['NOM', 'NOM']],
#  [('salles', 'recherche'), ['NOM', 'VER:pres']],
#  [('fiche', 'vous', 'explique'), ['NOM', 'PRO:PER', 'VER:pres']],
#  [('fiche', 'recherche'), ['NOM', 'VER:pres']],
#  [('prélèvement', 'guide'), ['NOM', 'VER:pres']],
#  [('prélèvement', 'guide', 'de', 'votre', 'séjour'),
#   ['NOM', 'VER:pres', 'PRP', 'DET:POS', 'NOM']],
#  [('hôpital', 'avant', 'de', 'vous', 'rendre', 'à', "l'", 'urgence'),
#   ['NOM', 'PRP', 'PRP', 'PRO:PER', 'VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('cadre', 'du', 'concours'), ['NOM', 'PRP:det', 'NOM']],
#  [('cadre', 'du', 'concours', 'de', 'subventions'),
#   ['NOM', 'PRP:det', 'NOM', 'PRP', 'NOM']],
#  [('cadre', 'du', 'concours', 'de', 'subventions', 'projet'),
#   ['NOM', 'PRP:det', 'NOM', 'PRP', 'NOM', 'NOM']],
#  [('concours', 'de', 'subventions'), ['NOM', 'PRP', 'NOM']],
#  [('concours', 'de', 'subventions', 'projet'), ['NOM', 'PRP', 'NOM', 'NOM']],
#  [('subventions', 'projet'), ['NOM', 'NOM']],
#  [('instituts', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('instituts', 'de', 'recherche', 'en', 'santé'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'NOM']],
#  [('instituts', 'de', 'recherche', 'en', 'santé', 'du', 'canada'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('recherche', 'en', 'santé'), ['NOM', 'PRP', 'NOM']],
#  [('recherche', 'en', 'santé', 'du', 'canada'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('recherche', 'en', 'santé', 'du', 'canada', '(', 'irsc', ')'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'PUN', 'NOM', 'PUN']],
#  [('santé', 'du', 'canada'), ['NOM', 'PRP:det', 'NOM']],
#  [('santé', 'du', 'canada', '(', 'irsc', ')'),
#   ['NOM', 'PRP:det', 'NOM', 'PUN', 'NOM', 'PUN']],
#  [('canada', '(', 'irsc', ')'), ['NOM', 'PUN', 'NOM', 'PUN']],
#  [('équipes', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('équipes', 'de', 'recherche', 'du', 'centre'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('équipes', 'de', 'recherche', 'du', 'centre', 'de', 'recherche'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'PRP', 'NOM']],
#  [('recherche', 'du', 'centre'), ['NOM', 'PRP:det', 'NOM']],
#  [('recherche', 'du', 'centre', 'de', 'recherche'),
#   ['NOM', 'PRP:det', 'NOM', 'PRP', 'NOM']],
#  [('recherche', 'du', 'centre', 'de', 'recherche', 'du', 'chum'),
#   ['NOM', 'PRP:det', 'NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('centre', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('centre', 'de', 'recherche', 'du', 'chum'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('centre', 'de', 'recherche', 'du', 'chum', '(', 'crchum', ')'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'PUN', 'NOM', 'PUN']],
#  [('recherche', 'du', 'chum'), ['NOM', 'PRP:det', 'NOM']],
#  [('recherche', 'du', 'chum', '(', 'crchum', ')'),
#   ['NOM', 'PRP:det', 'NOM', 'PUN', 'NOM', 'PUN']],
#  [('chum', '(', 'crchum', ')'), ['NOM', 'PUN', 'NOM', 'PUN']],
#  [('demandes', 'financées'), ['NOM', 'VER:pper']],
#  [('taux', 'de', 'succès'), ['NOM', 'PRP', 'NOM']],
#  [('taux', 'de', 'succès', 'du', 'crchum'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('taux', 'de', 'succès', 'du', 'crchum', 'se', 'situe'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'PRO:PER', 'VER:pres']],
#  [('taux', 'de', 'succès', 'du', 'crchum', 'se', 'situe', 'largement'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'PRO:PER', 'VER:pres', 'ADV']],
#  [('succès', 'du', 'crchum'), ['NOM', 'PRP:det', 'NOM']],
#  [('succès', 'du', 'crchum', 'se', 'situe'),
#   ['NOM', 'PRP:det', 'NOM', 'PRO:PER', 'VER:pres']],
#  [('succès', 'du', 'crchum', 'se', 'situe', 'largement'),
#   ['NOM', 'PRP:det', 'NOM', 'PRO:PER', 'VER:pres', 'ADV']],
#  [('succès', 'du', 'crchum', 'se', 'situe', 'largement', 'au-dessus'),
#   ['NOM', 'PRP:det', 'NOM', 'PRO:PER', 'VER:pres', 'ADV', 'ADV']],
#  [('crchum', 'se', 'situe'), ['NOM', 'PRO:PER', 'VER:pres']],
#  [('crchum', 'se', 'situe', 'largement'),
#   ['NOM', 'PRO:PER', 'VER:pres', 'ADV']],
#  [('crchum', 'se', 'situe', 'largement', 'au-dessus'),
#   ['NOM', 'PRO:PER', 'VER:pres', 'ADV', 'ADV']],
#  [('crchum', 'se', 'situe', 'largement', 'au-dessus', 'de', 'la', 'moyenne'),
#   ['NOM', 'PRO:PER', 'VER:pres', 'ADV', 'ADV', 'PRP', 'DET:ART', 'NOM']],
#  [('crchum', 'tient'), ['NOM', 'VER:pres']],
#  [('greg', 'fitzharris'), ['NOM', 'ADJ']],
#  [('subvention', 'projet'), ['NOM', 'NOM']],
#  [('subvention', 'projet', 'octroyée'), ['NOM', 'NOM', 'VER:pper']],
#  [('projet', 'octroyée'), ['NOM', 'VER:pper']],
#  [('marie-hélène', 'mayrand'), ['NOM', 'ADJ']],
#  [('subvention', 'projet'), ['NOM', 'NOM']],
#  [('subvention', 'projet', 'octroyée'), ['NOM', 'NOM', 'VER:pper']],
#  [('projet', 'octroyée'), ['NOM', 'VER:pper']],
#  [('subvention', 'projet'), ['NOM', 'NOM']],
#  [('subvention', 'projet', 'octroyée'), ['NOM', 'NOM', 'VER:pper']],
#  [('projet', 'octroyée'), ['NOM', 'VER:pper']],
#  [('subvention', 'projet'), ['NOM', 'NOM']],
#  [('subvention', 'projet', 'octroyée'), ['NOM', 'NOM', 'VER:pper']],
#  [('projet', 'octroyée'), ['NOM', 'VER:pper']],
#  [('subvention', 'projet'), ['NOM', 'NOM']],
#  [('subvention', 'projet', 'octroyée'), ['NOM', 'NOM', 'VER:pper']],
#  [('projet', 'octroyée'), ['NOM', 'VER:pper']],
#  [('subvention', 'projet'), ['NOM', 'NOM']],
#  [('subvention', 'projet', 'octroyée'), ['NOM', 'NOM', 'VER:pper']],
#  [('projet', 'octroyée'), ['NOM', 'VER:pper']],
#  [('subvention', 'projet'), ['NOM', 'NOM']],
#  [('subvention', 'projet', 'octroyée'), ['NOM', 'NOM', 'VER:pper']],
#  [('projet', 'octroyée'), ['NOM', 'VER:pper']],
#  [('shao-ling', 'zhang'), ['NOM', 'NOM']],
#  [('subventions', 'projet'), ['NOM', 'NOM']],
#  [('instituts', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('instituts', 'de', 'recherche', 'en', 'santé'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'NOM']],
#  [('instituts', 'de', 'recherche', 'en', 'santé', 'du', 'canada'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('instituts', 'de', 'recherche', 'en', 'santé', 'du', 'canada', 'financent'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'VER:pres']],
#  [('recherche', 'en', 'santé'), ['NOM', 'PRP', 'NOM']],
#  [('recherche', 'en', 'santé', 'du', 'canada'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('recherche', 'en', 'santé', 'du', 'canada', 'financent'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'VER:pres']],
#  [('santé', 'du', 'canada'), ['NOM', 'PRP:det', 'NOM']],
#  [('santé', 'du', 'canada', 'financent'),
#   ['NOM', 'PRP:det', 'NOM', 'VER:pres']],
#  [('canada', 'financent'), ['NOM', 'VER:pres']],
#  [('millions', 'de', 'dollars'), ['NOM', 'PRP', 'NOM']],
#  [('taux', 'de', 'succès'), ['NOM', 'PRP', 'NOM']],
#  [('résultats', 'de', 'concours'), ['NOM', 'PRP', 'NOM']],
#  [('résultats', 'de', 'concours', 'des', 'irsc'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('concours', 'des', 'irsc'), ['NOM', 'PRP:det', 'NOM']],
#  [('concours',
#    'des',
#    'irsc',
#    'facebook',
#    'twitter',
#    'linkedin',
#    'print',
#    'recherche'),
#   ['NOM', 'PRP:det', 'NOM', 'ADJ', 'NOM', 'ADJ', 'ADJ', 'NOM']],
#  [('irsc', 'facebook', 'twitter', 'linkedin', 'print', 'recherche'),
#   ['NOM', 'ADJ', 'NOM', 'ADJ', 'ADJ', 'NOM']],
#  [('centre', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('centre', 'de', 'recherche', 'du', 'chum'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('centre', 'de', 'recherche', 'du', 'chum', 'axe'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'NOM']],
#  [('centre', 'de', 'recherche', 'du', 'chum', 'axe', 'de', 'recherche'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'NOM', 'PRP', 'NOM']],
#  [('recherche', 'du', 'chum'), ['NOM', 'PRP:det', 'NOM']],
#  [('recherche', 'du', 'chum', 'axe'), ['NOM', 'PRP:det', 'NOM', 'NOM']],
#  [('recherche', 'du', 'chum', 'axe', 'de', 'recherche'),
#   ['NOM', 'PRP:det', 'NOM', 'NOM', 'PRP', 'NOM']],
#  [('recherche', 'du', 'chum', 'axe', 'de', 'recherche', 'cardiométabolique'),
#   ['NOM', 'PRP:det', 'NOM', 'NOM', 'PRP', 'NOM', 'ADJ']],
#  [('recherche',
#    'du',
#    'chum',
#    'axe',
#    'de',
#    'recherche',
#    'cardiométabolique',
#    'directeur'),
#   ['NOM', 'PRP:det', 'NOM', 'NOM', 'PRP', 'NOM', 'ADJ', 'ADJ']],
#  [('chum', 'axe'), ['NOM', 'NOM']],
#  [('chum', 'axe', 'de', 'recherche'), ['NOM', 'NOM', 'PRP', 'NOM']],
#  [('chum', 'axe', 'de', 'recherche', 'cardiométabolique'),
#   ['NOM', 'NOM', 'PRP', 'NOM', 'ADJ']],
#  [('chum', 'axe', 'de', 'recherche', 'cardiométabolique', 'directeur'),
#   ['NOM', 'NOM', 'PRP', 'NOM', 'ADJ', 'ADJ']],
#  [('chum',
#    'axe',
#    'de',
#    'recherche',
#    'cardiométabolique',
#    'directeur',
#    'laboratoire'),
#   ['NOM', 'NOM', 'PRP', 'NOM', 'ADJ', 'ADJ', 'NOM']],
#  [('axe', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('axe', 'de', 'recherche', 'cardiométabolique'),
#   ['NOM', 'PRP', 'NOM', 'ADJ']],
#  [('axe', 'de', 'recherche', 'cardiométabolique', 'directeur'),
#   ['NOM', 'PRP', 'NOM', 'ADJ', 'ADJ']],
#  [('axe', 'de', 'recherche', 'cardiométabolique', 'directeur', 'laboratoire'),
#   ['NOM', 'PRP', 'NOM', 'ADJ', 'ADJ', 'NOM']],
#  [('recherche', 'cardiométabolique'), ['NOM', 'ADJ']],
#  [('recherche', 'cardiométabolique', 'directeur'), ['NOM', 'ADJ', 'ADJ']],
#  [('recherche', 'cardiométabolique', 'directeur', 'laboratoire'),
#   ['NOM', 'ADJ', 'ADJ', 'NOM']],
#  [('crchum', 'professeur'), ['NOM', 'NOM']],
#  [('professeur', 'sous', 'octroi'), ['NOM', 'PRP', 'NOM']],
#  [('octroi', 'titulaire'), ['NOM', 'ADJ']],
#  [('octroi', 'titulaire', 'département'), ['NOM', 'ADJ', 'NOM']],
#  [('octroi', 'titulaire', 'département', 'de', 'médecine'),
#   ['NOM', 'ADJ', 'NOM', 'PRP', 'NOM']],
#  [('département', 'de', 'médecine'), ['NOM', 'PRP', 'NOM']],
#  [('patient', 'qui', 'a', 'besoin'), ['NOM', 'PRO:REL', 'VER:pres', 'NOM']],
#  [('patient', 'qui', 'a', 'besoin', "d'", 'assistance'),
#   ['NOM', 'PRO:REL', 'VER:pres', 'NOM', 'PRP', 'NOM']],
#  [('patient', 'qui', 'a', 'besoin', "d'", 'assistance', 'immédiate'),
#   ['NOM', 'PRO:REL', 'VER:pres', 'NOM', 'PRP', 'NOM', 'ADJ']],
#  [('besoin', "d'", 'assistance'), ['NOM', 'PRP', 'NOM']],
#  [('besoin', "d'", 'assistance', 'immédiate'), ['NOM', 'PRP', 'NOM', 'ADJ']],
#  [('besoin',
#    "d'",
#    'assistance',
#    'immédiate',
#    'ne',
#    'doit',
#    'pas',
#    'communiquer'),
#   ['NOM', 'PRP', 'NOM', 'ADJ', 'ADV', 'VER:pres', 'ADV', 'VER:infi']],
#  [('assistance', 'immédiate'), ['NOM', 'ADJ']],
#  [('assistance', 'immédiate', 'ne', 'doit', 'pas', 'communiquer'),
#   ['NOM', 'ADJ', 'ADV', 'VER:pres', 'ADV', 'VER:infi']],
#  [('cabinet', 'du', 'médecin'), ['NOM', 'PRP:det', 'NOM']],
#  [('cabinet', 'du', 'médecin', 'ou', 'prendre'),
#   ['NOM', 'PRP:det', 'NOM', 'KON', 'VER:infi']],
#  [('cabinet', 'du', 'médecin', 'ou', 'prendre', "d'", 'autres', 'mesures'),
#   ['NOM', 'PRP:det', 'NOM', 'KON', 'VER:infi', 'PRP', 'ADJ', 'NOM']],
#  [('médecin', 'ou', 'prendre'), ['NOM', 'KON', 'VER:infi']],
#  [('médecin', 'ou', 'prendre', "d'", 'autres', 'mesures'),
#   ['NOM', 'KON', 'VER:infi', 'PRP', 'ADJ', 'NOM']],
#  [('médecin', 'ou', 'prendre', "d'", 'autres', 'mesures', 'appropriées'),
#   ['NOM', 'KON', 'VER:infi', 'PRP', 'ADJ', 'NOM', 'ADJ']],
#  [('mesures', 'appropriées'), ['NOM', 'ADJ']],
#  [('service', "d'", 'urgence'), ['NOM', 'PRP', 'NOM']],
#  [('néphropathie', 'diabétique'), ['NOM', 'ADJ']],
#  [('apoptose', 'tubulaire'), ['NOM', 'ADJ']],
#  [('espèces', 'réactives'), ['NOM', 'ADJ']],
#  [('signaux', 'cellulaires'), ['NOM', 'ADJ']],
#  [('régulation', 'des', 'gènes'), ['NOM', 'PRP:det', 'NOM']],
#  [('biologie', 'moléculaire'), ['NOM', 'ADJ']],
#  [('puces', 'à', 'adn'), ['NOM', 'PRP', 'NOM']],
#  [('modèles', 'de', 'souris'), ['NOM', 'PRP', 'NOM']],
#  [('modèles', 'de', 'souris', 'transgéniques'), ['NOM', 'PRP', 'NOM', 'ADJ']],
#  [('souris', 'transgéniques'), ['NOM', 'ADJ']],
#  [('intérêts', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('néphropathie', 'diabétique'), ['NOM', 'ADJ']],
#  [('apoptose', 'tubulaire'), ['NOM', 'ADJ']],
#  [('souris', 'transgéniques'), ['NOM', 'ADJ']],
#  [('mécanismes', 'moléculaires'), ['NOM', 'ADJ']],
#  [('apoptose', 'tubulaire'), ['NOM', 'ADJ']],
#  [('puces', 'à', 'adn'), ['NOM', 'PRP', 'NOM']],
#  [('vitro', 'et', 'in', 'vivo'), ['NOM', 'KON', 'ADJ', 'ADV']],
#  [('succès', 'facebook', 'twitter', 'linkedin', 'print', 'recherche'),
#   ['NOM', 'ADJ', 'NOM', 'ADJ', 'ADJ', 'NOM']],
#  [('prélèvement', 'guide'), ['NOM', 'VER:pres']],
#  [('prélèvement', 'guide', 'de', 'votre', 'séjour'),
#   ['NOM', 'VER:pres', 'PRP', 'DET:POS', 'NOM']],
#  [('hôpital', 'avant', 'de', 'vous', 'rendre', 'à', "l'", 'urgence'),
#   ['NOM', 'PRP', 'PRP', 'PRO:PER', 'VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('phénotypage', 'de', 'rongeurs'), ['NOM', 'PRP', 'NOM']],
#  [('cages', 'métaboliques'), ['NOM', 'ADJ']],
#  [('plateforme', 'possède'), ['NOM', 'VER:pres']],
#  [('projets', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('analyse', 'des', 'données'), ['NOM', 'PRP:det', 'NOM']],
#  [('services', 'sont', 'disponibles'), ['NOM', 'VER:pres', 'ADJ']],
#  [('services', 'sont', 'disponibles', 'pour', 'les', 'chercheurs'),
#   ['NOM', 'VER:pres', 'ADJ', 'PRP', 'DET:ART', 'NOM']],
#  [('services',
#    'sont',
#    'disponibles',
#    'pour',
#    'les',
#    'chercheurs',
#    'des',
#    'milieux'),
#   ['NOM', 'VER:pres', 'ADJ', 'PRP', 'DET:ART', 'NOM', 'PRP:det', 'NOM']],
#  [('chercheurs', 'des', 'milieux'), ['NOM', 'PRP:det', 'NOM']],
#  [('chercheurs', 'des', 'milieux', 'universitaires'),
#   ['NOM', 'PRP:det', 'NOM', 'ADJ']],
#  [('milieux', 'universitaires'), ['NOM', 'ADJ']],
#  [('sécrétion', "d'", 'insuline'), ['NOM', 'PRP', 'NOM']],
#  [('homéostasie', 'glucidique'), ['NOM', 'ADJ']],
#  [('sécrétion', "d'", 'insuline'), ['NOM', 'PRP', 'NOM']],
#  [('cages', 'métaboliques'), ['NOM', 'ADJ']],
#  [('modèles', 'expérimentaux'), ['NOM', 'ADJ']],
#  [('services', 'demande'), ['NOM', 'VER:pres']],
#  [('services', 'demande', 'de', 'service'), ['NOM', 'VER:pres', 'PRP', 'NOM']],
#  [('services', 'demande', 'de', 'service', 'pour', 'toute', 'demande'),
#   ['NOM', 'VER:pres', 'PRP', 'NOM', 'PRP', 'PRO:IND', 'NOM']],
#  [('service', 'pour', 'toute', 'demande'), ['NOM', 'PRP', 'PRO:IND', 'NOM']],
#  [('service', 'pour', 'toute', 'demande', 'de', 'soumission'),
#   ['NOM', 'PRP', 'PRO:IND', 'NOM', 'PRP', 'NOM']],
#  [('demande', 'de', 'soumission'), ['NOM', 'PRP', 'NOM']],
#  [('demande', 'de', 'soumission', 'ou', 'de', 'service'),
#   ['NOM', 'PRP', 'NOM', 'KON', 'PRP', 'NOM']],
#  [('soumission', 'ou', 'de', 'service'), ['NOM', 'KON', 'PRP', 'NOM']],
#  [('santé', 'animale'), ['NOM', 'ADJ']],
#  [('conseiller', 'scientifique'), ['NOM', 'ADJ']],
#  [('thierry', 'alquier'), ['NOM', 'NOM']],
#  [('plateformes', 'et', 'services'), ['NOM', 'KON', 'NOM']],
#  [('plateformes', 'et', 'services', 'recherche'),
#   ['NOM', 'KON', 'NOM', 'VER:pres']],
#  [('plateformes', 'et', 'services', 'recherche', 'les', 'plateformes'),
#   ['NOM', 'KON', 'NOM', 'VER:pres', 'DET:ART', 'NOM']],
#  [('plateformes',
#    'et',
#    'services',
#    'recherche',
#    'les',
#    'plateformes',
#    'et',
#    'services'),
#   ['NOM', 'KON', 'NOM', 'VER:pres', 'DET:ART', 'NOM', 'KON', 'NOM']],
#  [('services', 'recherche'), ['NOM', 'VER:pres']],
#  [('services', 'recherche', 'les', 'plateformes'),
#   ['NOM', 'VER:pres', 'DET:ART', 'NOM']],
#  [('services', 'recherche', 'les', 'plateformes', 'et', 'services'),
#   ['NOM', 'VER:pres', 'DET:ART', 'NOM', 'KON', 'NOM']],
#  [('services',
#    'recherche',
#    'les',
#    'plateformes',
#    'et',
#    'services',
#    'du',
#    'crchum'),
#   ['NOM', 'VER:pres', 'DET:ART', 'NOM', 'KON', 'NOM', 'PRP:det', 'NOM']],
#  [('plateformes', 'et', 'services'), ['NOM', 'KON', 'NOM']],
#  [('plateformes', 'et', 'services', 'du', 'crchum'),
#   ['NOM', 'KON', 'NOM', 'PRP:det', 'NOM']],
#  [('services', 'du', 'crchum'), ['NOM', 'PRP:det', 'NOM']],
#  [('demande', "d'", 'information', 'sur', 'les', 'plateformes'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('demande',
#    "d'",
#    'information',
#    'sur',
#    'les',
#    'plateformes',
#    'et',
#    'services'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'DET:ART', 'NOM', 'KON', 'NOM']],
#  [('plateformes', 'et', 'services'), ['NOM', 'KON', 'NOM']],
#  [('plateformes', 'et', 'services', 'du', 'crchum'),
#   ['NOM', 'KON', 'NOM', 'PRP:det', 'NOM']],
#  [('services', 'du', 'crchum'), ['NOM', 'PRP:det', 'NOM']],
#  [('performance', 'scientifique'), ['NOM', 'ADJ']],
#  [('erik', 'joly'), ['NOM', 'ADJ']],
#  [('développement', 'de', 'la', 'recherche'),
#   ['NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('développement', 'de', 'la', 'recherche', 'et', 'des', 'plateformes'),
#   ['NOM', 'PRP', 'DET:ART', 'NOM', 'KON', 'PRP:det', 'NOM']],
#  [('recherche', 'et', 'des', 'plateformes'), ['NOM', 'KON', 'PRP:det', 'NOM']],
#  [('liste', 'des', 'responsables'), ['NOM', 'PRP:det', 'ADJ']],
#  [('liste', 'des', 'responsables', 'de', 'plateformes'),
#   ['NOM', 'PRP:det', 'ADJ', 'PRP', 'NOM']],
#  [('approches', 'pédagogiques'), ['NOM', 'ADJ']],
#  [('cours', 'de', 'réanimation'), ['NOM', 'PRP', 'NOM']],
#  [('simulation', 'clinique'), ['NOM', 'ADJ']],
#  [('saint-denis', 'montréal', '(', 'québec', ')'),
#   ['NOM', 'ADJ', 'PUN', 'NOM', 'PUN']],
#  [('demande', 'de', 'consultation'), ['NOM', 'PRP', 'NOM']],
#  [('saint-denis', 'montréal', '(', 'québec', ')'),
#   ['NOM', 'ADJ', 'PUN', 'NOM', 'PUN']],
#  [('demande', 'de', 'consultation'), ['NOM', 'PRP', 'NOM']],
#  [('médecin', 'de', 'famille'), ['NOM', 'PRP', 'NOM']],
#  [('médecin', 'de', 'famille', 'ou', 'votre', 'médecin'),
#   ['NOM', 'PRP', 'NOM', 'KON', 'DET:POS', 'NOM']],
#  [('médecin', 'de', 'famille', 'ou', 'votre', 'médecin', 'spécialiste'),
#   ['NOM', 'PRP', 'NOM', 'KON', 'DET:POS', 'NOM', 'NOM']],
#  [('famille', 'ou', 'votre', 'médecin'), ['NOM', 'KON', 'DET:POS', 'NOM']],
#  [('famille', 'ou', 'votre', 'médecin', 'spécialiste'),
#   ['NOM', 'KON', 'DET:POS', 'NOM', 'NOM']],
#  [('famille', 'ou', 'votre', 'médecin', 'spécialiste', 'doit', 'acheminer'),
#   ['NOM', 'KON', 'DET:POS', 'NOM', 'NOM', 'VER:pres', 'VER:infi']],
#  [('médecin', 'spécialiste'), ['NOM', 'NOM']],
#  [('médecin', 'spécialiste', 'doit', 'acheminer'),
#   ['NOM', 'NOM', 'VER:pres', 'VER:infi']],
#  [('médecin', 'spécialiste', 'doit', 'acheminer', 'une', 'demande'),
#   ['NOM', 'NOM', 'VER:pres', 'VER:infi', 'DET:ART', 'NOM']],
#  [('médecin',
#    'spécialiste',
#    'doit',
#    'acheminer',
#    'une',
#    'demande',
#    'de',
#    'consultation'),
#   ['NOM', 'NOM', 'VER:pres', 'VER:infi', 'DET:ART', 'NOM', 'PRP', 'NOM']],
#  [('spécialiste', 'doit', 'acheminer'), ['NOM', 'VER:pres', 'VER:infi']],
#  [('spécialiste', 'doit', 'acheminer', 'une', 'demande'),
#   ['NOM', 'VER:pres', 'VER:infi', 'DET:ART', 'NOM']],
#  [('spécialiste', 'doit', 'acheminer', 'une', 'demande', 'de', 'consultation'),
#   ['NOM', 'VER:pres', 'VER:infi', 'DET:ART', 'NOM', 'PRP', 'NOM']],
#  [('demande', 'de', 'consultation'), ['NOM', 'PRP', 'NOM']],
#  [('centrale', 'téléphonique'), ['NOM', 'ADJ']],
#  [('centrale', 'téléphonique', 'vous', 'contactera'),
#   ['NOM', 'ADJ', 'PRO:PER', 'VER:futu']],
#  [('centrale', 'téléphonique', 'vous', 'contactera', 'pour', 'vous', 'offrir'),
#   ['NOM', 'ADJ', 'PRO:PER', 'VER:futu', 'PRP', 'PRO:PER', 'VER:infi']],
#  [('notes', 'des', 'évaluations'), ['NOM', 'PRP:det', 'NOM']],
#  [('notes', 'des', 'évaluations', 'neurologiques'),
#   ['NOM', 'PRP:det', 'NOM', 'ADJ']],
#  [('évaluations', 'neurologiques'), ['NOM', 'ADJ']],
#  [('champagne', 'est', 'probablement'), ['NOM', 'VER:pres', 'ADV']],
#  [('champagne',
#    'est',
#    'probablement',
#    'la',
#    'personne',
#    'la',
#    'plus',
#    'dévouée'),
#   ['NOM', 'VER:pres', 'ADV', 'DET:ART', 'NOM', 'DET:ART', 'ADV', 'VER:pper']],
#  [('horaire', 'est', 'chargé'), ['NOM', 'VER:pres', 'VER:pper']],
#  [('collègue', 'hors', 'pair'), ['NOM', 'PRP', 'ADJ']],
#  [('prélèvement', 'guide'), ['NOM', 'VER:pres']],
#  [('prélèvement', 'guide', 'de', 'votre', 'séjour'),
#   ['NOM', 'VER:pres', 'PRP', 'DET:POS', 'NOM']],
#  [('hôpital', 'avant', 'de', 'vous', 'rendre', 'à', "l'", 'urgence'),
#   ['NOM', 'PRP', 'PRP', 'PRO:PER', 'VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('mélanome', 'de', "l'", 'œil'), ['NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('fiche', 'vous', 'aidera'), ['NOM', 'PRO:PER', 'VER:futu']],
#  [('fiche', 'vous', 'aidera', 'à', 'mieux'),
#   ['NOM', 'PRO:PER', 'VER:futu', 'PRP', 'ADV']],
#  [('fiche', 'vous', 'aidera', 'à', 'mieux', 'comprendre'),
#   ['NOM', 'PRO:PER', 'VER:futu', 'PRP', 'ADV', 'VER:infi']],
#  [('fiche', 'recherche'), ['NOM', 'VER:pres']],
#  [('prélèvement', 'guide'), ['NOM', 'VER:pres']],
#  [('prélèvement', 'guide', 'de', 'votre', 'séjour'),
#   ['NOM', 'VER:pres', 'PRP', 'DET:POS', 'NOM']],
#  [('hôpital', 'avant', 'de', 'vous', 'rendre', 'à', "l'", 'urgence'),
#   ['NOM', 'PRP', 'PRP', 'PRO:PER', 'VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('difficultés', 'à', 'avaler'), ['NOM', 'PRP', 'VER:infi']],
#  [('accident', 'vasculaire'), ['NOM', 'ADJ']],
#  [('accident', 'vasculaire', 'cérébral'), ['NOM', 'ADJ', 'ADJ']],
#  [('accident', 'vasculaire', 'cérébral', '(', 'avc', ')'),
#   ['NOM', 'ADJ', 'ADJ', 'PUN', 'NOM', 'PUN']],
#  [('difficultés', 'à', 'avaler'), ['NOM', 'PRP', 'VER:infi']],
#  [('fiche', 'décrit'), ['NOM', 'VER:pres']],
#  [('fiche', 'recherche'), ['NOM', 'VER:pres']],
#  [('prélèvement', 'guide'), ['NOM', 'VER:pres']],
#  [('prélèvement', 'guide', 'de', 'votre', 'séjour'),
#   ['NOM', 'VER:pres', 'PRP', 'DET:POS', 'NOM']],
#  [('hôpital', 'avant', 'de', 'vous', 'rendre', 'à', "l'", 'urgence'),
#   ['NOM', 'PRP', 'PRP', 'PRO:PER', 'VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('centre', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('centre', 'de', 'recherche', 'du', 'chum'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('centre', 'de', 'recherche', 'du', 'chum', 'axe'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'NOM']],
#  [('centre', 'de', 'recherche', 'du', 'chum', 'axe', 'de', 'recherche'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'NOM', 'PRP', 'NOM']],
#  [('recherche', 'du', 'chum'), ['NOM', 'PRP:det', 'NOM']],
#  [('recherche', 'du', 'chum', 'axe'), ['NOM', 'PRP:det', 'NOM', 'NOM']],
#  [('recherche', 'du', 'chum', 'axe', 'de', 'recherche'),
#   ['NOM', 'PRP:det', 'NOM', 'NOM', 'PRP', 'NOM']],
#  [('recherche', 'du', 'chum', 'axe', 'de', 'recherche', 'cardiométabolique'),
#   ['NOM', 'PRP:det', 'NOM', 'NOM', 'PRP', 'NOM', 'ADJ']],
#  [('chum', 'axe'), ['NOM', 'NOM']],
#  [('chum', 'axe', 'de', 'recherche'), ['NOM', 'NOM', 'PRP', 'NOM']],
#  [('chum', 'axe', 'de', 'recherche', 'cardiométabolique'),
#   ['NOM', 'NOM', 'PRP', 'NOM', 'ADJ']],
#  [('axe', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('axe', 'de', 'recherche', 'cardiométabolique'),
#   ['NOM', 'PRP', 'NOM', 'ADJ']],
#  [('recherche', 'cardiométabolique'), ['NOM', 'ADJ']],
#  [('axe', 'cardiométabolique'), ['NOM', 'ADJ']],
#  [('centre', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('centre', 'de', 'recherche', 'du', 'chum'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('recherche', 'du', 'chum'), ['NOM', 'PRP:det', 'NOM']],
#  [('recherche', 'du', 'chum', 'directeur'), ['NOM', 'PRP:det', 'NOM', 'ADJ']],
#  [('recherche', 'du', 'chum', 'directeur', 'scientifique'),
#   ['NOM', 'PRP:det', 'NOM', 'ADJ', 'ADJ']],
#  [('chum', 'directeur'), ['NOM', 'ADJ']],
#  [('chum', 'directeur', 'scientifique'), ['NOM', 'ADJ', 'ADJ']],
#  [('centre', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('centre', 'de', 'recherche', 'du', 'chum'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('centre', 'de', 'recherche', 'du', 'chum', 'professeur'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'NOM']],
#  [('recherche', 'du', 'chum'), ['NOM', 'PRP:det', 'NOM']],
#  [('recherche', 'du', 'chum', 'professeur'), ['NOM', 'PRP:det', 'NOM', 'NOM']],
#  [('chum', 'professeur'), ['NOM', 'NOM']],
#  [('chum', 'professeur', 'agrégé'), ['NOM', 'NOM', 'VER:pper']],
#  [('professeur', 'agrégé'), ['NOM', 'VER:pper']],
#  [('pathologie', 'et', 'biologie'), ['NOM', 'KON', 'NOM']],
#  [('pathologie', 'et', 'biologie', 'cellulaire'),
#   ['NOM', 'KON', 'NOM', 'ADJ']],
#  [('biologie', 'cellulaire'), ['NOM', 'ADJ']],
#  [('patient', 'qui', 'a', 'besoin'), ['NOM', 'PRO:REL', 'VER:pres', 'NOM']],
#  [('patient', 'qui', 'a', 'besoin', "d'", 'assistance'),
#   ['NOM', 'PRO:REL', 'VER:pres', 'NOM', 'PRP', 'NOM']],
#  [('patient', 'qui', 'a', 'besoin', "d'", 'assistance', 'immédiate'),
#   ['NOM', 'PRO:REL', 'VER:pres', 'NOM', 'PRP', 'NOM', 'ADJ']],
#  [('besoin', "d'", 'assistance'), ['NOM', 'PRP', 'NOM']],
#  [('besoin', "d'", 'assistance', 'immédiate'), ['NOM', 'PRP', 'NOM', 'ADJ']],
#  [('besoin',
#    "d'",
#    'assistance',
#    'immédiate',
#    'ne',
#    'doit',
#    'pas',
#    'communiquer'),
#   ['NOM', 'PRP', 'NOM', 'ADJ', 'ADV', 'VER:pres', 'ADV', 'VER:infi']],
#  [('assistance', 'immédiate'), ['NOM', 'ADJ']],
#  [('assistance', 'immédiate', 'ne', 'doit', 'pas', 'communiquer'),
#   ['NOM', 'ADJ', 'ADV', 'VER:pres', 'ADV', 'VER:infi']],
#  [('cabinet', 'du', 'médecin'), ['NOM', 'PRP:det', 'NOM']],
#  [('cabinet', 'du', 'médecin', 'ou', 'prendre'),
#   ['NOM', 'PRP:det', 'NOM', 'KON', 'VER:infi']],
#  [('cabinet', 'du', 'médecin', 'ou', 'prendre', "d'", 'autres', 'mesures'),
#   ['NOM', 'PRP:det', 'NOM', 'KON', 'VER:infi', 'PRP', 'ADJ', 'NOM']],
#  [('médecin', 'ou', 'prendre'), ['NOM', 'KON', 'VER:infi']],
#  [('médecin', 'ou', 'prendre', "d'", 'autres', 'mesures'),
#   ['NOM', 'KON', 'VER:infi', 'PRP', 'ADJ', 'NOM']],
#  [('médecin', 'ou', 'prendre', "d'", 'autres', 'mesures', 'appropriées'),
#   ['NOM', 'KON', 'VER:infi', 'PRP', 'ADJ', 'NOM', 'ADJ']],
#  [('mesures', 'appropriées'), ['NOM', 'ADJ']],
#  [('service', "d'", 'urgence'), ['NOM', 'PRP', 'NOM']],
#  [('membre', 'centre'), ['NOM', 'NOM']],
#  [('membre', 'centre', 'de', 'recherche'), ['NOM', 'NOM', 'PRP', 'NOM']],
#  [('centre', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('centre', 'de', 'recherche', 'sur', 'le', 'diabète'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('recherche', 'sur', 'le', 'diabète'), ['NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('système', 'nerveux'), ['NOM', 'ADJ']],
#  [('système', 'nerveux', 'central'), ['NOM', 'ADJ', 'ADJ']],
#  [('cellule', 'bêta'), ['NOM', 'ADJ']],
#  [('diabète', 'de', 'type'), ['NOM', 'PRP', 'NOM']],
#  [('intérêts', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('intérêts', 'de', 'recherche', 'études'), ['NOM', 'PRP', 'NOM', 'NOM']],
#  [('recherche', 'études'), ['NOM', 'NOM']],
#  [('acides', 'gras'), ['NOM', 'ADJ']],
#  [('rôle', 'dans', 'le', 'contrôle'), ['NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('homéostasie', 'glucidique'), ['NOM', 'ADJ']],
#  [('diabète', 'de', 'type'), ['NOM', 'PRP', 'NOM']],
#  [('diabète', 'de', 'type', '2.', 'publications', 'publications', 'indexées'),
#   ['NOM', 'PRP', 'NOM', 'SENT', 'NOM', 'NOM', 'VER:pper']],
#  [('type', '2.', 'publications', 'publications', 'indexées'),
#   ['NOM', 'SENT', 'NOM', 'NOM', 'VER:pper']],
#  [('type', '2.', 'publications', 'publications', 'indexées', 'sur', 'pubmed'),
#   ['NOM', 'SENT', 'NOM', 'NOM', 'VER:pper', 'PRP', 'NOM']],
#  [('rôle', 'clé'), ['NOM', 'NOM']],
#  [('frcpc', 'chercheur'), ['NOM', 'ADJ']],
#  [('frcpc', 'chercheur', 'régulier'), ['NOM', 'ADJ', 'ADJ']],
#  [('frcpc', 'chercheur', 'régulier', 'centre'), ['NOM', 'ADJ', 'ADJ', 'NOM']],
#  [('frcpc', 'chercheur', 'régulier', 'centre', 'de', 'recherche'),
#   ['NOM', 'ADJ', 'ADJ', 'NOM', 'PRP', 'NOM']],
#  [('frcpc',
#    'chercheur',
#    'régulier',
#    'centre',
#    'de',
#    'recherche',
#    'du',
#    'chum'),
#   ['NOM', 'ADJ', 'ADJ', 'NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('centre', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('centre', 'de', 'recherche', 'du', 'chum'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('centre', 'de', 'recherche', 'du', 'chum', 'axe'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'NOM']],
#  [('centre', 'de', 'recherche', 'du', 'chum', 'axe', 'de', 'recherche'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'NOM', 'PRP', 'NOM']],
#  [('recherche', 'du', 'chum'), ['NOM', 'PRP:det', 'NOM']],
#  [('recherche', 'du', 'chum', 'axe'), ['NOM', 'PRP:det', 'NOM', 'NOM']],
#  [('recherche', 'du', 'chum', 'axe', 'de', 'recherche'),
#   ['NOM', 'PRP:det', 'NOM', 'NOM', 'PRP', 'NOM']],
#  [('recherche', 'du', 'chum', 'axe', 'de', 'recherche', 'imagerie'),
#   ['NOM', 'PRP:det', 'NOM', 'NOM', 'PRP', 'NOM', 'NOM']],
#  [('chum', 'axe'), ['NOM', 'NOM']],
#  [('chum', 'axe', 'de', 'recherche'), ['NOM', 'NOM', 'PRP', 'NOM']],
#  [('chum', 'axe', 'de', 'recherche', 'imagerie'),
#   ['NOM', 'NOM', 'PRP', 'NOM', 'NOM']],
#  [('chum', 'axe', 'de', 'recherche', 'imagerie', 'et', 'ingénierie'),
#   ['NOM', 'NOM', 'PRP', 'NOM', 'NOM', 'KON', 'NOM']],
#  [('axe', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('axe', 'de', 'recherche', 'imagerie'), ['NOM', 'PRP', 'NOM', 'NOM']],
#  [('axe', 'de', 'recherche', 'imagerie', 'et', 'ingénierie'),
#   ['NOM', 'PRP', 'NOM', 'NOM', 'KON', 'NOM']],
#  [('recherche', 'imagerie'), ['NOM', 'NOM']],
#  [('recherche', 'imagerie', 'et', 'ingénierie'), ['NOM', 'NOM', 'KON', 'NOM']],
#  [('imagerie', 'et', 'ingénierie'), ['NOM', 'KON', 'NOM']],
#  [('imagerie', 'et', 'ingénierie'), ['NOM', 'KON', 'NOM']],
#  [('crchum', 'médecin'), ['NOM', 'NOM']],
#  [('chum', 'professeur'), ['NOM', 'NOM']],
#  [('chum', 'professeur', 'titulaire'), ['NOM', 'NOM', 'ADJ']],
#  [('chum', 'professeur', 'titulaire', 'département'),
#   ['NOM', 'NOM', 'ADJ', 'NOM']],
#  [('chum', 'professeur', 'titulaire', 'département', 'de', 'radiologie'),
#   ['NOM', 'NOM', 'ADJ', 'NOM', 'PRP', 'NOM']],
#  [('professeur', 'titulaire'), ['NOM', 'ADJ']],
#  [('professeur', 'titulaire', 'département'), ['NOM', 'ADJ', 'NOM']],
#  [('professeur', 'titulaire', 'département', 'de', 'radiologie'),
#   ['NOM', 'ADJ', 'NOM', 'PRP', 'NOM']],
#  [('département', 'de', 'radiologie'), ['NOM', 'PRP', 'NOM']],
#  [('radio-oncologie', 'et', 'médecine'), ['NOM', 'KON', 'VER:pres']],
#  [('radio-oncologie', 'et', 'médecine', 'nucléaire'),
#   ['NOM', 'KON', 'VER:pres', 'ADJ']],
#  [('université', 'de', 'montréal', 'directeur'), ['NOM', 'PRP', 'ADJ', 'NOM']],
# ...
#  [('évaluation', 'en', 'santé', 'professeure'),
#   ['NOM', 'PRP', 'NOM', 'VER:subp']],
#  [('évaluation', 'en', 'santé', 'professeure', 'adjointe'),
#   ['NOM', 'PRP', 'NOM', 'VER:subp', 'VER:pper']],
#  [('santé', 'professeure'), ['NOM', 'VER:subp']],
#  [('santé', 'professeure', 'adjointe'), ['NOM', 'VER:subp', 'VER:pper']],
#  [('patient', 'qui', 'a', 'besoin'), ['NOM', 'PRO:REL', 'VER:pres', 'NOM']],
#  [('patient', 'qui', 'a', 'besoin', "d'", 'assistance'),
#   ['NOM', 'PRO:REL', 'VER:pres', 'NOM', 'PRP', 'NOM']],
#  [('patient', 'qui', 'a', 'besoin', "d'", 'assistance', 'immédiate'),
#   ['NOM', 'PRO:REL', 'VER:pres', 'NOM', 'PRP', 'NOM', 'ADJ']],
#  [('besoin', "d'", 'assistance'), ['NOM', 'PRP', 'NOM']],
#  [('besoin', "d'", 'assistance', 'immédiate'), ['NOM', 'PRP', 'NOM', 'ADJ']],
#  [('besoin',
#    "d'",
#    'assistance',
#    'immédiate',
#    'ne',
#    'doit',
#    'pas',
#    'communiquer'),
#   ['NOM', 'PRP', 'NOM', 'ADJ', 'ADV', 'VER:pres', 'ADV', 'VER:infi']],
#  [('assistance', 'immédiate'), ['NOM', 'ADJ']],
#  [('assistance', 'immédiate', 'ne', 'doit', 'pas', 'communiquer'),
#   ['NOM', 'ADJ', 'ADV', 'VER:pres', 'ADV', 'VER:infi']],
#  [('cabinet', 'du', 'médecin'), ['NOM', 'PRP:det', 'NOM']],
#  [('cabinet', 'du', 'médecin', 'ou', 'prendre'),
#   ['NOM', 'PRP:det', 'NOM', 'KON', 'VER:infi']],
#  [('cabinet', 'du', 'médecin', 'ou', 'prendre', "d'", 'autres', 'mesures'),
#   ['NOM', 'PRP:det', 'NOM', 'KON', 'VER:infi', 'PRP', 'ADJ', 'NOM']],
#  [('médecin', 'ou', 'prendre'), ['NOM', 'KON', 'VER:infi']],
#  [('médecin', 'ou', 'prendre', "d'", 'autres', 'mesures'),
#   ['NOM', 'KON', 'VER:infi', 'PRP', 'ADJ', 'NOM']],
#  [('médecin', 'ou', 'prendre', "d'", 'autres', 'mesures', 'appropriées'),
#   ['NOM', 'KON', 'VER:infi', 'PRP', 'ADJ', 'NOM', 'ADJ']],
#  [('mesures', 'appropriées'), ['NOM', 'ADJ']],
#  [('service', "d'", 'urgence'), ['NOM', 'PRP', 'NOM']],
#  [('affiliations', 'chercheuse'), ['NOM', 'ADJ']],
#  [('intérêts', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('vieillissement', 'prématuré'), ['NOM', 'ADJ']],
#  [('système', 'immunitaire'), ['NOM', 'ADJ']],
#  [('infection', 'chronique'), ['NOM', 'ADJ']],
#  [('santé', 'cardiovasculaire'), ['NOM', 'ADJ']],
#  [('utilisation', 'secondaire'), ['NOM', 'ADJ']],
#  [('utilisation', 'secondaire', 'des', 'données'),
#   ['NOM', 'ADJ', 'PRP:det', 'NOM']],
#  [('données', 'en', 'santé'), ['NOM', 'PRP', 'NOM']],
#  [('québécoise', 'de', 'covid'), ['NOM', 'PRP', 'NOM']],
#  [('équipes', 'du', 'crchum'), ['NOM', 'PRP:det', 'NOM']],
#  [('équipes', 'du', 'crchum', 'aux', 'avant-postes'),
#   ['NOM', 'PRP:det', 'NOM', 'PRP:det', 'NOM']],
#  [('crchum', 'aux', 'avant-postes'), ['NOM', 'PRP:det', 'NOM']],
#  [('vih', 'recherche'), ['NOM', 'VER:pres']],
#  [('unité', "d'", 'hospitalisation'), ['NOM', 'PRP', 'NOM']],
#  [('syndromes', 'gériatriques'), ['NOM', 'ADJ']],
#  [('clinique', 'externe'), ['NOM', 'ADJ']],
#  [('évaluation', 'médicale'), ['NOM', 'ADJ']],
#  [('problèmes', 'de', 'santé'), ['NOM', 'PRP', 'NOM']],
#  [('perte', "d'", 'autonomie'), ['NOM', 'PRP', 'NOM']],
#  [('clinique', 'de', 'cognition'), ['NOM', 'PRP', 'NOM']],
#  [('évaluation', 'et', 'le', 'traitement'), ['NOM', 'KON', 'DET:ART', 'NOM']],
#  [('maladies', 'de', 'la', 'mémoire'), ['NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('patients', 'âgés'), ['NOM', 'ADJ']],
#  [('approche', 'thérapeutique'), ['NOM', 'ADJ']],
#  [('unité', 'ambulatoire'), ['NOM', 'ADJ']],
#  [('unité', 'ambulatoire', "d'", 'évaluation'), ['NOM', 'ADJ', 'PRP', 'NOM']],
#  [('fil', 'des', 'ans'), ['NOM', 'PRP:det', 'NOM']],
#  [('syndromes', 'gériatriques'), ['NOM', 'ADJ']],
#  [('service', 'de', 'consultation'), ['NOM', 'PRP', 'NOM']],
#  [('patients', 'hospitalisés'), ['NOM', 'VER:pper']],
#  [('unité', 'ambulatoire'), ['NOM', 'ADJ']],
#  [('unité', 'ambulatoire', "d'", 'évaluation'), ['NOM', 'ADJ', 'PRP', 'NOM']],
#  [('nausées', 'et', 'vomissements'), ['NOM', 'KON', 'NOM']],
#  [('nausées', 'et', 'vomissements', 'liés'),
#   ['NOM', 'KON', 'NOM', 'VER:pper']],
#  [('nausées', 'et', 'vomissements', 'liés', 'à', 'la', 'chimiothérapie'),
#   ['NOM', 'KON', 'NOM', 'VER:pper', 'PRP', 'DET:ART', 'NOM']],
#  [('vomissements', 'liés'), ['NOM', 'VER:pper']],
#  [('vomissements', 'liés', 'à', 'la', 'chimiothérapie'),
#   ['NOM', 'VER:pper', 'PRP', 'DET:ART', 'NOM']],
#  [('nausées', 'et', 'des', 'vomissements'), ['NOM', 'KON', 'PRP:det', 'NOM']],
#  [('conseils', 'pour', 'vous', 'aider'),
#   ['NOM', 'PRP', 'PRO:PER', 'VER:infi']],
#  [('fiche', 'recherche'), ['NOM', 'VER:pres']],
#  [('prélèvement', 'guide'), ['NOM', 'VER:pres']],
#  [('prélèvement', 'guide', 'de', 'votre', 'séjour'),
#   ['NOM', 'VER:pres', 'PRP', 'DET:POS', 'NOM']],
#  [('hôpital', 'avant', 'de', 'vous', 'rendre', 'à', "l'", 'urgence'),
#   ['NOM', 'PRP', 'PRP', 'PRO:PER', 'VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('fiche', 'explique'), ['NOM', 'VER:pres']],
#  [('fiche', 'recherche'), ['NOM', 'VER:pres']],
#  [('prélèvement', 'guide'), ['NOM', 'VER:pres']],
#  [('prélèvement', 'guide', 'de', 'votre', 'séjour'),
#   ['NOM', 'VER:pres', 'PRP', 'DET:POS', 'NOM']],
#  [('hôpital', 'avant', 'de', 'vous', 'rendre', 'à', "l'", 'urgence'),
#   ['NOM', 'PRP', 'PRP', 'PRO:PER', 'VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('investigateur', 'centre'), ['NOM', 'NOM']],
#  [('investigateur', 'centre', 'de', 'recherche'),
#   ['NOM', 'NOM', 'PRP', 'NOM']],
#  [('investigateur', 'centre', 'de', 'recherche', 'du', 'chum'),
#   ['NOM', 'NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('investigateur', 'centre', 'de', 'recherche', 'du', 'chum', 'axe'),
#   ['NOM', 'NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'NOM']],
#  [('centre', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('centre', 'de', 'recherche', 'du', 'chum'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('centre', 'de', 'recherche', 'du', 'chum', 'axe'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'NOM']],
#  [('centre', 'de', 'recherche', 'du', 'chum', 'axe', 'de', 'recherche'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'NOM', 'PRP', 'NOM']],
#  [('recherche', 'du', 'chum'), ['NOM', 'PRP:det', 'NOM']],
#  [('recherche', 'du', 'chum', 'axe'), ['NOM', 'PRP:det', 'NOM', 'NOM']],
#  [('recherche', 'du', 'chum', 'axe', 'de', 'recherche'),
#   ['NOM', 'PRP:det', 'NOM', 'NOM', 'PRP', 'NOM']],
#  [('recherche', 'du', 'chum', 'axe', 'de', 'recherche', 'immunopathologie'),
#   ['NOM', 'PRP:det', 'NOM', 'NOM', 'PRP', 'NOM', 'NOM']],
#  [('recherche',
#    'du',
#    'chum',
#    'axe',
#    'de',
#    'recherche',
#    'immunopathologie',
#    'professeur'),
#   ['NOM', 'PRP:det', 'NOM', 'NOM', 'PRP', 'NOM', 'NOM', 'NOM']],
#  [('chum', 'axe'), ['NOM', 'NOM']],
#  [('chum', 'axe', 'de', 'recherche'), ['NOM', 'NOM', 'PRP', 'NOM']],
#  [('chum', 'axe', 'de', 'recherche', 'immunopathologie'),
#   ['NOM', 'NOM', 'PRP', 'NOM', 'NOM']],
#  [('chum', 'axe', 'de', 'recherche', 'immunopathologie', 'professeur'),
#   ['NOM', 'NOM', 'PRP', 'NOM', 'NOM', 'NOM']],
#  [('chum',
#    'axe',
#    'de',
#    'recherche',
#    'immunopathologie',
#    'professeur',
#    'agrégé'),
#   ['NOM', 'NOM', 'PRP', 'NOM', 'NOM', 'NOM', 'VER:pper']],
#  [('axe', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('axe', 'de', 'recherche', 'immunopathologie'),
#   ['NOM', 'PRP', 'NOM', 'NOM']],
#  [('axe', 'de', 'recherche', 'immunopathologie', 'professeur'),
#   ['NOM', 'PRP', 'NOM', 'NOM', 'NOM']],
#  [('axe', 'de', 'recherche', 'immunopathologie', 'professeur', 'agrégé'),
#   ['NOM', 'PRP', 'NOM', 'NOM', 'NOM', 'VER:pper']],
#  [('recherche', 'immunopathologie'), ['NOM', 'NOM']],
#  [('recherche', 'immunopathologie', 'professeur'), ['NOM', 'NOM', 'NOM']],
#  [('recherche', 'immunopathologie', 'professeur', 'agrégé'),
#   ['NOM', 'NOM', 'NOM', 'VER:pper']],
#  [('immunopathologie', 'professeur'), ['NOM', 'NOM']],
#  [('immunopathologie', 'professeur', 'agrégé'), ['NOM', 'NOM', 'VER:pper']],
#  [('professeur', 'agrégé'), ['NOM', 'VER:pper']],
#  [('professeur', 'agrégé', 'département'), ['NOM', 'VER:pper', 'NOM']],
#  [('professeur', 'agrégé', 'département', 'de', 'médecine'),
#   ['NOM', 'VER:pper', 'NOM', 'PRP', 'NOM']],
#  [('département', 'de', 'médecine'), ['NOM', 'PRP', 'NOM']],
#  [('université', 'de', 'montréal', 'néphrologue'),
#   ['NOM', 'PRP', 'ADJ', 'NOM']],
#  [('université', 'de', 'montréal', 'néphrologue', 'chum'),
#   ['NOM', 'PRP', 'ADJ', 'NOM', 'NOM']],
#  [('néphrologue', 'chum'), ['NOM', 'NOM']],
#  [('patient', 'qui', 'a', 'besoin'), ['NOM', 'PRO:REL', 'VER:pres', 'NOM']],
#  [('patient', 'qui', 'a', 'besoin', "d'", 'assistance'),
#   ['NOM', 'PRO:REL', 'VER:pres', 'NOM', 'PRP', 'NOM']],
#  [('patient', 'qui', 'a', 'besoin', "d'", 'assistance', 'immédiate'),
#   ['NOM', 'PRO:REL', 'VER:pres', 'NOM', 'PRP', 'NOM', 'ADJ']],
#  [('besoin', "d'", 'assistance'), ['NOM', 'PRP', 'NOM']],
#  [('besoin', "d'", 'assistance', 'immédiate'), ['NOM', 'PRP', 'NOM', 'ADJ']],
#  [('besoin',
#    "d'",
#    'assistance',
#    'immédiate',
#    'ne',
#    'doit',
#    'pas',
#    'communiquer'),
#   ['NOM', 'PRP', 'NOM', 'ADJ', 'ADV', 'VER:pres', 'ADV', 'VER:infi']],
#  [('assistance', 'immédiate'), ['NOM', 'ADJ']],
#  [('assistance', 'immédiate', 'ne', 'doit', 'pas', 'communiquer'),
#   ['NOM', 'ADJ', 'ADV', 'VER:pres', 'ADV', 'VER:infi']],
#  [('cabinet', 'du', 'médecin'), ['NOM', 'PRP:det', 'NOM']],
#  [('cabinet', 'du', 'médecin', 'ou', 'prendre'),
#   ['NOM', 'PRP:det', 'NOM', 'KON', 'VER:infi']],
#  [('cabinet', 'du', 'médecin', 'ou', 'prendre', "d'", 'autres', 'mesures'),
#   ['NOM', 'PRP:det', 'NOM', 'KON', 'VER:infi', 'PRP', 'ADJ', 'NOM']],
#  [('médecin', 'ou', 'prendre'), ['NOM', 'KON', 'VER:infi']],
#  [('médecin', 'ou', 'prendre', "d'", 'autres', 'mesures'),
#   ['NOM', 'KON', 'VER:infi', 'PRP', 'ADJ', 'NOM']],
#  [('médecin', 'ou', 'prendre', "d'", 'autres', 'mesures', 'appropriées'),
#   ['NOM', 'KON', 'VER:infi', 'PRP', 'ADJ', 'NOM', 'ADJ']],
#  [('mesures', 'appropriées'), ['NOM', 'ADJ']],
#  [('service', "d'", 'urgence'), ['NOM', 'PRP', 'NOM']],
#  [('recherche', 'clinique'), ['NOM', 'ADJ']],
#  [('intérêts', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('néphropathie', 'diabétique'), ['NOM', 'ADJ']],
#  [('pubmed', 'recherche'), ['NOM', 'VER:pres']],
#  [('équipes', 'du', 'crchum'), ['NOM', 'PRP:det', 'NOM']],
#  [('équipes', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('cadre', 'du', 'concours'), ['NOM', 'PRP:det', 'NOM']],
#  [('cadre', 'du', 'concours', 'de', 'subventions'),
#   ['NOM', 'PRP:det', 'NOM', 'PRP', 'NOM']],
#  [('cadre', 'du', 'concours', 'de', 'subventions', 'projet'),
#   ['NOM', 'PRP:det', 'NOM', 'PRP', 'NOM', 'NOM']],
#  [('concours', 'de', 'subventions'), ['NOM', 'PRP', 'NOM']],
#  [('concours', 'de', 'subventions', 'projet'), ['NOM', 'PRP', 'NOM', 'NOM']],
#  [('concours', 'de', 'subventions', 'projet', 'de', "l'", 'automne'),
#   ['NOM', 'PRP', 'NOM', 'NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('subventions', 'projet'), ['NOM', 'NOM']],
#  [('subventions', 'projet', 'de', "l'", 'automne'),
#   ['NOM', 'NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('projet', 'de', "l'", 'automne'), ['NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('lancé', 'par', 'les', 'instituts'), ['NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('lancé', 'par', 'les', 'instituts', 'de', 'recherche'),
#   ['NOM', 'PRP', 'DET:ART', 'NOM', 'PRP', 'NOM']],
#  [('lancé', 'par', 'les', 'instituts', 'de', 'recherche', 'en', 'santé'),
#   ['NOM', 'PRP', 'DET:ART', 'NOM', 'PRP', 'NOM', 'PRP', 'NOM']],
#  [('instituts', 'de', 'recherche'), ['NOM', 'PRP', 'NOM']],
#  [('instituts', 'de', 'recherche', 'en', 'santé'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'NOM']],
#  [('instituts', 'de', 'recherche', 'en', 'santé', 'du', 'canada'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('recherche', 'en', 'santé'), ['NOM', 'PRP', 'NOM']],
#  [('recherche', 'en', 'santé', 'du', 'canada'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('recherche', 'en', 'santé', 'du', 'canada', '(', 'irsc', ')'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'PUN', 'NOM', 'PUN']],
#  [('santé', 'du', 'canada'), ['NOM', 'PRP:det', 'NOM']],
#  [('santé', 'du', 'canada', '(', 'irsc', ')'),
#   ['NOM', 'PRP:det', 'NOM', 'PUN', 'NOM', 'PUN']],
#  [('canada', '(', 'irsc', ')'), ['NOM', 'PUN', 'NOM', 'PUN']],
#  [('demandes', 'financées'), ['NOM', 'VER:pper']],
#  [('taux', 'de', 'succès'), ['NOM', 'PRP', 'NOM']],
#  [('taux', 'de', 'succès', 'du', 'crchum'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM']],
#  [('taux', 'de', 'succès', 'du', 'crchum', 'se', 'situe'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'PRO:PER', 'VER:pres']],
#  [('taux', 'de', 'succès', 'du', 'crchum', 'se', 'situe', 'largement'),
#   ['NOM', 'PRP', 'NOM', 'PRP:det', 'NOM', 'PRO:PER', 'VER:pres', 'ADV']],
#  [('succès', 'du', 'crchum'), ['NOM', 'PRP:det', 'NOM']],
#  [('succès', 'du', 'crchum', 'se', 'situe'),
#   ['NOM', 'PRP:det', 'NOM', 'PRO:PER', 'VER:pres']],
#  [('succès', 'du', 'crchum', 'se', 'situe', 'largement'),
#   ['NOM', 'PRP:det', 'NOM', 'PRO:PER', 'VER:pres', 'ADV']],
#  [('succès', 'du', 'crchum', 'se', 'situe', 'largement', 'au-dessus'),
#   ['NOM', 'PRP:det', 'NOM', 'PRO:PER', 'VER:pres', 'ADV', 'ADV']],
#  [('crchum', 'se', 'situe'), ['NOM', 'PRO:PER', 'VER:pres']],
#  [('crchum', 'se', 'situe', 'largement'),
#   ['NOM', 'PRO:PER', 'VER:pres', 'ADV']],
#  [('crchum', 'se', 'situe', 'largement', 'au-dessus'),
#   ['NOM', 'PRO:PER', 'VER:pres', 'ADV', 'ADV']],
#  [('crchum', 'se', 'situe', 'largement', 'au-dessus', 'de', 'la', 'moyenne'),
#   ['NOM', 'PRO:PER', 'VER:pres', 'ADV', 'ADV', 'PRP', 'DET:ART', 'NOM']],
#  [('imagerie', 'et', 'ingénierie'), ['NOM', 'KON', 'NOM']],
#  [('subvention', 'projet'), ['NOM', 'NOM']],
#  [('subvention', 'projet', 'octroyée'), ['NOM', 'NOM', 'VER:pper']],
#  [('projet', 'octroyée'), ['NOM', 'VER:pper']],
#  [('carrefour', 'de', "l'", 'innovation'), ['NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('carrefour', 'de', "l'", 'innovation', 'et', 'de', "l'", 'évaluation'),
#   ['NOM', 'PRP', 'DET:ART', 'NOM', 'KON', 'PRP', 'DET:ART', 'NOM']],
#  [('innovation', 'et', 'de', "l'", 'évaluation'),
#   ['NOM', 'KON', 'PRP', 'DET:ART', 'NOM']],
#  [('innovation', 'et', 'de', "l'", 'évaluation', 'en', 'santé'),
#   ['NOM', 'KON', 'PRP', 'DET:ART', 'NOM', 'PRP', 'NOM']],
#  [('évaluation', 'en', 'santé'), ['NOM', 'PRP', 'NOM']],
#  [('subvention', 'projet'), ['NOM', 'NOM']],
#  [('subvention', 'projet', 'octroyée'), ['NOM', 'NOM', 'VER:pper']],
#  [('projet', 'octroyée'), ['NOM', 'VER:pper']],
#  [('projet', 'mené'), ['NOM', 'VER:pper']],
#  [('university', 'of', 'toronto'), ['NOM', 'ADJ', 'NOM']],
#  [('subvention', 'projet'), ['NOM', 'NOM']],
#  [('subvention', 'projet', 'octroyée'), ['NOM', 'NOM', 'VER:pper']],
#  [('projet', 'octroyée'), ['NOM', 'VER:pper']],
#  [('subvention', 'projet'), ['NOM', 'NOM']],
#  [('subvention', 'projet', 'octroyée'), ['NOM', 'NOM', 'VER:pper']],
#  [('projet', 'octroyée'), ['NOM', 'VER:pper']],
#  [('subvention', 'projet'), ['NOM', 'NOM']],
#  [('subvention', 'projet', 'octroyée'), ['NOM', 'NOM', 'VER:pper']],
#  [('projet', 'octroyée'), ['NOM', 'VER:pper']],
#  [('subvention', 'projet'), ['NOM', 'NOM']],
#  [('subvention', 'projet', 'octroyée'), ['NOM', 'NOM', 'VER:pper']],
#  [('projet', 'octroyée'), ['NOM', 'VER:pper']],
#  [('quoc', 'dinh'), ['NOM', 'ADJ']],
#  [('quoc', 'dinh', 'nguyen'), ['NOM', 'ADJ', 'ADJ']],
#  [('carrefour', 'de', "l'", 'innovation'), ['NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('carrefour', 'de', "l'", 'innovation', 'et', 'de', "l'", 'évaluation'),
#   ['NOM', 'PRP', 'DET:ART', 'NOM', 'KON', 'PRP', 'DET:ART', 'NOM']],
#  [('innovation', 'et', 'de', "l'", 'évaluation'),
#   ['NOM', 'KON', 'PRP', 'DET:ART', 'NOM']],
#  [('innovation', 'et', 'de', "l'", 'évaluation', 'en', 'santé'),
#   ['NOM', 'KON', 'PRP', 'DET:ART', 'NOM', 'PRP', 'NOM']],
#  [('évaluation', 'en', 'santé'), ['NOM', 'PRP', 'NOM']],
#  [('subvention', 'projet'), ['NOM', 'NOM']],
#  [('subvention', 'projet', 'octroyée'), ['NOM', 'NOM', 'VER:pper']],
#  [('projet', 'octroyée'), ['NOM', 'VER:pper']],
#  [('older', 'adults'), ['NOM', 'ADJ']],
#  [('subvention', 'projet'), ['NOM', 'NOM']],
#  [('subvention', 'projet', 'octroyée'), ['NOM', 'NOM', 'VER:pper']],
#  [('projet', 'octroyée'), ['NOM', 'VER:pper']],
#  [('subvention', 'projet'), ['NOM', 'NOM']],
#  [('subvention', 'projet', 'octroyée'), ['NOM', 'NOM', 'VER:pper']],
#  [('projet', 'octroyée'), ['NOM', 'VER:pper']],
#  [('subvention', 'projet'), ['NOM', 'NOM']],
#  [('subvention', 'projet', 'octroyée'), ['NOM', 'NOM', 'VER:pper']],
#  ...]

# %%
phrases = [[term[0], " ".join(term[1])] for term in phrases]

# %%
for phrase in phrases:
    phrase.append(frequencies[tuple(phrase[0])])

# %% [markdown]
# ### **Filtrage (Patrons syntaxiques)**
# Lossio-Ventura, J. A., Jonquet, C., Roche, M., & Teisseire, M. (2014). *Biomedical Terminology Extraction : A new combination of Statistical and Web Mining Approaches*. 421. https://hal-lirmm.ccsd.cnrs.fr/lirmm-01056598
#
# On veut aller extraire les structures syntaxiques les plus courantes dans les MeSH pour filtrer notre corpus selon celles-ci (inspiré de la méthodologie de l'article ci-dessus ; voir le Notebook *Mesh_extract.ipynb*). Pour ce faire, nous allons donc ne sélectionner que les ngrammes qui y correspondent.

# %%
file_patterns = '../02-filtrage/MeSH/mesh_patterns-fr.csv'

with open (file_patterns, 'r') as f:
    patterns = read_csv(f)
    patterns = patterns['Structure'].tolist() # Pour prendre les structures syntaxiques attestées dans les MeSH

# %%
def filter_patterns(phrases):
    return [t for t in phrases if t[1] in patterns and not 'NUM' in t[1]] # and not 'NOM NOM' in t[1]

# %%
terms = filter_patterns(phrases)

# %%
print("Le filtrage syntaxique élimine environ {} % des termes".format(round((len(phrases) - len(terms)) / len(phrases) * 100)))
print("On avait {} ngrammes, ".format(len(phrases)) + "on en a maintenant {}.".format(len(terms)))
# Out:
# Le filtrage syntaxique élimine environ 32 % des termes
# On avait 195538 ngrammes, on en a maintenant 133166.

# %%
for phrase in terms:
    phrase[0] = tuple(phrase[0])


terms_patterns = DataFrame(terms, columns = ["Expression", "Structure syntaxique", "Fréquence"])
terms_patterns = terms_patterns.to_dict('records')
dict_patterns = {}
for term in terms_patterns:
     exp = term['Expression']
     pattern = term['Structure syntaxique']
     dict_patterns[exp] = pattern

# %%
terms_patterns
# Out:
# [{'Expression': ('imagerie', 'et', 'ingénierie'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence': 149},
#  {'Expression': ('axe', 'imagerie'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 48},
#  {'Expression': ('axe', 'imagerie', 'et', 'ingénierie'),
#   'Structure syntaxique': 'NOM NOM KON NOM',
#   'Fréquence': 48},
#  {'Expression': ('imagerie', 'et', 'ingénierie'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence': 149},
#  {'Expression': ('axe', 'imagerie'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 48},
#  {'Expression': ('axe', 'imagerie', 'et', 'ingénierie'),
#   'Structure syntaxique': 'NOM NOM KON NOM',
#   'Fréquence': 48},
#  {'Expression': ('imagerie', 'et', 'ingénierie'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence': 149},
#  {'Expression': ('crchum', 'abrite'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 7},
#  {'Expression': ('systèmes', 'biologiques'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 7},
#  {'Expression': ('développement', 'et', 'validation'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence': 8},
#  {'Expression': ('laboratoire', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 40},
#  {'Expression': ('laboratoire', 'de', 'recherche', 'en', 'imagerie'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM',
#   'Fréquence': 13},
#  {'Expression': ('laboratoire',
#    'de',
#    'recherche',
#    'en',
#    'imagerie',
#    'et',
#    'orthopédie'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM KON NOM',
#   'Fréquence': 13},
#  {'Expression': ('recherche', 'en', 'imagerie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 14},
#  {'Expression': ('recherche', 'en', 'imagerie', 'et', 'orthopédie'),
#   'Structure syntaxique': 'NOM PRP NOM KON NOM',
#   'Fréquence': 13},
#  {'Expression': ('imagerie', 'et', 'orthopédie'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence': 13},
#  {'Expression': ('imagerie', 'et', 'orthopédie', '(', 'lio', ')'),
#   'Structure syntaxique': 'NOM KON NOM PUN NOM PUN',
#   'Fréquence': 13},
#  {'Expression': ('orthopédie', '(', 'lio', ')'),
#   'Structure syntaxique': 'NOM PUN NOM PUN',
#   'Fréquence': 13},
#  {'Expression': ('laboratoire', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 40},
#  {'Expression': ('laboratoire', 'de', 'recherche', 'en', 'imagerie'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM',
#   'Fréquence': 13},
#  {'Expression': ('laboratoire',
#    'de',
#    'recherche',
#    'en',
#    'imagerie',
#    'et',
#    'orthopédie'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM KON NOM',
#   'Fréquence': 13},
#  {'Expression': ('recherche', 'en', 'imagerie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 14},
#  {'Expression': ('recherche', 'en', 'imagerie', 'et', 'orthopédie'),
#   'Structure syntaxique': 'NOM PRP NOM KON NOM',
#   'Fréquence': 13},
#  {'Expression': ('imagerie', 'et', 'orthopédie'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence': 13},
#  {'Expression': ('imagerie', 'et', 'orthopédie', '(', 'lio', ')'),
#   'Structure syntaxique': 'NOM KON NOM PUN NOM PUN',
#   'Fréquence': 13},
#  {'Expression': ('orthopédie', '(', 'lio', ')'),
#   'Structure syntaxique': 'NOM PUN NOM PUN',
#   'Fréquence': 13},
#  {'Expression': ('école', 'de', 'technologie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 22},
#  {'Expression': ('école', 'de', 'technologie', 'supérieure'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ',
#   'Fréquence': 22},
#  {'Expression': ('technologie', 'supérieure'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 22},
#  {'Expression': ('imagerie', 'médicale'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 49},
#  {'Expression': ('dispositifs', 'médicaux'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 18},
#  {'Expression': ('aides', 'techniques'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 11},
#  {'Expression': ('aide', 'à', 'la', 'décision'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM',
#   'Fréquence': 15},
#  {'Expression': ('systèmes', 'biologiques'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 7},
#  {'Expression': ('analyse', "d'", 'images'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 18},
#  {'Expression': ('dispositifs', 'médicaux'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 18},
#  {'Expression': ('laboratoire', 'de', 'biomatériaux'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('laboratoire', 'de', 'biomatériaux', 'endovasculaires'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('laboratoire',
#    'de',
#    'biomatériaux',
#    'endovasculaires',
#    '(',
#    'lbev',
#    ')'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ PUN ADJ PUN',
#   'Fréquence': 6},
#  {'Expression': ('biomatériaux', 'endovasculaires'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('biomatériaux', 'endovasculaires', '(', 'lbev', ')'),
#   'Structure syntaxique': 'NOM ADJ PUN ADJ PUN',
#   'Fréquence': 6},
#  {'Expression': ('laboratoire', 'de', 'biomatériaux'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('laboratoire', 'de', 'biomatériaux', 'endovasculaires'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('laboratoire',
#    'de',
#    'biomatériaux',
#    'endovasculaires',
#    '(',
#    'lbev',
#    ')'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ PUN ADJ PUN',
#   'Fréquence': 6},
#  {'Expression': ('biomatériaux', 'endovasculaires'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('biomatériaux', 'endovasculaires', '(', 'lbev', ')'),
#   'Structure syntaxique': 'NOM ADJ PUN ADJ PUN',
#   'Fréquence': 6},
#  {'Expression': ('laboratoire', 'étudie'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 10},
#  {'Expression': ('laboratoire', 'de', 'biorhéologie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('laboratoire',
#    'de',
#    'biorhéologie',
#    'et',
#    "d'",
#    'ultrasonographie'),
#   'Structure syntaxique': 'NOM PRP NOM KON PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('laboratoire',
#    'de',
#    'biorhéologie',
#    'et',
#    "d'",
#    'ultrasonographie',
#    'médicale'),
#   'Structure syntaxique': 'NOM PRP NOM KON PRP NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('ultrasonographie', 'médicale'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 8},
#  {'Expression': ('ultrasonographie', 'médicale', '(', 'lbum', ')'),
#   'Structure syntaxique': 'NOM ADJ PUN NOM PUN',
#   'Fréquence': 6},
#  {'Expression': ('laboratoire', 'de', 'biorhéologie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('laboratoire',
#    'de',
#    'biorhéologie',
#    'et',
#    "d'",
#    'ultrasonographie'),
#   'Structure syntaxique': 'NOM PRP NOM KON PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('laboratoire',
#    'de',
#    'biorhéologie',
#    'et',
#    "d'",
#    'ultrasonographie',
#    'médicale'),
#   'Structure syntaxique': 'NOM PRP NOM KON PRP NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('ultrasonographie', 'médicale'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 8},
#  {'Expression': ('ultrasonographie', 'médicale', '(', 'lbum', ')'),
#   'Structure syntaxique': 'NOM ADJ PUN NOM PUN',
#   'Fréquence': 6},
#  {'Expression': ('imagerie', 'médicale'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 49},
#  {'Expression': ('techniques', "d'", 'imagerie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 8},
#  {'Expression': ('traitement', 'de', "l'", 'image'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM',
#   'Fréquence': 7},
#  {'Expression': ('traitement', 'de', "l'", 'image'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM',
#   'Fréquence': 7},
#  {'Expression': ('champs', "d'", 'intérêts'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 12},
#  {'Expression': ('pathologies', 'vasculaires'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('laboratoire', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 40},
#  {'Expression': ('laboratoire', 'de', 'recherche', 'en', 'neuroradiologie'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('laboratoire',
#    'de',
#    'recherche',
#    'en',
#    'neuroradiologie',
#    'interventionnelle'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('recherche', 'en', 'neuroradiologie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('recherche', 'en', 'neuroradiologie', 'interventionnelle'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('neuroradiologie', 'interventionnelle'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 9},
#  {'Expression': ('laboratoire', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 40},
#  {'Expression': ('laboratoire', 'de', 'recherche', 'en', 'neuroradiologie'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('laboratoire',
#    'de',
#    'recherche',
#    'en',
#    'neuroradiologie',
#    'interventionnelle'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('recherche', 'en', 'neuroradiologie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('recherche', 'en', 'neuroradiologie', 'interventionnelle'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('neuroradiologie', 'interventionnelle'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 9},
#  {'Expression': ('pathologies', 'vasculaires'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('unité', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 30},
#  {'Expression': ('recherche', 'fondamentale'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 80},
#  {'Expression': ('unité', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 30},
#  {'Expression': ('recherche', 'clinique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 294},
#  {'Expression': ('efforts', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('traitement', 'endovasculaire'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 8},
#  {'Expression': ('modèles', 'animaux'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 47},
#  {'Expression': ('unité', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 30},
#  {'Expression': ('recherche', 'clinique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 294},
#  {'Expression': ('études', 'cliniques'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 37},
#  {'Expression': ('gestion', 'des', 'données'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 8},
#  {'Expression': ('retraitement', 'des', 'dispositifs'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 14},
#  {'Expression': ('retraitement', 'des', 'dispositifs', 'médicaux'),
#   'Structure syntaxique': 'NOM PRP:det NOM ADJ',
#   'Fréquence': 14},
#  {'Expression': ('dispositifs', 'médicaux'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 18},
#  {'Expression': ('rôle', 'méconnu'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence': 9},
#  {'Expression': ('patients', 'reçoivent'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 13},
#  {'Expression': ('soins', 'de', 'qualité'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 9},
#  {'Expression': ('période', 'de', 'pandémie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 11},
#  {'Expression': ('escouade', 'reconnaissance'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 6},
#  {'Expression': ('retraitement', 'des', 'dispositifs'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 14},
#  {'Expression': ('retraitement', 'des', 'dispositifs', 'médicaux'),
#   'Structure syntaxique': 'NOM PRP:det NOM ADJ',
#   'Fréquence': 14},
#  {'Expression': ('dispositifs', 'médicaux'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 18},
#  {'Expression': ('prélèvement', 'guide'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 1271},
#  {'Expression': ('radiologie', 'en', 'imagerie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('prélèvement', 'guide'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 1271},
#  {'Expression': ('traitement', 'intraveineux'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 8},
#  {'Expression': ('fuite', "d'", 'un', 'médicament'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM',
#   'Fréquence': 8},
#  {'Expression': ('médicament', 'hors', 'des', 'veines'),
#   'Structure syntaxique': 'NOM PRP PRP:det NOM',
#   'Fréquence': 8},
#  {'Expression': ('signes', 'et', 'symptômes'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence': 8},
#  {'Expression': ('symptômes', 'à', 'surveiller'),
#   'Structure syntaxique': 'NOM PRP VER:infi',
#   'Fréquence': 10},
#  {'Expression': ('fiche', 'recherche'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 404},
#  {'Expression': ('prélèvement', 'guide'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 1271},
#  {'Expression': ('ans', 'nellie'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence': 6},
#  {'Expression': ('ans', 'axelle'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 6},
#  {'Expression': ('ans', 'à', 'chaque', 'soir'),
#   'Structure syntaxique': 'NOM PRP PRO:IND NOM',
#   'Fréquence': 6},
#  {'Expression': ('prélèvement', 'guide'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 1271},
#  {'Expression': ('prélèvement', 'guide'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 1271},
#  {'Expression': ('mccpm', 'chercheur'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('santé', 'centre'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 108},
#  {'Expression': ('santé', 'centre', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM NOM PRP NOM',
#   'Fréquence': 106},
#  {'Expression': ('santé', 'centre', 'de', 'recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM NOM PRP NOM PRP:det NOM',
#   'Fréquence': 106},
#  {'Expression': ('santé', 'centre', 'de', 'recherche', 'du', 'chum', 'axe'),
#   'Structure syntaxique': 'NOM NOM PRP NOM PRP:det NOM NOM',
#   'Fréquence': 104},
#  {'Expression': ('centre', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 1421},
#  {'Expression': ('centre', 'de', 'recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 1173},
#  {'Expression': ('centre', 'de', 'recherche', 'du', 'chum', 'axe'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM NOM',
#   'Fréquence': 932},
#  {'Expression': ('recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 1199},
#  {'Expression': ('recherche', 'du', 'chum', 'axe'),
#   'Structure syntaxique': 'NOM PRP:det NOM NOM',
#   'Fréquence': 934},
#  {'Expression': ('recherche', 'du', 'chum', 'axe', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP:det NOM NOM PRP NOM',
#   'Fréquence': 934},
#  {'Expression': ('chum', 'axe'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 934},
#  {'Expression': ('chum', 'axe', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM NOM PRP NOM',
#   'Fréquence': 934},
#  {'Expression': ('chum', 'axe', 'de', 'recherche', 'imagerie'),
#   'Structure syntaxique': 'NOM NOM PRP NOM NOM',
#   'Fréquence': 92},
#  {'Expression': ('axe', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 965},
#  {'Expression': ('axe', 'de', 'recherche', 'imagerie'),
#   'Structure syntaxique': 'NOM PRP NOM NOM',
#   'Fréquence': 93},
#  {'Expression': ('recherche', 'imagerie'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 103},
#  {'Expression': ('recherche', 'imagerie', 'et', 'ingénierie'),
#   'Structure syntaxique': 'NOM NOM KON NOM',
#   'Fréquence': 93},
#  {'Expression': ('imagerie', 'et', 'ingénierie'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence': 149},
#  {'Expression': ('imagerie', 'et', 'ingénierie', 'physicien'),
#   'Structure syntaxique': 'NOM KON NOM NOM',
#   'Fréquence': 8},
#  {'Expression': ('ingénierie', 'physicien'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 8},
#  {'Expression': ('besoin', "d'", 'assistance'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 914},
#  {'Expression': ('besoin', "d'", 'assistance', 'immédiate'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ',
#   'Fréquence': 914},
#  {'Expression': ('assistance', 'immédiate'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 914},
#  {'Expression': ('cabinet', 'du', 'médecin'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 915},
#  {'Expression': ('mesures', 'appropriées'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 914},
#  {'Expression': ('service', "d'", 'urgence'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 914},
#  {'Expression': ('intérêts', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 825},
#  {'Expression': ('intérêts', 'de', 'recherche', 'développement'),
#   'Structure syntaxique': 'NOM PRP NOM NOM',
#   'Fréquence': 18},
#  {'Expression': ('recherche', 'développement'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 18},
#  {'Expression': ('développement', 'de', 'techniques'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 10},
#  {'Expression': ('recherche', 'préclinique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 7},
#  {'Expression': ('scholar', 'recherche'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 26},
#  {'Expression': ('prélèvement', 'guide'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 1271},
#  {'Expression': ('travail', 'exceptionnel'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 22},
#  {'Expression': ('biologiste', 'moléculaire'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('biologiste', 'moléculaire', 'au', 'laboratoire'),
#   'Structure syntaxique': 'NOM ADJ PRP:det NOM',
#   'Fréquence': 6},
#  {'Expression': ('biologiste',
#    'moléculaire',
#    'au',
#    'laboratoire',
#    'de',
#    'biologie'),
#   'Structure syntaxique': 'NOM ADJ PRP:det NOM PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('biologiste',
#    'moléculaire',
#    'au',
#    'laboratoire',
#    'de',
#    'biologie',
#    'moléculaire'),
#   'Structure syntaxique': 'NOM ADJ PRP:det NOM PRP NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('laboratoire', 'de', 'biologie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 12},
#  {'Expression': ('laboratoire', 'de', 'biologie', 'moléculaire'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ',
#   'Fréquence': 12},
#  {'Expression': ('laboratoire', 'de', 'biologie', 'moléculaire', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ PRP:det NOM',
#   'Fréquence': 6},
#  {'Expression': ('biologie', 'moléculaire'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 54},
#  {'Expression': ('biologie', 'moléculaire', 'du', 'chum'),
#   'Structure syntaxique': 'NOM ADJ PRP:det NOM',
#   'Fréquence': 6},
#  {'Expression': ('population', 'du', 'québec'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 10},
#  {'Expression': ('prélèvement', 'guide'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 1271},
#  {'Expression': ('urgence', 'salle'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 9},
#  {'Expression': ('urgence', 'salle', 'de', 'formation'),
#   'Structure syntaxique': 'NOM NOM PRP NOM',
#   'Fréquence': 9},
#  {'Expression': ('salle', 'de', 'formation'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 31},
#  {'Expression': ('projection', 'ordinateur'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 8},
#  {'Expression': ('projection', 'ordinateur', 'au', 'lutrin'),
#   'Structure syntaxique': 'NOM ADJ PRP:det NOM',
#   'Fréquence': 8},
#  {'Expression': ('projection',
#    'ordinateur',
#    'au',
#    'lutrin',
#    'avec',
#    'possibilité'),
#   'Structure syntaxique': 'NOM ADJ PRP:det NOM PRP NOM',
#   'Fréquence': 8},
#  {'Expression': ('lutrin', 'avec', 'possibilité'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 8},
#  {'Expression': ('lutrin', 'avec', 'possibilité', 'de', 'brancher'),
#   'Structure syntaxique': 'NOM PRP NOM PRP VER:infi',
#   'Fréquence': 8},
#  {'Expression': ('possibilité', 'de', 'brancher'),
#   'Structure syntaxique': 'NOM PRP VER:infi',
#   'Fréquence': 8},
#  {'Expression': ('possibilité', 'de', 'brancher', 'un', 'portable'),
#   'Structure syntaxique': 'NOM PRP VER:infi DET:ART ADJ',
#   'Fréquence': 8},
#  {'Expression': ('internet', 'sans', 'fil'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 8},
#  {'Expression': ('île', 'sans-fil'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 8},
#  {'Expression': ('île', 'sans-fil', 'chum'),
#   'Structure syntaxique': 'NOM NOM NOM',
#   'Fréquence': 8},
#  {'Expression': ('sans-fil', 'chum'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 8},
#  {'Expression': ('salles', 'recherche'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 49},
#  {'Expression': ('fiche', 'recherche'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 404},
#  {'Expression': ('prélèvement', 'guide'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 1271},
#  {'Expression': ('cadre', 'du', 'concours'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 16},
#  {'Expression': ('cadre', 'du', 'concours', 'de', 'subventions'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM',
#   'Fréquence': 11},
#  {'Expression': ('cadre', 'du', 'concours', 'de', 'subventions', 'projet'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM NOM',
#   'Fréquence': 9},
#  {'Expression': ('concours', 'de', 'subventions'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 18},
#  {'Expression': ('concours', 'de', 'subventions', 'projet'),
#   'Structure syntaxique': 'NOM PRP NOM NOM',
#   'Fréquence': 16},
#  {'Expression': ('subventions', 'projet'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 18},
#  {'Expression': ('instituts', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 114},
#  {'Expression': ('instituts', 'de', 'recherche', 'en', 'santé'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM',
#   'Fréquence': 114},
#  {'Expression': ('instituts',
#    'de',
#    'recherche',
#    'en',
#    'santé',
#    'du',
#    'canada'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM PRP:det NOM',
#   'Fréquence': 110},
#  {'Expression': ('recherche', 'en', 'santé'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 206},
#  {'Expression': ('recherche', 'en', 'santé', 'du', 'canada'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 113},
#  {'Expression': ('recherche', 'en', 'santé', 'du', 'canada', '(', 'irsc', ')'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM PUN NOM PUN',
#   'Fréquence': 43},
#  {'Expression': ('santé', 'du', 'canada'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 116},
#  {'Expression': ('santé', 'du', 'canada', '(', 'irsc', ')'),
#   'Structure syntaxique': 'NOM PRP:det NOM PUN NOM PUN',
#   'Fréquence': 44},
#  {'Expression': ('canada', '(', 'irsc', ')'),
#   'Structure syntaxique': 'NOM PUN NOM PUN',
#   'Fréquence': 44},
#  {'Expression': ('équipes', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 67},
#  {'Expression': ('équipes', 'de', 'recherche', 'du', 'centre'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 6},
#  {'Expression': ('équipes',
#    'de',
#    'recherche',
#    'du',
#    'centre',
#    'de',
#    'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('recherche', 'du', 'centre'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 110},
#  {'Expression': ('recherche', 'du', 'centre', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM',
#   'Fréquence': 12},
#  {'Expression': ('recherche', 'du', 'centre', 'de', 'recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM PRP:det NOM',
#   'Fréquence': 6},
#  {'Expression': ('centre', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 1421},
#  {'Expression': ('centre', 'de', 'recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 1173},
#  {'Expression': ('centre',
#    'de',
#    'recherche',
#    'du',
#    'chum',
#    '(',
#    'crchum',
#    ')'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM PUN NOM PUN',
#   'Fréquence': 66},
#  {'Expression': ('recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 1199},
#  {'Expression': ('recherche', 'du', 'chum', '(', 'crchum', ')'),
#   'Structure syntaxique': 'NOM PRP:det NOM PUN NOM PUN',
#   'Fréquence': 67},
#  {'Expression': ('chum', '(', 'crchum', ')'),
#   'Structure syntaxique': 'NOM PUN NOM PUN',
#   'Fréquence': 67},
#  {'Expression': ('demandes', 'financées'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence': 7},
#  {'Expression': ('taux', 'de', 'succès'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 26},
#  {'Expression': ('taux', 'de', 'succès', 'du', 'crchum'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 6},
#  {'Expression': ('succès', 'du', 'crchum'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 7},
#  {'Expression': ('crchum', 'tient'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 16},
#  {'Expression': ('greg', 'fitzharris'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 27},
#  {'Expression': ('subvention', 'projet'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 74},
#  {'Expression': ('subvention', 'projet', 'octroyée'),
#   'Structure syntaxique': 'NOM NOM VER:pper',
#   'Fréquence': 72},
#  {'Expression': ('projet', 'octroyée'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence': 72},
#  {'Expression': ('marie-hélène', 'mayrand'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 7},
#  {'Expression': ('subvention', 'projet'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 74},
#  {'Expression': ('subvention', 'projet', 'octroyée'),
#   'Structure syntaxique': 'NOM NOM VER:pper',
#   'Fréquence': 72},
#  {'Expression': ('projet', 'octroyée'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence': 72},
#  {'Expression': ('subvention', 'projet'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 74},
#  {'Expression': ('subvention', 'projet', 'octroyée'),
#   'Structure syntaxique': 'NOM NOM VER:pper',
#   'Fréquence': 72},
#  {'Expression': ('projet', 'octroyée'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence': 72},
#  {'Expression': ('subvention', 'projet'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 74},
#  {'Expression': ('subvention', 'projet', 'octroyée'),
#   'Structure syntaxique': 'NOM NOM VER:pper',
#   'Fréquence': 72},
#  {'Expression': ('projet', 'octroyée'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence': 72},
#  {'Expression': ('subvention', 'projet'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 74},
#  {'Expression': ('subvention', 'projet', 'octroyée'),
#   'Structure syntaxique': 'NOM NOM VER:pper',
#   'Fréquence': 72},
#  {'Expression': ('projet', 'octroyée'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence': 72},
#  {'Expression': ('subvention', 'projet'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 74},
#  {'Expression': ('subvention', 'projet', 'octroyée'),
#   'Structure syntaxique': 'NOM NOM VER:pper',
#   'Fréquence': 72},
#  {'Expression': ('projet', 'octroyée'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence': 72},
#  {'Expression': ('subvention', 'projet'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 74},
#  {'Expression': ('subvention', 'projet', 'octroyée'),
#   'Structure syntaxique': 'NOM NOM VER:pper',
#   'Fréquence': 72},
#  {'Expression': ('projet', 'octroyée'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence': 72},
#  {'Expression': ('shao-ling', 'zhang'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 6},
#  {'Expression': ('subventions', 'projet'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 18},
#  {'Expression': ('instituts', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 114},
#  {'Expression': ('instituts', 'de', 'recherche', 'en', 'santé'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM',
#   'Fréquence': 114},
#  {'Expression': ('instituts',
#    'de',
#    'recherche',
#    'en',
#    'santé',
#    'du',
#    'canada'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM PRP:det NOM',
#   'Fréquence': 110},
#  {'Expression': ('recherche', 'en', 'santé'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 206},
#  {'Expression': ('recherche', 'en', 'santé', 'du', 'canada'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 113},
#  {'Expression': ('santé', 'du', 'canada'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 116},
#  {'Expression': ('santé', 'du', 'canada', 'financent'),
#   'Structure syntaxique': 'NOM PRP:det NOM VER:pres',
#   'Fréquence': 8},
#  {'Expression': ('canada', 'financent'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 8},
#  {'Expression': ('millions', 'de', 'dollars'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 22},
#  {'Expression': ('taux', 'de', 'succès'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 26},
#  {'Expression': ('résultats', 'de', 'concours'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 10},
#  {'Expression': ('résultats', 'de', 'concours', 'des', 'irsc'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 10},
#  {'Expression': ('concours', 'des', 'irsc'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 11},
#  {'Expression': ('centre', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 1421},
#  {'Expression': ('centre', 'de', 'recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 1173},
#  {'Expression': ('centre', 'de', 'recherche', 'du', 'chum', 'axe'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM NOM',
#   'Fréquence': 932},
#  {'Expression': ('recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 1199},
#  {'Expression': ('recherche', 'du', 'chum', 'axe'),
#   'Structure syntaxique': 'NOM PRP:det NOM NOM',
#   'Fréquence': 934},
#  {'Expression': ('recherche', 'du', 'chum', 'axe', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP:det NOM NOM PRP NOM',
#   'Fréquence': 934},
#  {'Expression': ('recherche',
#    'du',
#    'chum',
#    'axe',
#    'de',
#    'recherche',
#    'cardiométabolique'),
#   'Structure syntaxique': 'NOM PRP:det NOM NOM PRP NOM ADJ',
#   'Fréquence': 148},
#  {'Expression': ('chum', 'axe'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 934},
#  {'Expression': ('chum', 'axe', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM NOM PRP NOM',
#   'Fréquence': 934},
#  {'Expression': ('chum', 'axe', 'de', 'recherche', 'cardiométabolique'),
#   'Structure syntaxique': 'NOM NOM PRP NOM ADJ',
#   'Fréquence': 148},
#  {'Expression': ('chum',
#    'axe',
#    'de',
#    'recherche',
#    'cardiométabolique',
#    'directeur'),
#   'Structure syntaxique': 'NOM NOM PRP NOM ADJ ADJ',
#   'Fréquence': 14},
#  {'Expression': ('axe', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 965},
#  {'Expression': ('axe', 'de', 'recherche', 'cardiométabolique'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ',
#   'Fréquence': 149},
#  {'Expression': ('axe', 'de', 'recherche', 'cardiométabolique', 'directeur'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ ADJ',
#   'Fréquence': 14},
#  {'Expression': ('axe',
#    'de',
#    'recherche',
#    'cardiométabolique',
#    'directeur',
#    'laboratoire'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ ADJ NOM',
#   'Fréquence': 10},
#  {'Expression': ('recherche', 'cardiométabolique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 149},
#  {'Expression': ('recherche', 'cardiométabolique', 'directeur'),
#   'Structure syntaxique': 'NOM ADJ ADJ',
#   'Fréquence': 14},
#  {'Expression': ('recherche', 'cardiométabolique', 'directeur', 'laboratoire'),
#   'Structure syntaxique': 'NOM ADJ ADJ NOM',
#   'Fréquence': 10},
#  {'Expression': ('crchum', 'professeur'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 42},
#  {'Expression': ('professeur', 'sous', 'octroi'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('octroi', 'titulaire'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 8},
#  {'Expression': ('octroi', 'titulaire', 'département'),
#   'Structure syntaxique': 'NOM ADJ NOM',
#   'Fréquence': 8},
#  {'Expression': ('octroi', 'titulaire', 'département', 'de', 'médecine'),
#   'Structure syntaxique': 'NOM ADJ NOM PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('département', 'de', 'médecine'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 416},
#  {'Expression': ('besoin', "d'", 'assistance'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 914},
#  {'Expression': ('besoin', "d'", 'assistance', 'immédiate'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ',
#   'Fréquence': 914},
#  {'Expression': ('assistance', 'immédiate'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 914},
#  {'Expression': ('cabinet', 'du', 'médecin'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 915},
#  {'Expression': ('mesures', 'appropriées'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 914},
#  {'Expression': ('service', "d'", 'urgence'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 914},
#  {'Expression': ('néphropathie', 'diabétique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('apoptose', 'tubulaire'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('espèces', 'réactives'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 8},
#  {'Expression': ('signaux', 'cellulaires'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 9},
#  {'Expression': ('régulation', 'des', 'gènes'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 6},
#  {'Expression': ('biologie', 'moléculaire'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 54},
#  {'Expression': ('puces', 'à', 'adn'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 8},
#  {'Expression': ('modèles', 'de', 'souris'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 19},
#  {'Expression': ('modèles', 'de', 'souris', 'transgéniques'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('souris', 'transgéniques'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 8},
#  {'Expression': ('intérêts', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 825},
#  {'Expression': ('néphropathie', 'diabétique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('apoptose', 'tubulaire'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('souris', 'transgéniques'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 8},
#  {'Expression': ('mécanismes', 'moléculaires'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 34},
#  {'Expression': ('apoptose', 'tubulaire'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('puces', 'à', 'adn'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 8},
#  {'Expression': ('prélèvement', 'guide'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 1271},
#  {'Expression': ('phénotypage', 'de', 'rongeurs'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 13},
#  {'Expression': ('cages', 'métaboliques'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 8},
#  {'Expression': ('plateforme', 'possède'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 6},
#  {'Expression': ('projets', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 195},
#  {'Expression': ('analyse', 'des', 'données'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 22},
#  {'Expression': ('services', 'sont', 'disponibles'),
#   'Structure syntaxique': 'NOM VER:pres ADJ',
#   'Fréquence': 33},
#  {'Expression': ('chercheurs', 'des', 'milieux'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 33},
#  {'Expression': ('chercheurs', 'des', 'milieux', 'universitaires'),
#   'Structure syntaxique': 'NOM PRP:det NOM ADJ',
#   'Fréquence': 33},
#  {'Expression': ('milieux', 'universitaires'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 33},
#  {'Expression': ('sécrétion', "d'", 'insuline'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 20},
#  {'Expression': ('homéostasie', 'glucidique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 10},
#  {'Expression': ('sécrétion', "d'", 'insuline'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 20},
#  {'Expression': ('cages', 'métaboliques'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 8},
#  {'Expression': ('modèles', 'expérimentaux'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('services', 'demande'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 22},
#  {'Expression': ('services', 'demande', 'de', 'service'),
#   'Structure syntaxique': 'NOM VER:pres PRP NOM',
#   'Fréquence': 22},
#  {'Expression': ('service', 'pour', 'toute', 'demande'),
#   'Structure syntaxique': 'NOM PRP PRO:IND NOM',
#   'Fréquence': 38},
#  {'Expression': ('demande', 'de', 'soumission'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 36},
#  {'Expression': ('demande', 'de', 'soumission', 'ou', 'de', 'service'),
#   'Structure syntaxique': 'NOM PRP NOM KON PRP NOM',
#   'Fréquence': 36},
#  {'Expression': ('santé', 'animale'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 12},
#  {'Expression': ('conseiller', 'scientifique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 12},
#  {'Expression': ('thierry', 'alquier'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 20},
#  {'Expression': ('plateformes', 'et', 'services'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence': 133},
#  {'Expression': ('services', 'recherche'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 41},
#  {'Expression': ('plateformes', 'et', 'services'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence': 133},
#  {'Expression': ('plateformes', 'et', 'services', 'du', 'crchum'),
#   'Structure syntaxique': 'NOM KON NOM PRP:det NOM',
#   'Fréquence': 88},
#  {'Expression': ('services', 'du', 'crchum'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 103},
#  {'Expression': ('demande', "d'", 'information', 'sur', 'les', 'plateformes'),
#   'Structure syntaxique': 'NOM PRP NOM PRP DET:ART NOM',
#   'Fréquence': 44},
#  {'Expression': ('plateformes', 'et', 'services'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence': 133},
#  {'Expression': ('plateformes', 'et', 'services', 'du', 'crchum'),
#   'Structure syntaxique': 'NOM KON NOM PRP:det NOM',
#   'Fréquence': 88},
#  {'Expression': ('services', 'du', 'crchum'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 103},
#  {'Expression': ('performance', 'scientifique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 48},
#  {'Expression': ('erik', 'joly'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 47},
#  {'Expression': ('développement', 'de', 'la', 'recherche'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM',
#   'Fréquence': 57},
#  {'Expression': ('développement',
#    'de',
#    'la',
#    'recherche',
#    'et',
#    'des',
#    'plateformes'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM KON PRP:det NOM',
#   'Fréquence': 47},
#  {'Expression': ('liste', 'des', 'responsables'),
#   'Structure syntaxique': 'NOM PRP:det ADJ',
#   'Fréquence': 44},
#  {'Expression': ('liste', 'des', 'responsables', 'de', 'plateformes'),
#   'Structure syntaxique': 'NOM PRP:det ADJ PRP NOM',
#   'Fréquence': 44},
#  {'Expression': ('approches', 'pédagogiques'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 8},
#  {'Expression': ('cours', 'de', 'réanimation'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('simulation', 'clinique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 24},
#  {'Expression': ('saint-denis', 'montréal', '(', 'québec', ')'),
#   'Structure syntaxique': 'NOM ADJ PUN NOM PUN',
#   'Fréquence': 28},
#  {'Expression': ('demande', 'de', 'consultation'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 148},
#  {'Expression': ('saint-denis', 'montréal', '(', 'québec', ')'),
#   'Structure syntaxique': 'NOM ADJ PUN NOM PUN',
#   'Fréquence': 28},
#  {'Expression': ('demande', 'de', 'consultation'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 148},
#  {'Expression': ('médecin', 'de', 'famille'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 145},
#  {'Expression': ('médecin', 'spécialiste'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 75},
#  {'Expression': ('demande', 'de', 'consultation'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 148},
#  {'Expression': ('centrale', 'téléphonique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 20},
#  {'Expression': ('notes', 'des', 'évaluations'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 16},
#  {'Expression': ('notes', 'des', 'évaluations', 'neurologiques'),
#   'Structure syntaxique': 'NOM PRP:det NOM ADJ',
#   'Fréquence': 16},
#  {'Expression': ('évaluations', 'neurologiques'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 16},
#  {'Expression': ('horaire', 'est', 'chargé'),
#   'Structure syntaxique': 'NOM VER:pres VER:pper',
#   'Fréquence': 6},
#  {'Expression': ('collègue', 'hors', 'pair'),
#   'Structure syntaxique': 'NOM PRP ADJ',
#   'Fréquence': 6},
#  {'Expression': ('prélèvement', 'guide'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 1271},
#  {'Expression': ('mélanome', 'de', "l'", 'œil'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM',
#   'Fréquence': 43},
#  {'Expression': ('fiche', 'recherche'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 404},
#  {'Expression': ('prélèvement', 'guide'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 1271},
#  {'Expression': ('difficultés', 'à', 'avaler'),
#   'Structure syntaxique': 'NOM PRP VER:infi',
#   'Fréquence': 14},
#  {'Expression': ('accident', 'vasculaire'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 77},
#  {'Expression': ('accident', 'vasculaire', 'cérébral'),
#   'Structure syntaxique': 'NOM ADJ ADJ',
#   'Fréquence': 73},
#  {'Expression': ('accident', 'vasculaire', 'cérébral', '(', 'avc', ')'),
#   'Structure syntaxique': 'NOM ADJ ADJ PUN NOM PUN',
#   'Fréquence': 61},
#  {'Expression': ('difficultés', 'à', 'avaler'),
#   'Structure syntaxique': 'NOM PRP VER:infi',
#   'Fréquence': 14},
#  {'Expression': ('fiche', 'décrit'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 52},
#  {'Expression': ('fiche', 'recherche'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 404},
#  {'Expression': ('prélèvement', 'guide'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence': 1271},
#  {'Expression': ('centre', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 1421},
#  {'Expression': ('centre', 'de', 'recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 1173},
#  {'Expression': ('centre', 'de', 'recherche', 'du', 'chum', 'axe'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM NOM',
#   'Fréquence': 932},
#  {'Expression': ('recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 1199},
#  {'Expression': ('recherche', 'du', 'chum', 'axe'),
#   'Structure syntaxique': 'NOM PRP:det NOM NOM',
#   'Fréquence': 934},
#  {'Expression': ('recherche', 'du', 'chum', 'axe', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP:det NOM NOM PRP NOM',
#   'Fréquence': 934},
#  {'Expression': ('recherche',
#    'du',
#    'chum',
#    'axe',
#    'de',
#    'recherche',
#    'cardiométabolique'),
#   'Structure syntaxique': 'NOM PRP:det NOM NOM PRP NOM ADJ',
#   'Fréquence': 148},
#  {'Expression': ('chum', 'axe'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 934},
#  {'Expression': ('chum', 'axe', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM NOM PRP NOM',
#   'Fréquence': 934},
#  {'Expression': ('chum', 'axe', 'de', 'recherche', 'cardiométabolique'),
#   'Structure syntaxique': 'NOM NOM PRP NOM ADJ',
#   'Fréquence': 148},
#  {'Expression': ('axe', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 965},
#  {'Expression': ('axe', 'de', 'recherche', 'cardiométabolique'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ',
#   'Fréquence': 149},
#  {'Expression': ('recherche', 'cardiométabolique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 149},
#  {'Expression': ('axe', 'cardiométabolique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 50},
#  {'Expression': ('centre', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 1421},
#  {'Expression': ('centre', 'de', 'recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 1173},
#  {'Expression': ('recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 1199},
#  {'Expression': ('recherche', 'du', 'chum', 'directeur'),
#   'Structure syntaxique': 'NOM PRP:det NOM ADJ',
#   'Fréquence': 9},
#  {'Expression': ('recherche', 'du', 'chum', 'directeur', 'scientifique'),
#   'Structure syntaxique': 'NOM PRP:det NOM ADJ ADJ',
#   'Fréquence': 7},
#  {'Expression': ('chum', 'directeur'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 35},
#  {'Expression': ('chum', 'directeur', 'scientifique'),
#   'Structure syntaxique': 'NOM ADJ ADJ',
#   'Fréquence': 9},
#  {'Expression': ('centre', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 1421},
#  {'Expression': ('centre', 'de', 'recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 1173},
#  {'Expression': ('centre', 'de', 'recherche', 'du', 'chum', 'professeur'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM NOM',
#   'Fréquence': 10},
#  {'Expression': ('recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 1199},
#  {'Expression': ('recherche', 'du', 'chum', 'professeur'),
#   'Structure syntaxique': 'NOM PRP:det NOM NOM',
#   'Fréquence': 11},
#  {'Expression': ('chum', 'professeur'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 176},
#  {'Expression': ('chum', 'professeur', 'agrégé'),
#   'Structure syntaxique': 'NOM NOM VER:pper',
#   'Fréquence': 46},
#  {'Expression': ('professeur', 'agrégé'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence': 169},
#  {'Expression': ('pathologie', 'et', 'biologie'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence': 9},
#  {'Expression': ('pathologie', 'et', 'biologie', 'cellulaire'),
#   'Structure syntaxique': 'NOM KON NOM ADJ',
#   'Fréquence': 9},
#  {'Expression': ('biologie', 'cellulaire'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 41},
#  {'Expression': ('besoin', "d'", 'assistance'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 914},
#  {'Expression': ('besoin', "d'", 'assistance', 'immédiate'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ',
#   'Fréquence': 914},
#  {'Expression': ('assistance', 'immédiate'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 914},
#  {'Expression': ('cabinet', 'du', 'médecin'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 915},
#  {'Expression': ('mesures', 'appropriées'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 914},
#  {'Expression': ('service', "d'", 'urgence'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 914},
#  {'Expression': ('membre', 'centre'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 6},
#  {'Expression': ('membre', 'centre', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM NOM PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('centre', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 1421},
#  {'Expression': ('centre', 'de', 'recherche', 'sur', 'le', 'diabète'),
#   'Structure syntaxique': 'NOM PRP NOM PRP DET:ART NOM',
#   'Fréquence': 6},
#  {'Expression': ('recherche', 'sur', 'le', 'diabète'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM',
#   'Fréquence': 16},
#  {'Expression': ('système', 'nerveux'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 62},
#  {'Expression': ('système', 'nerveux', 'central'),
#   'Structure syntaxique': 'NOM ADJ ADJ',
#   'Fréquence': 39},
#  {'Expression': ('cellule', 'bêta'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 9},
# ...
#   'Fréquence': 7},
#  {'Expression': ('fond', 'bleu'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 7},
#  {'Expression': ('fond', "d'", 'écran'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 14},
#  {'Expression': ('fond', "d'", 'écran', 'zoom'),
#   'Structure syntaxique': 'NOM PRP NOM NOM',
#   'Fréquence': 14},
#  {'Expression': ('écran', 'zoom'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 14},
#  {'Expression': ('écran', 'zoom', 'ou', 'teams'),
#   'Structure syntaxique': 'NOM NOM KON NOM',
#   'Fréquence': 14},
#  {'Expression': ('zoom', 'ou', 'teams'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence': 14},
#  {'Expression': ('teams', '(', 'fond', 'bleu-vert', ')'),
#   'Structure syntaxique': 'NOM PUN NOM ADJ PUN',
#   'Fréquence': 7},
#  {'Expression': ('fond', 'bleu-vert'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 7},
#  {'Expression': ('modèles', 'de', 'lettres'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 7},
#  {'Expression': ('modèles', 'de', 'lettres', 'de', 'sollicitation'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM',
#   'Fréquence': 7},
#  {'Expression': ('lettres', 'de', 'sollicitation'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 7},
#  {'Expression': ('gabarit', 'word'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 7},
#  {'Expression': ('gabarit', 'word', 'pour', 'lettre'),
#   'Structure syntaxique': 'NOM NOM PRP NOM',
#   'Fréquence': 7},
#  {'Expression': ('word', 'pour', 'lettre'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 7},
#  {'Expression': ('question', 'sur', 'le', 'défi'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM',
#   'Fréquence': 7},
#  {'Expression': ('thermomètre', 'défi'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 7},
#  {'Expression': ('thermomètre', 'défi', 'crchum'),
#   'Structure syntaxique': 'NOM NOM NOM',
#   'Fréquence': 7},
#  {'Expression': ('défi', 'crchum'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 92},
#  {'Expression': ('service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 150},
#  {'Expression': ('service', 'de', 'psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 93},
#  {'Expression': ('psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 137},
#  {'Expression': ('services', 'offerts'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 53},
#  {'Expression': ('services', 'offerts', 'adressés'),
#   'Structure syntaxique': 'NOM ADJ VER:pper',
#   'Fréquence': 6},
#  {'Expression': ('services', 'offerts', 'adressés', 'aux', 'professionnels'),
#   'Structure syntaxique': 'NOM ADJ VER:pper PRP:det NOM',
#   'Fréquence': 6},
#  {'Expression': ('services',
#    'offerts',
#    'adressés',
#    'aux',
#    'professionnels',
#    'de',
#    'la',
#    'santé'),
#   'Structure syntaxique': 'NOM ADJ VER:pper PRP:det NOM PRP DET:ART NOM',
#   'Fréquence': 6},
#  {'Expression': ('professionnels', 'de', 'la', 'santé'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM',
#   'Fréquence': 117},
#  {'Expression': ('critères', 'de', 'référence'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('critères', 'de', 'référence', 'à', 'la', 'clinique'),
#   'Structure syntaxique': 'NOM PRP NOM PRP DET:ART ADJ',
#   'Fréquence': 6},
#  {'Expression': ('référence', 'à', 'la', 'clinique'),
#   'Structure syntaxique': 'NOM PRP DET:ART ADJ',
#   'Fréquence': 6},
#  {'Expression': ('partenariat', 'avec', 'le', 'service'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM',
#   'Fréquence': 6},
#  {'Expression': ('partenariat', 'avec', 'le', 'service', 'de', 'médecine'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('partenariat',
#    'avec',
#    'le',
#    'service',
#    'de',
#    'médecine',
#    'des',
#    'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM PRP NOM PRP:det NOM',
#   'Fréquence': 6},
#  {'Expression': ('service', 'de', 'médecine'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 75},
#  {'Expression': ('service', 'de', 'médecine', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 47},
#  {'Expression': ('service',
#    'de',
#    'médecine',
#    'des',
#    'toxicomanies',
#    'du',
#    'chum'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM PRP:det NOM',
#   'Fréquence': 16},
#  {'Expression': ('médecine', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 99},
#  {'Expression': ('médecine', 'des', 'toxicomanies', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP:det NOM',
#   'Fréquence': 24},
#  {'Expression': ('toxicomanies', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 33},
#  {'Expression': ('psychiatres', 'responsables'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 15},
#  {'Expression': ('médecin', 'psychiatre'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 9},
#  {'Expression': ('rôle', 'principal'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('traitement', 'pharmacologique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 24},
#  {'Expression': ('santé', 'mentale'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 144},
#  {'Expression': ('épisode', 'de', 'soins'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 46},
#  {'Expression': ('épisode', 'de', 'soins', 'au', 'service'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 9},
#  {'Expression': ('épisode',
#    'de',
#    'soins',
#    'au',
#    'service',
#    'de',
#    'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM PRP NOM',
#   'Fréquence': 9},
#  {'Expression': ('soins', 'au', 'service'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 9},
#  {'Expression': ('soins', 'au', 'service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM',
#   'Fréquence': 9},
#  {'Expression': ('soins',
#    'au',
#    'service',
#    'de',
#    'psychiatrie',
#    'des',
#    'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM PRP:det NOM',
#   'Fréquence': 9},
#  {'Expression': ('service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 150},
#  {'Expression': ('service', 'de', 'psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 93},
#  {'Expression': ('psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 137},
#  {'Expression': ('cas', 'échéant'),
#   'Structure syntaxique': 'NOM VER:ppre',
#   'Fréquence': 6},
#  {'Expression': ('épisode', 'de', 'soins'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 46},
#  {'Expression': ('épisode', 'de', 'soins', 'au', 'service'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 9},
#  {'Expression': ('épisode',
#    'de',
#    'soins',
#    'au',
#    'service',
#    'de',
#    'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM PRP NOM',
#   'Fréquence': 9},
#  {'Expression': ('soins', 'au', 'service'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 9},
#  {'Expression': ('soins', 'au', 'service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM',
#   'Fréquence': 9},
#  {'Expression': ('soins',
#    'au',
#    'service',
#    'de',
#    'psychiatrie',
#    'des',
#    'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM PRP:det NOM',
#   'Fréquence': 9},
#  {'Expression': ('service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 150},
#  {'Expression': ('service', 'de', 'psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 93},
#  {'Expression': ('psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 137},
#  {'Expression': ('médecin', 'psychiatre'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence': 9},
#  {'Expression': ('rencontres', 'individuelles'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 9},
#  {'Expression': ('professionnel', 'désigné'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence': 39},
#  {'Expression': ('professionnel', 'désigné'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence': 39},
#  {'Expression': ('intégration', 'des', 'soins'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 6},
#  {'Expression': ('épisode', 'de', 'soins'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 46},
#  {'Expression': ('professionnel', 'désigné'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence': 39},
#  {'Expression': ('plan', 'de', 'traitement'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 31},
#  {'Expression': ('long', 'de', "l'", 'épisode'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM',
#   'Fréquence': 6},
#  {'Expression': ('long', 'de', "l'", 'épisode', 'de', 'soins'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('épisode', 'de', 'soins'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 46},
#  {'Expression': ('fin', 'de', "l'", 'épisode'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM',
#   'Fréquence': 6},
#  {'Expression': ('fin', 'de', "l'", 'épisode', 'de', 'soins'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('épisode', 'de', 'soins'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 46},
#  {'Expression': ('service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 150},
#  {'Expression': ('service', 'de', 'psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 93},
#  {'Expression': ('psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 137},
#  {'Expression': ('épisode', 'de', 'soins'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 46},
#  {'Expression': ('épisode', 'de', 'soins', 'au', 'service'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 9},
#  {'Expression': ('épisode',
#    'de',
#    'soins',
#    'au',
#    'service',
#    'de',
#    'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM PRP NOM',
#   'Fréquence': 9},
#  {'Expression': ('soins', 'au', 'service'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 9},
#  {'Expression': ('soins', 'au', 'service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM',
#   'Fréquence': 9},
#  {'Expression': ('soins',
#    'au',
#    'service',
#    'de',
#    'psychiatrie',
#    'des',
#    'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM PRP:det NOM',
#   'Fréquence': 9},
#  {'Expression': ('service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 150},
#  {'Expression': ('service', 'de', 'psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 93},
#  {'Expression': ('psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 137},
#  {'Expression': ('évaluation', 'diagnostique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('plan', 'de', 'traitement'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 31},
#  {'Expression': ('entente', 'de', 'services'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 6},
#  {'Expression': ('partenaires', 'du', 'réseau'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 14},
#  {'Expression': ('psychiatres', 'du', 'service'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 18},
#  {'Expression': ('psychiatres', 'du', 'service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM',
#   'Fréquence': 18},
#  {'Expression': ('psychiatres',
#    'du',
#    'service',
#    'de',
#    'psychiatrie',
#    'des',
#    'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM PRP:det NOM',
#   'Fréquence': 6},
#  {'Expression': ('service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 150},
#  {'Expression': ('service', 'de', 'psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 93},
#  {'Expression': ('psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 137},
#  {'Expression': ('professionnel', 'désigné'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence': 39},
#  {'Expression': ('professionnel', 'désigné'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence': 39},
#  {'Expression': ('professionnel', 'de', 'la', 'santé'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM',
#   'Fréquence': 154},
#  {'Expression': ('travailleur', 'social'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 42},
#  {'Expression': ('service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 150},
#  {'Expression': ('service', 'de', 'psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 93},
#  {'Expression': ('service',
#    'de',
#    'psychiatrie',
#    'des',
#    'toxicomanies',
#    'au',
#    'chum'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM PRP:det NOM',
#   'Fréquence': 6},
#  {'Expression': ('psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 137},
#  {'Expression': ('psychiatrie', 'des', 'toxicomanies', 'au', 'chum'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP:det NOM',
#   'Fréquence': 6},
#  {'Expression': ('toxicomanies', 'au', 'chum'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 11},
#  {'Expression': ('organisation', 'des', 'services'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 8},
#  {'Expression': ('suivi', 'clinique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('professionnel', 'désigné'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence': 39},
#  {'Expression': ('professionnel', 'désigné'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence': 39},
#  {'Expression': ('vision', 'globale'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('besoins', 'du', 'patient'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 10},
#  {'Expression': ('professionnel', 'désigné'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence': 39},
#  {'Expression': ('milieu', 'de', 'vie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 32},
#  {'Expression': ('projet', 'de', 'vie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 15},
#  {'Expression': ('professionnel', 'désigné'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence': 39},
#  {'Expression': ('durée', 'totale'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('épisode', 'de', 'soins'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 46},
#  {'Expression': ('partenaires', 'du', 'réseau'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 14},
#  {'Expression': ('suivi', 'clinique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('épisode', 'de', 'soins'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 46},
#  {'Expression': ('service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 150},
#  {'Expression': ('service', 'de', 'psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence': 93},
#  {'Expression': ('psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence': 137},
#  {'Expression': ('projet', 'de', 'vie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 15},
#  {'Expression': ('infirmière', 'de', 'liaison'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 8},
#  {'Expression': ('rôle', 'principal'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence': 6},
#  {'Expression': ('infirmière', 'de', 'liaison'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence': 8},
#  {'Expression': ('signes', 'et', 'symptômes'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence': 8},
#  ...]

# %% [markdown]
# ### **Filtrage (Collocations statistiquement significatives)** Log-Likelihood Ratio
#
# [Notebook - Collocation extraction methodologies compared](https://notebooks.githubusercontent.com/view/ipynb?azure_maps_enabled=false&browser=chrome&color_mode=auto&commit=33868e847376764d7733cd958986c88dedfaec97&device=unknown&enc_url=&enterprise_enabled=false&logged_in=false&nwo=todd-cook%2FML-You-Can-Use&path=probabilistic_language_modeling%2Fcollocation_extractions.ipynb&platform=android&repository_id=167140788&repository_type=Repository&version=102)
#
# On applique un test d'hypothèse statistique aux n-grammes sur lesquels une probabilité a été mesurée (Log-likelihood ratio) - seuls les n-grammes dont le test est significatif seront conservés.
# On considère que l'apparition de ces collocations dans notre corpus n'est pas dûe au hasard.

# %%
def loglikelihood_ratio(c_prior, c_n, c_ngram, N):
    """
    Compute the ratio of two hypotheses of likelihood and return the ratio.
    The formula here and test verification values are taken from 
    Manning & Schūtze _Foundations of Statistical Natural Language Processing_ p.172-175
    Parameters:
    c_prior: count of word 1 if bigrams or count of [w1w2 .. w(n-1)] if ngram
    c_n : count of word 2 if bigrams or count of wn if ngram
    c12: count of bigram (w1, w2) if bigram or count of ngram if ngram
    N: the number of words in the corpus
    """

    p = c_n / N
    p1 = c_ngram / c_prior
    p2 = (c_n - c_ngram) / (N - c_prior)   
    # We proactively trap a runtimeWarning: divide by zero encountered in log,
    # which may occur with extreme collocations
    import warnings
    with warnings.catch_warnings(): # this will reset our filterwarnings setting
        warnings.filterwarnings('error')
        try:
            return (np.log(binom.pmf(c_ngram, c_prior, p)) 
                    + np.log(binom.pmf(c_n - c_ngram, N - c_prior, p)) 
                    - np.log(binom.pmf(c_ngram, c_prior, p1) )
                    - np.log(binom.pmf(c_n - c_ngram, N - c_prior, p2)))             
        except Warning:
            return np.inf

# %%
len_prior = len(terms)
print("Au départ, on a {} ngrammes.".format(len_prior))
# Out:
# Au départ, on a 133166 ngrammes.

# %%
frequencies
# Out:
# FreqDist({('STOP',): 68484, ('de',): 55655, ('.',): 27777, ('la',): 21837, ('et',): 21314, ("l'",): 18482, ('le',): 17328, ('à',): 15197, ('du',): 15041, ('des',): 14624, ...})

# %%
# Pour le calcul des probabilités, on a besoin de traiter séparément les ngrammes selon la valeur de n
N = len(tokens)
fd_tokens = nltk.FreqDist(tokens)

# %%
def llr_ngrammes(terms):
    llr = []

    ngrammes = [term[0] for term in terms]
        
    for t in ngrammes:
        if len(t) == 1:
            try:
                llr.append({'Terme' : str(t[0]), 'Structure syntaxique': dict_patterns[t], 'Fréquence (TF)' : fd_tokens[str(t[0])], 'LLR': '-', 'p-value': '-'})
            except Exception as e:
                print(t, str(e))
        else:
            c_prior = frequencies[t[:-1]] # Antécédent = P(w1w2..w_n-1) (si on considère que P(w1w2...wn) = P(wn) | P(w1w2...w_n-1)
            c_n = fd_tokens[t[-1]]     # Dernier mot du ngramme  P(wn)
            c_ngram = frequencies[t]             # Le ngramme lui-même P(w1w2w3..wn)

            try:
                res = -2 * loglikelihood_ratio(c_prior, c_n, c_ngram, N)
                p_value = chi2.sf(res, 1) # 1 degrees of freedom

                if p_value < 0.001 or (res == float('-inf')):
                    #llr.append({'Collocation' : " ".join(t).replace("' ", "'").replace("( ", "(").replace(" )", ")"), 'Structure syntaxique': dict_patterns[" ".join(t).replace("' ", "'")], 'Fréquence' : c_ngram, 'LLR': res, 'p-value': p_value})
                    llr.append({'Terme' : t, 'Structure syntaxique': dict_patterns[t], 'Fréquence (TF)' : c_ngram, 'LLR': res, 'p-value': p_value})
            
            except Exception as e:
                print(t, str(e))
            
    return llr

# %%
significant_coll = llr_ngrammes(terms)
#terms = [{'Collocation' : t[0], 'Structure syntaxique': t[1], 'Fréquence' : t[2]} for t in terms] # Si on ne veut pas appliquer le LLR

# %%
significant_coll
# Out:
# [{'Terme': ('imagerie', 'et', 'ingénierie'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence (TF)': 149,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('axe', 'imagerie'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 48,
#   'LLR': 297.8555541377298,
#   'p-value': 9.660050488023589e-67},
#  {'Terme': ('axe', 'imagerie', 'et', 'ingénierie'),
#   'Structure syntaxique': 'NOM NOM KON NOM',
#   'Fréquence (TF)': 48,
#   'LLR': 831.5655250775928,
#   'p-value': 7.401362611705968e-183},
#  {'Terme': ('imagerie', 'et', 'ingénierie'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence (TF)': 149,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('axe', 'imagerie'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 48,
#   'LLR': 297.8555541377298,
#   'p-value': 9.660050488023589e-67},
#  {'Terme': ('axe', 'imagerie', 'et', 'ingénierie'),
#   'Structure syntaxique': 'NOM NOM KON NOM',
#   'Fréquence (TF)': 48,
#   'LLR': 831.5655250775928,
#   'p-value': 7.401362611705968e-183},
#  {'Terme': ('imagerie', 'et', 'ingénierie'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence (TF)': 149,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('crchum', 'abrite'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence (TF)': 7,
#   'LLR': 72.69828559280877,
#   'p-value': 1.5106526735747512e-17},
#  {'Terme': ('systèmes', 'biologiques'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 7,
#   'LLR': 79.71915106604423,
#   'p-value': 4.315969244033566e-19},
#  {'Terme': ('développement', 'et', 'validation'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence (TF)': 8,
#   'LLR': 110.38396704992505,
#   'p-value': 8.073542527936484e-26},
#  {'Terme': ('laboratoire', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 40,
#   'LLR': 197.10524229530256,
#   'p-value': 8.944485004486098e-45},
#  {'Terme': ('laboratoire', 'de', 'recherche', 'en', 'imagerie'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM',
#   'Fréquence (TF)': 13,
#   'LLR': 156.80581945823863,
#   'p-value': 5.643923363833195e-36},
#  {'Terme': ('laboratoire',
#    'de',
#    'recherche',
#    'en',
#    'imagerie',
#    'et',
#    'orthopédie'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM KON NOM',
#   'Fréquence (TF)': 13,
#   'LLR': 260.24704520694,
#   'p-value': 1.5158850939415349e-58},
#  {'Terme': ('recherche', 'en', 'imagerie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 14,
#   'LLR': 84.97291483982642,
#   'p-value': 3.0248031716871566e-20},
#  {'Terme': ('recherche', 'en', 'imagerie', 'et', 'orthopédie'),
#   'Structure syntaxique': 'NOM PRP NOM KON NOM',
#   'Fréquence (TF)': 13,
#   'LLR': 260.24704520694,
#   'p-value': 1.5158850939415349e-58},
#  {'Terme': ('imagerie', 'et', 'orthopédie'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence (TF)': 13,
#   'LLR': 166.30153549024163,
#   'p-value': 4.753341175501389e-38},
#  {'Terme': ('imagerie', 'et', 'orthopédie', '(', 'lio', ')'),
#   'Structure syntaxique': 'NOM KON NOM PUN NOM PUN',
#   'Fréquence (TF)': 13,
#   'LLR': 128.36655730678586,
#   'p-value': 9.331481891592084e-30},
#  {'Terme': ('orthopédie', '(', 'lio', ')'),
#   'Structure syntaxique': 'NOM PUN NOM PUN',
#   'Fréquence (TF)': 13,
#   'LLR': 128.36655730678586,
#   'p-value': 9.331481891592084e-30},
#  {'Terme': ('laboratoire', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 40,
#   'LLR': 197.10524229530256,
#   'p-value': 8.944485004486098e-45},
#  {'Terme': ('laboratoire', 'de', 'recherche', 'en', 'imagerie'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM',
#   'Fréquence (TF)': 13,
#   'LLR': 156.80581945823863,
#   'p-value': 5.643923363833195e-36},
#  {'Terme': ('laboratoire',
#    'de',
#    'recherche',
#    'en',
#    'imagerie',
#    'et',
#    'orthopédie'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM KON NOM',
#   'Fréquence (TF)': 13,
#   'LLR': 260.24704520694,
#   'p-value': 1.5158850939415349e-58},
#  {'Terme': ('recherche', 'en', 'imagerie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 14,
#   'LLR': 84.97291483982642,
#   'p-value': 3.0248031716871566e-20},
#  {'Terme': ('recherche', 'en', 'imagerie', 'et', 'orthopédie'),
#   'Structure syntaxique': 'NOM PRP NOM KON NOM',
#   'Fréquence (TF)': 13,
#   'LLR': 260.24704520694,
#   'p-value': 1.5158850939415349e-58},
#  {'Terme': ('imagerie', 'et', 'orthopédie'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence (TF)': 13,
#   'LLR': 166.30153549024163,
#   'p-value': 4.753341175501389e-38},
#  {'Terme': ('imagerie', 'et', 'orthopédie', '(', 'lio', ')'),
#   'Structure syntaxique': 'NOM KON NOM PUN NOM PUN',
#   'Fréquence (TF)': 13,
#   'LLR': 128.36655730678586,
#   'p-value': 9.331481891592084e-30},
#  {'Terme': ('orthopédie', '(', 'lio', ')'),
#   'Structure syntaxique': 'NOM PUN NOM PUN',
#   'Fréquence (TF)': 13,
#   'LLR': 128.36655730678586,
#   'p-value': 9.331481891592084e-30},
#  {'Terme': ('école', 'de', 'technologie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 22,
#   'LLR': 283.2426282880316,
#   'p-value': 1.4756572964404778e-63},
#  {'Terme': ('école', 'de', 'technologie', 'supérieure'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ',
#   'Fréquence (TF)': 22,
#   'LLR': 462.81808261695363,
#   'p-value': 1.1712021073198053e-102},
#  {'Terme': ('technologie', 'supérieure'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 22,
#   'LLR': 330.4680232513577,
#   'p-value': 7.600663135778523e-74},
#  {'Terme': ('imagerie', 'médicale'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 49,
#   'LLR': 391.7923204134454,
#   'p-value': 3.370460194605764e-87},
#  {'Terme': ('dispositifs', 'médicaux'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 18,
#   'LLR': 292.40569547475445,
#   'p-value': 1.4872513775448807e-65},
#  {'Terme': ('aides', 'techniques'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 11,
#   'LLR': 141.37178043012273,
#   'p-value': 1.3342805200926432e-32},
#  {'Terme': ('aide', 'à', 'la', 'décision'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM',
#   'Fréquence (TF)': 15,
#   'LLR': 242.94349991769823,
#   'p-value': 8.972368505390985e-55},
#  {'Terme': ('systèmes', 'biologiques'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 7,
#   'LLR': 79.71915106604423,
#   'p-value': 4.315969244033566e-19},
#  {'Terme': ('analyse', "d'", 'images'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 18,
#   'LLR': 285.6197247995303,
#   'p-value': 4.4771671911130836e-64},
#  {'Terme': ('dispositifs', 'médicaux'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 18,
#   'LLR': 292.40569547475445,
#   'p-value': 1.4872513775448807e-65},
#  {'Terme': ('laboratoire', 'de', 'biomatériaux'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 77.89456434009992,
#   'p-value': 1.086900728804354e-18},
#  {'Terme': ('laboratoire', 'de', 'biomatériaux', 'endovasculaires'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 135.21440449781306,
#   'p-value': 2.9637334295813215e-31},
#  {'Terme': ('laboratoire',
#    'de',
#    'biomatériaux',
#    'endovasculaires',
#    '(',
#    'lbev',
#    ')'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ PUN ADJ PUN',
#   'Fréquence (TF)': 6,
#   'LLR': 59.240339643705,
#   'p-value': 1.3954370217322105e-14},
#  {'Terme': ('biomatériaux', 'endovasculaires'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 107.66078496486648,
#   'p-value': 3.1895146704339608e-25},
#  {'Terme': ('biomatériaux', 'endovasculaires', '(', 'lbev', ')'),
#   'Structure syntaxique': 'NOM ADJ PUN ADJ PUN',
#   'Fréquence (TF)': 6,
#   'LLR': 59.240339643705,
#   'p-value': 1.3954370217322105e-14},
#  {'Terme': ('laboratoire', 'de', 'biomatériaux'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 77.89456434009992,
#   'p-value': 1.086900728804354e-18},
#  {'Terme': ('laboratoire', 'de', 'biomatériaux', 'endovasculaires'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 135.21440449781306,
#   'p-value': 2.9637334295813215e-31},
#  {'Terme': ('laboratoire',
#    'de',
#    'biomatériaux',
#    'endovasculaires',
#    '(',
#    'lbev',
#    ')'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ PUN ADJ PUN',
#   'Fréquence (TF)': 6,
#   'LLR': 59.240339643705,
#   'p-value': 1.3954370217322105e-14},
#  {'Terme': ('biomatériaux', 'endovasculaires'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 107.66078496486648,
#   'p-value': 3.1895146704339608e-25},
#  {'Terme': ('biomatériaux', 'endovasculaires', '(', 'lbev', ')'),
#   'Structure syntaxique': 'NOM ADJ PUN ADJ PUN',
#   'Fréquence (TF)': 6,
#   'LLR': 59.240339643705,
#   'p-value': 1.3954370217322105e-14},
#  {'Terme': ('laboratoire', 'étudie'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence (TF)': 10,
#   'LLR': 119.71678920332435,
#   'p-value': 7.296879676356065e-28},
#  {'Terme': ('laboratoire', 'de', 'biorhéologie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 105.44286958829161,
#   'p-value': 9.7673747040687e-25},
#  {'Terme': ('laboratoire',
#    'de',
#    'biorhéologie',
#    'et',
#    "d'",
#    'ultrasonographie'),
#   'Structure syntaxique': 'NOM PRP NOM KON PRP NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 137.26300118725527,
#   'p-value': 1.0562653199177517e-31},
#  {'Terme': ('laboratoire',
#    'de',
#    'biorhéologie',
#    'et',
#    "d'",
#    'ultrasonographie',
#    'médicale'),
#   'Structure syntaxique': 'NOM PRP NOM KON PRP NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 88.65178355730299,
#   'p-value': 4.7080195994885134e-21},
#  {'Terme': ('ultrasonographie', 'médicale'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 8,
#   'LLR': 99.1140141999055,
#   'p-value': 2.3837539449089322e-23},
#  {'Terme': ('ultrasonographie', 'médicale', '(', 'lbum', ')'),
#   'Structure syntaxique': 'NOM ADJ PUN NOM PUN',
#   'Fréquence (TF)': 6,
#   'LLR': 59.240339643705,
#   'p-value': 1.3954370217322105e-14},
#  {'Terme': ('laboratoire', 'de', 'biorhéologie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 105.44286958829161,
#   'p-value': 9.7673747040687e-25},
#  {'Terme': ('laboratoire',
#    'de',
#    'biorhéologie',
#    'et',
#    "d'",
#    'ultrasonographie'),
#   'Structure syntaxique': 'NOM PRP NOM KON PRP NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 137.26300118725527,
#   'p-value': 1.0562653199177517e-31},
#  {'Terme': ('laboratoire',
#    'de',
#    'biorhéologie',
#    'et',
#    "d'",
#    'ultrasonographie',
#    'médicale'),
#   'Structure syntaxique': 'NOM PRP NOM KON PRP NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 88.65178355730299,
#   'p-value': 4.7080195994885134e-21},
#  {'Terme': ('ultrasonographie', 'médicale'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 8,
#   'LLR': 99.1140141999055,
#   'p-value': 2.3837539449089322e-23},
#  {'Terme': ('ultrasonographie', 'médicale', '(', 'lbum', ')'),
#   'Structure syntaxique': 'NOM ADJ PUN NOM PUN',
#   'Fréquence (TF)': 6,
#   'LLR': 59.240339643705,
#   'p-value': 1.3954370217322105e-14},
#  {'Terme': ('imagerie', 'médicale'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 49,
#   'LLR': 391.7923204134454,
#   'p-value': 3.370460194605764e-87},
#  {'Terme': ('techniques', "d'", 'imagerie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 8,
#   'LLR': 82.90148094718262,
#   'p-value': 8.624654101091733e-20},
#  {'Terme': ('traitement', 'de', "l'", 'image'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM',
#   'Fréquence (TF)': 7,
#   'LLR': 103.39368121917569,
#   'p-value': 2.7474960868212046e-24},
#  {'Terme': ('traitement', 'de', "l'", 'image'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM',
#   'Fréquence (TF)': 7,
#   'LLR': 103.39368121917569,
#   'p-value': 2.7474960868212046e-24},
#  {'Terme': ('champs', "d'", 'intérêts'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 12,
#   'LLR': 115.20067014875534,
#   'p-value': 7.11235612825707e-27},
#  {'Terme': ('pathologies', 'vasculaires'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 72.62503509406154,
#   'p-value': 1.5677760516095098e-17},
#  {'Terme': ('laboratoire', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 40,
#   'LLR': 197.10524229530256,
#   'p-value': 8.944485004486098e-45},
#  {'Terme': ('laboratoire', 'de', 'recherche', 'en', 'neuroradiologie'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 101.99904463436442,
#   'p-value': 5.5548546004490885e-24},
#  {'Terme': ('laboratoire',
#    'de',
#    'recherche',
#    'en',
#    'neuroradiologie',
#    'interventionnelle'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 119.19120349413346,
#   'p-value': 9.510574104297958e-28},
#  {'Terme': ('recherche', 'en', 'neuroradiologie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 66.91395189725101,
#   'p-value': 2.8362051322691173e-16},
#  {'Terme': ('recherche', 'en', 'neuroradiologie', 'interventionnelle'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 119.19120349413346,
#   'p-value': 9.510574104297958e-28},
#  {'Terme': ('neuroradiologie', 'interventionnelle'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 9,
#   'LLR': 149.59611561605885,
#   'p-value': 2.1244182060411563e-34},
#  {'Terme': ('laboratoire', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 40,
#   'LLR': 197.10524229530256,
#   'p-value': 8.944485004486098e-45},
#  {'Terme': ('laboratoire', 'de', 'recherche', 'en', 'neuroradiologie'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 101.99904463436442,
#   'p-value': 5.5548546004490885e-24},
#  {'Terme': ('laboratoire',
#    'de',
#    'recherche',
#    'en',
#    'neuroradiologie',
#    'interventionnelle'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 119.19120349413346,
#   'p-value': 9.510574104297958e-28},
#  {'Terme': ('recherche', 'en', 'neuroradiologie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 66.91395189725101,
#   'p-value': 2.8362051322691173e-16},
#  {'Terme': ('recherche', 'en', 'neuroradiologie', 'interventionnelle'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 119.19120349413346,
#   'p-value': 9.510574104297958e-28},
#  {'Terme': ('neuroradiologie', 'interventionnelle'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 9,
#   'LLR': 149.59611561605885,
#   'p-value': 2.1244182060411563e-34},
#  {'Terme': ('pathologies', 'vasculaires'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 72.62503509406154,
#   'p-value': 1.5677760516095098e-17},
#  {'Terme': ('unité', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 30,
#   'LLR': 145.97948228688696,
#   'p-value': 1.3116761054411597e-33},
#  {'Terme': ('recherche', 'fondamentale'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 80,
#   'LLR': 588.1227982880122,
#   'p-value': 6.415459034269594e-130},
#  {'Terme': ('unité', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 30,
#   'LLR': 145.97948228688696,
#   'p-value': 1.3116761054411597e-33},
#  {'Terme': ('recherche', 'clinique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 294,
#   'LLR': 1106.2883210413204,
#   'p-value': 1.4195725757391618e-242},
#  {'Terme': ('efforts', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 44.54260724006926,
#   'p-value': 2.4888150424557263e-11},
#  {'Terme': ('traitement', 'endovasculaire'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 8,
#   'LLR': 80.44471769398253,
#   'p-value': 2.9895267143387506e-19},
#  {'Terme': ('modèles', 'animaux'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 47,
#   'LLR': 704.7825944022165,
#   'p-value': 2.727109595124228e-155},
#  {'Terme': ('unité', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 30,
#   'LLR': 145.97948228688696,
#   'p-value': 1.3116761054411597e-33},
#  {'Terme': ('recherche', 'clinique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 294,
#   'LLR': 1106.2883210413204,
#   'p-value': 1.4195725757391618e-242},
#  {'Terme': ('études', 'cliniques'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 37,
#   'LLR': 320.74384459979785,
#   'p-value': 9.97416070361183e-72},
#  {'Terme': ('gestion', 'des', 'données'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 8,
#   'LLR': 66.35893623966714,
#   'p-value': 3.758510618318039e-16},
#  {'Terme': ('retraitement', 'des', 'dispositifs'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 14,
#   'LLR': 294.06173108617384,
#   'p-value': 6.479816391286287e-66},
#  {'Terme': ('retraitement', 'des', 'dispositifs', 'médicaux'),
#   'Structure syntaxique': 'NOM PRP:det NOM ADJ',
#   'Fréquence (TF)': 14,
#   'LLR': 264.4052187678165,
#   'p-value': 1.8806761453206088e-59},
#  {'Terme': ('dispositifs', 'médicaux'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 18,
#   'LLR': 292.40569547475445,
#   'p-value': 1.4872513775448807e-65},
#  {'Terme': ('rôle', 'méconnu'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence (TF)': 9,
#   'LLR': 143.93428189704494,
#   'p-value': 3.672477393017039e-33},
#  {'Terme': ('patients', 'reçoivent'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence (TF)': 13,
#   'LLR': 113.04548908565936,
#   'p-value': 2.1088082338525303e-26},
#  {'Terme': ('soins', 'de', 'qualité'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 9,
#   'LLR': 61.73688626070179,
#   'p-value': 3.925572323578662e-15},
#  {'Terme': ('période', 'de', 'pandémie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 11,
#   'LLR': 120.14695034069874,
#   'p-value': 5.874386442133554e-28},
#  {'Terme': ('escouade', 'reconnaissance'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 107.96312721141824,
#   'p-value': 2.73825360688201e-25},
#  {'Terme': ('retraitement', 'des', 'dispositifs'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 14,
#   'LLR': 294.06173108617384,
#   'p-value': 6.479816391286287e-66},
#  {'Terme': ('retraitement', 'des', 'dispositifs', 'médicaux'),
#   'Structure syntaxique': 'NOM PRP:det NOM ADJ',
#   'Fréquence (TF)': 14,
#   'LLR': 264.4052187678165,
#   'p-value': 1.8806761453206088e-59},
#  {'Terme': ('dispositifs', 'médicaux'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 18,
#   'LLR': 292.40569547475445,
#   'p-value': 1.4872513775448807e-65},
#  {'Terme': ('prélèvement', 'guide'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence (TF)': 1271,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('radiologie', 'en', 'imagerie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 89.54996571187822,
#   'p-value': 2.989909875453311e-21},
#  {'Terme': ('prélèvement', 'guide'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence (TF)': 1271,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('traitement', 'intraveineux'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 8,
#   'LLR': 93.92370919242289,
#   'p-value': 3.2792255313105555e-22},
#  {'Terme': ('fuite', "d'", 'un', 'médicament'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM',
#   'Fréquence (TF)': 8,
#   'LLR': 128.08736370418478,
#   'p-value': 1.0740943674254887e-29},
#  {'Terme': ('médicament', 'hors', 'des', 'veines'),
#   'Structure syntaxique': 'NOM PRP PRP:det NOM',
#   'Fréquence (TF)': 8,
#   'LLR': 174.18947856511187,
#   'p-value': 8.999243599812708e-40},
#  {'Terme': ('signes', 'et', 'symptômes'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence (TF)': 8,
#   'LLR': 106.56303123300658,
#   'p-value': 5.549892202660158e-25},
#  {'Terme': ('symptômes', 'à', 'surveiller'),
#   'Structure syntaxique': 'NOM PRP VER:infi',
#   'Fréquence (TF)': 10,
#   'LLR': 170.81369101516603,
#   'p-value': 4.914175675551951e-39},
#  {'Terme': ('fiche', 'recherche'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence (TF)': 404,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('prélèvement', 'guide'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence (TF)': 1271,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('ans', 'nellie'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence (TF)': 6,
#   'LLR': 90.12302426847556,
#   'p-value': 2.2380206842101396e-21},
#  {'Terme': ('ans', 'axelle'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence (TF)': 6,
#   'LLR': 90.12302426847556,
#   'p-value': 2.2380206842101396e-21},
#  {'Terme': ('ans', 'à', 'chaque', 'soir'),
#   'Structure syntaxique': 'NOM PRP PRO:IND NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 123.58482289201159,
#   'p-value': 1.0385046351172767e-28},
#  {'Terme': ('prélèvement', 'guide'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence (TF)': 1271,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('prélèvement', 'guide'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence (TF)': 1271,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('mccpm', 'chercheur'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 73.43321139357398,
#   'p-value': 1.0409968164337962e-17},
#  {'Terme': ('santé', 'centre'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 108,
#   'LLR': 291.5796856448338,
#   'p-value': 2.250921141532083e-65},
#  {'Terme': ('santé', 'centre', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM NOM PRP NOM',
#   'Fréquence (TF)': 106,
#   'LLR': 989.4310681304945,
#   'p-value': 3.561089621188529e-217},
#  {'Terme': ('santé', 'centre', 'de', 'recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 106,
#   'LLR': 1088.5061098001947,
#   'p-value': 1.039987343296366e-238},
#  {'Terme': ('santé', 'centre', 'de', 'recherche', 'du', 'chum', 'axe'),
#   'Structure syntaxique': 'NOM NOM PRP NOM PRP:det NOM NOM',
#   'Fréquence (TF)': 104,
#   'LLR': 1344.4836023498096,
#   'p-value': 2.4346421163171925e-294},
#  {'Terme': ('centre', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 1421,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('centre', 'de', 'recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 1173,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('centre', 'de', 'recherche', 'du', 'chum', 'axe'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM NOM',
#   'Fréquence (TF)': 932,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 1199,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('recherche', 'du', 'chum', 'axe'),
#   'Structure syntaxique': 'NOM PRP:det NOM NOM',
#   'Fréquence (TF)': 934,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('recherche', 'du', 'chum', 'axe', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP:det NOM NOM PRP NOM',
#   'Fréquence (TF)': 934,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('chum', 'axe'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 934,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('chum', 'axe', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM NOM PRP NOM',
#   'Fréquence (TF)': 934,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('chum', 'axe', 'de', 'recherche', 'imagerie'),
#   'Structure syntaxique': 'NOM NOM PRP NOM NOM',
#   'Fréquence (TF)': 92,
#   'LLR': 787.2557629560255,
#   'p-value': 3.183577105776979e-173},
#  {'Terme': ('axe', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 965,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('axe', 'de', 'recherche', 'imagerie'),
#   'Structure syntaxique': 'NOM PRP NOM NOM',
#   'Fréquence (TF)': 93,
#   'LLR': 791.7362384375305,
#   'p-value': 3.378805937703017e-174},
#  {'Terme': ('recherche', 'imagerie'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 103,
#   'LLR': 427.0694212988633,
#   'p-value': 7.05883874569681e-95},
#  {'Terme': ('recherche', 'imagerie', 'et', 'ingénierie'),
#   'Structure syntaxique': 'NOM NOM KON NOM',
#   'Fréquence (TF)': 93,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('imagerie', 'et', 'ingénierie'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence (TF)': 149,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('imagerie', 'et', 'ingénierie', 'physicien'),
#   'Structure syntaxique': 'NOM KON NOM NOM',
#   'Fréquence (TF)': 8,
#   'LLR': 113.64843800603998,
#   'p-value': 1.555868235281501e-26},
#  {'Terme': ('ingénierie', 'physicien'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 8,
#   'LLR': 108.9085668661316,
#   'p-value': 1.6994726256812766e-25},
#  {'Terme': ('besoin', "d'", 'assistance'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 914,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('besoin', "d'", 'assistance', 'immédiate'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ',
#   'Fréquence (TF)': 914,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('assistance', 'immédiate'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 914,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('cabinet', 'du', 'médecin'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 915,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('mesures', 'appropriées'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 914,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('service', "d'", 'urgence'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 914,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('intérêts', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 825,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('intérêts', 'de', 'recherche', 'développement'),
#   'Structure syntaxique': 'NOM PRP NOM NOM',
#   'Fréquence (TF)': 18,
#   'LLR': 94.37371871673143,
#   'p-value': 2.612377921930379e-22},
#  {'Terme': ('recherche', 'développement'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 18,
#   'LLR': 16.377893255911545,
#   'p-value': 5.1886884310807406e-05},
#  {'Terme': ('développement', 'de', 'techniques'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 10,
#   'LLR': 95.01461761392959,
#   'p-value': 1.889846007702303e-22},
#  {'Terme': ('recherche', 'préclinique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 7,
#   'LLR': 47.43651303968749,
#   'p-value': 5.681449737601714e-12},
#  {'Terme': ('scholar', 'recherche'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence (TF)': 26,
#   'LLR': 175.16444356615418,
#   'p-value': 5.511839039820948e-40},
#  {'Terme': ('prélèvement', 'guide'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence (TF)': 1271,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('travail', 'exceptionnel'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 22,
#   'LLR': 249.00757291900482,
#   'p-value': 4.2736546091304635e-56},
#  {'Terme': ('biologiste', 'moléculaire'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 96.93047257017439,
#   'p-value': 7.180502107525535e-23},
#  {'Terme': ('biologiste', 'moléculaire', 'au', 'laboratoire'),
#   'Structure syntaxique': 'NOM ADJ PRP:det NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 91.3343408902371,
#   'p-value': 1.2133651340457426e-21},
#  {'Terme': ('biologiste',
#    'moléculaire',
#    'au',
#    'laboratoire',
#    'de',
#    'biologie'),
#   'Structure syntaxique': 'NOM ADJ PRP:det NOM PRP NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 105.44286958834361,
#   'p-value': 9.767374703812415e-25},
#  {'Terme': ('biologiste',
#    'moléculaire',
#    'au',
#    'laboratoire',
#    'de',
#    'biologie',
#    'moléculaire'),
#   'Structure syntaxique': 'NOM ADJ PRP:det NOM PRP NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 102.67172214065027,
#   'p-value': 3.955504503106819e-24},
#  {'Terme': ('laboratoire', 'de', 'biologie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 12,
#   'LLR': 126.63368597567839,
#   'p-value': 2.2343211151592755e-29},
#  {'Terme': ('laboratoire', 'de', 'biologie', 'moléculaire'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ',
#   'Fréquence (TF)': 12,
#   'LLR': 205.72039824923678,
#   'p-value': 1.1792298530098977e-46},
#  {'Terme': ('laboratoire', 'de', 'biologie', 'moléculaire', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ PRP:det NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 61.51338546427002,
#   'p-value': 4.397434795361712e-15},
#  {'Terme': ('biologie', 'moléculaire'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 54,
#   'LLR': 736.6910859476451,
#   'p-value': 3.1424839894023347e-162},
#  {'Terme': ('biologie', 'moléculaire', 'du', 'chum'),
#   'Structure syntaxique': 'NOM ADJ PRP:det NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 61.51338546427002,
#   'p-value': 4.397434795361712e-15},
#  {'Terme': ('population', 'du', 'québec'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 10,
#   'LLR': 140.85481809428552,
#   'p-value': 1.730966670713386e-32},
#  {'Terme': ('prélèvement', 'guide'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence (TF)': 1271,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('urgence', 'salle'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 9,
#   'LLR': 25.36834954751402,
#   'p-value': 4.7362555242987303e-07},
#  {'Terme': ('urgence', 'salle', 'de', 'formation'),
#   'Structure syntaxique': 'NOM NOM PRP NOM',
#   'Fréquence (TF)': 9,
#   'LLR': 131.1549257519679,
#   'p-value': 2.2901664625144444e-30},
#  {'Terme': ('salle', 'de', 'formation'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 31,
#   'LLR': 294.75605788234685,
#   'p-value': 4.5738599051098674e-66},
#  {'Terme': ('projection', 'ordinateur'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 8,
#   'LLR': 143.82537865499685,
#   'p-value': 3.879442507747671e-33},
#  {'Terme': ('projection', 'ordinateur', 'au', 'lutrin'),
#   'Structure syntaxique': 'NOM ADJ PRP:det NOM',
#   'Fréquence (TF)': 8,
#   'LLR': 203.90964179791447,
#   'p-value': 2.9288742434169587e-46},
#  {'Terme': ('projection', 'ordinateur', 'au', 'lutrin', 'avec', 'possibilité'),
#   'Structure syntaxique': 'NOM ADJ PRP:det NOM PRP NOM',
#   'Fréquence (TF)': 8,
#   'LLR': 147.8256716215559,
#   'p-value': 5.1789130109987075e-34},
#  {'Terme': ('lutrin', 'avec', 'possibilité'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 8,
#   'LLR': 147.8256716215559,
#   'p-value': 5.1789130109987075e-34},
#  {'Terme': ('lutrin', 'avec', 'possibilité', 'de', 'brancher'),
#   'Structure syntaxique': 'NOM PRP NOM PRP VER:infi',
#   'Fréquence (TF)': 8,
#   'LLR': 178.0457212580259,
#   'p-value': 1.294587065681902e-40},
#  {'Terme': ('possibilité', 'de', 'brancher'),
#   'Structure syntaxique': 'NOM PRP VER:infi',
#   'Fréquence (TF)': 8,
#   'LLR': 130.64227375479328,
#   'p-value': 2.9650084219530236e-30},
#  {'Terme': ('possibilité', 'de', 'brancher', 'un', 'portable'),
#   'Structure syntaxique': 'NOM PRP VER:infi DET:ART ADJ',
#   'Fréquence (TF)': 8,
#   'LLR': 175.0684437462478,
#   'p-value': 5.7844269600257086e-40},
#  {'Terme': ('internet', 'sans', 'fil'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 8,
#   'LLR': 165.27593906832934,
#   'p-value': 7.962180091557534e-38},
#  {'Terme': ('île', 'sans-fil'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 8,
#   'LLR': 184.78821486630127,
#   'p-value': 4.365486588448443e-42},
#  {'Terme': ('île', 'sans-fil', 'chum'),
#   'Structure syntaxique': 'NOM NOM NOM',
#   'Fréquence (TF)': 8,
#   'LLR': 82.02050372609632,
#   'p-value': 1.346822168171793e-19},
#  {'Terme': ('sans-fil', 'chum'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 8,
#   'LLR': 82.02050372609632,
#   'p-value': 1.346822168171793e-19},
#  {'Terme': ('salles', 'recherche'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence (TF)': 49,
#   'LLR': 248.1831365173159,
#   'p-value': 6.464545146847257e-56},
#  {'Terme': ('fiche', 'recherche'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence (TF)': 404,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('prélèvement', 'guide'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence (TF)': 1271,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('cadre', 'du', 'concours'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 16,
#   'LLR': 221.95652708986276,
#   'p-value': 3.38550556341458e-50},
#  {'Terme': ('cadre', 'du', 'concours', 'de', 'subventions'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM',
#   'Fréquence (TF)': 11,
#   'LLR': 193.73833254431443,
#   'p-value': 4.857071145242533e-44},
#  {'Terme': ('cadre', 'du', 'concours', 'de', 'subventions', 'projet'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM NOM',
#   'Fréquence (TF)': 9,
#   'LLR': 125.47076478135912,
#   'p-value': 4.0146110496192254e-29},
#  {'Terme': ('concours', 'de', 'subventions'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 18,
#   'LLR': 305.39311296719575,
#   'p-value': 2.2020538226583236e-68},
#  {'Terme': ('concours', 'de', 'subventions', 'projet'),
#   'Structure syntaxique': 'NOM PRP NOM NOM',
#   'Fréquence (TF)': 16,
#   'LLR': 229.25620151300106,
#   'p-value': 8.660715034121344e-52},
#  {'Terme': ('subventions', 'projet'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 18,
#   'LLR': 172.08193698895496,
#   'p-value': 2.596967254887094e-39},
#  {'Terme': ('instituts', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 114,
#   'LLR': 1036.353165771676,
#   'p-value': 2.2518399478849214e-227},
#  {'Terme': ('instituts', 'de', 'recherche', 'en', 'santé'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM',
#   'Fréquence (TF)': 114,
#   'LLR': 1331.214580503976,
#   'p-value': 1.8617318506428992e-291},
#  {'Terme': ('instituts', 'de', 'recherche', 'en', 'santé', 'du', 'canada'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 110,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('recherche', 'en', 'santé'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 206,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('recherche', 'en', 'santé', 'du', 'canada'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 113,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('recherche', 'en', 'santé', 'du', 'canada', '(', 'irsc', ')'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM PUN NOM PUN',
#   'Fréquence (TF)': 43,
#   'LLR': 424.7744077060973,
#   'p-value': 2.22973764579163e-94},
#  {'Terme': ('santé', 'du', 'canada'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 116,
#   'LLR': 1469.8768758633407,
#   'p-value': 0.0},
#  {'Terme': ('santé', 'du', 'canada', '(', 'irsc', ')'),
#   'Structure syntaxique': 'NOM PRP:det NOM PUN NOM PUN',
#   'Fréquence (TF)': 44,
#   'LLR': 434.6589396210033,
#   'p-value': 1.5735580927516487e-96},
#  {'Terme': ('canada', '(', 'irsc', ')'),
#   'Structure syntaxique': 'NOM PUN NOM PUN',
#   'Fréquence (TF)': 44,
#   'LLR': 434.6589396210033,
#   'p-value': 1.5735580927516487e-96},
#  {'Terme': ('équipes', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 67,
#   'LLR': 358.9773447381622,
#   'p-value': 4.701809927195799e-80},
#  {'Terme': ('équipes', 'de', 'recherche', 'du', 'centre'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 57.477773124706644,
#   'p-value': 3.418202982455083e-14},
#  {'Terme': ('équipes', 'de', 'recherche', 'du', 'centre', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM PRP NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 55.94292012744091,
#   'p-value': 7.460591650042098e-14},
#  {'Terme': ('recherche', 'du', 'centre'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 110,
#   'LLR': 426.3115903714329,
#   'p-value': 1.0319960549610833e-94},
#  {'Terme': ('recherche', 'du', 'centre', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM',
#   'Fréquence (TF)': 12,
#   'LLR': 111.89332869800236,
#   'p-value': 3.770614671007743e-26},
#  {'Terme': ('recherche', 'du', 'centre', 'de', 'recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 44.94930521795659,
#   'p-value': 2.022019395697391e-11},
#  {'Terme': ('centre', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 1421,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('centre', 'de', 'recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 1173,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('centre', 'de', 'recherche', 'du', 'chum', '(', 'crchum', ')'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM PUN NOM PUN',
#   'Fréquence (TF)': 66,
#   'LLR': 652.1885154596481,
#   'p-value': 7.46712472993243e-144},
#  {'Terme': ('recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 1199,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('recherche', 'du', 'chum', '(', 'crchum', ')'),
#   'Structure syntaxique': 'NOM PRP:det NOM PUN NOM PUN',
#   'Fréquence (TF)': 67,
#   'LLR': 662.0794030931243,
#   'p-value': 5.2737052539429695e-146},
#  {'Terme': ('chum', '(', 'crchum', ')'),
#   'Structure syntaxique': 'NOM PUN NOM PUN',
#   'Fréquence (TF)': 67,
#   'LLR': 662.0794030931243,
#   'p-value': 5.2737052539429695e-146},
#  {'Terme': ('demandes', 'financées'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence (TF)': 7,
#   'LLR': 117.46299200549716,
#   'p-value': 2.2730196424983636e-27},
#  {'Terme': ('taux', 'de', 'succès'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 26,
#   'LLR': 400.9409295394659,
#   'p-value': 3.436423775723366e-89},
#  {'Terme': ('taux', 'de', 'succès', 'du', 'crchum'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 74.65673020814866,
#   'p-value': 5.6010365257758024e-18},
#  {'Terme': ('succès', 'du', 'crchum'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 7,
#   'LLR': 74.89762959741216,
#   'p-value': 4.957649077512385e-18},
#  {'Terme': ('crchum', 'tient'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence (TF)': 16,
#   'LLR': 153.51427206439487,
#   'p-value': 2.9571999878109324e-35},
#  {'Terme': ('greg', 'fitzharris'),
#   'Structure syntaxique': 'NOM VER:simp',
#   'Fréquence (TF)': 27,
#   'LLR': 556.6414906072661,
#   'p-value': 4.520762149362955e-123},
#  {'Terme': ('subvention', 'projet'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 74,
#   'LLR': 886.3772829609475,
#   'p-value': 8.979677188094153e-195},
#  {'Terme': ('subvention', 'projet', 'octroyée'),
#   'Structure syntaxique': 'NOM NOM VER:pper',
#   'Fréquence (TF)': 72,
#   'LLR': 1463.3810281551207,
#   'p-value': 0.0},
#  {'Terme': ('projet', 'octroyée'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence (TF)': 72,
#   'LLR': 1059.1244794769464,
#   'p-value': 2.5298742153563473e-232},
#  {'Terme': ('marie-hélène', 'mayrand'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 7,
#   'LLR': 129.73425096275292,
#   'p-value': 4.6848176935408e-30},
#  {'Terme': ('subvention', 'projet'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 74,
#   'LLR': 886.3772829609475,
#   'p-value': 8.979677188094153e-195},
#  {'Terme': ('subvention', 'projet', 'octroyée'),
#   'Structure syntaxique': 'NOM NOM VER:pper',
#   'Fréquence (TF)': 72,
#   'LLR': 1463.3810281551207,
#   'p-value': 0.0},
#  {'Terme': ('projet', 'octroyée'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence (TF)': 72,
#   'LLR': 1059.1244794769464,
#   'p-value': 2.5298742153563473e-232},
#  {'Terme': ('subvention', 'projet'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 74,
#   'LLR': 886.3772829609475,
#   'p-value': 8.979677188094153e-195},
#  {'Terme': ('subvention', 'projet', 'octroyée'),
#   'Structure syntaxique': 'NOM NOM VER:pper',
#   'Fréquence (TF)': 72,
#   'LLR': 1463.3810281551207,
#   'p-value': 0.0},
#  {'Terme': ('projet', 'octroyée'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence (TF)': 72,
#   'LLR': 1059.1244794769464,
#   'p-value': 2.5298742153563473e-232},
#  {'Terme': ('subvention', 'projet'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 74,
#   'LLR': 886.3772829609475,
#   'p-value': 8.979677188094153e-195},
#  {'Terme': ('subvention', 'projet', 'octroyée'),
#   'Structure syntaxique': 'NOM NOM VER:pper',
#   'Fréquence (TF)': 72,
#   'LLR': 1463.3810281551207,
#   'p-value': 0.0},
#  {'Terme': ('projet', 'octroyée'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence (TF)': 72,
#   'LLR': 1059.1244794769464,
#   'p-value': 2.5298742153563473e-232},
#  {'Terme': ('subvention', 'projet'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 74,
#   'LLR': 886.3772829609475,
#   'p-value': 8.979677188094153e-195},
#  {'Terme': ('subvention', 'projet', 'octroyée'),
#   'Structure syntaxique': 'NOM NOM VER:pper',
#   'Fréquence (TF)': 72,
#   'LLR': 1463.3810281551207,
#   'p-value': 0.0},
#  {'Terme': ('projet', 'octroyée'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence (TF)': 72,
#   'LLR': 1059.1244794769464,
#   'p-value': 2.5298742153563473e-232},
#  {'Terme': ('subvention', 'projet'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 74,
#   'LLR': 886.3772829609475,
#   'p-value': 8.979677188094153e-195},
#  {'Terme': ('subvention', 'projet', 'octroyée'),
#   'Structure syntaxique': 'NOM NOM VER:pper',
#   'Fréquence (TF)': 72,
#   'LLR': 1463.3810281551207,
#   'p-value': 0.0},
#  {'Terme': ('projet', 'octroyée'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence (TF)': 72,
#   'LLR': 1059.1244794769464,
#   'p-value': 2.5298742153563473e-232},
#  {'Terme': ('subvention', 'projet'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 74,
#   'LLR': 886.3772829609475,
#   'p-value': 8.979677188094153e-195},
#  {'Terme': ('subvention', 'projet', 'octroyée'),
#   'Structure syntaxique': 'NOM NOM VER:pper',
#   'Fréquence (TF)': 72,
#   'LLR': 1463.3810281551207,
#   'p-value': 0.0},
#  {'Terme': ('projet', 'octroyée'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence (TF)': 72,
#   'LLR': 1059.1244794769464,
#   'p-value': 2.5298742153563473e-232},
#  {'Terme': ('shao-ling', 'zhang'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 122.10487728148708,
#   'p-value': 2.1895237157848225e-28},
#  {'Terme': ('subventions', 'projet'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 18,
#   'LLR': 172.08193698895496,
#   'p-value': 2.596967254887094e-39},
#  {'Terme': ('instituts', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 114,
#   'LLR': 1036.353165771676,
#   'p-value': 2.2518399478849214e-227},
#  {'Terme': ('instituts', 'de', 'recherche', 'en', 'santé'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM',
#   'Fréquence (TF)': 114,
#   'LLR': 1331.214580503976,
#   'p-value': 1.8617318506428992e-291},
#  {'Terme': ('instituts', 'de', 'recherche', 'en', 'santé', 'du', 'canada'),
#   'Structure syntaxique': 'NOM PRP NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 110,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('recherche', 'en', 'santé'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 206,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('recherche', 'en', 'santé', 'du', 'canada'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 113,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('santé', 'du', 'canada'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 116,
#   'LLR': 1469.8768758633407,
#   'p-value': 0.0},
#  {'Terme': ('santé', 'du', 'canada', 'financent'),
#   'Structure syntaxique': 'NOM PRP:det NOM VER:pres',
#   'Fréquence (TF)': 8,
#   'LLR': 132.79781227658924,
#   'p-value': 1.0010484827351437e-30},
#  {'Terme': ('canada', 'financent'),
#   'Structure syntaxique': 'NOM VER:pres',
#   'Fréquence (TF)': 8,
#   'LLR': 101.04363111261769,
#   'p-value': 8.997943801887114e-24},
#  {'Terme': ('millions', 'de', 'dollars'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 22,
#   'LLR': 421.7731233516994,
#   'p-value': 1.0034758219803943e-93},
#  {'Terme': ('taux', 'de', 'succès'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 26,
#   'LLR': 400.9409295394659,
#   'p-value': 3.436423775723366e-89},
#  {'Terme': ('résultats', 'de', 'concours'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 10,
#   'LLR': 118.03241500958423,
#   'p-value': 1.705774276452202e-27},
#  {'Terme': ('résultats', 'de', 'concours', 'des', 'irsc'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 10,
#   'LLR': 173.6454427268743,
#   'p-value': 1.1830784886944723e-39},
#  {'Terme': ('concours', 'des', 'irsc'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 11,
#   'LLR': 184.19134250856894,
#   'p-value': 5.893006972771957e-42},
#  {'Terme': ('centre', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 1421,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('centre', 'de', 'recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 1173,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('centre', 'de', 'recherche', 'du', 'chum', 'axe'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM NOM',
#   'Fréquence (TF)': 932,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('recherche', 'du', 'chum'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 1199,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('recherche', 'du', 'chum', 'axe'),
#   'Structure syntaxique': 'NOM PRP:det NOM NOM',
#   'Fréquence (TF)': 934,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('recherche', 'du', 'chum', 'axe', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP:det NOM NOM PRP NOM',
#   'Fréquence (TF)': 934,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('recherche',
#    'du',
#    'chum',
#    'axe',
#    'de',
#    'recherche',
#    'cardiométabolique'),
#   'Structure syntaxique': 'NOM PRP:det NOM NOM PRP NOM ADJ',
#   'Fréquence (TF)': 148,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('chum', 'axe'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 934,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('chum', 'axe', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM NOM PRP NOM',
#   'Fréquence (TF)': 934,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('chum', 'axe', 'de', 'recherche', 'cardiométabolique'),
#   'Structure syntaxique': 'NOM NOM PRP NOM ADJ',
#   'Fréquence (TF)': 148,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('chum',
#    'axe',
#    'de',
#    'recherche',
#    'cardiométabolique',
#    'directeur'),
#   'Structure syntaxique': 'NOM NOM PRP NOM ADJ ADJ',
#   'Fréquence (TF)': 14,
#   'LLR': 130.23870714291098,
#   'p-value': 3.6334668953151155e-30},
#  {'Terme': ('axe', 'de', 'recherche'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 965,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('axe', 'de', 'recherche', 'cardiométabolique'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ',
#   'Fréquence (TF)': 149,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('axe', 'de', 'recherche', 'cardiométabolique', 'directeur'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ ADJ',
#   'Fréquence (TF)': 14,
#   'LLR': 130.04135130447665,
#   'p-value': 4.0132933752011286e-30},
#  {'Terme': ('axe',
#    'de',
#    'recherche',
#    'cardiométabolique',
#    'directeur',
#    'laboratoire'),
#   'Structure syntaxique': 'NOM PRP NOM ADJ ADJ NOM',
#   'Fréquence (TF)': 10,
#   'LLR': 135.55675613755588,
#   'p-value': 2.4943485984356346e-31},
#  {'Terme': ('recherche', 'cardiométabolique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 149,
#   'LLR': 1139.534050564649,
#   'p-value': 8.443472129053618e-250},
#  {'Terme': ('recherche', 'cardiométabolique', 'directeur'),
#   'Structure syntaxique': 'NOM ADJ ADJ',
#   'Fréquence (TF)': 14,
#   'LLR': 130.04135130447665,
#   'p-value': 4.0132933752011286e-30},
#  {'Terme': ('recherche', 'cardiométabolique', 'directeur', 'laboratoire'),
#   'Structure syntaxique': 'NOM ADJ ADJ NOM',
#   'Fréquence (TF)': 10,
#   'LLR': 135.55675613755588,
#   'p-value': 2.4943485984356346e-31},
#  {'Terme': ('crchum', 'professeur'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 42,
#   'LLR': 196.49584276203993,
#   'p-value': 1.2149279012763904e-44},
#  {'Terme': ('professeur', 'sous', 'octroi'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 122.24699658411086,
#   'p-value': 2.0381691375263464e-28},
#  {'Terme': ('octroi', 'titulaire'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 8,
#   'LLR': 82.84847472518541,
#   'p-value': 8.85905833190302e-20},
#  {'Terme': ('octroi', 'titulaire', 'département'),
#   'Structure syntaxique': 'NOM ADJ NOM',
#   'Fréquence (TF)': 8,
#   'LLR': 105.53812898716969,
#   'p-value': 9.308935023118572e-25},
#  {'Terme': ('octroi', 'titulaire', 'département', 'de', 'médecine'),
#   'Structure syntaxique': 'NOM ADJ NOM PRP NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 68.42153869876077,
#   'p-value': 1.3202759147905845e-16},
# ...
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 9,
#   'LLR': 112.33442688652471,
#   'p-value': 3.018485963193327e-26},
#  {'Terme': ('épisode', 'de', 'soins', 'au', 'service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM PRP NOM',
#   'Fréquence (TF)': 9,
#   'LLR': 142.07218957978935,
#   'p-value': 9.377707763306918e-33},
#  {'Terme': ('soins', 'au', 'service'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 9,
#   'LLR': 81.59982146537621,
#   'p-value': 1.666291946514779e-19},
#  {'Terme': ('soins', 'au', 'service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM',
#   'Fréquence (TF)': 9,
#   'LLR': 142.07218957978935,
#   'p-value': 9.377707763306918e-33},
#  {'Terme': ('soins',
#    'au',
#    'service',
#    'de',
#    'psychiatrie',
#    'des',
#    'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 9,
#   'LLR': 149.5512984940717,
#   'p-value': 2.172882044073154e-34},
#  {'Terme': ('service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 150,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('service', 'de', 'psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 93,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 137,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('cas', 'échéant'),
#   'Structure syntaxique': 'NOM VER:ppre',
#   'Fréquence (TF)': 6,
#   'LLR': 92.44205966929682,
#   'p-value': 6.932498465413862e-22},
#  {'Terme': ('épisode', 'de', 'soins'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 46,
#   'LLR': 549.1221745028479,
#   'p-value': 1.9541284703279048e-121},
#  {'Terme': ('épisode', 'de', 'soins', 'au', 'service'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 9,
#   'LLR': 112.33442688652471,
#   'p-value': 3.018485963193327e-26},
#  {'Terme': ('épisode', 'de', 'soins', 'au', 'service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM PRP NOM',
#   'Fréquence (TF)': 9,
#   'LLR': 142.07218957978935,
#   'p-value': 9.377707763306918e-33},
#  {'Terme': ('soins', 'au', 'service'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 9,
#   'LLR': 81.59982146537621,
#   'p-value': 1.666291946514779e-19},
#  {'Terme': ('soins', 'au', 'service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM',
#   'Fréquence (TF)': 9,
#   'LLR': 142.07218957978935,
#   'p-value': 9.377707763306918e-33},
#  {'Terme': ('soins',
#    'au',
#    'service',
#    'de',
#    'psychiatrie',
#    'des',
#    'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 9,
#   'LLR': 149.5512984940717,
#   'p-value': 2.172882044073154e-34},
#  {'Terme': ('service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 150,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('service', 'de', 'psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 93,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 137,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('médecin', 'psychiatre'),
#   'Structure syntaxique': 'NOM NOM',
#   'Fréquence (TF)': 9,
#   'LLR': 64.79334236209755,
#   'p-value': 8.317971318665554e-16},
#  {'Terme': ('rencontres', 'individuelles'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 9,
#   'LLR': 143.24396089939924,
#   'p-value': 5.198647060592892e-33},
#  {'Terme': ('professionnel', 'désigné'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence (TF)': 39,
#   'LLR': 555.6329009979338,
#   'p-value': 7.492323408925736e-123},
#  {'Terme': ('professionnel', 'désigné'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence (TF)': 39,
#   'LLR': 555.6329009979338,
#   'p-value': 7.492323408925736e-123},
#  {'Terme': ('intégration', 'des', 'soins'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 50.07085099281167,
#   'p-value': 1.482935976978573e-12},
#  {'Terme': ('épisode', 'de', 'soins'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 46,
#   'LLR': 549.1221745028479,
#   'p-value': 1.9541284703279048e-121},
#  {'Terme': ('professionnel', 'désigné'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence (TF)': 39,
#   'LLR': 555.6329009979338,
#   'p-value': 7.492323408925736e-123},
#  {'Terme': ('plan', 'de', 'traitement'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 31,
#   'LLR': 266.3332009959805,
#   'p-value': 7.146477386803936e-60},
#  {'Terme': ('long', 'de', "l'", 'épisode'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 116.17246326876905,
#   'p-value': 4.357099287015803e-27},
#  {'Terme': ('long', 'de', "l'", 'épisode', 'de', 'soins'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM PRP NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 74.44885551796882,
#   'p-value': 6.222974771206139e-18},
#  {'Terme': ('épisode', 'de', 'soins'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 46,
#   'LLR': 549.1221745028479,
#   'p-value': 1.9541284703279048e-121},
#  {'Terme': ('fin', 'de', "l'", 'épisode'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 110.4309538266416,
#   'p-value': 7.884429579604442e-26},
#  {'Terme': ('fin', 'de', "l'", 'épisode', 'de', 'soins'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM PRP NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 74.44885551796882,
#   'p-value': 6.222974771206139e-18},
#  {'Terme': ('épisode', 'de', 'soins'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 46,
#   'LLR': 549.1221745028479,
#   'p-value': 1.9541284703279048e-121},
#  {'Terme': ('service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 150,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('service', 'de', 'psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 93,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 137,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('épisode', 'de', 'soins'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 46,
#   'LLR': 549.1221745028479,
#   'p-value': 1.9541284703279048e-121},
#  {'Terme': ('épisode', 'de', 'soins', 'au', 'service'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 9,
#   'LLR': 112.33442688652471,
#   'p-value': 3.018485963193327e-26},
#  {'Terme': ('épisode', 'de', 'soins', 'au', 'service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM PRP NOM',
#   'Fréquence (TF)': 9,
#   'LLR': 142.07218957978935,
#   'p-value': 9.377707763306918e-33},
#  {'Terme': ('soins', 'au', 'service'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 9,
#   'LLR': 81.59982146537621,
#   'p-value': 1.666291946514779e-19},
#  {'Terme': ('soins', 'au', 'service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM',
#   'Fréquence (TF)': 9,
#   'LLR': 142.07218957978935,
#   'p-value': 9.377707763306918e-33},
#  {'Terme': ('soins',
#    'au',
#    'service',
#    'de',
#    'psychiatrie',
#    'des',
#    'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 9,
#   'LLR': 149.5512984940717,
#   'p-value': 2.172882044073154e-34},
#  {'Terme': ('service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 150,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('service', 'de', 'psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 93,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 137,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('évaluation', 'diagnostique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 48.68574234345019,
#   'p-value': 3.004426495608164e-12},
#  {'Terme': ('plan', 'de', 'traitement'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 31,
#   'LLR': 266.3332009959805,
#   'p-value': 7.146477386803936e-60},
#  {'Terme': ('entente', 'de', 'services'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 75.28971299191707,
#   'p-value': 4.064719052235259e-18},
#  {'Terme': ('partenaires', 'du', 'réseau'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 14,
#   'LLR': 218.73817720522078,
#   'p-value': 1.7046013934067864e-49},
#  {'Terme': ('psychiatres', 'du', 'service'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 18,
#   'LLR': 224.7513464603356,
#   'p-value': 8.318458033275261e-51},
#  {'Terme': ('psychiatres', 'du', 'service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM',
#   'Fréquence (TF)': 18,
#   'LLR': 284.5797448595676,
#   'p-value': 7.54429619539724e-64},
#  {'Terme': ('psychiatres',
#    'du',
#    'service',
#    'de',
#    'psychiatrie',
#    'des',
#    'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 99.62829874770057,
#   'p-value': 1.838584895875491e-23},
#  {'Terme': ('service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 150,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('service', 'de', 'psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 93,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 137,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('professionnel', 'désigné'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence (TF)': 39,
#   'LLR': 555.6329009979338,
#   'p-value': 7.492323408925736e-123},
#  {'Terme': ('professionnel', 'désigné'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence (TF)': 39,
#   'LLR': 555.6329009979338,
#   'p-value': 7.492323408925736e-123},
#  {'Terme': ('professionnel', 'de', 'la', 'santé'),
#   'Structure syntaxique': 'NOM PRP DET:ART NOM',
#   'Fréquence (TF)': 154,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('travailleur', 'social'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 42,
#   'LLR': 826.7183406528314,
#   'p-value': 8.377815929211756e-182},
#  {'Terme': ('service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 150,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('service', 'de', 'psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 93,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('service',
#    'de',
#    'psychiatrie',
#    'des',
#    'toxicomanies',
#    'au',
#    'chum'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM PRP:det NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 61.51338546427002,
#   'p-value': 4.397434795361712e-15},
#  {'Terme': ('psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 137,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('psychiatrie', 'des', 'toxicomanies', 'au', 'chum'),
#   'Structure syntaxique': 'NOM PRP:det NOM PRP:det NOM',
#   'Fréquence (TF)': 6,
#   'LLR': 61.51338546427002,
#   'p-value': 4.397434795361712e-15},
#  {'Terme': ('toxicomanies', 'au', 'chum'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 11,
#   'LLR': 112.7836730667143,
#   'p-value': 2.4064933667658367e-26},
#  {'Terme': ('organisation', 'des', 'services'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 8,
#   'LLR': 81.08251806903341,
#   'p-value': 2.1648661620641057e-19},
#  {'Terme': ('suivi', 'clinique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 11.22141549124548,
#   'p-value': 0.0008085879838971084},
#  {'Terme': ('professionnel', 'désigné'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence (TF)': 39,
#   'LLR': 555.6329009979338,
#   'p-value': 7.492323408925736e-123},
#  {'Terme': ('professionnel', 'désigné'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence (TF)': 39,
#   'LLR': 555.6329009979338,
#   'p-value': 7.492323408925736e-123},
#  {'Terme': ('vision', 'globale'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 81.50273277601339,
#   'p-value': 1.7501939256748043e-19},
#  {'Terme': ('besoins', 'du', 'patient'),
#   'Structure syntaxique': 'NOM PRP:det ADJ',
#   'Fréquence (TF)': 10,
#   'LLR': 112.026016668858,
#   'p-value': 3.5265202381511676e-26},
#  {'Terme': ('professionnel', 'désigné'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence (TF)': 39,
#   'LLR': 555.6329009979338,
#   'p-value': 7.492323408925736e-123},
#  {'Terme': ('milieu', 'de', 'vie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 32,
#   'LLR': 359.0592877779347,
#   'p-value': 4.5125504862389674e-80},
#  {'Terme': ('projet', 'de', 'vie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 15,
#   'LLR': 127.86608566382371,
#   'p-value': 1.2007764525212954e-29},
#  {'Terme': ('professionnel', 'désigné'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence (TF)': 39,
#   'LLR': 555.6329009979338,
#   'p-value': 7.492323408925736e-123},
#  {'Terme': ('durée', 'totale'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 65.73886686633203,
#   'p-value': 5.14805548728128e-16},
#  {'Terme': ('épisode', 'de', 'soins'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 46,
#   'LLR': 549.1221745028479,
#   'p-value': 1.9541284703279048e-121},
#  {'Terme': ('partenaires', 'du', 'réseau'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 14,
#   'LLR': 218.73817720522078,
#   'p-value': 1.7046013934067864e-49},
#  {'Terme': ('suivi', 'clinique'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 11.22141549124548,
#   'p-value': 0.0008085879838971084},
#  {'Terme': ('épisode', 'de', 'soins'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 46,
#   'LLR': 549.1221745028479,
#   'p-value': 1.9541284703279048e-121},
#  {'Terme': ('service', 'de', 'psychiatrie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 150,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('service', 'de', 'psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP NOM PRP:det NOM',
#   'Fréquence (TF)': 93,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('psychiatrie', 'des', 'toxicomanies'),
#   'Structure syntaxique': 'NOM PRP:det NOM',
#   'Fréquence (TF)': 137,
#   'LLR': -inf,
#   'p-value': 1.0},
#  {'Terme': ('projet', 'de', 'vie'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 15,
#   'LLR': 127.86608566382371,
#   'p-value': 1.2007764525212954e-29},
#  {'Terme': ('infirmière', 'de', 'liaison'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 8,
#   'LLR': 133.71811467940128,
#   'p-value': 6.29703386744827e-31},
#  {'Terme': ('rôle', 'principal'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 6,
#   'LLR': 47.83697611836464,
#   'p-value': 4.63173688515725e-12},
#  {'Terme': ('infirmière', 'de', 'liaison'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 8,
#   'LLR': 133.71811467940128,
#   'p-value': 6.29703386744827e-31},
#  {'Terme': ('signes', 'et', 'symptômes'),
#   'Structure syntaxique': 'NOM KON NOM',
#   'Fréquence (TF)': 8,
#   'LLR': 106.56303123300658,
#   'p-value': 5.549892202660158e-25},
#  {'Terme': ('symptômes', 'liés'),
#   'Structure syntaxique': 'NOM VER:pper',
#   'Fréquence (TF)': 7,
#   'LLR': 58.97656934960102,
#   'p-value': 1.5956070070737608e-14},
#  {'Terme': ('trouble', 'concomitant'),
#   'Structure syntaxique': 'NOM ADJ',
#   'Fréquence (TF)': 11,
#   'LLR': 192.54283381753277,
#   'p-value': 8.857358904148203e-44},
#  {'Terme': ('service', 'de', 'médecine'),
#   'Structure syntaxique': 'NOM PRP NOM',
#   'Fréquence (TF)': 75,
#   'LLR': 533.6695982529442,
#   'p-value': 4.49379211670923e-118},
#  ...]

# %%
print('Après avoir calculé le log-likelihood ratio, on a retiré {} collocations qui n\'étaient pas statistiquement significatives.'.format(len(terms) - len(significant_coll)))
print('Ça représente environ {} % de nos n-grammes.'.format(round((len(terms) - len(significant_coll)) / len(terms) *100 )))
# Out:
# Après avoir calculé le log-likelihood ratio, on a retiré 368 collocations qui n'étaient pas statistiquement significatives.
# Ça représente environ 0 % de nos n-grammes.

# %%
df = DataFrame(significant_coll).sort_values(by = "Fréquence (TF)", ascending=False).drop_duplicates()

# On veut faire join pour tous les termes[collocation]
def join_term(x):
    if type(x) == tuple:
        return " ".join(x).replace("' ", "'").replace("( ", "(").replace(" )", ")")
    else:
        return x

df['Terme'] = df['Terme'].apply(lambda x: join_term(x))

if lng == 'en':
    acteur = acteur + '_' + lng

df = df.drop(columns=['p-value'])

# %% [markdown]
# ### **Filtrage - Fréquence documentaire**

# %%
dfs = {term: len([doc for doc in text if term in doc]) for term in df['Terme'].tolist()}

# %%
max_df = round(0.95 * nb_docs)        # Pour rejeter les termes qui se retrouvent dans plus de 95% des documents 
min_df = round(0.01 * nb_docs)        # Pour rejeter les termes qui se retrouvent dans moins de 1% des documents
max_df
# Out:
# 3390

# %%
min_df
# Out:
# 36

# %%
max_df_observed = dfs[max(dfs, key=dfs.get)] # Voir quelle est la fréquence documentaire maximale qu'on retrouve
max_df_observed
# Out:
# 1280

# %%
max_df_to_remove = {term:df for term,df in dfs.items() if df > max_df}
max_df_to_remove
# Out:
# {}

# %%
dfs = {term:df for term,df in dfs.items() if df < max_df and df > min_df} # Si df = 0, c'est un artefact créé par le prétraitement lui-même

# %% [markdown]
# Porter attention aux termes qui sortent ici - en comptant la fréquence documentaire, techniquement on ne devrait pas retrouver de 0

# %%
zeros =  {term:df for term,df in dfs.items() if df == 0}  
print(len(zeros))
zeros
# Out:
# 0
# {}

# %%
dfs = DataFrame(list(dfs.items()),columns = ['Terme','Fréquence documentaire (DF)']) 

dfs
# Out:
#                                  Terme  Fréquence documentaire (DF)
# 0                  centre de recherche                         1216
# 1                centre de prélèvement                         1280
# 2                    prélèvement guide                         1271
# 3                    recherche du chum                         1119
# 4          centre de recherche du chum                         1105
# ..                                 ...                          ...
# 454  université de montréal professeur                           39
# 455                 tension artérielle                           37
# 456                  soins et services                           49
# 457                   recherche du chu                         1120
# 458                 chum et professeur                           43
#
# [459 rows x 2 columns]

# %%
df = df.merge(dfs, on='Terme').drop_duplicates()

df.sort_values(['Fréquence (TF)'], 
            axis=0,
            ascending=[False], 
            inplace=True)

# %%
df
# Out:
#                                  Terme     Structure syntaxique  \
# 0                  centre de recherche              NOM PRP NOM
# 1                centre de prélèvement              NOM PRP NOM
# 2                    prélèvement guide             NOM VER:pres
# 3                    recherche du chum          NOM PRP:det NOM
# 4          centre de recherche du chum  NOM PRP NOM PRP:det NOM
# ..                                 ...                      ...
# 454  université de montréal professeur          NOM PRP ADJ NOM
# 455                 tension artérielle                  NOM ADJ
# 456                  soins et services              NOM KON NOM
# 457                   recherche du chu     NOM PRP:det VER:pper
# 458                 chum et professeur              NOM KON NOM
#
#      Fréquence (TF)         LLR  Fréquence documentaire (DF)
# 0              1421        -inf                         1216
# 1              1304        -inf                         1280
# 2              1271        -inf                         1271
# 3              1199        -inf                         1119
# 4              1173        -inf                         1105
# ..              ...         ...                          ...
# 454              24   97.634363                           39
# 455              19  309.824178                           37
# 456              11   78.225674                           49
# 457               8   51.863171                         1120
# 458               6   29.653402                           43
#
# [459 rows x 5 columns]

# %%
list_terms = df['Terme'].tolist()

# %% [markdown]
# ### **KWIC (Keyword in Context)**
# Termes d'intérêt :
# - « Programme »
# - « Plan »
# - « Service(s) de »
# - « Intervenant(e) en »
# - « Professionnel de »
# - « Institut (du/de) »
# - « Groupe de recherche en »
# - « Personne »
# - « Infirmière (en) »

# %%
# Dans notre cas on veut que ça débute par le mot-clé donc le contexte est un peu plus simple
# penser à généraliser avec des expressions régulières
# kw = ['programme', 'plan ', 'service', 'intervenant', 'infirmière en', 'institut', 'groupe de recherche', 'personne', 'maladie']

# ngrammes_kwic = [" ".join([t[0] for t in ng]).replace("' ", "'").replace("( ", "(").replace(" )", ")") for ng in ngrammes]

# %%
# ngrammes_kwic = [t for t in ngrammes_kwic if not 'STOP' in t]

# %%
# extrant = DataFrame(columns=['Mot-clé','Concordance', 'Fréquence (TF)'])
# kwic = {w : [] for w in kw}

# %%
# for t in ngrammes_kwic: # on pourrait aussi chercher dans les terms, mais on perd certains termes d'intérêt avec le filtrage syntaxique
#     for w in kw:
#         if t.startswith(w):
#             kwic[w].append(t)

# %%
# kwic = {term: FreqDist(kwic[term]) for term in kwic}

# %%
# for term in kw:
#     df_kw = DataFrame(kwic[term].items(), columns=['Concordance', "Fréquence (TF)"])
#     df_kw.sort_values(["Fréquence (TF)"], 
#         axis=0,
#         ascending=[False], 
#         inplace=True)

#     df_kw.insert(0, 'Mot-clé', term)
#     extrant = concat([extrant, df])


# extrant = extrant[extrant['Fréquence (TF)'] > 30] 

# # file_path = '../04-filtrage/output/'
# # file_path = path.join(file_path, acteur, tag)


# # extrant.to_csv(file_path + '_KWIC' +'.csv')

# extrant

# %% [markdown]
# ### **Extraction de termes MeSH**

# %%
df['isMeSHTerm']= False # On set à False puis on va changer pour True si on trouve le terme
df['MeSHID'] = None
df['MesH_prefLabel_fr'] = None
df['MesH_prefLabel_en'] = None

# %%
from nltk.tokenize import MWETokenizer
file_path = '../02-filtrage/MeSH/mesh-fr.txt'

with open (file_path, 'r', encoding='utf-8') as f:
    mesh = [tuple(tokenizer_re.tokenize(w)) for w in f.readlines()]
    tokenizer_mesh = MWETokenizer(mesh, separator= ' ')
    mesh = [tokenizer_mesh.tokenize(w)[0].lower() for w in mesh]
    mesh = [w for w in mesh if len(w.split()) > 1] # On ne retient que les termes complexes
    #mesh = [tuple(t.strip('.').lower().split()) for t in f.readlines()]

# %%
extr_mesh = tokenizer_mesh.tokenize(list_terms)

# %%
for t in extr_mesh:
    if t in mesh:
        df.loc[df['Terme'] == t, 'isMeSHTerm'] = True
df
# Out:
#                                  Terme     Structure syntaxique  \
# 0                  centre de recherche              NOM PRP NOM
# 1                centre de prélèvement              NOM PRP NOM
# 2                    prélèvement guide             NOM VER:pres
# 3                    recherche du chum          NOM PRP:det NOM
# 4          centre de recherche du chum  NOM PRP NOM PRP:det NOM
# ..                                 ...                      ...
# 454  université de montréal professeur          NOM PRP ADJ NOM
# 455                 tension artérielle                  NOM ADJ
# 456                  soins et services              NOM KON NOM
# 457                   recherche du chu     NOM PRP:det VER:pper
# 458                 chum et professeur              NOM KON NOM
#
#      Fréquence (TF)         LLR  Fréquence documentaire (DF)  isMeSHTerm  \
# 0              1421        -inf                         1216       False
# 1              1304        -inf                         1280       False
# 2              1271        -inf                         1271       False
# 3              1199        -inf                         1119       False
# 4              1173        -inf                         1105       False
# ..              ...         ...                          ...         ...
# 454              24   97.634363                           39       False
# 455              19  309.824178                           37        True
# 456              11   78.225674                           49       False
# 457               8   51.863171                         1120       False
# 458               6   29.653402                           43       False
#
#     MeSHID MesH_prefLabel_fr MesH_prefLabel_en
# 0     None              None              None
# 1     None              None              None
# 2     None              None              None
# 3     None              None              None
# 4     None              None              None
# ..     ...               ...               ...
# 454   None              None              None
# 455   None              None              None
# 456   None              None              None
# 457   None              None              None
# 458   None              None              None
#
# [459 rows x 9 columns]

# %%
# Termes MeSH présents dans notre corpus 
df[df['isMeSHTerm'] == True]
# Out:
#                                     Terme Structure syntaxique  \
# 22                        soins intensifs              NOM ADJ
# 35               fibrillation auriculaire              NOM ADJ
# 46                reconstruction mammaire              NOM ADJ
# 62                      produits naturels              NOM ADJ
# 63                  boissons énergisantes              NOM ADJ
# 66                syndromes parkinsoniens              NOM ADJ
# 67                   maladie de parkinson          NOM PRP NOM
# 96                         santé publique              NOM ADJ
# 99                          santé mentale              NOM ADJ
# 101                    médecine nucléaire              NOM ADJ
# 106                      médecine interne              NOM ADJ
# 112            professionnels de la santé  NOM PRP DET:ART NOM
# 115                      soins infirmiers              NOM NOM
# 116                   système immunitaire              NOM ADJ
# 118                instituts de recherche          NOM PRP NOM
# 125                 cancer de la prostate  NOM PRP DET:ART NOM
# 140                   sclérose en plaques          NOM PRP NOM
# 150                        qualité de vie          NOM PRP NOM
# 152             intelligence artificielle              NOM ADJ
# 153                   projet de recherche          NOM PRP NOM
# 158             prévention des infections      NOM PRP:det NOM
# 161                      cellules souches              NOM NOM
# 182                 troubles du mouvement      NOM PRP:det NOM
# 254  paralysie supranucléaire progressive          NOM ADJ ADJ
# 208                       sens du toucher      NOM PRP:det NOM
# 315          accident vasculaire cérébral          NOM ADJ ADJ
# 321                     douleur chronique              NOM ADJ
# 327                     cancer colorectal              NOM ADJ
# 329                     qualité des soins      NOM PRP:det NOM
# 338                       système nerveux              NOM ADJ
# 343                      cancer du poumon      NOM PRP:det NOM
# 344                      services sociaux              NOM ADJ
# 354                        soins de santé          NOM PRP NOM
# 355                       cancer oculaire              NOM ADJ
# 363                  biologie moléculaire              NOM ADJ
# 380                     imagerie médicale              NOM ADJ
# 391                       modèles animaux              NOM ADJ
# 400                 santé des populations      NOM PRP:det NOM
# 431                    facteurs de risque          NOM PRP NOM
# 455                    tension artérielle              NOM ADJ
#
#      Fréquence (TF)          LLR  Fréquence documentaire (DF)  isMeSHTerm  \
# 22              453         -inf                          161        True
# 35              293         -inf                           43        True
# 46              202         -inf                           50        True
# 62              168         -inf                           84        True
# 63              167         -inf                           86        True
# 66              165         -inf                           59        True
# 67              163         -inf                           62        True
# 96              145  1572.986426                           95        True
# 99              144  1579.079685                           68        True
# 101             141         -inf                          119        True
# 106             124  1390.961677                           51        True
# 112             117  1366.366535                           77        True
# 115             116  1262.889646                           67        True
# 116             115  1574.417236                           63        True
# 118             114  1036.353166                           93        True
# 125             110         -inf                           46        True
# 140             104         -inf                           56        True
# 150              99  1324.037527                           88        True
# 152              97         -inf                           55        True
# 153              95   702.895059                           74        True
# 158              93  1369.536445                           89        True
# 161              93  1335.733368                           56        True
# 182              83  1475.154781                           45        True
# 254              81  1504.622917                           41        True
# 208              81  1568.073157                           81        True
# 315              73  1409.586583                           50        True
# 321              70   881.219284                           42        True
# 327              67   756.914408                           37        True
# 329              66   716.606289                           52        True
# 338              62   869.569025                           45        True
# 343              61   827.358531                           39        True
# 344              60   628.594270                           55        True
# 354              56   372.161820                           54        True
# 355              55   393.186699                           37        True
# 363              54   736.691086                           46        True
# 380              49   391.792320                           41        True
# 391              47   704.782594                           42        True
# 400              46   769.974699                           39        True
# 431              42   544.081317                           38        True
# 455              19   309.824178                           37        True
#
#     MeSHID MesH_prefLabel_fr MesH_prefLabel_en
# 22    None              None              None
# 35    None              None              None
# 46    None              None              None
# 62    None              None              None
# 63    None              None              None
# 66    None              None              None
# 67    None              None              None
# 96    None              None              None
# 99    None              None              None
# 101   None              None              None
# 106   None              None              None
# 112   None              None              None
# 115   None              None              None
# 116   None              None              None
# 118   None              None              None
# 125   None              None              None
# 140   None              None              None
# 150   None              None              None
# 152   None              None              None
# 153   None              None              None
# 158   None              None              None
# 161   None              None              None
# 182   None              None              None
# 254   None              None              None
# 208   None              None              None
# 315   None              None              None
# 321   None              None              None
# 327   None              None              None
# 329   None              None              None
# 338   None              None              None
# 343   None              None              None
# 344   None              None              None
# 354   None              None              None
# 355   None              None              None
# 363   None              None              None
# 380   None              None              None
# 391   None              None              None
# 400   None              None              None
# 431   None              None              None
# 455   None              None              None

# %% [markdown]
# ### **Extraction de termes existant dans la taxonomie**

# %%
df['isTaxoTerm']= 'False' # On set à False puis on va changer pour True si on trouve le terme

# %%
file_path = '../02-filtrage/default_taxo_labels.csv'

with open(file_path, 'r', encoding='utf-8') as f:
    default = read_csv(f, sep=';')
    taxo_terms = list(dict.fromkeys([str(t).strip().lower() for t in default['Label'].tolist()]))

taxo_terms
# Out:
# ['1 on 1 support',
#  '10 weeks and less ultrasound',
#  '12-step facilitation therapy',
#  '12-step programs',
#  '18f pet bone scan',
#  '18f bone pet',
#  '18f bone scan',
#  '1st generation antipsychotics',
#  '2019 ncov testing',
#  '2d doppler echocardiography',
#  '2d echocardiography',
#  '2d ultrasound',
#  '2nd generation antipsychotics',
#  '3d imaging',
#  '3d sonography',
#  '3d dental imaging',
#  '3d echocardiography',
#  '3d fetal ultrasound',
#  '3d mammography',
#  '3d prenatal ultrasound',
#  '3d reconstruction',
#  '46, xx disorder of sex development',
#  '46,xy disorder of sex development',
#  '4d echocardiography',
#  '4d prenatal ultrasound',
#  'a1c diabetes test',
#  'a1c test',
#  'abo + rh pnl bld',
#  'abo and rh group in cord blood',
#  'abpm device',
#  'acl reconstruction surgery',
#  'acth deficiency',
#  'acth stimulation test',
#  'adhd assessment',
#  'adhd diagnostic',
#  'adhd evaluation',
#  'adhd testing',
#  'adn foetal circulant',
#  'aids',
#  'aids nephropathy',
#  'aids serodiagnosis',
#  'aids-associated nephropathy',
#  'aids-related nephropathy',
#  'apud cell',
#  'arfi imaging',
#  'abandonment',
#  'abdomen',
#  'abdominal ct scan',
#  'abdominal abscess',
#  'abdominal and pelvis ct scan',
#  'abdominal aorta ultrasound',
#  'abdominal aortic aneurysm',
#  'abdominal cavity',
#  'abdominal computed tomography',
#  'abdominal delivery',
#  'abdominal doppler',
#  'abdominal doppler ultrasound',
#  'abdominal hernia',
#  'abdominal hysterectomy',
#  'abdominal imaging',
#  'abdominal muscles',
#  'abdominal oblique muscles',
#  'abdominal pain',
#  'abdominal pregnancy',
#  'abdominal radiologist',
#  'abdominal region ultrasound',
#  'abdominal spasm',
#  'abdominal ultrasound',
#  'abdominal wall',
#  'abdominal wall ultrasound',
#  'abdominoplasty',
#  'abducens nerve',
#  'aberration des chromosome',
#  'aberrometry',
#  'abilify',
#  'ablation',
#  'abobotulinum toxin a',
#  'abominal muscles ultrasound',
#  'aboriginal health',
#  'aboriginal outreach worker',
#  'aboriginal peoples',
#  'aboriginals',
#  'aborted fetus',
#  'abortion doula',
#  'abruptio placentae',
#  'abscess',
#  'abscess drainage',
#  'abscess draining',
#  'absence of periods',
#  'absence of voice',
#  'absense of menstruation',
#  'absorbant insoles',
#  'absorbent dressing',
#  'abuse',
#  'abutment bridge',
#  'academic & research practice',
#  'academic education services',
#  'acamprosate',
#  'accent modification',
#  'acceptance and commitment therapy',
#  'accident',
#  'accident at work',
#  'accident prevention',
#  'accident proneness',
#  'accidental fall',
#  'accidental injury',
#  'accommodative plantar orthotics',
#  'accompanied transport',
#  'accompaniment service',
#  'accoutumance',
#  'accutane',
#  'acetabuloplasty',
#  'acetabulum',
#  'acetylsalicylic acid',
#  'ache',
#  'achievement',
#  'achilles tendinitis',
#  'achilles tendon',
#  'achlorhydria',
#  'achondroplasia',
#  'acid reflux',
#  'acid-base equilibrium',
#  'acid-fast stain',
#  'acidosis',
#  'acne',
#  'acne scar',
#  'acne vulgaris',
#  'acneiform eruption',
#  'acoumetry',
#  'acoustic impedance test',
#  'acoustic microscopy',
#  'acoustic prosthesis',
#  'acoustic trauma',
#  'acquired brain injury',
#  'acquired dyslexia',
#  'acquired immunodeficiency syndrome',
#  'acquired lactase deficiency',
#  'acrochordon',
#  'acromegaly',
#  'acromioclavicular joint',
#  'acromion',
#  'actigraphy',
#  'actinic keratosis',
#  'activated partial thromboplastin time',
#  'activator method',
#  'activator method chiropractic technique',
#  'active immunotherapy',
#  'active noise reduction hearing protector',
#  'active release techniques',
#  'activités de réseautage',
#  'acupressure for induction of labor',
#  'acupressure for labor',
#  'acupuncture',
#  'acupuncture après la grossesse',
#  'acupuncture clinic',
#  'acupuncture for induction of labor',
#  'acupuncture for labor',
#  'acupuncture treatments',
#  'acupuncturist',
#  'acute abdomen',
#  'acute adult psychiatry',
#  'acute erythroblastic leukemia',
#  'acute kidney injury',
#  'acute kidney tubular necrosis',
#  'acute knee pain',
#  'acute pain',
#  'acute stress disorder',
#  'acute yellow atrophy',
#  'acute-phase reaction',
#  'acyanopsia',
#  "adam's apple",
#  'adamantinoma',
#  'adams-stokes syndrome',
#  'adapted beds',
#  'adapted chairs',
#  'adapted driving assessment',
#  'adapted driving evaluation',
#  'adapted recliner',
#  'adapted utensils',
#  'adaptive behavior',
#  'adaptive immunity',
#  'addiction',
#  'addiction issues',
#  'addiction medicine',
#  'addiction psychiatry',
#  'addiction rehabilitation centre',
#  'addiction treatment center',
#  'addiction treatment facility',
#  'addictions intervention worker',
#  'addictions unit',
#  'addictions worker',
#  'addictive behavior',
#  'addictive disorders',
#  'addictivedisorderdrug',
#  'addison disease',
#  'adenocarcinoma',
#  'adenoidectomy',
#  'adenoids',
#  'adenoma',
#  'adenomyosis',
#  'adenosarcoma',
#  'adhesions of uterus',
#  'adipose tissue',
#  'adiposity',
#  'adjustable gastric band surgery',
#  'adjustment of contact lenses',
#  'adjustment of glasses',
#  'adjuvant chemoradiotherapy',
#  'administration en psychiatrie',
#  'administration route',
#  'administrative psychiatry',
#  'adnexa uteri',
#  'adolescent',
#  'adolescent & family psychiatry',
#  'adolescent behavior',
#  'adolescent clinic',
#  'adolescent development',
#  'adolescent gynecology',
#  'adolescent medicine',
#  'adolescent psychiatry',
#  'adolescent psychology',
#  'adoption',
#  'adoption disclosure',
#  'adranalectomy',
#  'adrenal cortex',
#  'adrenal cortex diseases',
#  'adrenal cortex function test',
#  'adrenal cortex hormone',
#  'adrenal cortex neoplasm',
#  'adrenal disorder',
#  'adrenal gland',
#  'adrenal gland disease',
#  'adrenal gland hyperfunction',
#  'adrenal gland neoplasm',
#  'adrenal gland neuroendocrine tumor',
#  'adrenal insufficiency',
#  'adrenal medulla',
#  'adrenalectomy',
#  'adrenocortical adenoma',
#  'adrenocortical carcinoma',
#  'adrenocortical hyperfunction',
#  'adrenocorticotropic hormone',
#  'adrenocorticotropic hormone deficiency',
#  'adrenogenital syndrome',
#  'adult care nurse practitioner',
#  'adult clinical psychiatry',
#  'adult education',
#  'adult general psychiatry',
#  'adult hip & knee reconstruction',
#  'adult outpatient psychiatry',
#  'adult psychiatry',
#  'adult reconstructive surgery',
#  'adult spine/trauma',
#  'adultery',
#  'adulthood',
#  'adults',
#  'advanced esthetician',
#  'advanced gyn surg',
#  'advanced laparoscopy and hysterectomy',
#  'advanced obstetrics',
#  'advanced sclerosing glomerulonephritis',
#  'advanced sleep phase syndrome',
#  'adverse drug reaction reporting',
#  'advocacy',
#  'aerospace medicine',
#  'aesthetic',
#  'aesthetic medicine',
#  'aesthetic surgeon',
#  'affect',
#  'affection de la vulve',
#  'affective disorders',
#  'afferent loop syndrome',
#  'affordable housing',
#  'agatston coronary artery calcium score',
#  'age determination by skeleton',
#  'age determination by teeth',
#  'age management',
#  'age-related maculopathy',
#  'age-related hearing loss',
#  'age-related osteoporosis',
#  'aged',
#  'agender',
#  'ageusia',
#  'aggression',
#  'aggressiveness',
#  'agnosia',
#  'agoraphobia',
#  'agraphia',
#  'aicardi syndrome',
#  'aire ouverte',
#  'airway',
#  'airway extubation',
#  'airway management',
#  'airway remodeling',
#  'airway resistance',
#  'airway resistance assessment',
#  'airway suctioning',
#  'ajustement émotionnel',
#  'ajustment of ophtalmic lenses',
#  'alaryngeal speech',
#  'alastrim',
#  'albinism',
#  'alclometasone',
#  'alcohol',
#  'alcohol amnestic disorder',
#  'alcohol abstinence',
#  'alcohol abuse',
#  'alcohol addiction',
#  'alcohol binging',
#  'alcohol intoxication',
#  'alcohol poisoning',
#  'alcohol septal ablation',
#  'alcohol withdrawal seizure',
#  'alcohol-related seizure',
#  'alcoholic beverage',
#  'alcoholic cardiomyopathy',
#  'alcoholic fatty liver',
#  'alcoholic hepatitis',
#  'alcoholic liver cirrhosis',
#  'alcoholic psychosis',
#  'alcoholic seizure',
#  'alcoholics anonymous',
#  'alcoholism',
#  'aldosterone',
#  'alexithymia',
#  'algia',
#  'algie',
#  'alginate',
#  'alginate dressing',
#  'algologist',
#  'algologue',
#  'alice in wonderland syndrome',
#  'alimentarytractmetabolismdrug',
#  'allergen',
#  'allergens immunotherapy',
#  'allergic conjunctivitis',
#  'allergic rhinitis',
#  'allergies',
#  'allergist',
#  'allergoglogy',
#  'allergologist',
#  'allergy',
#  'allergy and immunology',
#  'allergy and immunology unit',
#  'allesthesia',
#  'alliesthesia',
#  'alliesthésie',
#  'allodynia',
#  'allogenic graft',
#  'allograft',
#  'allotransplantation',
#  'alopecia',
#  'alpecia reduction',
#  'alpha-linolenic acid',
#  'alphapapillomavirus',
#  'alport syndrome',
#  'altered consciousness',
#  'alternate binaural loudness balance',
#  'alveolar bone grafting',
#  'alveolar cleft grafting',
#  'alveolar epithelial cell',
#  'alveolar process',
#  'alveolectomy',
#  'alveoloplasty',
#  'alzheimer',
#  'alzheimer syndrome',
#  "alzheimer's disease",
#  "alzheimer's prothetic unit",
#  'alzheimer-type dementia',
#  'amalgam filling',
#  'amaurosis fugax',
#  'ambien',
#  'amblyopia',
#  'ambulance technician',
#  'ambulance transportation',
#  'ambulatory ekg monitoring',
#  'ambulatory blood pressure monitor',
#  'ambulatory blood pressure monitoring device',
#  'ambulatory cardiac monitoring',
#  'ambulatory electrocardiogram',
#  'ambulatory electrocardiography',
#  'ambulatory monitoring',
#  'ambulatory services',
#  'ambulatory surgery',
#  'amebiasis',
#  'amenorrhea',
#  'american board of opticianry and national contact lens examiners',
#  'american society of ocularists',
#  'american sign language',
#  'amides',
#  'amma massage',
#  'amnesia',
#  'amnesic aphasia',
#  'amniocentesis',
#  'amnioscopy',
#  'amniotic band syndrome',
#  'amniotic fluid',
#  'amniotic fluid embolism',
#  'amniotic fluid sample',
#  'amniotomy',
#  'amphetamine',
#  'amphetamines drug test',
#  'amphibian venom',
#  'amputated person',
#  'amputation',
#  'amputation stump',
#  'amputee',
#  'amygdala',
#  'amyloid plaque',
#  'amyotrophic lateral sclerosis',
#  'anaerobic threshold',
#  'anal sphincter',
#  'anal canal',
#  'anal fissure',
#  'anal fistula',
#  'anal ulcer',
#  'analgesics',
#  'analgetics',
#  'analysis laboratory',
#  'anankastic personality',
#  'anankastic personality disorder',
#  'anaphylactic shock',
#  'anaphylaxis',
#  'anaplasia',
#  'anaplastic thyroid cancer',
#  'anaplastic thyroid carcinoma',
#  'anastomosis',
#  'anastomotic leak',
#  'anatomic and clinical pathology',
#  'anatomical pathologist',
#  'anatomical pathology',
#  'anatomical signs',
#  'anatomicalpathologicalconditions',
#  'anatomopathological examination',
#  'anchor mini-screws',
#  'androgen suppression therapy',
#  'androgen-resistant prostatic cancer',
#  'androgens',
#  'andrologist',
#  'andrology',
#  'andrology and infertility',
#  'andropause',
#  'andropause treatment',
#  'anemia',
#  'anesthesiologist',
#  'anesthesiology',
#  'anesthesiology department',
#  'anesthesiology unit',
#  'anesthesist',
#  'anesthetics',
#  'aneurysm',
#  'anger',
#  'anger management',
#  'angina',
#  'angina pectoris',
#  'angio-radiology',
#  'angiocardiography',
#  'angioedema',
#  'angiogram',
#  'angiography',
#  'angioma',
#  'angioplasty',
#  'angioscopy',
#  'angriness',
#  'anguish',
#  'anhedonia',
#  'animal allergy',
#  'animal assisted therapy',
#  'aniridia',
#  'anisocoria',
#  'ankle',
#  'ankle syndesmosis',
#  'ankle arthroplasty',
#  'ankle bone',
#  'ankle fracture',
#  'ankle injury',
#  'ankle joint',
#  'ankle prostheses',
#  'ankle replacement',
#  'ankle replacement arthroplasty',
#  'ankle sprain',
#  'ankle trauma',
#  'ankle-foot orthosis',
#  'ankylos implant',
#  'ankylosing spondylitis',
#  'annual exam',
#  'annual examination',
#  'annual physical examination',
#  'annular groove',
#  'annuloplasty',
#  'anomia',
#  'anophthalmia',
#  'anorectal manometry',
#  'anorexia',
#  'anorexia nervosa',
#  'anoscopy',
#  'anosmia',
#  'anovulation',
#  'ant venom',
#  'antabuse',
#  'antebrachium',
#  'antenatal surgery',
#  'antepartum doula',
#  'anterior chamber',
#  'anterior cranial fossa',
#  'anterior cruciate ligament',
#  'anterior cruciate ligament reconstruction',
#  'anterior pituitary gland',
#  'anterograde amnesia',
#  'anthrax',
#  'anthropology',
#  'anti-ccp test',
#  'anti-cyclic citrullinated peptide test',
#  'anti-dementia drug',
#  'anti-depressants',
#  'anti-parkinson drug',
#  'anti-snoring device',
#  'antiacid',
#  'antiarrhytmics',
#  'antibacterials',
#  'antibiotic associated colitis',
#  'antibody',
#  'anticholinesterases',
#  'anticoagulant therapy',
#  'anticoagulants',
#  'anticoagulation therapy',
#  'anticoagulotherapy',
#  'anticonvulsants',
#  'antidepressants',
#  'antidiarrheals',
#  'antiemetics',
#  'antiepileptic',
#  'antifungals',
#  'antigen',
#  'antihistamines',
#  'antihyperglycemic drug',
#  'antihypertensives',
#  'antimicrobial susceptibility testing',
#  'antineoplastics',
#  'antioxidant',
#  'antiplatelet drugs',
#  'antipsychotics',
#  'antipyretics',
#  'antirejection therapy',
#  'antisocial behavior',
#  'antisocial personality',
#  'antisocial personality disorder',
#  'antithrombotic enzyme',
#  'antithrombotics',
#  'antivirals',
#  'anton-babinski syndrome',
#  'anuria',
#  'anus prolapse',
#  'anxiety',
#  'anxiety disorder',
#  'anxiolytics',
#  'anxious',
#  'aorta',
#  'aortic valve',
#  'aortic valve insufficiency',
#  'aortic valve prolapse',
#  'aortic valve repair',
#  'aortic valve stenosis',
#  'aortic valvuloplasty',
#  'aortocoronary bypass',
#  'aortography',
#  'apathy',
#  'apexification',
#  'apgar score',
#  'aphakia',
#  'aphasia',
#  'aphonia',
#  'apicoectomy',
#  'aplasic anemia',
#  'apnea',
#  'aponeurosis',
#  'apothecary',
#  'appareil complètement dans le conduit',
#  'appendectomy',
#  'appendicitis',
#  'appendix',
#  'appetite',
#  'appetite alteration',
#  'applied behavior analysis',
#  'applied kinesiology',
#  'aquatic exercise therapy',
#  'aquatic physiotherapy',
#  'aquatic therapy',
#  'aqueous humor',
#  'arachnodactyly',
#  'arachnoid',
#  'arch of the feet',
#  'archaea',
#  'arcus senilis',
#  'areola',
#  'aripiprazole',
#  'arm',
#  'arm arterial doppler',
#  'arm lift',
#  'arm orthosis',
#  'armodafinil',
#  'armpit',
#  'aromatherapy',
#  'aromatherapy for labor',
#  'aromatherapy massage',
#  'around the navel',
#  'around the umbilic',
#  'arousal',
#  'arret de la nicotine',
#  'arret de la vapoteuse',
#  'arrhythmogenic right ventricular dysplasia',
#  'arrythmia',
#  'art studio',
#  'art therapy',
#  'artecoll',
#  'arterial doppler',
#  'arterial doppler ultrasound',
#  'arterial pressure',
#  'arterial pressure measurement',
#  'arterial pressure monitoring',
#  'arterial switch operation',
#  'arterial switch procedure',
#  'arteries',
#  'arteriography',
#  'arterioles',
#  'arteriosclerotic dementia',
#  'arteriovenous shunt',
#  'arthralgia',
#  'arthritic psoriasis',
#  'arthritis',
#  'arthritis clinic',
#  'arthrodesis',
#  'arthrogram',
#  'arthrography',
#  'arthroplasty',
#  'arthropod venom',
#  'arthroscopic hip surgery',
#  'arthroscopic knee surgery',
#  'arthroscopic shoulder surgery',
#  'arthroscopic surgery',
#  'arthroscopy',
#  'articular cartilage',
#  'articular ligament',
#  'articular range of motion',
#  'articulatio talocruralis',
#  'articulation disorder',
#  'artificial rupture of membranes',
#  'artificial cardiac pacing',
#  'artificial heart valve implant',
#  'artificial insemination',
#  'artificial lens implant migration',
#  'artificial pneumothorax',
#  'artificial respiration',
#  'artificial sweetener',
#  'artificial sweetening agent',
#  'artificial tooth',
#  'artificial ventilation',
#  'artificially sweetened beverages',
#  'artistic creativity',
#  'arytenoid cartilage',
#  "asherman's syndrome",
#  'ashiatsu massage',
#  'aspartame',
#  'asperger disease',
#  'asperger syndrome',
#  "asperger's disease",
#  "asperger's disorder",
#  "asperger's syndrome",
#  'asphyxia neonatorum',
#  'aspiration',
#  'aspiration thrombectomy',
#  'aspirin',
#  'aspirin-induced asthma',
#  'assertive community treatment',
#  'assertive community treatment teams',
#  'assessment for environmental adaptation',
#  'assessment of personal injury damages',
#  'assessment of risk to others',
#  'assisted reproductive technology',
#  'assisted circulation',
#  'assisted reproductive techniques',
#  'assisted suicide',
#  'assistive technology assessment',
#  'association',
#  'association learning',
#  'association of acupuncturists of quebec',
#  'astasia',
#  'asthma',
#  'asthma-copd overlap syndrome',
#  'astigmatism',
#  'asymptomatic bacteriuria',
#  'at-home services',
#  'ataxia',
#  'atherectomy',
#  'atherosclerosis',
#  'atherosclerotic plaque',
#  'athlete foot',
#  "athlete's foot",
#  'athletes',
#  'athletic tape',
#  'athletic therapist',
#  'athletic therapy',
#  'atlanto-axial joint',
#  'atlanto-occipital joint',
#  'atlas orthogonal',
#  'atlas orthogonal instrument',
#  'atlas orthogonal technique',
#  'atopic dermatitis',
#  'atopic eczema',
#  'atrial fibrillation',
#  'atrial flutter',
#  'atrial premature complex',
#  'atrial remodeling',
#  'atrial septum',
#  'atrial switch operation',
#  'atrial switch repair',
#  'atrioventricular block',
#  'atrioventricular node',
#  'atrophy',
#  'attachment and biobehavioral catch-up',
#  'attachment disorder',
#  'attachment-based therapy',
#  'attempted suicide',
#  'attention',
#  'attention deficit and disruptive behavior disorder',
#  'attention deficit disorder',
#  'attention deficit disorder with hyperactivity',
#  'attention deficit disorder without hyperactivity',
#  'attention deficit hyperactivity disorder',
#  'attention deficit hyperactivity disorder assessment',
#  'attitude',
#  'attitude to death',
#  'attitude to health',
#  'atypical antipsychotics',
#  'atypical sexuality',
#  'audiogram',
#  'audiogramme tonal',
#  'audiogramme vocal',
#  'audiologic evaluation',
#  'audiologic recruitment detection',
#  'audiologist',
#  'audiology',
#  'audiology and speech-therapy unit',
#  'audiology clinic',
#  'audiology exam',
#  'audiologyassessmenttools',
#  'audiometer',
#  'audiometry',
#  'audioprosthesis',
#  'audioprosthetics',
#  'audioprosthetics clinic',
#  'audioprosthetics laboratory',
#  'audioprosthetist',
#  'audition test',
#  'auditory agnosia',
#  'auditory brain stem implantation',
#  'auditory brainstem response test',
#  'auditory disability with normal hearing',
#  'auditory dys-synchrony',
#  'auditory fatigue',
#  'auditory hair cell',
#  'auditory illusion',
#  'auditory integration training',
#  'auditory memory test',
#  'auditory nerve',
#  'auditory neuropathy',
#  'auditory neuropathy spectrum disorder',
#  'auditory perception',
#  'auditory perception correction',
#  'auditory perceptual disorder',
#  'auditory processing disorder',
#  'auditory rehabilitation center',
#  'auditory threshold',
#  'augmentation cystoplasty',
#  'augmentative and alternative communication',
#  'aural rehabilitation',
#  'auscultation',
#  'auscultation sounds',
#  'autism',
#  'autism spectrum disorder',
#  'autist',
#  'autistic disorder',
#  'autistic person',
#  'auto-locking rocking chair',
#  'autogenic training',
#  'autograft',
#  'autokinetic illusion',
#  'autokinetic effect',
#  'autologous tissue transfer',
#  'autonomic nervous system',
#  'autonomic pathways',
#  'autopsy',
#  'autosuggestion',
#  'autour du nombril',
#  'avascular necrosis',
#  'avascular necrosis of the femoral head',
#  'aviation professionals',
#  'avitaminosis',
#  'avoidant food intake disorder',
#  'avoidant personality disorder',
#  'awareness',
#  'axilla',
#  'axillary vein',
#  'b and t cell crossmatch',
#  'b-lymphocytes',
#  'b-mode ultrasonography',
#  'bte hearing aid',
#  'babinski reflex',
#  'baby sign language',
#  'baby sign language education',
#  'baby teeth',
#  'baby tooth',
#  'baby weighing',
#  'baby-led weaning',
#  'babysitting',
#  'babysitting training',
#  'back',
#  'back injury',
#  'back muscles',
#  'back pain',
#  'back-to-school period',
#  'bacteria',
#  'bacterial antibiotic resistance',
#  'bacterial conjunctivitis',
#  'bacterial drug resistance',
#  'bacterial endocarditis',
#  'bacterial infection',
#  'bacterial meningitis',
#  'bacterial overgrowth syndrome',
#  'bacterial sensitivity test',
#  'bacterial skin disease',
#  'bacterial susceptibility panel',
#  'bacterial toxin',
#  'bacterial vaginitis',
#  'bacterial vaginosis',
#  'bacteriemia',
#  'bacteriuria',
#  'bad back',
#  'bailey-lovie test',
#  'baisse de vision',
#  "baker's cyst",
#  'balance disorder',
#  'balance retraining exercise',
#  'balanced denture',
#  'balanitis',
#  'baldness',
#  'balloon embolectomy',
#  'balloon enteroscopy',
#  'balloon valvuloplasty',
#  'balls',
#  'baloon angioplasty',
#  'bandage lenses',
#  'bandages',
#  "barany's test",
#  'barbiturates',
#  'barbiturates drug test',
#  'bariatric medicine',
#  'bariatric surgeon',
#  'bariatric surgery',
#  'bariatrics',
#  'barium enema',
#  'barium examination',
#  'barium meal',
#  'barium swallow',
#  'barium swallow test',
#  'baroreflex',
#  'barostat',
#  'bas de compression',
#  'bas du nombril',
#  'basal cell carcinoma',
#  'basic metabolic panel',
#  'basilar membrane',
#  'basophil degranulation test',
#  'bathing plug',
#  'bathroom aids',
#  'beauty salon',
#  'beauty shop',
#  'beclomethasone',
#  'bedsore',
#  'bedwetting',
#  'bee venom',
#  'beef insulin',
#  'beer',
#  'behavior',
#  'behavior control',
#  'behavior disorder',
#  'behavior management',
#  'behavior mechanisms',
#  'behavioral disorder',
#  'behavioral genetics',
#  'behavioral medicine',
#  'behavioral optometry',
#  'behavioral psychotherapy',
#  'behavioral research',
#  'behavioral symptom',
#  'behavioral therapy',
#  'behaviorism',
#  'behavioural neurology',
#  'behavioural problems',
#  'behind',
#  'behind-the-ear aid',
#  'behind-the-ear hearing aid',
#  'bekesy audiometry',
#  'belkyra',
#  'bell palsy',
#  "bell's palsy",
#  'bellafill',
#  'belly',
#  'belly ache',
#  'belly band',
#  'belly binder',
#  'belly casting',
#  'below navel',
#  'benign brenner tumor',
#  'benign essential tremor',
#  'benign paroxysmal positional vertigo',
#  'benign tremor',
#  'benzocaine',
#  'benzodiazepine',
#  'benzodiazepine derivative',
#  'benzodiazepine related drug',
#  'benzodiazepines drug test',
#  'benzoylecgonine drug test',
#  'benzydamine',
#  'bereaved',
#  'bereavement',
#  'bereavement doula',
#  'beta-hcg blood test',
#  'betamethasone',
#  'beverage',
#  'bi-cros aid',
#  'bi-ventricular assist device',
#  'bibliotherapy',
#  'bicornuate uterus',
#  'bicuspid',
#  'bifocal lens',
#  'bifurcated ligament',
#  'big noise',
#  'big toe',
#  'bigender',
#  'biguanides',
#  'bilan des capacités auditives de québec',
#  'bilateral hearing loss',
#  'bile',
#  'bile duct',
#  'bile duct cancer',
#  'bile duct disease',
#  'bile duct neoplasm',
#  'bile duct obstruction',
#  'bile ducts ultrasound',
#  'bile reflux',
#  'biliary atresia',
#  'biliary fistula',
#  'biliary tract',
#  'biliary tract mri',
#  'biliary tract cancer',
#  'biliary tract disease',
#  'biliary tract neoplasm',
#  'biliblanket',
#  'bilio pancreatic bypass',
#  'bilio pancreatic diversion',
#  'biliopancreatic diversion',
#  'biliopancreatic diversion with duodenal switch',
#  'billroth i',
#  'billroth ii',
#  'bimalleolar fracture',
#  'binasal hemianopsia',
#  'bind loop syndrome',
#  'binge drinking',
#  'binocular vision test',
#  'bio-ethics',
#  'bio-identical hormone replacement',
#  'biochemistry',
#  'bioelectric impedance',
#  'bioelectric impedance analysis',
#  'bioelectric impedance test',
#  'biofeedback',
#  'bioimpedance analysis',
#  'biological marker',
#  'biological agent',
#  'biological culture service',
#  'biological factor',
#  'biological phenomena',
#  'biological psychiatry',
#  'biological sciences',
#  'biological therapy',
#  'biological toxin',
#  'biologicalproduct',
#  'biomarker',
#  'biomechanical evaluation',
#  'biomechanical exam',
#  'biomedical engineer',
#  'biomedical engineering',
#  'biomedical engineering technologist',
#  'biophotonic technology',
#  'biophotonics',
#  'biopsie choriale',
#  'biopsie des nodules thyroïdiens',
#  'biopsie par grattage',
#  'biopsy',
#  ...]

# %%
for t in df['Terme'].tolist():
    if t in taxo_terms:
        df.loc[df['Terme'] == t, 'isTaxoTerm'] = True
df[df['isTaxoTerm'] == True]
# Out:
#                                     Terme Structure syntaxique  \
# 1                   centre de prélèvement          NOM PRP NOM
# 22                        soins intensifs              NOM ADJ
# 34                     recherche clinique              NOM ADJ
# 35               fibrillation auriculaire              NOM ADJ
# 42                     centre hospitalier              NOM ADJ
# 46                reconstruction mammaire              NOM ADJ
# 67                   maladie de parkinson          NOM PRP NOM
# 96                         santé publique              NOM ADJ
# 97                     médecin de famille          NOM PRP NOM
# 99                          santé mentale              NOM ADJ
# 101                    médecine nucléaire              NOM ADJ
# 106                      médecine interne              NOM ADJ
# 115                      soins infirmiers              NOM NOM
# 116                   système immunitaire              NOM ADJ
# 125                 cancer de la prostate  NOM PRP DET:ART NOM
# 133             département de radiologie          NOM PRP NOM
# 140                   sclérose en plaques          NOM PRP NOM
# 151            soins intensifs cardiaques          NOM ADJ ADJ
# 181                   maladie d'alzheimer     NOM PRP VER:infi
# 254  paralysie supranucléaire progressive          NOM ADJ ADJ
# 315          accident vasculaire cérébral          NOM ADJ ADJ
# 321                     douleur chronique              NOM ADJ
# 327                     cancer colorectal              NOM ADJ
# 338                       système nerveux              NOM ADJ
# 343                      cancer du poumon      NOM PRP:det NOM
# 344                      services sociaux              NOM ADJ
# 346                            fin de vie          NOM PRP NOM
# 455                    tension artérielle              NOM ADJ
#
#      Fréquence (TF)          LLR  Fréquence documentaire (DF)  isMeSHTerm  \
# 1              1304         -inf                         1280       False
# 22              453         -inf                          161        True
# 34              294  1106.288321                          183       False
# 35              293         -inf                           43        True
# 42              215         -inf                          147       False
# 46              202         -inf                           50        True
# 67              163         -inf                           62        True
# 96              145  1572.986426                           95        True
# 97              145         -inf                          100       False
# 99              144  1579.079685                           68        True
# 101             141         -inf                          119        True
# 106             124  1390.961677                           51        True
# 115             116  1262.889646                           67        True
# 116             115  1574.417236                           63        True
# 125             110         -inf                           46        True
# 133             106  1113.419258                           92       False
# 140             104         -inf                           56        True
# 151              97  1267.834478                           85       False
# 181              83         -inf                           40       False
# 254              81  1504.622917                           41        True
# 315              73  1409.586583                           50        True
# 321              70   881.219284                           42        True
# 327              67   756.914408                           37        True
# 338              62   869.569025                           45        True
# 343              61   827.358531                           39        True
# 344              60   628.594270                           55        True
# 346              59   759.479485                           42       False
# 455              19   309.824178                           37        True
#
#     MeSHID MesH_prefLabel_fr MesH_prefLabel_en isTaxoTerm
# 1     None              None              None       True
# 22    None              None              None       True
# 34    None              None              None       True
# 35    None              None              None       True
# 42    None              None              None       True
# 46    None              None              None       True
# 67    None              None              None       True
# 96    None              None              None       True
# 97    None              None              None       True
# 99    None              None              None       True
# 101   None              None              None       True
# 106   None              None              None       True
# 115   None              None              None       True
# 116   None              None              None       True
# 125   None              None              None       True
# 133   None              None              None       True
# 140   None              None              None       True
# 151   None              None              None       True
# 181   None              None              None       True
# 254   None              None              None       True
# 315   None              None              None       True
# 321   None              None              None       True
# 327   None              None              None       True
# 338   None              None              None       True
# 343   None              None              None       True
# 344   None              None              None       True
# 346   None              None              None       True
# 455   None              None              None       True

# %% [markdown]
# ### **Mapping to MeSH IDs**

# %% [markdown]
# Lire le fichier XML contenant le MeSH Bilingue
#
# Le MeSH 2019 comprend 29 351 descripteurs
# https://mesh.inserm.fr/FrenchMesh/presentation.htm

# %%
import xml.etree.ElementTree as ET
import re
import pandas as pd
base_path = '../02-filtrage/MeSH/'

tree = ET.parse(base_path + 'fredesc2019.xml')
root = tree.getroot()

def flatten(l):
    return [item for sublist in l for item in sublist]

data_mesh = [{'mesh_id' : x.find('DescriptorUI').text.strip('\n'), \
         'label_fr' : x.find('DescriptorName').find('String').text.split('[')[0], \
         'label_en' : x.find('DescriptorName').find('String').text.split('[')[1].strip(']'), \
         'synonymes (en/fr)' : flatten([[term.find('String').text for term in concept.find('TermList').findall('Term')] for concept in x.find('ConceptList').findall('Concept')]) \
         } for x in root.findall('DescriptorRecord')]

# %%
for t in df[df['isMeSHTerm'] == True]['Terme'].tolist():
    for d in data_mesh:
        if t in [str(x).lower() for x in d['synonymes (en/fr)']]:
            df.loc[df['Terme'] == t, 'MeSHID'] = d['mesh_id']
            df.loc[df['Terme'] == t, 'MesH_prefLabel_fr'] = d['label_fr']
            df.loc[df['Terme'] == t, 'MesH_prefLabel_en'] = d['label_en']

df = df[['Terme', 'Structure syntaxique',	'Fréquence (TF)', 'Fréquence documentaire (DF)', 'LLR', 'isMeSHTerm', 'isTaxoTerm', 'MeSHID', 'MesH_prefLabel_fr', 'MesH_prefLabel_en']]

# %%
df.insert(0, 'Corpus', acteur)
df
# Out:
#     Corpus                              Terme     Structure syntaxique  \
# 0     chum                centre de recherche              NOM PRP NOM
# 1     chum              centre de prélèvement              NOM PRP NOM
# 2     chum                  prélèvement guide             NOM VER:pres
# 3     chum                  recherche du chum          NOM PRP:det NOM
# 4     chum        centre de recherche du chum  NOM PRP NOM PRP:det NOM
# ..     ...                                ...                      ...
# 454   chum  université de montréal professeur          NOM PRP ADJ NOM
# 455   chum                 tension artérielle                  NOM ADJ
# 456   chum                  soins et services              NOM KON NOM
# 457   chum                   recherche du chu     NOM PRP:det VER:pper
# 458   chum                 chum et professeur              NOM KON NOM
#
#      Fréquence (TF)  Fréquence documentaire (DF)         LLR  isMeSHTerm  \
# 0              1421                         1216        -inf       False
# 1              1304                         1280        -inf       False
# 2              1271                         1271        -inf       False
# 3              1199                         1119        -inf       False
# 4              1173                         1105        -inf       False
# ..              ...                          ...         ...         ...
# 454              24                           39   97.634363       False
# 455              19                           37  309.824178        True
# 456              11                           49   78.225674       False
# 457               8                         1120   51.863171       False
# 458               6                           43   29.653402       False
#
#     isTaxoTerm   MeSHID    MesH_prefLabel_fr  MesH_prefLabel_en
# 0        False     None                 None               None
# 1         True     None                 None               None
# 2        False     None                 None               None
# 3        False     None                 None               None
# 4        False     None                 None               None
# ..         ...      ...                  ...                ...
# 454      False     None                 None               None
# 455       True  D062186  Pression artérielle  Arterial Pressure
# 456      False     None                 None               None
# 457      False     None                 None               None
# 458      False     None                 None               None
#
# [459 rows x 11 columns]

# %%
output_path = path.join('../02-filtrage/output/', acteur + '_candidate-terms.csv') 
df.to_csv(output_path)
