# %% [markdown]
# ## **2. Prétraitement**
# - Segmentation (phrases)
# - Tokenization (mots)
# - Étiquetage morphosyntaxique (POS Tagging)
# - Filtrage (stopwords)
# - Extraction de termes complexes (MWE / n-grammes / segments répétés)
# - Chunking / Filtrage par patrons syntaxiques (basés sur les patrons fréquents dans les MeSH)
# - Extraction de termes MeSH présents dans les données / Termes de la taxonomie présents dans les données

# %% [markdown]
# ### **Lire le corpus**

# %%
import shutil, re, random
from os import listdir, chdir, path
from pathlib import Path
import pandas as pd
import glob

import nltk
#nltk.download(['popular'])
from nltk.tokenize import RegexpTokenizer
tokenizer_re = RegexpTokenizer(r"\w\'|\w+")
from nltk import bigrams, trigrams, ngrams, everygrams
from nltk.probability import FreqDist


import treetaggerwrapper
tagger = treetaggerwrapper.TreeTagger(TAGLANG='fr')


from collections import Counter
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.stats import binom, chi2

# %%
lng = 'fr'
acteur = 'doctissimo' # Paramètre à indiquer avant de rouler le script
file = acteur +'.csv'

# %%
file
# Out:
# 'doctissimo.csv'

# %%
data = pd.read_csv('../'+file)
data
# Out:
#                                                 original  \
# 0              https://forum.doctissimo.fr/experts/sante
# 1      https://forum.doctissimo.fr/forme-beaute/Beaut...
# 2      https://forum.doctissimo.fr/forme-beaute/Beaut...
# 3      https://forum.doctissimo.fr/forme-beaute/Beaut...
# 4      https://forum.doctissimo.fr/forme-beaute/Beaut...
# ...                                                  ...
# 16211  https://forum.doctissimo.fr/sante/ventre-estom...
# 16212  https://forum.doctissimo.fr/sante/ventre-estom...
# 16213  https://forum.doctissimo.fr/sante/ventre-estom...
# 16214  https://forum.doctissimo.fr/sante/ventre-estom...
# 16215  https://forum.doctissimo.fr/sante/ventre-estom...
#
#                                            raw_sentences
# 0      ['', '\nConcours\n', "\n\n\n\n\n\n\n\n\n\n\n\n...
# 1      ['', "La levure de bière n'accélère pas la pou...
# 2      ['', "Mais quel pub masque !! Je te dis je sui...
# 3      ['', '\n\n\n\n\n\n\n\n\n\n\n\n\n\t\t\tYour bro...
# 4      ['', "Une des principales fonction du gel d'al...
# ...                                                  ...
# 16211  ['', 'bonjours je ne sait pas comment abordé s...
# 16212  ['', '[h3]27 Causes of Stomachaches—And How to...
# 16213  ['', "Tu as raison, c'est tôt... je devrais pr...
# 16214  ['', "Bonjour,Pour info on m'a enlevé la vésic...
# 16215  ['', 'Bonsoir,Si je viens sur ce forum c\'est ...
#
# [16216 rows x 2 columns]

# %%
print("On a un corpus de {} documents.".format(len(data)))
# Out:
# On a un corpus de 16216 documents.

# %%
data = data[:len(data)/2]
print("On a un corpus de {} documents.".format(len(data)))

# %% [markdown]
# ### **Nettoyage**

# %%
punct = '[!#$%&•►*+,;\/\\<=>?@[\]^_{|}~©«»—“”–—]'
spaces = '\s+'
postals = '([a-zA-Z]+\d+|\d+[a-zA-Z]+)+'

text = [str(t).strip('\n').lower().replace('’', '\'') for t in data['raw_sentences'].tolist()]
text = [re.sub(spaces, ' ', t) for t in text]
text = [re.sub(postals, ' STOP ', t) for t in text]
text = [re.sub(punct, ' STOP ', t) for t in text]
text = [t.replace("  ", " " ) for t in text]

# %% [markdown]
# ### **Filtrage**
# On va filtrer tout de suite filtrer certaines expressions relatives à l'architecture d'information / navigation Web

# %%
def filter_mwesw(corpus):
    file_mwesw = '../02-filtrage/mwe_stopwords.txt'
    with open (file_mwesw, 'r', encoding='utf-8') as f:
        mwe_sw = [t.lower().strip('\n') for t in f.readlines()]
    for mwe in mwe_sw:
        corpus = corpus.replace(mwe, ' STOP ').replace('  ', " ")
    return corpus

# %%
corpus = filter_mwesw(corpus)

# %% [markdown]
# ### **Tokenisation / POS tagging** (TreeTagger)
# https://github.com/miotto/treetagger-python/blob/master/README.rst
# https://treetaggerwrapper.readthedocs.io/en/latest/

# %%
# Ici, on tokenise une première fois avec le Regex Tokenizer de NLTK pour voir combien de temps ça devrait 
# prendre au Tree Tagger pour tokeniser et tagger notre corpus ; en théorie, le Tree Tagger est capable d'étiquetter
# environ 15 000 tokens / seconde. 
def tok(corpus):
    # Seulement les caractères alphabétiques
    tokens = tokenizer_re.tokenize(corpus)
    print("Avec le RegExpTokenizer, notre corpus contient {} tokens.".format(len(tokens)))
    temps = round(len(tokens) / 15000 / 60)
    print('Le POS tagging devrait prendre environ {} minutes.'.format(temps))
    return tokens

tok(corpus)[:10]
# Out:
# Avec le RegExpTokenizer, notre corpus contient 7496801 tokens.
# Le POS tagging devrait prendre environ 8 minutes.
# ['STOP',
#  'STOP',
#  'ah',
#  'oui',
#  'pour',
#  'les',
#  'logement',
#  'sociaux',
#  "c'",
#  'est']

# %%
def tagging(corpus):
    output = []
    for t in tagger.tag_text(corpus):
        try: 
            output.append([t.split('\t')[0], t.split('\t')[1]])
        except Exception as e:
            output.append(('STOP', 'NAM'))

    return output

# %%
tagged = tagging(corpus)
tokens = [t[0] for t in tagged]

# %%
tagged
# Out:
# [['STOP', 'NOM'],
#  ["'", 'PUN'],
#  ["'", 'PUN'],
#  ['STOP', 'NOM'],
#  ['"', 'PUN:cit'],
#  ['ah', 'INT'],
#  ['oui', 'INT'],
#  ['pour', 'PRP'],
#  ['les', 'DET:ART'],
#  ['logement', 'NOM'],
#  ['sociaux', 'ADJ'],
#  ["c'", 'PRO:DEM'],
#  ['est', 'VER:pres'],
#  ['assez', 'ADV'],
#  ['long', 'ADV'],
#  ['dns-remplacé', 'VER:pper'],
#  ('STOP', 'NAM'),
#  ['on', 'PRO:PER'],
#  ['va', 'VER:pres'],
#  ['commencer', 'VER:infi'],
#  ['des', 'PRP:det'],
#  ['travaux', 'NOM'],
#  ['dans', 'PRP'],
#  ['notre', 'DET:POS'],
#  ['maison', 'NOM'],
#  ['STOP', 'NOM'],
#  ['on', 'PRO:PER'],
#  ['aménage', 'VER:pres'],
#  ['des', 'PRP:det'],
#  ['chambres', 'NOM'],
#  ['dans', 'PRP'],
#  ['le', 'DET:ART'],
#  ['grenier', 'NOM'],
#  ['pour', 'PRP'],
#  ['nos', 'DET:POS'],
#  ['grands', 'ADJ'],
#  ['.', 'SENT'],
#  ['et', 'KON'],
#  ['bébé', 'NOM'],
#  ['récupérera', 'VER:futu'],
#  ['une', 'DET:ART'],
#  ['chambre', 'NOM'],
#  ['du', 'PRP:det'],
#  ['STOP', 'NOM'],
#  ['.', 'SENT'],
#  ['je', 'PRO:PER'],
#  ['pense', 'VER:pres'],
#  ['que', 'KON'],
#  ['ce', 'PRO:DEM'],
#  ['ne', 'ADV'],
#  ['sera', 'VER:futu'],
#  ['pas', 'ADV'],
#  ['fini', 'VER:pper'],
#  ['à', 'PRP'],
#  ['la', 'DET:ART'],
#  ['naissance', 'NOM'],
#  ['STOP', 'INT'],
#  ['on', 'PRO:PER'],
#  ['fait', 'VER:pres'],
#  ['nous', 'PRO:PER'],
#  ['même', 'ADV'],
#  ['donc', 'ADV'],
#  ["c'", 'PRO:DEM'],
#  ['est', 'VER:pres'],
#  ['plus', 'ADV'],
#  ['dns-remplacé', 'VER:pper'],
#  ('STOP', 'NAM'),
#  ['toute', 'PRO:IND'],
#  ['façon', 'NOM'],
#  ['bébé', 'NOM'],
#  ['reste', 'VER:pres'],
#  ['avec', 'PRP'],
#  ['nous', 'PRO:PER'],
#  ['le', 'DET:ART'],
#  ['temps', 'NOM'],
#  ["qu'", 'PRO:REL'],
#  ['il', 'PRO:PER'],
#  ['fasse', 'VER:subp'],
#  ['ses', 'DET:POS'],
#  ['nuits', 'NOM'],
#  ['STOP', 'NOM'],
#  ['voir', 'VER:infi'],
#  ['plus', 'ADV'],
#  ['.', 'SENT'],
#  ['(', 'PUN'],
#  ['on', 'PRO:PER'],
#  ['le', 'DET:ART'],
#  ['garde', 'NOM'],
#  ['mini', 'ADJ'],
#  ['6', 'NUM'],
#  ['mois', 'NOM'],
#  ['STOP', 'INT'],
#  ['STOP', 'NOM'],
#  ["s'", 'PRO:PER'],
#  ['il', 'PRO:PER'],
#  ['fait', 'VER:pres'],
#  ['pas', 'ADV'],
#  ['ses', 'DET:POS'],
#  ['nuits', 'NOM'],
#  [')', 'PUN'],
#  ['sinon', 'KON'],
#  ['moi', 'PRO:PER'],
#  ["j'", 'PRO:PER'],
#  ['achète', 'VER:pres'],
#  ['les', 'DET:ART'],
#  ['vêtements', 'NOM'],
#  ['au', 'PRP:det'],
#  ['troc', 'NOM'],
#  ['et', 'KON'],
#  ['puce', 'NOM'],
#  ['ou', 'KON'],
#  ['sur', 'PRP'],
#  ['vinted', 'NOM'],
#  ['ça', 'PRO:DEM'],
#  ['revient', 'VER:pres'],
#  ['bcp', 'NOM'],
#  ['moins', 'ADV'],
#  ['cher', 'ADJ'],
#  ['.', 'SENT'],
#  ['"', 'PUN:cit'],
#  ['STOP', 'NOM'],
#  ["'", 'PUN'],
#  ['gwayn', 'NOM'],
#  ['super', 'ADJ'],
#  ['pour', 'PRP'],
#  ['la', 'DET:ART'],
#  ['liste', 'NOM'],
#  ['de', 'PRP'],
#  ['naissance', 'NOM'],
#  ['.', 'SENT'],
#  ['nous', 'PRO:PER'],
#  ['elle', 'PRO:PER'],
#  ['sera', 'VER:futu'],
#  ['dispo', 'NOM'],
#  ['après', 'PRP'],
#  ['notre', 'DET:POS'],
#  ['mariage', 'NOM'],
#  ["'", 'PUN'],
#  ['STOP', 'NOM'],
#  ["'", 'PUN'],
#  ["j'", 'PRO:PER'],
#  ['ai', 'VER:pres'],
#  ['passé', 'VER:pper'],
#  ['le', 'DET:ART'],
#  ['cap', 'NOM'],
#  ['et', 'KON'],
#  ['diffuser', 'VER:infi'],
#  ['la', 'DET:ART'],
#  ['liste', 'NOM'],
#  ['de', 'PRP'],
#  ['naissance', 'NOM'],
#  ['et', 'KON'],
#  ["j'", 'PRO:PER'],
#  ['ai', 'VER:pres'],
#  ['également', 'ADV'],
#  ['acheté', 'VER:pper'],
#  ['des', 'PRP:det'],
#  ['packs', 'NOM'],
#  ['de', 'PRP'],
#  ['couches', 'NOM'],
#  ['pampers', 'ADJ'],
#  ['harmonie', 'NOM'],
#  ['en', 'PRP'],
#  ['promo', 'NOM'],
#  ['sur', 'PRP'],
#  ['amazon', 'NOM'],
#  ['😁', 'ABR'],
#  ["'", 'PUN'],
#  ['STOP', 'INT'],
#  ["'", 'PUN'],
#  ['oui', 'INT'],
#  ['pareil', 'ADJ'],
#  ['que', 'KON'],
#  ['toi', 'PRO:PER'],
#  ['arliaje', 'VER:subp'],
#  ['les', 'DET:ART'],
#  ['garde', 'NOM'],
#  ['au', 'PRP:det'],
#  ['minimum', 'NOM'],
#  ['6', 'NUM'],
#  ['mois', 'NOM'],
#  ['mais', 'KON'],
#  ["j'", 'PRO:PER'],
#  ['ai', 'VER:pres'],
#  ['de', 'PRP'],
#  ['la', 'DET:ART'],
#  ['chance', 'NOM'],
#  ['à', 'PRP'],
#  ['chaque', 'PRO:IND'],
#  ['fois', 'NOM'],
#  ['ils', 'PRO:PER'],
#  ['ont', 'VER:pres'],
#  ['fait', 'VER:pper'],
#  ['leur', 'DET:POS'],
#  ['nuit', 'NOM'],
#  ['rapidement', 'ADV'],
#  ['...', 'PUN'],
#  ['pour', 'PRP'],
#  ['la', 'DET:ART'],
#  ['construction', 'NOM'],
#  ['bin', 'ADJ'],
#  ['on', 'PRO:PER'],
#  ['attend', 'VER:pres'],
#  ['tjrs', 'NOM'],
#  ['le', 'DET:ART'],
#  ['permis', 'NOM'],
#  ['de', 'PRP'],
#  ['construire', 'VER:infi'],
#  ['mais', 'KON'],
#  ['on', 'PRO:PER'],
#  ['se', 'PRO:PER'],
#  ['prend', 'VER:pres'],
#  ['déjà', 'ADV'],
#  ['la', 'DET:ART'],
#  ['tête', 'NOM'],
#  ['pour', 'PRP'],
#  ['savoir', 'VER:infi'],
#  ['comment', 'ADV'],
#  ['il', 'PRO:PER'],
#  ['faut', 'VER:pres'],
#  ['aménager', 'VER:infi'],
#  ['...', 'PUN'],
#  ['achat', 'NOM'],
#  ['cuisine', 'NOM'],
#  ['salle', 'NOM'],
#  ['de', 'PRP'],
#  ['bain', 'NOM'],
#  ['sol', 'NOM'],
#  ['...', 'PUN'],
#  ['peinture', 'NOM'],
#  ['...', 'PUN'],
#  ['on', 'PRO:PER'],
#  ['achète', 'VER:pres'],
#  ['tout', 'ADV'],
#  ['quand', 'KON'],
#  ['c', 'NOM'],
#  ['en', 'PRP'],
#  ['promo', 'NOM'],
#  ['ou', 'KON'],
#  ['en', 'PRP'],
#  ['solde', 'NOM'],
#  ['pour', 'PRP'],
#  ['faire', 'VER:infi'],
#  ['les', 'DET:ART'],
#  ['plus', 'ADV'],
#  ["d'", 'PRP'],
#  ['économie', 'NOM'],
#  ['possible', 'ADJ'],
#  ['...', 'PUN'],
#  ['pour', 'PRP'],
#  ['cette', 'PRO:DEM'],
#  ['grossesse', 'NOM'],
#  ['STOP', 'INT'],
#  ["c'", 'PRO:DEM'],
#  ['est', 'VER:pres'],
#  ['plus', 'ADV'],
#  ['de', 'PRP'],
#  ['douleur', 'NOM'],
#  ['plus', 'ADV'],
#  ['de', 'PRP'],
#  ['fatigue', 'NOM'],
#  ['.', 'SENT'],
#  ['et', 'KON'],
#  ['des', 'PRP:det'],
#  ['angoisses', 'NOM'],
#  ['des', 'PRP:det'],
#  ['que', 'ADV'],
#  ['je', 'PRO:PER'],
#  ['ne', 'ADV'],
#  ['sens', 'VER:pres'],
#  ['pas', 'ADV'],
#  ['bb', 'NOM'],
#  ['bougé', 'VER:pper'],
#  ["'", 'PUN'],
#  ['c', 'NOM'],
#  ['sûrement', 'ADV'],
#  ['du', 'PRP:det'],
#  ['au', 'PRP:det'],
#  ['fait', 'NOM'],
#  ['de', 'PRP'],
#  ['ma', 'DET:POS'],
#  ['fc', 'NOM'],
#  ['juste', 'ADJ'],
#  ['avant', 'PRP'],
#  ['...', 'PUN'],
#  ['alors', 'ADV'],
#  ['je', 'PRO:PER'],
#  ['me', 'PRO:PER'],
#  ['rassure', 'VER:pres'],
#  ['toute', 'PRO:IND'],
#  ['seule', 'ADJ'],
#  ['en', 'PRP'],
#  ['me', 'PRO:PER'],
#  ['disant', 'VER:ppre'],
#  ['que', 'KON'],
#  ['la', 'DET:ART'],
#  ['STOP', 'NOM'],
#  ['arrive', 'VER:pres'],
#  ['dans', 'PRP'],
#  ['4', 'NUM'],
#  ['semaines', 'NOM'],
#  ['...', 'PUN'],
#  ['même', 'ADJ'],
#  ['si', 'KON'],
#  ['c', 'NOM'],
#  ['long', 'ADJ'],
#  ['...', 'PUN'],
#  ["'", 'PUN'],
#  ['STOP', 'NOM'],
#  ['"', 'PUN:cit'],
#  ['ici', 'ADV'],
#  ['aussi', 'ADV'],
#  ["j'", 'PRO:PER'],
#  ['ai', 'VER:pres'],
#  ['fais', 'VER:pres'],
#  ['une', 'DET:ART'],
#  ['fausse', 'ADJ'],
#  ['couche', 'NOM'],
#  ['juste', 'ADJ'],
#  ['avant', 'NOM'],
#  ['.', 'SENT'],
#  ['et', 'KON'],
#  ['le', 'DET:ART'],
#  ['debut', 'NOM'],
#  ['de', 'PRP'],
#  ['grossesse', 'NOM'],
#  ['ne', 'ADV'],
#  ["c'", 'PRO:DEM'],
#  ['est', 'VER:pres'],
#  ['pas', 'ADV'],
#  ['bien', 'ADV'],
#  ['passé', 'VER:pper'],
#  ['du', 'PRP:det'],
#  ['tout', 'PRO:IND'],
#  ['STOP', 'NOM'],
#  ["j'", 'PRO:PER'],
#  ['ai', 'VER:pres'],
#  ['eu', 'VER:pper'],
#  ['bcp', 'NOM'],
#  ['de', 'PRP'],
#  ['saignement', 'NOM'],
#  ['mais', 'KON'],
#  ['bébé', 'NOM'],
#  ['est', 'VER:pres'],
#  ['bien', 'ADV'],
#  ['là', 'ADV'],
#  ['.', 'SENT'],
#  ['moi', 'PRO:PER'],
#  ['je', 'PRO:PER'],
#  ['le', 'DET:ART'],
#  ['sens', 'NOM'],
#  ['super', 'ADJ'],
#  ['bien', 'ADV'],
#  ['depuis', 'PRP'],
#  ['STOP', 'NOM'],
#  ['STOP', 'NOM'],
#  ['tout', 'ADV'],
#  ['les', 'DET:ART'],
#  ['jours', 'NOM'],
#  ['.', 'SENT'],
#  ["c'", 'PRO:DEM'],
#  ['est', 'VER:pres'],
#  ['STOP', 'NOM'],
#  ['ça', 'PRO:DEM'],
#  ['que', 'PRO:REL'],
#  ["j'", 'PRO:PER'],
#  ['ai', 'VER:pres'],
#  ['pu', 'VER:pper'],
#  ['arrêté', 'VER:pper'],
#  ['de', 'PRP'],
#  ['stressé.ici', 'NOM'],
#  ['la', 'DET:ART'],
#  ['STOP', 'NOM'],
#  ['est', 'VER:pres'],
#  ['la', 'DET:ART'],
#  ['semaine', 'NOM'],
#  ['prochaine', 'ADJ'],
#  ['.', 'SENT'],
#  ["j'", 'PRO:PER'],
#  ['ai', 'VER:pres'],
#  ['tellement', 'ADV'],
#  ['hâte', 'NOM'],
#  ['.', 'SENT'],
#  ['"', 'PUN:cit'],
#  ['STOP', 'NOM'],
#  ['"', 'PUN:cit'],
#  ['moi', 'PRO:PER'],
#  ['ma', 'DET:POS'],
#  ['STOP', 'NOM'],
#  ["n'", 'ADV'],
#  ['est', 'VER:pres'],
#  ['pas', 'ADV'],
#  ['avant', 'PRP'],
#  ['le', 'DET:ART'],
#  ['26.09', 'NUM'],
#  ['alors', 'ADV'],
#  ['ca', 'VER:simp'],
#  ['me', 'PRO:PER'],
#  ['parrait', 'VER:cond'],
#  ['encore', 'ADV'],
#  ['loin', 'ADV'],
#  ['...', 'PUN'],
#  ['je', 'PRO:PER'],
#  ['le', 'PRO:PER'],
#  ['sens', 'VER:pres'],
#  ['bouger', 'VER:infi'],
#  ['aussi', 'ADV'],
#  ['tous', 'PRO:IND'],
#  ['les', 'DET:ART'],
#  ['jours', 'NOM'],
#  ['mais', 'KON'],
#  ['je', 'PRO:PER'],
#  ['sais', 'VER:pres'],
#  ['pas', 'ADV'],
#  ["j'", 'PRO:PER'],
#  ['ai', 'VER:pres'],
#  ['des', 'PRP:det'],
#  ["angoisses.c'est", 'NOM'],
#  ['surement', 'NOM'],
#  ['les', 'DET:ART'],
#  ['hormones', 'NOM'],
#  ["lolj'ai", 'VER:simp'],
#  ['hâte', 'NOM'],
#  ["d'", 'PRP'],
#  ['être', 'VER:infi'],
#  ['dans', 'PRP'],
#  ['un', 'DET:ART'],
#  ['mois', 'NOM'],
#  ['du', 'PRP:det'],
#  ['coup', 'NOM'],
#  ['.', 'SENT'],
#  ['ma', 'DET:POS'],
#  ['grand', 'ADJ'],
#  ['mère', 'NOM'],
#  ['STOP', 'INT'],
#  ['ma', 'DET:POS'],
#  ['belle', 'ADJ'],
#  ['mère', 'NOM'],
#  ['et', 'KON'],
#  ['ma', 'DET:POS'],
#  ['mère', 'NOM'],
#  ['ont', 'VER:pres'],
#  ['déjà', 'ADV'],
#  ['commencé', 'VER:pper'],
#  ['à', 'PRP'],
#  ['acheter', 'VER:infi'],
#  ['et', 'KON'],
#  ['à', 'PRP'],
#  ['préparer', 'VER:infi'],
#  ['alors', 'ADV'],
#  ['que', 'KON'],
#  ['moi', 'PRO:PER'],
#  ['STOP', 'NOM'],
#  ['je', 'PRO:PER'],
#  ['leur', 'PRO:PER'],
#  ['dit', 'VER:pres'],
#  ['eh', 'INT'],
#  ['oh', 'INT'],
#  ['doucement', 'ADV'],
#  ['lol', 'NOM'],
#  ['"', 'PUN:cit'],
#  ['STOP', 'NOM'],
#  ['"', 'PUN:cit'],
#  ['piticlaire', 'NOM'],
#  ['difficile', 'ADJ'],
#  ["d'", 'PRP'],
#  ['etre', 'NOM'],
#  ['sereine', 'ADJ'],
#  ['après', 'PRP'],
#  ['les', 'DET:ART'],
#  ['fc', 'NOM'],
#  ['.', 'SENT'],
#  ['mais', 'KON'],
#  ['on', 'PRO:PER'],
#  ['ne', 'ADV'],
#  ['peut', 'VER:pres'],
#  ['pas', 'ADV'],
#  ['encore', 'ADV'],
#  ['sentir', 'VER:infi'],
#  ['bébé', 'NOM'],
#  ['bouger', 'VER:infi'],
#  ['tous', 'PRO:IND'],
#  ['les', 'DET:ART'],
#  ['jours', 'NOM'],
#  ['.', 'SENT'],
#  ['ou', 'KON'],
#  ['parfois', 'ADV'],
#  ['il', 'PRO:PER'],
#  ['bouge', 'VER:pres'],
#  ['pendant', 'PRP'],
#  ['nos', 'DET:POS'],
#  ['phase', 'NOM'],
#  ['de', 'PRP'],
#  ['dns-remplacé', 'ADJ'],
#  ('STOP', 'NAM'),
#  ['STOP', 'NOM'],
#  ["c'", 'PRO:DEM'],
#  ['est', 'VER:pres'],
#  ['ce', 'PRO:DEM'],
#  ['que', 'PRO:REL'],
#  ["j'", 'PRO:PER'],
#  ['avais', 'VER:impf'],
#  ['fait', 'VER:pper'],
#  ['pour', 'PRP'],
#  ['notre', 'DET:POS'],
#  ['premier', 'NOM'],
#  ['.', 'SENT'],
#  ['celui', 'PRO:DEM'],
#  ['ce', 'PRO:DEM'],
#  ['sera', 'VER:futu'],
#  ['la', 'DET:ART'],
#  ['même', 'ADJ'],
#  ['.', 'SENT'],
#  ['sauf', 'PRP'],
#  ['quelques', 'PRO:IND'],
#  ['tenues', 'NOM'],
#  ['.', 'SENT'],
#  ['où', 'PRO:REL'],
#  ["l'", 'PRO:PER'],
#  ['on', 'PRO:PER'],
#  ['craque', 'VER:pres'],
#  ['toujours', 'ADV'],
#  ['en', 'PRP'],
#  ['magasin', 'NOM'],
#  ['pour', 'PRP'],
#  ['quelque', 'PRO:IND'],
#  ['trucs', 'NOM'],
#  ['"', 'PUN:cit'],
#  ['STOP', 'NOM'],
#  ["'", 'PUN'],
#  ['coucou', 'NOM'],
#  ['à', 'PRP'],
#  ['toutesest', 'NOM'],
#  ['-ce', 'PRO:DEM'],
#  ['que', 'PRO:REL'],
#  ['parmi', 'PRP'],
#  ['vous', 'PRO:PER'],
#  ['certaines', 'PRO:IND'],
#  ['ont', 'VER:pres'],
#  ['déjà', 'ADV'],
#  ['essayé', 'VER:pper'],
#  ['les', 'DET:ART'],
#  ['couches', 'NOM'],
#  ['lavables', 'ADJ'],
#  ['STOP', 'NOM'],
#  ["qu'", 'PRO:REL'],
#  ['en', 'PRO:PER'],
#  ['pensez', 'VER:pres'],
#  ['-vous', 'PRO:PER'],
#  ['STOP', 'NOM'],
#  ["'", 'PUN'],
#  ['STOP', 'NOM'],
#  ["'", 'PUN'],
#  ['bon', 'ADJ'],
#  ['courage', 'NOM'],
#  ['à', 'PRP'],
#  ['vous', 'PRO:PER'],
#  ['pour', 'PRP'],
#  ['les', 'DET:ART'],
#  ['travaux', 'NOM'],
#  [':', 'PUN'],
#  ['-', 'PUN'],
#  ['STOP', 'INT'],
#  ["'", 'PUN'],
#  ['STOP', 'INT'],
#  ["'", 'PUN'],
#  ['hello', 'INT'],
#  ['STOP', 'NOM'],
#  ['ici', 'ADV'],
#  ["c'", 'PRO:DEM'],
#  ['est', 'VER:pres'],
#  ['mon', 'DET:POS'],
#  ['3ème', 'NUM'],
#  ['(', 'PUN'],
#  ['mais', 'KON'],
#  ['les', 'DET:ART'],
#  ['deux', 'NUM'],
#  ['sont', 'VER:pres'],
#  ['grands', 'ADJ'],
#  [')', 'PUN'],
#  ['et', 'KON'],
#  ['le', 'DET:ART'],
#  ['STOP', 'NOM'],
#  ['de', 'PRP'],
#  ['dns-remplacé', 'NOM'],
#  ('STOP', 'NAM'),
#  ['doit', 'VER:pres'],
#  ['tout', 'ADV'],
#  ['acheter', 'VER:infi'],
#  ['mais', 'KON'],
#  ['en', 'PRO:PER'],
#  ['fait', 'VER:pres'],
#  ['on', 'PRO:PER'],
#  ['ne', 'ADV'],
#  ['veut', 'VER:pres'],
#  ['pas', 'ADV'],
#  ['grand', 'ADJ'],
#  ['chose', 'NOM'],
#  [':', 'PUN'],
#  ['des', 'PRP:det'],
#  ['vêtementsun', 'ADJ'],
#  ['matelas', 'NOM'],
#  ['en', 'PRP'],
#  ['STOP', 'NOM'],
#  ['cosygwayn', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['mon', 'DET:POS'],
#  ['deuxième', 'NUM'],
#  ['à', 'PRP'],
#  ['été', 'NOM'],
#  ['en', 'PRP'],
#  ['couches', 'NOM'],
#  ['lavables', 'ADJ'],
#  ['et', 'KON'],
#  ['ce', 'PRO:DEM'],
#  ['bébé', 'NOM'],
#  ['le', 'PRO:PER'],
#  ['sera', 'VER:futu'],
#  ['aussi', 'ADV'],
#  ['.', 'SENT'],
#  ['que', 'ADV'],
#  ['voudrais', 'VER:cond'],
#  ['tu', 'PRO:PER'],
#  ['savoir', 'VER:infi'],
#  ['STOP', 'NOM'],
#  ["'", 'PUN'],
#  ['STOP', 'NOM'],
#  ['"', 'PUN:cit'],
#  ['coucou', 'NOM'],
#  ['STOP', 'INT'],
#  ['STOP', 'NOM'],
#  ['merci', 'NOM'],
#  ['de', 'PRP'],
#  ['ta', 'DET:POS'],
#  ['réponse', 'NOM'],
#  ['STOP', 'NOM'],
#  ['je', 'PRO:PER'],
#  ['voudrais', 'VER:cond'],
#  ['savoir', 'VER:infi'],
#  ['un', 'DET:ART'],
#  ['peu', 'ADV'],
#  ['les', 'DET:ART'],
#  ['achats', 'NOM'],
#  ['nécessaires', 'ADJ'],
#  ['pour', 'PRP'],
#  ['un', 'DET:ART'],
#  ['enfant', 'NOM'],
#  ['STOP', 'INT'],
#  ["j'", 'PRO:PER'],
#  ['ai', 'VER:pres'],
#  ['regardé', 'VER:pper'],
#  ['quelques', 'PRO:IND'],
#  ['vidéos', 'NOM'],
#  ['comment', 'ADV'],
#  ['ça', 'PRO:DEM'],
#  ['fonctionnait', 'VER:impf'],
#  ['STOP', 'NOM'],
#  ['tu', 'PRO:PER'],
#  ['achètes', 'VER:pres'],
#  ['combien', 'ADV'],
#  ['de', 'PRP'],
#  ['couches', 'NOM'],
#  ['STOP', 'NOM'],
#  ["d'", 'PRP'],
#  ['inserts', 'NOM'],
#  ['et', 'KON'],
#  ['de', 'PRP'],
#  ['langes', 'NOM'],
#  ['(', 'PUN'],
#  ['environ', 'ADV'],
#  [')', 'PUN'],
#  ['STOP', 'NOM'],
#  ['est', 'VER:pres'],
#  ['-ce', 'PRO:DEM'],
#  ['que', 'PRO:REL'],
#  ["d'", 'PRP'],
#  ['un', 'DET:ART'],
#  ['point', 'NOM'],
#  ['de', 'PRP'],
#  ['vue', 'NOM'],
#  ['économique', 'ADJ'],
#  ["c'", 'PRO:DEM'],
#  ['est', 'VER:pres'],
#  ['une', 'DET:ART'],
#  ['grosse', 'ADJ'],
#  ['différence', 'NOM'],
#  ['STOP', 'NOM'],
#  ["j'", 'PRO:PER'],
#  ['attends', 'VER:pres'],
#  ['des', 'PRP:det'],
#  ['jumelles', 'ADJ'],
#  ['STOP', 'NOM'],
#  ["j'", 'PRO:PER'],
#  ['ai', 'VER:pres'],
#  ['peur', 'NOM'],
#  ["d'", 'PRP'],
#  ['être', 'VER:infi'],
#  ['un', 'DET:ART'],
#  ['peu', 'ADV'],
#  ['débordée', 'VER:pper'],
#  ['par', 'PRP'],
#  ['les', 'DET:ART'],
#  ['machines', 'NOM'],
#  ['si', 'KON'],
#  ["j'", 'PRO:PER'],
#  ['opte', 'VER:pres'],
#  ['pour', 'PRP'],
#  ['ce', 'PRO:DEM'],
#  ['choix', 'NOM'],
#  ['STOP', 'NOM'],
#  ['tu', 'PRO:PER'],
#  ['en', 'PRO:PER'],
#  ['penses', 'VER:pres'],
#  ['quoi', 'PRO:REL'],
#  ['STOP', 'NOM'],
#  ['merci', 'NOM'],
#  ['pour', 'PRP'],
#  ['ton', 'DET:POS'],
#  ['retour', 'NOM'],
#  ['🙂', 'NAM'],
#  ['"', 'PUN:cit'],
#  ['STOP', 'NOM'],
#  ['"', 'PUN:cit'],
#  ['bonjour', 'NOM'],
#  ['STOP', 'NOM'],
#  ['a', 'VER:pres'],
#  ['dns-remplacé', 'VER:pper'],
#  ('STOP', 'NAM'),
#  ['vois', 'VER:pres'],
#  ["qu'", 'KON'],
#  ['il', 'PRO:PER'],
#  ["n'", 'ADV'],
#  ['y', 'PRO:PER'],
#  ['a', 'VER:pres'],
#  ['pas', 'ADV'],
#  ['de', 'PRP'],
#  ['post', 'NOM'],
#  ['afin', 'KON'],
#  ['de', 'PRP'],
#  ['partagé', 'ADJ'],
#  ['nos', 'DET:POS'],
#  ['achats', 'NOM'],
#  ['STOP', 'INT'],
#  ['coup', 'NOM'],
#  ['de', 'PRP'],
#  ['cœur', 'NOM'],
#  ['ou', 'KON'],
#  ['coup', 'NOM'],
#  ['de', 'PRP'],
#  ['gueule', 'NOM'],
#  ['sur', 'PRP'],
#  ['les', 'DET:ART'],
#  ['produits', 'NOM'],
#  ['pour', 'KON'],
#  ['bébé.avez', 'VER:pres'],
#  ['vous', 'PRO:PER'],
#  ['déjà', 'ADV'],
#  ['commencé', 'VER:pper'],
#  ['STOP', 'NOM'],
#  ['ici', 'ADV'],
#  ['STOP', 'NOM'],
#  ['le', 'DET:ART'],
#  ['doudou', 'NOM'],
#  ['à', 'PRP'],
#  ['été', 'NOM'],
#  ['choisi', 'VER:pper'],
#  ['par', 'PRP'],
#  ["l'", 'DET:ART'],
#  ['aînée', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['tour', 'NOM'],
#  ['de', 'PRP'],
#  ['lit', 'NOM'],
#  ['gigoteuse', 'NOM'],
#  ['et', 'KON'],
#  ['poussette', 'NOM'],
#  ['acheté', 'VER:pper'],
#  ['pendant', 'PRP'],
#  ['les', 'DET:ART'],
#  ['dns-remplacé', 'NOM'],
#  ('STOP', 'NAM'),
#  ['allons', 'VER:pres'],
#  ['commencer', 'VER:infi'],
#  ['la', 'DET:ART'],
#  ['peinture', 'NOM'],
#  ['dans', 'PRP'],
#  ['la', 'DET:ART'],
#  ['chambre', 'NOM'],
#  ['du', 'PRP:det'],
#  ['futur', 'ADJ'],
#  ['bébé', 'NOM'],
#  ['.', 'SENT'],
#  ['"', 'PUN:cit'],
#  ['STOP', 'NOM'],
#  ["'", 'PUN'],
#  ['non', 'ADV'],
#  ['même', 'ADV'],
#  ['pas', 'ADV'],
#  ['c', 'NOM'],
#  ['le', 'DET:ART'],
#  ['troisième', 'NUM'],
#  ['...', 'PUN'],
#  ['c', 'NOM'],
#  ['des', 'PRP:det'],
#  ['acheteuses', 'NOM'],
#  ['compulsives', 'ADJ'],
#  ['lol', 'ADJ'],
#  ['c', 'NOM'],
#  ['pour', 'PRP'],
#  ['ça', 'PRO:DEM'],
#  ["j'", 'PRO:PER'],
#  ['achète', 'VER:pres'],
#  ['rien', 'ADV'],
#  ['ou', 'KON'],
#  ['je', 'PRO:PER'],
#  ['vais', 'VER:pres'],
#  ['en', 'PRP'],
#  ['avoir', 'VER:infi'],
#  ['en', 'PRP'],
#  ['pagaille', 'NOM'],
#  ['lol', 'ADJ'],
#  ["'", 'PUN'],
#  ['STOP', 'NOM'],
#  ["'", 'PUN'],
#  ['haha', 'NOM'],
#  ['autant', 'ADV'],
#  ['en', 'PRP'],
#  ['profiter', 'VER:infi'],
#  ['alors', 'ADV'],
#  ["'", 'PUN'],
#  ['STOP', 'NOM'],
#  ['"', 'PUN:cit'],
#  ['piticlaire', 'NOM'],
#  ['excellent', 'ADJ'],
#  ['STOP', 'NOM'],
#  ['elleso', 'ADJ'],
#  ['ont', 'VER:pres'],
#  ['hâte', 'NOM'],
#  ['.', 'SENT'],
#  ["c'", 'PRO:DEM'],
#  ['est', 'VER:pres'],
#  ["t'", 'PRO:PER'],
#  ['on', 'PRO:PER'],
#  ['STOP', 'NOM'],
#  ['STOP', 'NOM'],
#  ['"', 'PUN:cit'],
#  ['STOP', 'NOM'],
#  ["'", 'PUN'],
#  ['\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\t\\t\\tyour', 'NAM'],
#  ['browser', 'VER:simp'],
#  ['cannot', 'NOM'],
#  ['play', 'INT'],
#  ['this', 'NOM'],
#  ['video.\\t\\t\\n\\n\\n\\n\\n', 'ADJ'],
#  ["'", 'PUN'],
#  ['STOP', 'NOM'],
#  ['STOP', 'NOM'],
#  ["'", 'PUN'],
#  ["'", 'PUN'],
#  ['STOP', 'NOM'],
#  ["'", 'PUN'],
#  ['\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\t\\t\\tyour', 'NAM'],
#  ['browser', 'VER:simp'],
#  ['cannot', 'NOM'],
#  ['play', 'INT'],
#  ['this', 'NOM'],
#  ['video.\\t\\t\\n\\n\\n\\n\\n', 'ADJ'],
#  ["'", 'PUN'],
#  ['STOP', 'NOM'],
#  ["'", 'PUN'],
#  ['bonsoir', 'NOM'],
#  ['STOP', 'NOM'],
#  ['on', 'PRO:PER'],
#  ["m\\'a", 'VER:simp'],
#  ['retiré', 'VER:pper'],
#  ['la', 'DET:ART'],
#  ['glande', 'NOM'],
#  ['thyroïde', 'ADJ'],
#  ['il', 'PRO:PER'],
#  ['y', 'PRO:PER'],
#  ['a', 'VER:pres'],
#  ['20', 'NUM'],
#  ['ans', 'NOM'],
#  ['pour', 'KON'],
#  ['des', 'PRP:det'],
#  ['nodules', 'NOM'],
#  ['non', 'ADV'],
#  ['cancéreux', 'ADJ'],
#  ['qui', 'PRO:REL'],
#  ['accéléraient', 'VER:impf'],
#  ['les', 'DET:ART'],
#  ['battements', 'NOM'],
#  ['de', 'PRP'],
#  ['mon', 'DET:POS'],
#  ['cœur', 'NOM'],
#  ['.', 'SENT'],
#  ['donc', 'ADV'],
#  ['STOP', 'NOM'],
#  ['depuis', 'PRP'],
#  ['je', 'PRO:PER'],
#  ['prend', 'VER:pres'],
#  ['du', 'PRP:det'],
#  ['lévothyrox', 'NOM'],
#  ['tous', 'PRO:IND'],
#  ['les', 'DET:ART'],
#  ['dns-remplacé', 'NOM'],
#  ('STOP', 'NAM'),
#  ['fait', 'VER:pres'],
#  ['cette', 'PRO:DEM'],
#  ['molécule', 'NOM'],
#  ['est', 'VER:pres'],
#  ['une', 'DET:ART'],
#  ['hormone', 'NOM'],
#  ['enrobée', 'VER:pper'],
#  ["d\\'une", 'ADJ'],
#  ['substance', 'NOM'],
#  ['permettant', 'VER:ppre'],
#  ['de', 'PRP'],
#  ["l\\'avaler", 'VER:infi'],
#  ['et', 'KON'],
#  ['de', 'PRP'],
#  ['la', 'PRO:PER'],
#  ['faire', 'VER:infi'],
#  ['passer', 'VER:infi'],
#  ['dans', 'PRP'],
#  ['le', 'DET:ART'],
#  ['sang', 'NOM'],
#  ['afin', 'KON'],
#  ['de', 'PRP'],
#  ['produire', 'VER:infi'],
#  ['les', 'DET:ART'],
#  ['mêmes', 'ADJ'],
#  ['effets', 'NOM'],
#  ['que', 'KON'],
#  ['la', 'DET:ART'],
#  ['vrai', 'ADJ'],
#  ['glande', 'NOM'],
#  ['thyroïde', 'ADJ'],
#  ["qu\\'on", 'NOM'],
#  ["m\\'a", 'VER:simp'],
#  ["retirée.c\\'est", 'NOM'],
#  ['très', 'ADV'],
#  ['difficile', 'ADJ'],
#  ['a', 'VER:pres'],
#  ['doser', 'VER:infi'],
#  ['sachant', 'VER:ppre'],
#  ['que', 'KON'],
#  ['nous', 'PRO:PER'],
#  ['ne', 'ADV'],
#  ['réagissant', 'VER:ppre'],
#  ['pas', 'ADV'],
#  ['toutes', 'PRO:IND'],
#  ['de', 'PRP'],
#  ['la', 'DET:ART'],
#  ['même', 'ADJ'],
#  ['faç', 'NOM'],
#  ['dns-remplacé', 'ADJ'],
#  ('STOP', 'NAM'),
#  ['allant', 'VER:ppre'],
#  ['sur', 'PRP'],
#  ['le', 'DET:ART'],
#  ['site', 'NOM'],
#  ['"', 'PUN:cit'],
#  ['vivre', 'VER:infi'],
#  ['sans', 'PRP'],
#  ['thyroïde', 'NOM'],
#  ['"', 'PUN:cit'],
#  ["j\\'ai", 'VER:simp'],
#  ['appris', 'VER:pper'],
#  ['de', 'PRP'],
#  ['choses', 'NOM'],
#  ['intéressantes', 'ADJ'],
#  ['de', 'PRP'],
#  ['la', 'DET:ART'],
#  ['part', 'NOM'],
#  ['des', 'PRP:det'],
#  ['membres', 'NOM'],
#  ['de', 'PRP'],
#  ['ce', 'PRO:DEM'],
#  ['groupe', 'NOM'],
#  ['qui', 'PRO:REL'],
#  ['ont', 'VER:pres'],
#  ['encore', 'ADV'],
#  ['ou', 'KON'],
#  ['non', 'ADV'],
#  ['leur', 'DET:POS'],
#  ['thyroï', 'NOM'],
#  ['dns-remplacé', 'ADJ'],
#  ('STOP', 'NAM'),
#  ['lorsque', 'KON'],
#  ["l\\'on", 'NOM'],
#  ['change', 'VER:pres'],
#  ['de', 'PRP'],
#  ['dosage', 'NOM'],
#  ['les', 'DET:ART'],
#  ['effets', 'NOM'],
#  ['ne', 'ADV'],
#  ['se', 'PRO:PER'],
#  ['font', 'VER:pres'],
#  ['sentir', 'VER:infi'],
#  ...]

# %% [markdown]
# ### **Collocations / Phrases / N-Grammes (MWE)**
# https://www.kaggle.com/code/alvations/n-gram-language-model-with-nltk/notebook

# %%
def extr_ngrams(tagged):
    ngrammes= list(everygrams(tagged, min_len=2, max_len=8))
    print("Avant filtrage, on a {} ngrammes.".format(len(ngrammes)))
    return ngrammes

# %%
ngrammes = extr_ngrams(tagged)
#ngrammes_lem = extr_ngrams(tagged_lem)
# Out:
# Avant filtrage, on a 54029234 ngrammes.

# %%
ngrammes
# Out:
# [(['STOP', 'NOM'], ["'", 'PUN']),
#  (['STOP', 'NOM'], ["'", 'PUN'], ["'", 'PUN']),
#  (['STOP', 'NOM'], ["'", 'PUN'], ["'", 'PUN'], ['STOP', 'NOM']),
#  (['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ['"', 'PUN:cit']),
#  (['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ['"', 'PUN:cit'],
#   ['ah', 'INT']),
#  (['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ['"', 'PUN:cit'],
#   ['ah', 'INT'],
#   ['oui', 'INT']),
#  (['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ['"', 'PUN:cit'],
#   ['ah', 'INT'],
#   ['oui', 'INT'],
#   ['pour', 'PRP']),
#  (["'", 'PUN'], ["'", 'PUN']),
#  (["'", 'PUN'], ["'", 'PUN'], ['STOP', 'NOM']),
#  (["'", 'PUN'], ["'", 'PUN'], ['STOP', 'NOM'], ['"', 'PUN:cit']),
#  (["'", 'PUN'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ['"', 'PUN:cit'],
#   ['ah', 'INT']),
#  (["'", 'PUN'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ['"', 'PUN:cit'],
#   ['ah', 'INT'],
#   ['oui', 'INT']),
#  (["'", 'PUN'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ['"', 'PUN:cit'],
#   ['ah', 'INT'],
#   ['oui', 'INT'],
#   ['pour', 'PRP']),
#  (["'", 'PUN'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ['"', 'PUN:cit'],
#   ['ah', 'INT'],
#   ['oui', 'INT'],
#   ['pour', 'PRP'],
#   ['les', 'DET:ART']),
#  (["'", 'PUN'], ['STOP', 'NOM']),
#  (["'", 'PUN'], ['STOP', 'NOM'], ['"', 'PUN:cit']),
#  (["'", 'PUN'], ['STOP', 'NOM'], ['"', 'PUN:cit'], ['ah', 'INT']),
#  (["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ['"', 'PUN:cit'],
#   ['ah', 'INT'],
#   ['oui', 'INT']),
#  (["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ['"', 'PUN:cit'],
#   ['ah', 'INT'],
#   ['oui', 'INT'],
#   ['pour', 'PRP']),
#  (["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ['"', 'PUN:cit'],
#   ['ah', 'INT'],
#   ['oui', 'INT'],
#   ['pour', 'PRP'],
#   ['les', 'DET:ART']),
#  (["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ['"', 'PUN:cit'],
#   ['ah', 'INT'],
#   ['oui', 'INT'],
#   ['pour', 'PRP'],
#   ['les', 'DET:ART'],
#   ['logement', 'NOM']),
#  (['STOP', 'NOM'], ['"', 'PUN:cit']),
#  (['STOP', 'NOM'], ['"', 'PUN:cit'], ['ah', 'INT']),
#  (['STOP', 'NOM'], ['"', 'PUN:cit'], ['ah', 'INT'], ['oui', 'INT']),
#  (['STOP', 'NOM'],
#   ['"', 'PUN:cit'],
#   ['ah', 'INT'],
#   ['oui', 'INT'],
#   ['pour', 'PRP']),
#  (['STOP', 'NOM'],
#   ['"', 'PUN:cit'],
#   ['ah', 'INT'],
#   ['oui', 'INT'],
#   ['pour', 'PRP'],
#   ['les', 'DET:ART']),
#  (['STOP', 'NOM'],
#   ['"', 'PUN:cit'],
#   ['ah', 'INT'],
#   ['oui', 'INT'],
#   ['pour', 'PRP'],
#   ['les', 'DET:ART'],
#   ['logement', 'NOM']),
#  (['STOP', 'NOM'],
#   ['"', 'PUN:cit'],
#   ['ah', 'INT'],
#   ['oui', 'INT'],
#   ['pour', 'PRP'],
#   ['les', 'DET:ART'],
#   ['logement', 'NOM'],
#   ['sociaux', 'ADJ']),
#  (['"', 'PUN:cit'], ['ah', 'INT']),
#  (['"', 'PUN:cit'], ['ah', 'INT'], ['oui', 'INT']),
#  (['"', 'PUN:cit'], ['ah', 'INT'], ['oui', 'INT'], ['pour', 'PRP']),
#  (['"', 'PUN:cit'],
#   ['ah', 'INT'],
#   ['oui', 'INT'],
#   ['pour', 'PRP'],
#   ['les', 'DET:ART']),
#  (['"', 'PUN:cit'],
#   ['ah', 'INT'],
#   ['oui', 'INT'],
#   ['pour', 'PRP'],
#   ['les', 'DET:ART'],
#   ['logement', 'NOM']),
#  (['"', 'PUN:cit'],
#   ['ah', 'INT'],
#   ['oui', 'INT'],
#   ['pour', 'PRP'],
#   ['les', 'DET:ART'],
#   ['logement', 'NOM'],
#   ['sociaux', 'ADJ']),
#  (['"', 'PUN:cit'],
#   ['ah', 'INT'],
#   ['oui', 'INT'],
#   ['pour', 'PRP'],
#   ['les', 'DET:ART'],
#   ['logement', 'NOM'],
#   ['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM']),
#  (['ah', 'INT'], ['oui', 'INT']),
#  (['ah', 'INT'], ['oui', 'INT'], ['pour', 'PRP']),
#  (['ah', 'INT'], ['oui', 'INT'], ['pour', 'PRP'], ['les', 'DET:ART']),
#  (['ah', 'INT'],
#   ['oui', 'INT'],
#   ['pour', 'PRP'],
#   ['les', 'DET:ART'],
#   ['logement', 'NOM']),
#  (['ah', 'INT'],
#   ['oui', 'INT'],
#   ['pour', 'PRP'],
#   ['les', 'DET:ART'],
#   ['logement', 'NOM'],
#   ['sociaux', 'ADJ']),
#  (['ah', 'INT'],
#   ['oui', 'INT'],
#   ['pour', 'PRP'],
#   ['les', 'DET:ART'],
#   ['logement', 'NOM'],
#   ['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM']),
#  (['ah', 'INT'],
#   ['oui', 'INT'],
#   ['pour', 'PRP'],
#   ['les', 'DET:ART'],
#   ['logement', 'NOM'],
#   ['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres']),
#  (['oui', 'INT'], ['pour', 'PRP']),
#  (['oui', 'INT'], ['pour', 'PRP'], ['les', 'DET:ART']),
#  (['oui', 'INT'], ['pour', 'PRP'], ['les', 'DET:ART'], ['logement', 'NOM']),
#  (['oui', 'INT'],
#   ['pour', 'PRP'],
#   ['les', 'DET:ART'],
#   ['logement', 'NOM'],
#   ['sociaux', 'ADJ']),
#  (['oui', 'INT'],
#   ['pour', 'PRP'],
#   ['les', 'DET:ART'],
#   ['logement', 'NOM'],
#   ['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM']),
#  (['oui', 'INT'],
#   ['pour', 'PRP'],
#   ['les', 'DET:ART'],
#   ['logement', 'NOM'],
#   ['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres']),
#  (['oui', 'INT'],
#   ['pour', 'PRP'],
#   ['les', 'DET:ART'],
#   ['logement', 'NOM'],
#   ['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['assez', 'ADV']),
#  (['pour', 'PRP'], ['les', 'DET:ART']),
#  (['pour', 'PRP'], ['les', 'DET:ART'], ['logement', 'NOM']),
#  (['pour', 'PRP'],
#   ['les', 'DET:ART'],
#   ['logement', 'NOM'],
#   ['sociaux', 'ADJ']),
#  (['pour', 'PRP'],
#   ['les', 'DET:ART'],
#   ['logement', 'NOM'],
#   ['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM']),
#  (['pour', 'PRP'],
#   ['les', 'DET:ART'],
#   ['logement', 'NOM'],
#   ['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres']),
#  (['pour', 'PRP'],
#   ['les', 'DET:ART'],
#   ['logement', 'NOM'],
#   ['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['assez', 'ADV']),
#  (['pour', 'PRP'],
#   ['les', 'DET:ART'],
#   ['logement', 'NOM'],
#   ['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['assez', 'ADV'],
#   ['long', 'ADV']),
#  (['les', 'DET:ART'], ['logement', 'NOM']),
#  (['les', 'DET:ART'], ['logement', 'NOM'], ['sociaux', 'ADJ']),
#  (['les', 'DET:ART'],
#   ['logement', 'NOM'],
#   ['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM']),
#  (['les', 'DET:ART'],
#   ['logement', 'NOM'],
#   ['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres']),
#  (['les', 'DET:ART'],
#   ['logement', 'NOM'],
#   ['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['assez', 'ADV']),
#  (['les', 'DET:ART'],
#   ['logement', 'NOM'],
#   ['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['assez', 'ADV'],
#   ['long', 'ADV']),
#  (['les', 'DET:ART'],
#   ['logement', 'NOM'],
#   ['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['assez', 'ADV'],
#   ['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper']),
#  (['logement', 'NOM'], ['sociaux', 'ADJ']),
#  (['logement', 'NOM'], ['sociaux', 'ADJ'], ["c'", 'PRO:DEM']),
#  (['logement', 'NOM'],
#   ['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres']),
#  (['logement', 'NOM'],
#   ['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['assez', 'ADV']),
#  (['logement', 'NOM'],
#   ['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['assez', 'ADV'],
#   ['long', 'ADV']),
#  (['logement', 'NOM'],
#   ['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['assez', 'ADV'],
#   ['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper']),
#  (['logement', 'NOM'],
#   ['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['assez', 'ADV'],
#   ['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM')),
#  (['sociaux', 'ADJ'], ["c'", 'PRO:DEM']),
#  (['sociaux', 'ADJ'], ["c'", 'PRO:DEM'], ['est', 'VER:pres']),
#  (['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['assez', 'ADV']),
#  (['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['assez', 'ADV'],
#   ['long', 'ADV']),
#  (['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['assez', 'ADV'],
#   ['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper']),
#  (['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['assez', 'ADV'],
#   ['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM')),
#  (['sociaux', 'ADJ'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['assez', 'ADV'],
#   ['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['on', 'PRO:PER']),
#  (["c'", 'PRO:DEM'], ['est', 'VER:pres']),
#  (["c'", 'PRO:DEM'], ['est', 'VER:pres'], ['assez', 'ADV']),
#  (["c'", 'PRO:DEM'], ['est', 'VER:pres'], ['assez', 'ADV'], ['long', 'ADV']),
#  (["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['assez', 'ADV'],
#   ['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper']),
#  (["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['assez', 'ADV'],
#   ['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM')),
#  (["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['assez', 'ADV'],
#   ['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['on', 'PRO:PER']),
#  (["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['assez', 'ADV'],
#   ['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['on', 'PRO:PER'],
#   ['va', 'VER:pres']),
#  (['est', 'VER:pres'], ['assez', 'ADV']),
#  (['est', 'VER:pres'], ['assez', 'ADV'], ['long', 'ADV']),
#  (['est', 'VER:pres'],
#   ['assez', 'ADV'],
#   ['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper']),
#  (['est', 'VER:pres'],
#   ['assez', 'ADV'],
#   ['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM')),
#  (['est', 'VER:pres'],
#   ['assez', 'ADV'],
#   ['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['on', 'PRO:PER']),
#  (['est', 'VER:pres'],
#   ['assez', 'ADV'],
#   ['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['on', 'PRO:PER'],
#   ['va', 'VER:pres']),
#  (['est', 'VER:pres'],
#   ['assez', 'ADV'],
#   ['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['on', 'PRO:PER'],
#   ['va', 'VER:pres'],
#   ['commencer', 'VER:infi']),
#  (['assez', 'ADV'], ['long', 'ADV']),
#  (['assez', 'ADV'], ['long', 'ADV'], ['dns-remplacé', 'VER:pper']),
#  (['assez', 'ADV'],
#   ['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM')),
#  (['assez', 'ADV'],
#   ['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['on', 'PRO:PER']),
#  (['assez', 'ADV'],
#   ['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['on', 'PRO:PER'],
#   ['va', 'VER:pres']),
#  (['assez', 'ADV'],
#   ['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['on', 'PRO:PER'],
#   ['va', 'VER:pres'],
#   ['commencer', 'VER:infi']),
#  (['assez', 'ADV'],
#   ['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['on', 'PRO:PER'],
#   ['va', 'VER:pres'],
#   ['commencer', 'VER:infi'],
#   ['des', 'PRP:det']),
#  (['long', 'ADV'], ['dns-remplacé', 'VER:pper']),
#  (['long', 'ADV'], ['dns-remplacé', 'VER:pper'], ('STOP', 'NAM')),
#  (['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['on', 'PRO:PER']),
#  (['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['on', 'PRO:PER'],
#   ['va', 'VER:pres']),
#  (['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['on', 'PRO:PER'],
#   ['va', 'VER:pres'],
#   ['commencer', 'VER:infi']),
#  (['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['on', 'PRO:PER'],
#   ['va', 'VER:pres'],
#   ['commencer', 'VER:infi'],
#   ['des', 'PRP:det']),
#  (['long', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['on', 'PRO:PER'],
#   ['va', 'VER:pres'],
#   ['commencer', 'VER:infi'],
#   ['des', 'PRP:det'],
#   ['travaux', 'NOM']),
#  (['dns-remplacé', 'VER:pper'], ('STOP', 'NAM')),
#  (['dns-remplacé', 'VER:pper'], ('STOP', 'NAM'), ['on', 'PRO:PER']),
#  (['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['on', 'PRO:PER'],
#   ['va', 'VER:pres']),
#  (['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['on', 'PRO:PER'],
#   ['va', 'VER:pres'],
#   ['commencer', 'VER:infi']),
#  (['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['on', 'PRO:PER'],
#   ['va', 'VER:pres'],
#   ['commencer', 'VER:infi'],
#   ['des', 'PRP:det']),
#  (['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['on', 'PRO:PER'],
#   ['va', 'VER:pres'],
#   ['commencer', 'VER:infi'],
#   ['des', 'PRP:det'],
#   ['travaux', 'NOM']),
#  (['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['on', 'PRO:PER'],
#   ['va', 'VER:pres'],
#   ['commencer', 'VER:infi'],
#   ['des', 'PRP:det'],
#   ['travaux', 'NOM'],
#   ['dans', 'PRP']),
#  (('STOP', 'NAM'), ['on', 'PRO:PER']),
#  (('STOP', 'NAM'), ['on', 'PRO:PER'], ['va', 'VER:pres']),
#  (('STOP', 'NAM'),
#   ['on', 'PRO:PER'],
#   ['va', 'VER:pres'],
#   ['commencer', 'VER:infi']),
#  (('STOP', 'NAM'),
#   ['on', 'PRO:PER'],
#   ['va', 'VER:pres'],
#   ['commencer', 'VER:infi'],
#   ['des', 'PRP:det']),
#  (('STOP', 'NAM'),
#   ['on', 'PRO:PER'],
#   ['va', 'VER:pres'],
#   ['commencer', 'VER:infi'],
#   ['des', 'PRP:det'],
#   ['travaux', 'NOM']),
#  (('STOP', 'NAM'),
#   ['on', 'PRO:PER'],
#   ['va', 'VER:pres'],
#   ['commencer', 'VER:infi'],
#   ['des', 'PRP:det'],
#   ['travaux', 'NOM'],
#   ['dans', 'PRP']),
#  (('STOP', 'NAM'),
#   ['on', 'PRO:PER'],
#   ['va', 'VER:pres'],
#   ['commencer', 'VER:infi'],
#   ['des', 'PRP:det'],
#   ['travaux', 'NOM'],
#   ['dans', 'PRP'],
#   ['notre', 'DET:POS']),
#  (['on', 'PRO:PER'], ['va', 'VER:pres']),
#  (['on', 'PRO:PER'], ['va', 'VER:pres'], ['commencer', 'VER:infi']),
#  (['on', 'PRO:PER'],
#   ['va', 'VER:pres'],
#   ['commencer', 'VER:infi'],
#   ['des', 'PRP:det']),
#  (['on', 'PRO:PER'],
#   ['va', 'VER:pres'],
#   ['commencer', 'VER:infi'],
#   ['des', 'PRP:det'],
#   ['travaux', 'NOM']),
#  (['on', 'PRO:PER'],
#   ['va', 'VER:pres'],
#   ['commencer', 'VER:infi'],
#   ['des', 'PRP:det'],
#   ['travaux', 'NOM'],
#   ['dans', 'PRP']),
#  (['on', 'PRO:PER'],
#   ['va', 'VER:pres'],
#   ['commencer', 'VER:infi'],
#   ['des', 'PRP:det'],
#   ['travaux', 'NOM'],
#   ['dans', 'PRP'],
#   ['notre', 'DET:POS']),
#  (['on', 'PRO:PER'],
#   ['va', 'VER:pres'],
#   ['commencer', 'VER:infi'],
#   ['des', 'PRP:det'],
#   ['travaux', 'NOM'],
#   ['dans', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['maison', 'NOM']),
#  (['va', 'VER:pres'], ['commencer', 'VER:infi']),
#  (['va', 'VER:pres'], ['commencer', 'VER:infi'], ['des', 'PRP:det']),
#  (['va', 'VER:pres'],
#   ['commencer', 'VER:infi'],
#   ['des', 'PRP:det'],
#   ['travaux', 'NOM']),
#  (['va', 'VER:pres'],
#   ['commencer', 'VER:infi'],
#   ['des', 'PRP:det'],
#   ['travaux', 'NOM'],
#   ['dans', 'PRP']),
#  (['va', 'VER:pres'],
#   ['commencer', 'VER:infi'],
#   ['des', 'PRP:det'],
#   ['travaux', 'NOM'],
#   ['dans', 'PRP'],
#   ['notre', 'DET:POS']),
#  (['va', 'VER:pres'],
#   ['commencer', 'VER:infi'],
#   ['des', 'PRP:det'],
#   ['travaux', 'NOM'],
#   ['dans', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['maison', 'NOM']),
#  (['va', 'VER:pres'],
#   ['commencer', 'VER:infi'],
#   ['des', 'PRP:det'],
#   ['travaux', 'NOM'],
#   ['dans', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['maison', 'NOM'],
#   ['STOP', 'NOM']),
#  (['commencer', 'VER:infi'], ['des', 'PRP:det']),
#  (['commencer', 'VER:infi'], ['des', 'PRP:det'], ['travaux', 'NOM']),
#  (['commencer', 'VER:infi'],
#   ['des', 'PRP:det'],
#   ['travaux', 'NOM'],
#   ['dans', 'PRP']),
#  (['commencer', 'VER:infi'],
#   ['des', 'PRP:det'],
#   ['travaux', 'NOM'],
#   ['dans', 'PRP'],
#   ['notre', 'DET:POS']),
#  (['commencer', 'VER:infi'],
#   ['des', 'PRP:det'],
#   ['travaux', 'NOM'],
#   ['dans', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['maison', 'NOM']),
#  (['commencer', 'VER:infi'],
#   ['des', 'PRP:det'],
#   ['travaux', 'NOM'],
#   ['dans', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['maison', 'NOM'],
#   ['STOP', 'NOM']),
#  (['commencer', 'VER:infi'],
#   ['des', 'PRP:det'],
#   ['travaux', 'NOM'],
#   ['dans', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['maison', 'NOM'],
#   ['STOP', 'NOM'],
#   ['on', 'PRO:PER']),
#  (['des', 'PRP:det'], ['travaux', 'NOM']),
#  (['des', 'PRP:det'], ['travaux', 'NOM'], ['dans', 'PRP']),
#  (['des', 'PRP:det'],
#   ['travaux', 'NOM'],
#   ['dans', 'PRP'],
#   ['notre', 'DET:POS']),
#  (['des', 'PRP:det'],
#   ['travaux', 'NOM'],
#   ['dans', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['maison', 'NOM']),
#  (['des', 'PRP:det'],
#   ['travaux', 'NOM'],
#   ['dans', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['maison', 'NOM'],
#   ['STOP', 'NOM']),
#  (['des', 'PRP:det'],
#   ['travaux', 'NOM'],
#   ['dans', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['maison', 'NOM'],
#   ['STOP', 'NOM'],
#   ['on', 'PRO:PER']),
#  (['des', 'PRP:det'],
#   ['travaux', 'NOM'],
#   ['dans', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['maison', 'NOM'],
#   ['STOP', 'NOM'],
#   ['on', 'PRO:PER'],
#   ['aménage', 'VER:pres']),
#  (['travaux', 'NOM'], ['dans', 'PRP']),
#  (['travaux', 'NOM'], ['dans', 'PRP'], ['notre', 'DET:POS']),
#  (['travaux', 'NOM'],
#   ['dans', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['maison', 'NOM']),
#  (['travaux', 'NOM'],
#   ['dans', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['maison', 'NOM'],
#   ['STOP', 'NOM']),
#  (['travaux', 'NOM'],
#   ['dans', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['maison', 'NOM'],
#   ['STOP', 'NOM'],
#   ['on', 'PRO:PER']),
#  (['travaux', 'NOM'],
#   ['dans', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['maison', 'NOM'],
#   ['STOP', 'NOM'],
#   ['on', 'PRO:PER'],
#   ['aménage', 'VER:pres']),
#  (['travaux', 'NOM'],
#   ['dans', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['maison', 'NOM'],
#   ['STOP', 'NOM'],
#   ['on', 'PRO:PER'],
#   ['aménage', 'VER:pres'],
#   ['des', 'PRP:det']),
#  (['dans', 'PRP'], ['notre', 'DET:POS']),
#  (['dans', 'PRP'], ['notre', 'DET:POS'], ['maison', 'NOM']),
#  (['dans', 'PRP'], ['notre', 'DET:POS'], ['maison', 'NOM'], ['STOP', 'NOM']),
#  (['dans', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['maison', 'NOM'],
#   ['STOP', 'NOM'],
#   ['on', 'PRO:PER']),
#  (['dans', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['maison', 'NOM'],
#   ['STOP', 'NOM'],
#   ['on', 'PRO:PER'],
#   ['aménage', 'VER:pres']),
#  (['dans', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['maison', 'NOM'],
#   ['STOP', 'NOM'],
#   ['on', 'PRO:PER'],
#   ['aménage', 'VER:pres'],
#   ['des', 'PRP:det']),
#  (['dans', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['maison', 'NOM'],
#   ['STOP', 'NOM'],
#   ['on', 'PRO:PER'],
#   ['aménage', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chambres', 'NOM']),
#  (['notre', 'DET:POS'], ['maison', 'NOM']),
#  (['notre', 'DET:POS'], ['maison', 'NOM'], ['STOP', 'NOM']),
#  (['notre', 'DET:POS'], ['maison', 'NOM'], ['STOP', 'NOM'], ['on', 'PRO:PER']),
#  (['notre', 'DET:POS'],
#   ['maison', 'NOM'],
#   ['STOP', 'NOM'],
#   ['on', 'PRO:PER'],
#   ['aménage', 'VER:pres']),
#  (['notre', 'DET:POS'],
#   ['maison', 'NOM'],
#   ['STOP', 'NOM'],
#   ['on', 'PRO:PER'],
#   ['aménage', 'VER:pres'],
#   ['des', 'PRP:det']),
#  (['notre', 'DET:POS'],
#   ['maison', 'NOM'],
#   ['STOP', 'NOM'],
#   ['on', 'PRO:PER'],
#   ['aménage', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chambres', 'NOM']),
#  (['notre', 'DET:POS'],
#   ['maison', 'NOM'],
#   ['STOP', 'NOM'],
#   ['on', 'PRO:PER'],
#   ['aménage', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chambres', 'NOM'],
#   ['dans', 'PRP']),
#  (['maison', 'NOM'], ['STOP', 'NOM']),
#  (['maison', 'NOM'], ['STOP', 'NOM'], ['on', 'PRO:PER']),
#  (['maison', 'NOM'],
#   ['STOP', 'NOM'],
#   ['on', 'PRO:PER'],
#   ['aménage', 'VER:pres']),
#  (['maison', 'NOM'],
#   ['STOP', 'NOM'],
#   ['on', 'PRO:PER'],
#   ['aménage', 'VER:pres'],
#   ['des', 'PRP:det']),
#  (['maison', 'NOM'],
#   ['STOP', 'NOM'],
#   ['on', 'PRO:PER'],
#   ['aménage', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chambres', 'NOM']),
#  (['maison', 'NOM'],
#   ['STOP', 'NOM'],
#   ['on', 'PRO:PER'],
#   ['aménage', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chambres', 'NOM'],
#   ['dans', 'PRP']),
#  (['maison', 'NOM'],
#   ['STOP', 'NOM'],
#   ['on', 'PRO:PER'],
#   ['aménage', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chambres', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART']),
#  (['STOP', 'NOM'], ['on', 'PRO:PER']),
#  (['STOP', 'NOM'], ['on', 'PRO:PER'], ['aménage', 'VER:pres']),
#  (['STOP', 'NOM'],
#   ['on', 'PRO:PER'],
#   ['aménage', 'VER:pres'],
#   ['des', 'PRP:det']),
#  (['STOP', 'NOM'],
#   ['on', 'PRO:PER'],
#   ['aménage', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chambres', 'NOM']),
#  (['STOP', 'NOM'],
#   ['on', 'PRO:PER'],
#   ['aménage', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chambres', 'NOM'],
#   ['dans', 'PRP']),
#  (['STOP', 'NOM'],
#   ['on', 'PRO:PER'],
#   ['aménage', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chambres', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART']),
#  (['STOP', 'NOM'],
#   ['on', 'PRO:PER'],
#   ['aménage', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chambres', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['grenier', 'NOM']),
#  (['on', 'PRO:PER'], ['aménage', 'VER:pres']),
#  (['on', 'PRO:PER'], ['aménage', 'VER:pres'], ['des', 'PRP:det']),
#  (['on', 'PRO:PER'],
#   ['aménage', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chambres', 'NOM']),
#  (['on', 'PRO:PER'],
#   ['aménage', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chambres', 'NOM'],
#   ['dans', 'PRP']),
#  (['on', 'PRO:PER'],
#   ['aménage', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chambres', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART']),
#  (['on', 'PRO:PER'],
#   ['aménage', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chambres', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['grenier', 'NOM']),
#  (['on', 'PRO:PER'],
#   ['aménage', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chambres', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['grenier', 'NOM'],
#   ['pour', 'PRP']),
#  (['aménage', 'VER:pres'], ['des', 'PRP:det']),
#  (['aménage', 'VER:pres'], ['des', 'PRP:det'], ['chambres', 'NOM']),
#  (['aménage', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chambres', 'NOM'],
#   ['dans', 'PRP']),
#  (['aménage', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chambres', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART']),
#  (['aménage', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chambres', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['grenier', 'NOM']),
#  (['aménage', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chambres', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['grenier', 'NOM'],
#   ['pour', 'PRP']),
#  (['aménage', 'VER:pres'],
#   ['des', 'PRP:det'],
#   ['chambres', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['grenier', 'NOM'],
#   ['pour', 'PRP'],
#   ['nos', 'DET:POS']),
#  (['des', 'PRP:det'], ['chambres', 'NOM']),
#  (['des', 'PRP:det'], ['chambres', 'NOM'], ['dans', 'PRP']),
#  (['des', 'PRP:det'], ['chambres', 'NOM'], ['dans', 'PRP'], ['le', 'DET:ART']),
#  (['des', 'PRP:det'],
#   ['chambres', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['grenier', 'NOM']),
#  (['des', 'PRP:det'],
#   ['chambres', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['grenier', 'NOM'],
#   ['pour', 'PRP']),
#  (['des', 'PRP:det'],
#   ['chambres', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['grenier', 'NOM'],
#   ['pour', 'PRP'],
#   ['nos', 'DET:POS']),
#  (['des', 'PRP:det'],
#   ['chambres', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['grenier', 'NOM'],
#   ['pour', 'PRP'],
#   ['nos', 'DET:POS'],
#   ['grands', 'ADJ']),
#  (['chambres', 'NOM'], ['dans', 'PRP']),
#  (['chambres', 'NOM'], ['dans', 'PRP'], ['le', 'DET:ART']),
#  (['chambres', 'NOM'], ['dans', 'PRP'], ['le', 'DET:ART'], ['grenier', 'NOM']),
#  (['chambres', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['grenier', 'NOM'],
#   ['pour', 'PRP']),
#  (['chambres', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['grenier', 'NOM'],
#   ['pour', 'PRP'],
#   ['nos', 'DET:POS']),
#  (['chambres', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['grenier', 'NOM'],
#   ['pour', 'PRP'],
#   ['nos', 'DET:POS'],
#   ['grands', 'ADJ']),
#  (['chambres', 'NOM'],
#   ['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['grenier', 'NOM'],
#   ['pour', 'PRP'],
#   ['nos', 'DET:POS'],
#   ['grands', 'ADJ'],
#   ['.', 'SENT']),
#  (['dans', 'PRP'], ['le', 'DET:ART']),
#  (['dans', 'PRP'], ['le', 'DET:ART'], ['grenier', 'NOM']),
#  (['dans', 'PRP'], ['le', 'DET:ART'], ['grenier', 'NOM'], ['pour', 'PRP']),
#  (['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['grenier', 'NOM'],
#   ['pour', 'PRP'],
#   ['nos', 'DET:POS']),
#  (['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['grenier', 'NOM'],
#   ['pour', 'PRP'],
#   ['nos', 'DET:POS'],
#   ['grands', 'ADJ']),
#  (['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['grenier', 'NOM'],
#   ['pour', 'PRP'],
#   ['nos', 'DET:POS'],
#   ['grands', 'ADJ'],
#   ['.', 'SENT']),
#  (['dans', 'PRP'],
#   ['le', 'DET:ART'],
#   ['grenier', 'NOM'],
#   ['pour', 'PRP'],
#   ['nos', 'DET:POS'],
#   ['grands', 'ADJ'],
#   ['.', 'SENT'],
#   ['et', 'KON']),
#  (['le', 'DET:ART'], ['grenier', 'NOM']),
#  (['le', 'DET:ART'], ['grenier', 'NOM'], ['pour', 'PRP']),
#  (['le', 'DET:ART'], ['grenier', 'NOM'], ['pour', 'PRP'], ['nos', 'DET:POS']),
#  (['le', 'DET:ART'],
#   ['grenier', 'NOM'],
#   ['pour', 'PRP'],
#   ['nos', 'DET:POS'],
#   ['grands', 'ADJ']),
#  (['le', 'DET:ART'],
#   ['grenier', 'NOM'],
#   ['pour', 'PRP'],
#   ['nos', 'DET:POS'],
#   ['grands', 'ADJ'],
#   ['.', 'SENT']),
#  (['le', 'DET:ART'],
#   ['grenier', 'NOM'],
#   ['pour', 'PRP'],
#   ['nos', 'DET:POS'],
#   ['grands', 'ADJ'],
#   ['.', 'SENT'],
#   ['et', 'KON']),
#  (['le', 'DET:ART'],
#   ['grenier', 'NOM'],
#   ['pour', 'PRP'],
#   ['nos', 'DET:POS'],
#   ['grands', 'ADJ'],
#   ['.', 'SENT'],
#   ['et', 'KON'],
#   ['bébé', 'NOM']),
#  (['grenier', 'NOM'], ['pour', 'PRP']),
#  (['grenier', 'NOM'], ['pour', 'PRP'], ['nos', 'DET:POS']),
#  (['grenier', 'NOM'], ['pour', 'PRP'], ['nos', 'DET:POS'], ['grands', 'ADJ']),
#  (['grenier', 'NOM'],
#   ['pour', 'PRP'],
#   ['nos', 'DET:POS'],
#   ['grands', 'ADJ'],
#   ['.', 'SENT']),
#  (['grenier', 'NOM'],
#   ['pour', 'PRP'],
#   ['nos', 'DET:POS'],
#   ['grands', 'ADJ'],
#   ['.', 'SENT'],
#   ['et', 'KON']),
#  (['grenier', 'NOM'],
#   ['pour', 'PRP'],
#   ['nos', 'DET:POS'],
#   ['grands', 'ADJ'],
#   ['.', 'SENT'],
#   ['et', 'KON'],
#   ['bébé', 'NOM']),
#  (['grenier', 'NOM'],
#   ['pour', 'PRP'],
#   ['nos', 'DET:POS'],
#   ['grands', 'ADJ'],
#   ['.', 'SENT'],
#   ['et', 'KON'],
#   ['bébé', 'NOM'],
#   ['récupérera', 'VER:futu']),
#  (['pour', 'PRP'], ['nos', 'DET:POS']),
#  (['pour', 'PRP'], ['nos', 'DET:POS'], ['grands', 'ADJ']),
#  (['pour', 'PRP'], ['nos', 'DET:POS'], ['grands', 'ADJ'], ['.', 'SENT']),
#  (['pour', 'PRP'],
#   ['nos', 'DET:POS'],
#   ['grands', 'ADJ'],
#   ['.', 'SENT'],
#   ['et', 'KON']),
#  (['pour', 'PRP'],
#   ['nos', 'DET:POS'],
#   ['grands', 'ADJ'],
#   ['.', 'SENT'],
#   ['et', 'KON'],
#   ['bébé', 'NOM']),
#  (['pour', 'PRP'],
#   ['nos', 'DET:POS'],
#   ['grands', 'ADJ'],
#   ['.', 'SENT'],
#   ['et', 'KON'],
#   ['bébé', 'NOM'],
#   ['récupérera', 'VER:futu']),
#  (['pour', 'PRP'],
#   ['nos', 'DET:POS'],
#   ['grands', 'ADJ'],
#   ['.', 'SENT'],
#   ['et', 'KON'],
#   ['bébé', 'NOM'],
#   ['récupérera', 'VER:futu'],
#   ['une', 'DET:ART']),
#  (['nos', 'DET:POS'], ['grands', 'ADJ']),
#  (['nos', 'DET:POS'], ['grands', 'ADJ'], ['.', 'SENT']),
#  (['nos', 'DET:POS'], ['grands', 'ADJ'], ['.', 'SENT'], ['et', 'KON']),
#  (['nos', 'DET:POS'],
#   ['grands', 'ADJ'],
#   ['.', 'SENT'],
#   ['et', 'KON'],
#   ['bébé', 'NOM']),
#  (['nos', 'DET:POS'],
#   ['grands', 'ADJ'],
#   ['.', 'SENT'],
#   ['et', 'KON'],
#   ['bébé', 'NOM'],
#   ['récupérera', 'VER:futu']),
#  (['nos', 'DET:POS'],
#   ['grands', 'ADJ'],
#   ['.', 'SENT'],
#   ['et', 'KON'],
#   ['bébé', 'NOM'],
#   ['récupérera', 'VER:futu'],
#   ['une', 'DET:ART']),
#  (['nos', 'DET:POS'],
#   ['grands', 'ADJ'],
#   ['.', 'SENT'],
#   ['et', 'KON'],
#   ['bébé', 'NOM'],
#   ['récupérera', 'VER:futu'],
#   ['une', 'DET:ART'],
#   ['chambre', 'NOM']),
#  (['grands', 'ADJ'], ['.', 'SENT']),
#  (['grands', 'ADJ'], ['.', 'SENT'], ['et', 'KON']),
#  (['grands', 'ADJ'], ['.', 'SENT'], ['et', 'KON'], ['bébé', 'NOM']),
#  (['grands', 'ADJ'],
#   ['.', 'SENT'],
#   ['et', 'KON'],
#   ['bébé', 'NOM'],
#   ['récupérera', 'VER:futu']),
#  (['grands', 'ADJ'],
#   ['.', 'SENT'],
#   ['et', 'KON'],
#   ['bébé', 'NOM'],
#   ['récupérera', 'VER:futu'],
#   ['une', 'DET:ART']),
#  (['grands', 'ADJ'],
#   ['.', 'SENT'],
#   ['et', 'KON'],
#   ['bébé', 'NOM'],
#   ['récupérera', 'VER:futu'],
#   ['une', 'DET:ART'],
#   ['chambre', 'NOM']),
#  (['grands', 'ADJ'],
#   ['.', 'SENT'],
#   ['et', 'KON'],
#   ['bébé', 'NOM'],
#   ['récupérera', 'VER:futu'],
#   ['une', 'DET:ART'],
#   ['chambre', 'NOM'],
#   ['du', 'PRP:det']),
#  (['.', 'SENT'], ['et', 'KON']),
#  (['.', 'SENT'], ['et', 'KON'], ['bébé', 'NOM']),
#  (['.', 'SENT'], ['et', 'KON'], ['bébé', 'NOM'], ['récupérera', 'VER:futu']),
#  (['.', 'SENT'],
#   ['et', 'KON'],
#   ['bébé', 'NOM'],
#   ['récupérera', 'VER:futu'],
#   ['une', 'DET:ART']),
#  (['.', 'SENT'],
#   ['et', 'KON'],
#   ['bébé', 'NOM'],
#   ['récupérera', 'VER:futu'],
#   ['une', 'DET:ART'],
#   ['chambre', 'NOM']),
#  (['.', 'SENT'],
#   ['et', 'KON'],
#   ['bébé', 'NOM'],
#   ['récupérera', 'VER:futu'],
#   ['une', 'DET:ART'],
#   ['chambre', 'NOM'],
#   ['du', 'PRP:det']),
#  (['.', 'SENT'],
#   ['et', 'KON'],
#   ['bébé', 'NOM'],
#   ['récupérera', 'VER:futu'],
#   ['une', 'DET:ART'],
#   ['chambre', 'NOM'],
#   ['du', 'PRP:det'],
#   ['STOP', 'NOM']),
#  (['et', 'KON'], ['bébé', 'NOM']),
#  (['et', 'KON'], ['bébé', 'NOM'], ['récupérera', 'VER:futu']),
#  (['et', 'KON'],
#   ['bébé', 'NOM'],
#   ['récupérera', 'VER:futu'],
#   ['une', 'DET:ART']),
#  (['et', 'KON'],
#   ['bébé', 'NOM'],
#   ['récupérera', 'VER:futu'],
#   ['une', 'DET:ART'],
#   ['chambre', 'NOM']),
#  (['et', 'KON'],
#   ['bébé', 'NOM'],
#   ['récupérera', 'VER:futu'],
#   ['une', 'DET:ART'],
#   ['chambre', 'NOM'],
#   ['du', 'PRP:det']),
#  (['et', 'KON'],
#   ['bébé', 'NOM'],
#   ['récupérera', 'VER:futu'],
#   ['une', 'DET:ART'],
#   ['chambre', 'NOM'],
#   ['du', 'PRP:det'],
#   ['STOP', 'NOM']),
#  (['et', 'KON'],
#   ['bébé', 'NOM'],
#   ['récupérera', 'VER:futu'],
#   ['une', 'DET:ART'],
#   ['chambre', 'NOM'],
#   ['du', 'PRP:det'],
#   ['STOP', 'NOM'],
#   ['.', 'SENT']),
#  (['bébé', 'NOM'], ['récupérera', 'VER:futu']),
#  (['bébé', 'NOM'], ['récupérera', 'VER:futu'], ['une', 'DET:ART']),
#  (['bébé', 'NOM'],
#   ['récupérera', 'VER:futu'],
#   ['une', 'DET:ART'],
#   ['chambre', 'NOM']),
#  (['bébé', 'NOM'],
#   ['récupérera', 'VER:futu'],
#   ['une', 'DET:ART'],
#   ['chambre', 'NOM'],
#   ['du', 'PRP:det']),
#  (['bébé', 'NOM'],
#   ['récupérera', 'VER:futu'],
#   ['une', 'DET:ART'],
#   ['chambre', 'NOM'],
#   ['du', 'PRP:det'],
#   ['STOP', 'NOM']),
#  (['bébé', 'NOM'],
#   ['récupérera', 'VER:futu'],
#   ['une', 'DET:ART'],
#   ['chambre', 'NOM'],
#   ['du', 'PRP:det'],
#   ['STOP', 'NOM'],
#   ['.', 'SENT']),
#  (['bébé', 'NOM'],
#   ['récupérera', 'VER:futu'],
#   ['une', 'DET:ART'],
#   ['chambre', 'NOM'],
#   ['du', 'PRP:det'],
#   ['STOP', 'NOM'],
#   ['.', 'SENT'],
#   ['je', 'PRO:PER']),
#  (['récupérera', 'VER:futu'], ['une', 'DET:ART']),
#  (['récupérera', 'VER:futu'], ['une', 'DET:ART'], ['chambre', 'NOM']),
#  (['récupérera', 'VER:futu'],
#   ['une', 'DET:ART'],
#   ['chambre', 'NOM'],
#   ['du', 'PRP:det']),
#  (['récupérera', 'VER:futu'],
#   ['une', 'DET:ART'],
#   ['chambre', 'NOM'],
#   ['du', 'PRP:det'],
#   ['STOP', 'NOM']),
#  (['récupérera', 'VER:futu'],
#   ['une', 'DET:ART'],
#   ['chambre', 'NOM'],
#   ['du', 'PRP:det'],
#   ['STOP', 'NOM'],
#   ['.', 'SENT']),
#  (['récupérera', 'VER:futu'],
#   ['une', 'DET:ART'],
#   ['chambre', 'NOM'],
#   ['du', 'PRP:det'],
#   ['STOP', 'NOM'],
#   ['.', 'SENT'],
#   ['je', 'PRO:PER']),
#  (['récupérera', 'VER:futu'],
#   ['une', 'DET:ART'],
#   ['chambre', 'NOM'],
#   ['du', 'PRP:det'],
#   ['STOP', 'NOM'],
#   ['.', 'SENT'],
#   ['je', 'PRO:PER'],
#   ['pense', 'VER:pres']),
#  (['une', 'DET:ART'], ['chambre', 'NOM']),
#  (['une', 'DET:ART'], ['chambre', 'NOM'], ['du', 'PRP:det']),
#  (['une', 'DET:ART'], ['chambre', 'NOM'], ['du', 'PRP:det'], ['STOP', 'NOM']),
#  (['une', 'DET:ART'],
#   ['chambre', 'NOM'],
#   ['du', 'PRP:det'],
#   ['STOP', 'NOM'],
#   ['.', 'SENT']),
#  (['une', 'DET:ART'],
#   ['chambre', 'NOM'],
#   ['du', 'PRP:det'],
#   ['STOP', 'NOM'],
#   ['.', 'SENT'],
#   ['je', 'PRO:PER']),
#  (['une', 'DET:ART'],
#   ['chambre', 'NOM'],
#   ['du', 'PRP:det'],
#   ['STOP', 'NOM'],
#   ['.', 'SENT'],
#   ['je', 'PRO:PER'],
#   ['pense', 'VER:pres']),
#  (['une', 'DET:ART'],
#   ['chambre', 'NOM'],
#   ['du', 'PRP:det'],
#   ['STOP', 'NOM'],
#   ['.', 'SENT'],
#   ['je', 'PRO:PER'],
#   ['pense', 'VER:pres'],
#   ['que', 'KON']),
#  (['chambre', 'NOM'], ['du', 'PRP:det']),
#  (['chambre', 'NOM'], ['du', 'PRP:det'], ['STOP', 'NOM']),
#  (['chambre', 'NOM'], ['du', 'PRP:det'], ['STOP', 'NOM'], ['.', 'SENT']),
#  (['chambre', 'NOM'],
#   ['du', 'PRP:det'],
#   ['STOP', 'NOM'],
#   ['.', 'SENT'],
#   ['je', 'PRO:PER']),
#  (['chambre', 'NOM'],
#   ['du', 'PRP:det'],
#   ['STOP', 'NOM'],
#   ['.', 'SENT'],
#   ['je', 'PRO:PER'],
#   ['pense', 'VER:pres']),
#  (['chambre', 'NOM'],
#   ['du', 'PRP:det'],
#   ['STOP', 'NOM'],
#   ['.', 'SENT'],
#   ['je', 'PRO:PER'],
#   ['pense', 'VER:pres'],
#   ['que', 'KON']),
#  (['chambre', 'NOM'],
#   ['du', 'PRP:det'],
#   ['STOP', 'NOM'],
#   ['.', 'SENT'],
#   ['je', 'PRO:PER'],
#   ['pense', 'VER:pres'],
#   ['que', 'KON'],
#   ['ce', 'PRO:DEM']),
#  (['du', 'PRP:det'], ['STOP', 'NOM']),
#  (['du', 'PRP:det'], ['STOP', 'NOM'], ['.', 'SENT']),
#  (['du', 'PRP:det'], ['STOP', 'NOM'], ['.', 'SENT'], ['je', 'PRO:PER']),
#  (['du', 'PRP:det'],
#   ['STOP', 'NOM'],
#   ['.', 'SENT'],
#   ['je', 'PRO:PER'],
#   ['pense', 'VER:pres']),
#  (['du', 'PRP:det'],
#   ['STOP', 'NOM'],
#   ['.', 'SENT'],
#   ['je', 'PRO:PER'],
#   ['pense', 'VER:pres'],
#   ['que', 'KON']),
#  (['du', 'PRP:det'],
#   ['STOP', 'NOM'],
#   ['.', 'SENT'],
#   ['je', 'PRO:PER'],
#   ['pense', 'VER:pres'],
#   ['que', 'KON'],
#   ['ce', 'PRO:DEM']),
#  (['du', 'PRP:det'],
#   ['STOP', 'NOM'],
#   ['.', 'SENT'],
#   ['je', 'PRO:PER'],
#   ['pense', 'VER:pres'],
#   ['que', 'KON'],
#   ['ce', 'PRO:DEM'],
#   ['ne', 'ADV']),
#  (['STOP', 'NOM'], ['.', 'SENT']),
#  (['STOP', 'NOM'], ['.', 'SENT'], ['je', 'PRO:PER']),
#  (['STOP', 'NOM'], ['.', 'SENT'], ['je', 'PRO:PER'], ['pense', 'VER:pres']),
#  (['STOP', 'NOM'],
#   ['.', 'SENT'],
#   ['je', 'PRO:PER'],
#   ['pense', 'VER:pres'],
#   ['que', 'KON']),
#  (['STOP', 'NOM'],
#   ['.', 'SENT'],
#   ['je', 'PRO:PER'],
#   ['pense', 'VER:pres'],
#   ['que', 'KON'],
#   ['ce', 'PRO:DEM']),
#  (['STOP', 'NOM'],
#   ['.', 'SENT'],
#   ['je', 'PRO:PER'],
#   ['pense', 'VER:pres'],
#   ['que', 'KON'],
#   ['ce', 'PRO:DEM'],
#   ['ne', 'ADV']),
#  (['STOP', 'NOM'],
#   ['.', 'SENT'],
#   ['je', 'PRO:PER'],
#   ['pense', 'VER:pres'],
#   ['que', 'KON'],
#   ['ce', 'PRO:DEM'],
#   ['ne', 'ADV'],
#   ['sera', 'VER:futu']),
#  (['.', 'SENT'], ['je', 'PRO:PER']),
#  (['.', 'SENT'], ['je', 'PRO:PER'], ['pense', 'VER:pres']),
#  (['.', 'SENT'], ['je', 'PRO:PER'], ['pense', 'VER:pres'], ['que', 'KON']),
#  (['.', 'SENT'],
#   ['je', 'PRO:PER'],
#   ['pense', 'VER:pres'],
#   ['que', 'KON'],
#   ['ce', 'PRO:DEM']),
#  (['.', 'SENT'],
#   ['je', 'PRO:PER'],
#   ['pense', 'VER:pres'],
#   ['que', 'KON'],
#   ['ce', 'PRO:DEM'],
#   ['ne', 'ADV']),
#  (['.', 'SENT'],
#   ['je', 'PRO:PER'],
#   ['pense', 'VER:pres'],
#   ['que', 'KON'],
#   ['ce', 'PRO:DEM'],
#   ['ne', 'ADV'],
#   ['sera', 'VER:futu']),
#  (['.', 'SENT'],
#   ['je', 'PRO:PER'],
#   ['pense', 'VER:pres'],
#   ['que', 'KON'],
#   ['ce', 'PRO:DEM'],
#   ['ne', 'ADV'],
#   ['sera', 'VER:futu'],
#   ['pas', 'ADV']),
#  (['je', 'PRO:PER'], ['pense', 'VER:pres']),
#  (['je', 'PRO:PER'], ['pense', 'VER:pres'], ['que', 'KON']),
#  (['je', 'PRO:PER'], ['pense', 'VER:pres'], ['que', 'KON'], ['ce', 'PRO:DEM']),
#  (['je', 'PRO:PER'],
#   ['pense', 'VER:pres'],
#   ['que', 'KON'],
#   ['ce', 'PRO:DEM'],
#   ['ne', 'ADV']),
#  (['je', 'PRO:PER'],
#   ['pense', 'VER:pres'],
#   ['que', 'KON'],
#   ['ce', 'PRO:DEM'],
#   ['ne', 'ADV'],
#   ['sera', 'VER:futu']),
#  (['je', 'PRO:PER'],
#   ['pense', 'VER:pres'],
#   ['que', 'KON'],
#   ['ce', 'PRO:DEM'],
#   ['ne', 'ADV'],
#   ['sera', 'VER:futu'],
#   ['pas', 'ADV']),
#  (['je', 'PRO:PER'],
#   ['pense', 'VER:pres'],
#   ['que', 'KON'],
#   ['ce', 'PRO:DEM'],
#   ['ne', 'ADV'],
#   ['sera', 'VER:futu'],
#   ['pas', 'ADV'],
#   ['fini', 'VER:pper']),
#  (['pense', 'VER:pres'], ['que', 'KON']),
#  (['pense', 'VER:pres'], ['que', 'KON'], ['ce', 'PRO:DEM']),
#  (['pense', 'VER:pres'], ['que', 'KON'], ['ce', 'PRO:DEM'], ['ne', 'ADV']),
#  (['pense', 'VER:pres'],
#   ['que', 'KON'],
#   ['ce', 'PRO:DEM'],
#   ['ne', 'ADV'],
#   ['sera', 'VER:futu']),
#  (['pense', 'VER:pres'],
#   ['que', 'KON'],
#   ['ce', 'PRO:DEM'],
#   ['ne', 'ADV'],
#   ['sera', 'VER:futu'],
#   ['pas', 'ADV']),
#  (['pense', 'VER:pres'],
#   ['que', 'KON'],
#   ['ce', 'PRO:DEM'],
#   ['ne', 'ADV'],
#   ['sera', 'VER:futu'],
#   ['pas', 'ADV'],
#   ['fini', 'VER:pper']),
#  (['pense', 'VER:pres'],
#   ['que', 'KON'],
#   ['ce', 'PRO:DEM'],
#   ['ne', 'ADV'],
#   ['sera', 'VER:futu'],
#   ['pas', 'ADV'],
#   ['fini', 'VER:pper'],
#   ['à', 'PRP']),
#  (['que', 'KON'], ['ce', 'PRO:DEM']),
#  (['que', 'KON'], ['ce', 'PRO:DEM'], ['ne', 'ADV']),
#  (['que', 'KON'], ['ce', 'PRO:DEM'], ['ne', 'ADV'], ['sera', 'VER:futu']),
#  (['que', 'KON'],
#   ['ce', 'PRO:DEM'],
#   ['ne', 'ADV'],
#   ['sera', 'VER:futu'],
#   ['pas', 'ADV']),
#  (['que', 'KON'],
#   ['ce', 'PRO:DEM'],
#   ['ne', 'ADV'],
#   ['sera', 'VER:futu'],
#   ['pas', 'ADV'],
#   ['fini', 'VER:pper']),
#  (['que', 'KON'],
#   ['ce', 'PRO:DEM'],
#   ['ne', 'ADV'],
#   ['sera', 'VER:futu'],
#   ['pas', 'ADV'],
#   ['fini', 'VER:pper'],
#   ['à', 'PRP']),
#  (['que', 'KON'],
#   ['ce', 'PRO:DEM'],
#   ['ne', 'ADV'],
#   ['sera', 'VER:futu'],
#   ['pas', 'ADV'],
#   ['fini', 'VER:pper'],
#   ['à', 'PRP'],
#   ['la', 'DET:ART']),
#  (['ce', 'PRO:DEM'], ['ne', 'ADV']),
#  (['ce', 'PRO:DEM'], ['ne', 'ADV'], ['sera', 'VER:futu']),
#  (['ce', 'PRO:DEM'], ['ne', 'ADV'], ['sera', 'VER:futu'], ['pas', 'ADV']),
#  (['ce', 'PRO:DEM'],
#   ['ne', 'ADV'],
#   ['sera', 'VER:futu'],
#   ['pas', 'ADV'],
#   ['fini', 'VER:pper']),
#  (['ce', 'PRO:DEM'],
#   ['ne', 'ADV'],
#   ['sera', 'VER:futu'],
#   ['pas', 'ADV'],
#   ['fini', 'VER:pper'],
#   ['à', 'PRP']),
#  (['ce', 'PRO:DEM'],
#   ['ne', 'ADV'],
#   ['sera', 'VER:futu'],
#   ['pas', 'ADV'],
#   ['fini', 'VER:pper'],
#   ['à', 'PRP'],
#   ['la', 'DET:ART']),
#  (['ce', 'PRO:DEM'],
#   ['ne', 'ADV'],
#   ['sera', 'VER:futu'],
#   ['pas', 'ADV'],
#   ['fini', 'VER:pper'],
#   ['à', 'PRP'],
#   ['la', 'DET:ART'],
#   ['naissance', 'NOM']),
#  (['ne', 'ADV'], ['sera', 'VER:futu']),
#  (['ne', 'ADV'], ['sera', 'VER:futu'], ['pas', 'ADV']),
#  (['ne', 'ADV'], ['sera', 'VER:futu'], ['pas', 'ADV'], ['fini', 'VER:pper']),
#  (['ne', 'ADV'],
#   ['sera', 'VER:futu'],
#   ['pas', 'ADV'],
#   ['fini', 'VER:pper'],
#   ['à', 'PRP']),
#  (['ne', 'ADV'],
#   ['sera', 'VER:futu'],
#   ['pas', 'ADV'],
#   ['fini', 'VER:pper'],
#   ['à', 'PRP'],
#   ['la', 'DET:ART']),
#  (['ne', 'ADV'],
#   ['sera', 'VER:futu'],
#   ['pas', 'ADV'],
#   ['fini', 'VER:pper'],
#   ['à', 'PRP'],
#   ['la', 'DET:ART'],
#   ['naissance', 'NOM']),
#  (['ne', 'ADV'],
#   ['sera', 'VER:futu'],
#   ['pas', 'ADV'],
#   ['fini', 'VER:pper'],
#   ['à', 'PRP'],
#   ['la', 'DET:ART'],
#   ['naissance', 'NOM'],
#   ['STOP', 'INT']),
#  (['sera', 'VER:futu'], ['pas', 'ADV']),
#  (['sera', 'VER:futu'], ['pas', 'ADV'], ['fini', 'VER:pper']),
#  (['sera', 'VER:futu'], ['pas', 'ADV'], ['fini', 'VER:pper'], ['à', 'PRP']),
#  (['sera', 'VER:futu'],
#   ['pas', 'ADV'],
#   ['fini', 'VER:pper'],
#   ['à', 'PRP'],
#   ['la', 'DET:ART']),
#  (['sera', 'VER:futu'],
#   ['pas', 'ADV'],
#   ['fini', 'VER:pper'],
#   ['à', 'PRP'],
#   ['la', 'DET:ART'],
#   ['naissance', 'NOM']),
#  (['sera', 'VER:futu'],
#   ['pas', 'ADV'],
#   ['fini', 'VER:pper'],
#   ['à', 'PRP'],
#   ['la', 'DET:ART'],
#   ['naissance', 'NOM'],
#   ['STOP', 'INT']),
#  (['sera', 'VER:futu'],
#   ['pas', 'ADV'],
#   ['fini', 'VER:pper'],
#   ['à', 'PRP'],
#   ['la', 'DET:ART'],
#   ['naissance', 'NOM'],
#   ['STOP', 'INT'],
#   ['on', 'PRO:PER']),
#  (['pas', 'ADV'], ['fini', 'VER:pper']),
#  (['pas', 'ADV'], ['fini', 'VER:pper'], ['à', 'PRP']),
#  (['pas', 'ADV'], ['fini', 'VER:pper'], ['à', 'PRP'], ['la', 'DET:ART']),
#  (['pas', 'ADV'],
#   ['fini', 'VER:pper'],
#   ['à', 'PRP'],
#   ['la', 'DET:ART'],
#   ['naissance', 'NOM']),
#  (['pas', 'ADV'],
#   ['fini', 'VER:pper'],
#   ['à', 'PRP'],
#   ['la', 'DET:ART'],
#   ['naissance', 'NOM'],
#   ['STOP', 'INT']),
#  (['pas', 'ADV'],
#   ['fini', 'VER:pper'],
#   ['à', 'PRP'],
#   ['la', 'DET:ART'],
#   ['naissance', 'NOM'],
#   ['STOP', 'INT'],
#   ['on', 'PRO:PER']),
#  (['pas', 'ADV'],
#   ['fini', 'VER:pper'],
#   ['à', 'PRP'],
#   ['la', 'DET:ART'],
#   ['naissance', 'NOM'],
#   ['STOP', 'INT'],
#   ['on', 'PRO:PER'],
#   ['fait', 'VER:pres']),
#  (['fini', 'VER:pper'], ['à', 'PRP']),
#  (['fini', 'VER:pper'], ['à', 'PRP'], ['la', 'DET:ART']),
#  (['fini', 'VER:pper'], ['à', 'PRP'], ['la', 'DET:ART'], ['naissance', 'NOM']),
#  (['fini', 'VER:pper'],
#   ['à', 'PRP'],
#   ['la', 'DET:ART'],
#   ['naissance', 'NOM'],
#   ['STOP', 'INT']),
#  (['fini', 'VER:pper'],
#   ['à', 'PRP'],
#   ['la', 'DET:ART'],
#   ['naissance', 'NOM'],
#   ['STOP', 'INT'],
#   ['on', 'PRO:PER']),
#  (['fini', 'VER:pper'],
#   ['à', 'PRP'],
#   ['la', 'DET:ART'],
#   ['naissance', 'NOM'],
#   ['STOP', 'INT'],
#   ['on', 'PRO:PER'],
#   ['fait', 'VER:pres']),
#  (['fini', 'VER:pper'],
#   ['à', 'PRP'],
#   ['la', 'DET:ART'],
#   ['naissance', 'NOM'],
#   ['STOP', 'INT'],
#   ['on', 'PRO:PER'],
#   ['fait', 'VER:pres'],
#   ['nous', 'PRO:PER']),
#  (['à', 'PRP'], ['la', 'DET:ART']),
#  (['à', 'PRP'], ['la', 'DET:ART'], ['naissance', 'NOM']),
#  (['à', 'PRP'], ['la', 'DET:ART'], ['naissance', 'NOM'], ['STOP', 'INT']),
#  (['à', 'PRP'],
#   ['la', 'DET:ART'],
#   ['naissance', 'NOM'],
#   ['STOP', 'INT'],
#   ['on', 'PRO:PER']),
#  (['à', 'PRP'],
#   ['la', 'DET:ART'],
#   ['naissance', 'NOM'],
#   ['STOP', 'INT'],
#   ['on', 'PRO:PER'],
#   ['fait', 'VER:pres']),
#  (['à', 'PRP'],
#   ['la', 'DET:ART'],
#   ['naissance', 'NOM'],
#   ['STOP', 'INT'],
#   ['on', 'PRO:PER'],
#   ['fait', 'VER:pres'],
#   ['nous', 'PRO:PER']),
#  (['à', 'PRP'],
#   ['la', 'DET:ART'],
#   ['naissance', 'NOM'],
#   ['STOP', 'INT'],
#   ['on', 'PRO:PER'],
#   ['fait', 'VER:pres'],
#   ['nous', 'PRO:PER'],
#   ['même', 'ADV']),
#  (['la', 'DET:ART'], ['naissance', 'NOM']),
#  (['la', 'DET:ART'], ['naissance', 'NOM'], ['STOP', 'INT']),
#  (['la', 'DET:ART'], ['naissance', 'NOM'], ['STOP', 'INT'], ['on', 'PRO:PER']),
#  (['la', 'DET:ART'],
#   ['naissance', 'NOM'],
#   ['STOP', 'INT'],
#   ['on', 'PRO:PER'],
#   ['fait', 'VER:pres']),
#  (['la', 'DET:ART'],
#   ['naissance', 'NOM'],
#   ['STOP', 'INT'],
#   ['on', 'PRO:PER'],
#   ['fait', 'VER:pres'],
#   ['nous', 'PRO:PER']),
#  (['la', 'DET:ART'],
#   ['naissance', 'NOM'],
#   ['STOP', 'INT'],
#   ['on', 'PRO:PER'],
#   ['fait', 'VER:pres'],
#   ['nous', 'PRO:PER'],
#   ['même', 'ADV']),
#  (['la', 'DET:ART'],
#   ['naissance', 'NOM'],
#   ['STOP', 'INT'],
#   ['on', 'PRO:PER'],
#   ['fait', 'VER:pres'],
#   ['nous', 'PRO:PER'],
#   ['même', 'ADV'],
#   ['donc', 'ADV']),
#  (['naissance', 'NOM'], ['STOP', 'INT']),
#  (['naissance', 'NOM'], ['STOP', 'INT'], ['on', 'PRO:PER']),
#  (['naissance', 'NOM'],
#   ['STOP', 'INT'],
#   ['on', 'PRO:PER'],
#   ['fait', 'VER:pres']),
#  (['naissance', 'NOM'],
#   ['STOP', 'INT'],
#   ['on', 'PRO:PER'],
#   ['fait', 'VER:pres'],
#   ['nous', 'PRO:PER']),
#  (['naissance', 'NOM'],
#   ['STOP', 'INT'],
#   ['on', 'PRO:PER'],
#   ['fait', 'VER:pres'],
#   ['nous', 'PRO:PER'],
#   ['même', 'ADV']),
#  (['naissance', 'NOM'],
#   ['STOP', 'INT'],
#   ['on', 'PRO:PER'],
#   ['fait', 'VER:pres'],
#   ['nous', 'PRO:PER'],
#   ['même', 'ADV'],
#   ['donc', 'ADV']),
#  (['naissance', 'NOM'],
#   ['STOP', 'INT'],
#   ['on', 'PRO:PER'],
#   ['fait', 'VER:pres'],
#   ['nous', 'PRO:PER'],
#   ['même', 'ADV'],
#   ['donc', 'ADV'],
#   ["c'", 'PRO:DEM']),
#  (['STOP', 'INT'], ['on', 'PRO:PER']),
#  (['STOP', 'INT'], ['on', 'PRO:PER'], ['fait', 'VER:pres']),
#  (['STOP', 'INT'],
#   ['on', 'PRO:PER'],
#   ['fait', 'VER:pres'],
#   ['nous', 'PRO:PER']),
#  (['STOP', 'INT'],
#   ['on', 'PRO:PER'],
#   ['fait', 'VER:pres'],
#   ['nous', 'PRO:PER'],
#   ['même', 'ADV']),
#  (['STOP', 'INT'],
#   ['on', 'PRO:PER'],
#   ['fait', 'VER:pres'],
#   ['nous', 'PRO:PER'],
#   ['même', 'ADV'],
#   ['donc', 'ADV']),
#  (['STOP', 'INT'],
#   ['on', 'PRO:PER'],
#   ['fait', 'VER:pres'],
#   ['nous', 'PRO:PER'],
#   ['même', 'ADV'],
#   ['donc', 'ADV'],
#   ["c'", 'PRO:DEM']),
#  (['STOP', 'INT'],
#   ['on', 'PRO:PER'],
#   ['fait', 'VER:pres'],
#   ['nous', 'PRO:PER'],
#   ['même', 'ADV'],
#   ['donc', 'ADV'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres']),
#  (['on', 'PRO:PER'], ['fait', 'VER:pres']),
#  (['on', 'PRO:PER'], ['fait', 'VER:pres'], ['nous', 'PRO:PER']),
#  (['on', 'PRO:PER'],
#   ['fait', 'VER:pres'],
#   ['nous', 'PRO:PER'],
#   ['même', 'ADV']),
#  (['on', 'PRO:PER'],
#   ['fait', 'VER:pres'],
#   ['nous', 'PRO:PER'],
#   ['même', 'ADV'],
#   ['donc', 'ADV']),
#  (['on', 'PRO:PER'],
#   ['fait', 'VER:pres'],
#   ['nous', 'PRO:PER'],
#   ['même', 'ADV'],
#   ['donc', 'ADV'],
#   ["c'", 'PRO:DEM']),
#  (['on', 'PRO:PER'],
#   ['fait', 'VER:pres'],
#   ['nous', 'PRO:PER'],
#   ['même', 'ADV'],
#   ['donc', 'ADV'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres']),
#  (['on', 'PRO:PER'],
#   ['fait', 'VER:pres'],
#   ['nous', 'PRO:PER'],
#   ['même', 'ADV'],
#   ['donc', 'ADV'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['plus', 'ADV']),
#  (['fait', 'VER:pres'], ['nous', 'PRO:PER']),
#  (['fait', 'VER:pres'], ['nous', 'PRO:PER'], ['même', 'ADV']),
#  (['fait', 'VER:pres'], ['nous', 'PRO:PER'], ['même', 'ADV'], ['donc', 'ADV']),
#  (['fait', 'VER:pres'],
#   ['nous', 'PRO:PER'],
#   ['même', 'ADV'],
#   ['donc', 'ADV'],
#   ["c'", 'PRO:DEM']),
#  (['fait', 'VER:pres'],
#   ['nous', 'PRO:PER'],
#   ['même', 'ADV'],
#   ['donc', 'ADV'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres']),
#  (['fait', 'VER:pres'],
#   ['nous', 'PRO:PER'],
#   ['même', 'ADV'],
#   ['donc', 'ADV'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['plus', 'ADV']),
#  (['fait', 'VER:pres'],
#   ['nous', 'PRO:PER'],
#   ['même', 'ADV'],
#   ['donc', 'ADV'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper']),
#  (['nous', 'PRO:PER'], ['même', 'ADV']),
#  (['nous', 'PRO:PER'], ['même', 'ADV'], ['donc', 'ADV']),
#  (['nous', 'PRO:PER'], ['même', 'ADV'], ['donc', 'ADV'], ["c'", 'PRO:DEM']),
#  (['nous', 'PRO:PER'],
#   ['même', 'ADV'],
#   ['donc', 'ADV'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres']),
#  (['nous', 'PRO:PER'],
#   ['même', 'ADV'],
#   ['donc', 'ADV'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['plus', 'ADV']),
#  (['nous', 'PRO:PER'],
#   ['même', 'ADV'],
#   ['donc', 'ADV'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper']),
#  (['nous', 'PRO:PER'],
#   ['même', 'ADV'],
#   ['donc', 'ADV'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM')),
#  (['même', 'ADV'], ['donc', 'ADV']),
#  (['même', 'ADV'], ['donc', 'ADV'], ["c'", 'PRO:DEM']),
#  (['même', 'ADV'], ['donc', 'ADV'], ["c'", 'PRO:DEM'], ['est', 'VER:pres']),
#  (['même', 'ADV'],
#   ['donc', 'ADV'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['plus', 'ADV']),
#  (['même', 'ADV'],
#   ['donc', 'ADV'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper']),
#  (['même', 'ADV'],
#   ['donc', 'ADV'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM')),
#  (['même', 'ADV'],
#   ['donc', 'ADV'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['toute', 'PRO:IND']),
#  (['donc', 'ADV'], ["c'", 'PRO:DEM']),
#  (['donc', 'ADV'], ["c'", 'PRO:DEM'], ['est', 'VER:pres']),
#  (['donc', 'ADV'], ["c'", 'PRO:DEM'], ['est', 'VER:pres'], ['plus', 'ADV']),
#  (['donc', 'ADV'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper']),
#  (['donc', 'ADV'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM')),
#  (['donc', 'ADV'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['toute', 'PRO:IND']),
#  (['donc', 'ADV'],
#   ["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['toute', 'PRO:IND'],
#   ['façon', 'NOM']),
#  (["c'", 'PRO:DEM'], ['est', 'VER:pres']),
#  (["c'", 'PRO:DEM'], ['est', 'VER:pres'], ['plus', 'ADV']),
#  (["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper']),
#  (["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM')),
#  (["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['toute', 'PRO:IND']),
#  (["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['toute', 'PRO:IND'],
#   ['façon', 'NOM']),
#  (["c'", 'PRO:DEM'],
#   ['est', 'VER:pres'],
#   ['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['toute', 'PRO:IND'],
#   ['façon', 'NOM'],
#   ['bébé', 'NOM']),
#  (['est', 'VER:pres'], ['plus', 'ADV']),
#  (['est', 'VER:pres'], ['plus', 'ADV'], ['dns-remplacé', 'VER:pper']),
#  (['est', 'VER:pres'],
#   ['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM')),
#  (['est', 'VER:pres'],
#   ['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['toute', 'PRO:IND']),
#  (['est', 'VER:pres'],
#   ['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['toute', 'PRO:IND'],
#   ['façon', 'NOM']),
#  (['est', 'VER:pres'],
#   ['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['toute', 'PRO:IND'],
#   ['façon', 'NOM'],
#   ['bébé', 'NOM']),
#  (['est', 'VER:pres'],
#   ['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['toute', 'PRO:IND'],
#   ['façon', 'NOM'],
#   ['bébé', 'NOM'],
#   ['reste', 'VER:pres']),
#  (['plus', 'ADV'], ['dns-remplacé', 'VER:pper']),
#  (['plus', 'ADV'], ['dns-remplacé', 'VER:pper'], ('STOP', 'NAM')),
#  (['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['toute', 'PRO:IND']),
#  (['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['toute', 'PRO:IND'],
#   ['façon', 'NOM']),
#  (['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['toute', 'PRO:IND'],
#   ['façon', 'NOM'],
#   ['bébé', 'NOM']),
#  (['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['toute', 'PRO:IND'],
#   ['façon', 'NOM'],
#   ['bébé', 'NOM'],
#   ['reste', 'VER:pres']),
#  (['plus', 'ADV'],
#   ['dns-remplacé', 'VER:pper'],
#   ('STOP', 'NAM'),
#   ['toute', 'PRO:IND'],
# ...
#   ['super', 'ADJ'],
#   ['pour', 'PRP'],
#   ['la', 'DET:ART']),
#  (['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ['gwayn', 'NOM'],
#   ['super', 'ADJ'],
#   ['pour', 'PRP'],
#   ['la', 'DET:ART'],
#   ['liste', 'NOM']),
#  (['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ['gwayn', 'NOM'],
#   ['super', 'ADJ'],
#   ['pour', 'PRP'],
#   ['la', 'DET:ART'],
#   ['liste', 'NOM'],
#   ['de', 'PRP']),
#  (["'", 'PUN'], ['gwayn', 'NOM']),
#  (["'", 'PUN'], ['gwayn', 'NOM'], ['super', 'ADJ']),
#  (["'", 'PUN'], ['gwayn', 'NOM'], ['super', 'ADJ'], ['pour', 'PRP']),
#  (["'", 'PUN'],
#   ['gwayn', 'NOM'],
#   ['super', 'ADJ'],
#   ['pour', 'PRP'],
#   ['la', 'DET:ART']),
#  (["'", 'PUN'],
#   ['gwayn', 'NOM'],
#   ['super', 'ADJ'],
#   ['pour', 'PRP'],
#   ['la', 'DET:ART'],
#   ['liste', 'NOM']),
#  (["'", 'PUN'],
#   ['gwayn', 'NOM'],
#   ['super', 'ADJ'],
#   ['pour', 'PRP'],
#   ['la', 'DET:ART'],
#   ['liste', 'NOM'],
#   ['de', 'PRP']),
#  (["'", 'PUN'],
#   ['gwayn', 'NOM'],
#   ['super', 'ADJ'],
#   ['pour', 'PRP'],
#   ['la', 'DET:ART'],
#   ['liste', 'NOM'],
#   ['de', 'PRP'],
#   ['naissance', 'NOM']),
#  (['gwayn', 'NOM'], ['super', 'ADJ']),
#  (['gwayn', 'NOM'], ['super', 'ADJ'], ['pour', 'PRP']),
#  (['gwayn', 'NOM'], ['super', 'ADJ'], ['pour', 'PRP'], ['la', 'DET:ART']),
#  (['gwayn', 'NOM'],
#   ['super', 'ADJ'],
#   ['pour', 'PRP'],
#   ['la', 'DET:ART'],
#   ['liste', 'NOM']),
#  (['gwayn', 'NOM'],
#   ['super', 'ADJ'],
#   ['pour', 'PRP'],
#   ['la', 'DET:ART'],
#   ['liste', 'NOM'],
#   ['de', 'PRP']),
#  (['gwayn', 'NOM'],
#   ['super', 'ADJ'],
#   ['pour', 'PRP'],
#   ['la', 'DET:ART'],
#   ['liste', 'NOM'],
#   ['de', 'PRP'],
#   ['naissance', 'NOM']),
#  (['gwayn', 'NOM'],
#   ['super', 'ADJ'],
#   ['pour', 'PRP'],
#   ['la', 'DET:ART'],
#   ['liste', 'NOM'],
#   ['de', 'PRP'],
#   ['naissance', 'NOM'],
#   ['.', 'SENT']),
#  (['super', 'ADJ'], ['pour', 'PRP']),
#  (['super', 'ADJ'], ['pour', 'PRP'], ['la', 'DET:ART']),
#  (['super', 'ADJ'], ['pour', 'PRP'], ['la', 'DET:ART'], ['liste', 'NOM']),
#  (['super', 'ADJ'],
#   ['pour', 'PRP'],
#   ['la', 'DET:ART'],
#   ['liste', 'NOM'],
#   ['de', 'PRP']),
#  (['super', 'ADJ'],
#   ['pour', 'PRP'],
#   ['la', 'DET:ART'],
#   ['liste', 'NOM'],
#   ['de', 'PRP'],
#   ['naissance', 'NOM']),
#  (['super', 'ADJ'],
#   ['pour', 'PRP'],
#   ['la', 'DET:ART'],
#   ['liste', 'NOM'],
#   ['de', 'PRP'],
#   ['naissance', 'NOM'],
#   ['.', 'SENT']),
#  (['super', 'ADJ'],
#   ['pour', 'PRP'],
#   ['la', 'DET:ART'],
#   ['liste', 'NOM'],
#   ['de', 'PRP'],
#   ['naissance', 'NOM'],
#   ['.', 'SENT'],
#   ['nous', 'PRO:PER']),
#  (['pour', 'PRP'], ['la', 'DET:ART']),
#  (['pour', 'PRP'], ['la', 'DET:ART'], ['liste', 'NOM']),
#  (['pour', 'PRP'], ['la', 'DET:ART'], ['liste', 'NOM'], ['de', 'PRP']),
#  (['pour', 'PRP'],
#   ['la', 'DET:ART'],
#   ['liste', 'NOM'],
#   ['de', 'PRP'],
#   ['naissance', 'NOM']),
#  (['pour', 'PRP'],
#   ['la', 'DET:ART'],
#   ['liste', 'NOM'],
#   ['de', 'PRP'],
#   ['naissance', 'NOM'],
#   ['.', 'SENT']),
#  (['pour', 'PRP'],
#   ['la', 'DET:ART'],
#   ['liste', 'NOM'],
#   ['de', 'PRP'],
#   ['naissance', 'NOM'],
#   ['.', 'SENT'],
#   ['nous', 'PRO:PER']),
#  (['pour', 'PRP'],
#   ['la', 'DET:ART'],
#   ['liste', 'NOM'],
#   ['de', 'PRP'],
#   ['naissance', 'NOM'],
#   ['.', 'SENT'],
#   ['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER']),
#  (['la', 'DET:ART'], ['liste', 'NOM']),
#  (['la', 'DET:ART'], ['liste', 'NOM'], ['de', 'PRP']),
#  (['la', 'DET:ART'], ['liste', 'NOM'], ['de', 'PRP'], ['naissance', 'NOM']),
#  (['la', 'DET:ART'],
#   ['liste', 'NOM'],
#   ['de', 'PRP'],
#   ['naissance', 'NOM'],
#   ['.', 'SENT']),
#  (['la', 'DET:ART'],
#   ['liste', 'NOM'],
#   ['de', 'PRP'],
#   ['naissance', 'NOM'],
#   ['.', 'SENT'],
#   ['nous', 'PRO:PER']),
#  (['la', 'DET:ART'],
#   ['liste', 'NOM'],
#   ['de', 'PRP'],
#   ['naissance', 'NOM'],
#   ['.', 'SENT'],
#   ['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER']),
#  (['la', 'DET:ART'],
#   ['liste', 'NOM'],
#   ['de', 'PRP'],
#   ['naissance', 'NOM'],
#   ['.', 'SENT'],
#   ['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER'],
#   ['sera', 'VER:futu']),
#  (['liste', 'NOM'], ['de', 'PRP']),
#  (['liste', 'NOM'], ['de', 'PRP'], ['naissance', 'NOM']),
#  (['liste', 'NOM'], ['de', 'PRP'], ['naissance', 'NOM'], ['.', 'SENT']),
#  (['liste', 'NOM'],
#   ['de', 'PRP'],
#   ['naissance', 'NOM'],
#   ['.', 'SENT'],
#   ['nous', 'PRO:PER']),
#  (['liste', 'NOM'],
#   ['de', 'PRP'],
#   ['naissance', 'NOM'],
#   ['.', 'SENT'],
#   ['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER']),
#  (['liste', 'NOM'],
#   ['de', 'PRP'],
#   ['naissance', 'NOM'],
#   ['.', 'SENT'],
#   ['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER'],
#   ['sera', 'VER:futu']),
#  (['liste', 'NOM'],
#   ['de', 'PRP'],
#   ['naissance', 'NOM'],
#   ['.', 'SENT'],
#   ['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER'],
#   ['sera', 'VER:futu'],
#   ['dispo', 'NOM']),
#  (['de', 'PRP'], ['naissance', 'NOM']),
#  (['de', 'PRP'], ['naissance', 'NOM'], ['.', 'SENT']),
#  (['de', 'PRP'], ['naissance', 'NOM'], ['.', 'SENT'], ['nous', 'PRO:PER']),
#  (['de', 'PRP'],
#   ['naissance', 'NOM'],
#   ['.', 'SENT'],
#   ['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER']),
#  (['de', 'PRP'],
#   ['naissance', 'NOM'],
#   ['.', 'SENT'],
#   ['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER'],
#   ['sera', 'VER:futu']),
#  (['de', 'PRP'],
#   ['naissance', 'NOM'],
#   ['.', 'SENT'],
#   ['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER'],
#   ['sera', 'VER:futu'],
#   ['dispo', 'NOM']),
#  (['de', 'PRP'],
#   ['naissance', 'NOM'],
#   ['.', 'SENT'],
#   ['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER'],
#   ['sera', 'VER:futu'],
#   ['dispo', 'NOM'],
#   ['après', 'PRP']),
#  (['naissance', 'NOM'], ['.', 'SENT']),
#  (['naissance', 'NOM'], ['.', 'SENT'], ['nous', 'PRO:PER']),
#  (['naissance', 'NOM'],
#   ['.', 'SENT'],
#   ['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER']),
#  (['naissance', 'NOM'],
#   ['.', 'SENT'],
#   ['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER'],
#   ['sera', 'VER:futu']),
#  (['naissance', 'NOM'],
#   ['.', 'SENT'],
#   ['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER'],
#   ['sera', 'VER:futu'],
#   ['dispo', 'NOM']),
#  (['naissance', 'NOM'],
#   ['.', 'SENT'],
#   ['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER'],
#   ['sera', 'VER:futu'],
#   ['dispo', 'NOM'],
#   ['après', 'PRP']),
#  (['naissance', 'NOM'],
#   ['.', 'SENT'],
#   ['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER'],
#   ['sera', 'VER:futu'],
#   ['dispo', 'NOM'],
#   ['après', 'PRP'],
#   ['notre', 'DET:POS']),
#  (['.', 'SENT'], ['nous', 'PRO:PER']),
#  (['.', 'SENT'], ['nous', 'PRO:PER'], ['elle', 'PRO:PER']),
#  (['.', 'SENT'],
#   ['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER'],
#   ['sera', 'VER:futu']),
#  (['.', 'SENT'],
#   ['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER'],
#   ['sera', 'VER:futu'],
#   ['dispo', 'NOM']),
#  (['.', 'SENT'],
#   ['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER'],
#   ['sera', 'VER:futu'],
#   ['dispo', 'NOM'],
#   ['après', 'PRP']),
#  (['.', 'SENT'],
#   ['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER'],
#   ['sera', 'VER:futu'],
#   ['dispo', 'NOM'],
#   ['après', 'PRP'],
#   ['notre', 'DET:POS']),
#  (['.', 'SENT'],
#   ['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER'],
#   ['sera', 'VER:futu'],
#   ['dispo', 'NOM'],
#   ['après', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['mariage', 'NOM']),
#  (['nous', 'PRO:PER'], ['elle', 'PRO:PER']),
#  (['nous', 'PRO:PER'], ['elle', 'PRO:PER'], ['sera', 'VER:futu']),
#  (['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER'],
#   ['sera', 'VER:futu'],
#   ['dispo', 'NOM']),
#  (['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER'],
#   ['sera', 'VER:futu'],
#   ['dispo', 'NOM'],
#   ['après', 'PRP']),
#  (['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER'],
#   ['sera', 'VER:futu'],
#   ['dispo', 'NOM'],
#   ['après', 'PRP'],
#   ['notre', 'DET:POS']),
#  (['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER'],
#   ['sera', 'VER:futu'],
#   ['dispo', 'NOM'],
#   ['après', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['mariage', 'NOM']),
#  (['nous', 'PRO:PER'],
#   ['elle', 'PRO:PER'],
#   ['sera', 'VER:futu'],
#   ['dispo', 'NOM'],
#   ['après', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['mariage', 'NOM'],
#   ["'", 'PUN']),
#  (['elle', 'PRO:PER'], ['sera', 'VER:futu']),
#  (['elle', 'PRO:PER'], ['sera', 'VER:futu'], ['dispo', 'NOM']),
#  (['elle', 'PRO:PER'],
#   ['sera', 'VER:futu'],
#   ['dispo', 'NOM'],
#   ['après', 'PRP']),
#  (['elle', 'PRO:PER'],
#   ['sera', 'VER:futu'],
#   ['dispo', 'NOM'],
#   ['après', 'PRP'],
#   ['notre', 'DET:POS']),
#  (['elle', 'PRO:PER'],
#   ['sera', 'VER:futu'],
#   ['dispo', 'NOM'],
#   ['après', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['mariage', 'NOM']),
#  (['elle', 'PRO:PER'],
#   ['sera', 'VER:futu'],
#   ['dispo', 'NOM'],
#   ['après', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['mariage', 'NOM'],
#   ["'", 'PUN']),
#  (['elle', 'PRO:PER'],
#   ['sera', 'VER:futu'],
#   ['dispo', 'NOM'],
#   ['après', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['mariage', 'NOM'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM']),
#  (['sera', 'VER:futu'], ['dispo', 'NOM']),
#  (['sera', 'VER:futu'], ['dispo', 'NOM'], ['après', 'PRP']),
#  (['sera', 'VER:futu'],
#   ['dispo', 'NOM'],
#   ['après', 'PRP'],
#   ['notre', 'DET:POS']),
#  (['sera', 'VER:futu'],
#   ['dispo', 'NOM'],
#   ['après', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['mariage', 'NOM']),
#  (['sera', 'VER:futu'],
#   ['dispo', 'NOM'],
#   ['après', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['mariage', 'NOM'],
#   ["'", 'PUN']),
#  (['sera', 'VER:futu'],
#   ['dispo', 'NOM'],
#   ['après', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['mariage', 'NOM'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM']),
#  (['sera', 'VER:futu'],
#   ['dispo', 'NOM'],
#   ['après', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['mariage', 'NOM'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ["'", 'PUN']),
#  (['dispo', 'NOM'], ['après', 'PRP']),
#  (['dispo', 'NOM'], ['après', 'PRP'], ['notre', 'DET:POS']),
#  (['dispo', 'NOM'],
#   ['après', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['mariage', 'NOM']),
#  (['dispo', 'NOM'],
#   ['après', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['mariage', 'NOM'],
#   ["'", 'PUN']),
#  (['dispo', 'NOM'],
#   ['après', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['mariage', 'NOM'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM']),
#  (['dispo', 'NOM'],
#   ['après', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['mariage', 'NOM'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ["'", 'PUN']),
#  (['dispo', 'NOM'],
#   ['après', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['mariage', 'NOM'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["j'", 'PRO:PER']),
#  (['après', 'PRP'], ['notre', 'DET:POS']),
#  (['après', 'PRP'], ['notre', 'DET:POS'], ['mariage', 'NOM']),
#  (['après', 'PRP'], ['notre', 'DET:POS'], ['mariage', 'NOM'], ["'", 'PUN']),
#  (['après', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['mariage', 'NOM'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM']),
#  (['après', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['mariage', 'NOM'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ["'", 'PUN']),
#  (['après', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['mariage', 'NOM'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["j'", 'PRO:PER']),
#  (['après', 'PRP'],
#   ['notre', 'DET:POS'],
#   ['mariage', 'NOM'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["j'", 'PRO:PER'],
#   ['ai', 'VER:pres']),
#  (['notre', 'DET:POS'], ['mariage', 'NOM']),
#  (['notre', 'DET:POS'], ['mariage', 'NOM'], ["'", 'PUN']),
#  (['notre', 'DET:POS'], ['mariage', 'NOM'], ["'", 'PUN'], ['STOP', 'NOM']),
#  (['notre', 'DET:POS'],
#   ['mariage', 'NOM'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ["'", 'PUN']),
#  (['notre', 'DET:POS'],
#   ['mariage', 'NOM'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["j'", 'PRO:PER']),
#  (['notre', 'DET:POS'],
#   ['mariage', 'NOM'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["j'", 'PRO:PER'],
#   ['ai', 'VER:pres']),
#  (['notre', 'DET:POS'],
#   ['mariage', 'NOM'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["j'", 'PRO:PER'],
#   ['ai', 'VER:pres'],
#   ['passé', 'VER:pper']),
#  (['mariage', 'NOM'], ["'", 'PUN']),
#  (['mariage', 'NOM'], ["'", 'PUN'], ['STOP', 'NOM']),
#  (['mariage', 'NOM'], ["'", 'PUN'], ['STOP', 'NOM'], ["'", 'PUN']),
#  (['mariage', 'NOM'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["j'", 'PRO:PER']),
#  (['mariage', 'NOM'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["j'", 'PRO:PER'],
#   ['ai', 'VER:pres']),
#  (['mariage', 'NOM'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["j'", 'PRO:PER'],
#   ['ai', 'VER:pres'],
#   ['passé', 'VER:pper']),
#  (['mariage', 'NOM'],
#   ["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["j'", 'PRO:PER'],
#   ['ai', 'VER:pres'],
#   ['passé', 'VER:pper'],
#   ['le', 'DET:ART']),
#  (["'", 'PUN'], ['STOP', 'NOM']),
#  (["'", 'PUN'], ['STOP', 'NOM'], ["'", 'PUN']),
#  (["'", 'PUN'], ['STOP', 'NOM'], ["'", 'PUN'], ["j'", 'PRO:PER']),
#  (["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["j'", 'PRO:PER'],
#   ['ai', 'VER:pres']),
#  (["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["j'", 'PRO:PER'],
#   ['ai', 'VER:pres'],
#   ['passé', 'VER:pper']),
#  (["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["j'", 'PRO:PER'],
#   ['ai', 'VER:pres'],
#   ['passé', 'VER:pper'],
#   ['le', 'DET:ART']),
#  (["'", 'PUN'],
#   ['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["j'", 'PRO:PER'],
#   ['ai', 'VER:pres'],
#   ['passé', 'VER:pper'],
#   ['le', 'DET:ART'],
#   ['cap', 'NOM']),
#  (['STOP', 'NOM'], ["'", 'PUN']),
#  (['STOP', 'NOM'], ["'", 'PUN'], ["j'", 'PRO:PER']),
#  (['STOP', 'NOM'], ["'", 'PUN'], ["j'", 'PRO:PER'], ['ai', 'VER:pres']),
#  (['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["j'", 'PRO:PER'],
#   ['ai', 'VER:pres'],
#   ['passé', 'VER:pper']),
#  (['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["j'", 'PRO:PER'],
#   ['ai', 'VER:pres'],
#   ['passé', 'VER:pper'],
#   ['le', 'DET:ART']),
#  (['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["j'", 'PRO:PER'],
#   ['ai', 'VER:pres'],
#   ['passé', 'VER:pper'],
#   ['le', 'DET:ART'],
#   ['cap', 'NOM']),
#  (['STOP', 'NOM'],
#   ["'", 'PUN'],
#   ["j'", 'PRO:PER'],
#   ['ai', 'VER:pres'],
#   ['passé', 'VER:pper'],
#   ['le', 'DET:ART'],
#   ['cap', 'NOM'],
#   ['et', 'KON']),
#  (["'", 'PUN'], ["j'", 'PRO:PER']),
#  (["'", 'PUN'], ["j'", 'PRO:PER'], ['ai', 'VER:pres']),
#  (["'", 'PUN'], ["j'", 'PRO:PER'], ['ai', 'VER:pres'], ['passé', 'VER:pper']),
#  (["'", 'PUN'],
#   ["j'", 'PRO:PER'],
#   ['ai', 'VER:pres'],
#   ['passé', 'VER:pper'],
#   ['le', 'DET:ART']),
#  (["'", 'PUN'],
#   ["j'", 'PRO:PER'],
#   ['ai', 'VER:pres'],
#   ['passé', 'VER:pper'],
#   ['le', 'DET:ART'],
#   ['cap', 'NOM']),
#  (["'", 'PUN'],
#   ["j'", 'PRO:PER'],
#   ['ai', 'VER:pres'],
#   ['passé', 'VER:pper'],
#   ['le', 'DET:ART'],
#   ['cap', 'NOM'],
#   ['et', 'KON']),
#  (["'", 'PUN'],
#   ["j'", 'PRO:PER'],
#   ['ai', 'VER:pres'],
#   ['passé', 'VER:pper'],
#   ['le', 'DET:ART'],
#   ['cap', 'NOM'],
#   ['et', 'KON'],
#   ['diffuser', 'VER:infi']),
#  (["j'", 'PRO:PER'], ['ai', 'VER:pres']),
#  (["j'", 'PRO:PER'], ['ai', 'VER:pres'], ['passé', 'VER:pper']),
#  (["j'", 'PRO:PER'],
#   ['ai', 'VER:pres'],
#   ['passé', 'VER:pper'],
#   ['le', 'DET:ART']),
#  (["j'", 'PRO:PER'],
#   ['ai', 'VER:pres'],
#   ['passé', 'VER:pper'],
#   ['le', 'DET:ART'],
#   ['cap', 'NOM']),
#  (["j'", 'PRO:PER'],
#   ['ai', 'VER:pres'],
#   ['passé', 'VER:pper'],
#   ['le', 'DET:ART'],
#   ['cap', 'NOM'],
#   ['et', 'KON']),
#  (["j'", 'PRO:PER'],
#   ['ai', 'VER:pres'],
#   ['passé', 'VER:pper'],
#   ['le', 'DET:ART'],
#   ['cap', 'NOM'],
#   ['et', 'KON'],
#   ['diffuser', 'VER:infi']),
#  (["j'", 'PRO:PER'],
#   ['ai', 'VER:pres'],
#   ['passé', 'VER:pper'],
#   ['le', 'DET:ART'],
#   ['cap', 'NOM'],
#   ['et', 'KON'],
#   ['diffuser', 'VER:infi'],
#   ['la', 'DET:ART']),
#  (['ai', 'VER:pres'], ['passé', 'VER:pper']),
#  (['ai', 'VER:pres'], ['passé', 'VER:pper'], ['le', 'DET:ART']),
#  (['ai', 'VER:pres'],
#   ['passé', 'VER:pper'],
#   ['le', 'DET:ART'],
#   ['cap', 'NOM']),
#  (['ai', 'VER:pres'],
#   ['passé', 'VER:pper'],
#   ['le', 'DET:ART'],
#   ['cap', 'NOM'],
#   ['et', 'KON']),
#  (['ai', 'VER:pres'],
#   ['passé', 'VER:pper'],
#   ['le', 'DET:ART'],
#   ['cap', 'NOM'],
#   ['et', 'KON'],
#   ['diffuser', 'VER:infi']),
#  (['ai', 'VER:pres'],
#   ['passé', 'VER:pper'],
#   ['le', 'DET:ART'],
#   ['cap', 'NOM'],
#   ['et', 'KON'],
#   ['diffuser', 'VER:infi'],
#   ['la', 'DET:ART']),
#  (['ai', 'VER:pres'],
#   ['passé', 'VER:pper'],
#   ['le', 'DET:ART'],
#   ['cap', 'NOM'],
#   ['et', 'KON'],
#   ['diffuser', 'VER:infi'],
#   ['la', 'DET:ART'],
#   ['liste', 'NOM']),
#  (['passé', 'VER:pper'], ['le', 'DET:ART']),
#  (['passé', 'VER:pper'], ['le', 'DET:ART'], ['cap', 'NOM']),
#  (['passé', 'VER:pper'], ['le', 'DET:ART'], ['cap', 'NOM'], ['et', 'KON']),
#  (['passé', 'VER:pper'],
#   ['le', 'DET:ART'],
#   ['cap', 'NOM'],
#   ['et', 'KON'],
#   ['diffuser', 'VER:infi']),
#  (['passé', 'VER:pper'],
#   ['le', 'DET:ART'],
#   ['cap', 'NOM'],
#   ['et', 'KON'],
#   ['diffuser', 'VER:infi'],
#   ['la', 'DET:ART']),
#  (['passé', 'VER:pper'],
#   ['le', 'DET:ART'],
#   ['cap', 'NOM'],
#   ['et', 'KON'],
#   ['diffuser', 'VER:infi'],
#   ['la', 'DET:ART'],
#   ['liste', 'NOM']),
#  ...]

# %% [markdown]
# ### **Extraction des patrons syntaxiques**

# %%
def extract_patterns(ngrammes):
    patterns = []
    for ng in ngrammes:
        phrase = tuple([t[0] for t in ng])
        pattern = [t[1] for t in ng]
        patterns.append([phrase, pattern])
    return patterns

# %%
phrases = extract_patterns(ngrammes)

# %%
frequencies = FreqDist(everygrams(tokens, min_len=1, max_len=8))

# %%
frequencies
# Out:
# FreqDist({('STOP',): 748938, ('de',): 205394, ('je',): 142012, ('et',): 136742, ('.',): 126438, ('STOP', 'STOP'): 125571, ('"',): 124191, ('le',): 111338, ("'",): 106264, ('la',): 102137, ...})

# %% [markdown]
# ### **Filtrage**
# On retire les n-grammes qui débutent ou se terminent par un stopword (antidictionnaire)

# %%
# Importer l'antidictionnaire pour filtrer les données

# Stopwords fréquents en français (non lemmatisés)
file_path = "../02-filtrage/stopwords.txt"
with open(file_path, 'r', encoding="utf-8") as f:
    stopwords = [t.lower().strip('\n') for t in f.readlines()]


# Stopwords fréquents en anglais (non lemmatisés)
file_path = '../02-filtrage/stop_words_english.txt'
with open(file_path, 'r', encoding="utf-8") as f:
    stopwords += [t.lower().strip('\n') for t in f.readlines()]

# %%
def filtrer_stopwords(x): 
    return [term for term in x if not 'STOP' in term[0] and not term[0][0] in stopwords and not term[0][-1] in stopwords \
        and not 'NUM' in term[1] and not '.' in term[0] and not '-' in term[0] and not ':' in term[0]\
        
        # Une parenthèse fermante peut juste se trouver comme dernier token
        # Si une parenthèse est ouverte, elle doit aussi être fermée (et vice versa)
        and not ')' in term[0][:-1] and not ('(' in term[0] and not ')' in term[0]) \
        and not (')' in term[0] and not '(' in term[0])]

# %%
phrases = filtrer_stopwords(phrases)

# %% [markdown]
# On retire les n-grammes qui débutent ou se terminent par un token dont la longueur est inférieure à 2 caractères ou supérieure à 18 caractères

# %%
def filter_len(x):
    return [term for term in x if \
        (len(term[0][0]) > 2 or term[0][0] == '(')  and (len(term[0][-1]) > 2 or term[0][-1] == ')') and \
        len(term[0][0]) < 18 and len(term[0][-1]) < 18]

phrases = filter_len(phrases)

# %% [markdown]
# On retire les n-grammes qui apparaissent moins de N fois dans le corpus

# %%
def filter_freq(x):
    return [term for term in x if frequencies[tuple(term[0])] > 5]

#phrases = filter_freq(phrases)

# %%
phrases
# Out:
# [[('oui', 'pour', 'les', 'logement'), ['INT', 'PRP', 'DET:ART', 'NOM']],
#  [('oui', 'pour', 'les', 'logement', 'sociaux'),
#   ['INT', 'PRP', 'DET:ART', 'NOM', 'ADJ']],
#  [('logement', 'sociaux'), ['NOM', 'ADJ']],
#  [('logement', 'sociaux', "c'", 'est', 'assez', 'long'),
#   ['NOM', 'ADJ', 'PRO:DEM', 'VER:pres', 'ADV', 'ADV']],
#  [('sociaux', "c'", 'est', 'assez', 'long'),
#   ['ADJ', 'PRO:DEM', 'VER:pres', 'ADV', 'ADV']],
#  [('commencer', 'des', 'travaux'), ['VER:infi', 'PRP:det', 'NOM']],
#  [('commencer', 'des', 'travaux', 'dans', 'notre', 'maison'),
#   ['VER:infi', 'PRP:det', 'NOM', 'PRP', 'DET:POS', 'NOM']],
#  [('travaux', 'dans', 'notre', 'maison'), ['NOM', 'PRP', 'DET:POS', 'NOM']],
#  [('aménage', 'des', 'chambres'), ['VER:pres', 'PRP:det', 'NOM']],
#  [('chambres', 'dans', 'le', 'grenier', 'pour', 'nos', 'grands'),
#   ['NOM', 'PRP', 'DET:ART', 'NOM', 'PRP', 'DET:POS', 'ADJ']],
#  [('bébé', 'récupérera'), ['NOM', 'VER:futu']],
#  [('bébé', 'récupérera', 'une', 'chambre'),
#   ['NOM', 'VER:futu', 'DET:ART', 'NOM']],
#  [('récupérera', 'une', 'chambre'), ['VER:futu', 'DET:ART', 'NOM']],
#  [('fini', 'à', 'la', 'naissance'), ['VER:pper', 'PRP', 'DET:ART', 'NOM']],
#  [('bébé', 'reste', 'avec', 'nous', 'le', 'temps'),
#   ['NOM', 'VER:pres', 'PRP', 'PRO:PER', 'DET:ART', 'NOM']],
#  [('bébé', 'reste', 'avec', 'nous', 'le', 'temps', "qu'"),
#   ['NOM', 'VER:pres', 'PRP', 'PRO:PER', 'DET:ART', 'NOM', 'PRO:REL']],
#  [('temps', "qu'"), ['NOM', 'PRO:REL']],
#  [('temps', "qu'", 'il', 'fasse'), ['NOM', 'PRO:REL', 'PRO:PER', 'VER:subp']],
#  [('temps', "qu'", 'il', 'fasse', 'ses', 'nuits'),
#   ['NOM', 'PRO:REL', 'PRO:PER', 'VER:subp', 'DET:POS', 'NOM']],
#  [("qu'", 'il', 'fasse'), ['PRO:REL', 'PRO:PER', 'VER:subp']],
#  [("qu'", 'il', 'fasse', 'ses', 'nuits'),
#   ['PRO:REL', 'PRO:PER', 'VER:subp', 'DET:POS', 'NOM']],
#  [('fasse', 'ses', 'nuits'), ['VER:subp', 'DET:POS', 'NOM']],
#  [('garde', 'mini'), ['NOM', 'ADJ']],
#  [('achète', 'les', 'vêtements'), ['VER:pres', 'DET:ART', 'NOM']],
#  [('achète', 'les', 'vêtements', 'au', 'troc'),
#   ['VER:pres', 'DET:ART', 'NOM', 'PRP:det', 'NOM']],
#  [('achète', 'les', 'vêtements', 'au', 'troc', 'et', 'puce'),
#   ['VER:pres', 'DET:ART', 'NOM', 'PRP:det', 'NOM', 'KON', 'NOM']],
#  [('vêtements', 'au', 'troc'), ['NOM', 'PRP:det', 'NOM']],
#  [('vêtements', 'au', 'troc', 'et', 'puce'),
#   ['NOM', 'PRP:det', 'NOM', 'KON', 'NOM']],
#  [('vêtements', 'au', 'troc', 'et', 'puce', 'ou', 'sur', 'vinted'),
#   ['NOM', 'PRP:det', 'NOM', 'KON', 'NOM', 'KON', 'PRP', 'NOM']],
#  [('troc', 'et', 'puce'), ['NOM', 'KON', 'NOM']],
#  [('troc', 'et', 'puce', 'ou', 'sur', 'vinted'),
#   ['NOM', 'KON', 'NOM', 'KON', 'PRP', 'NOM']],
#  [('troc', 'et', 'puce', 'ou', 'sur', 'vinted', 'ça', 'revient'),
#   ['NOM', 'KON', 'NOM', 'KON', 'PRP', 'NOM', 'PRO:DEM', 'VER:pres']],
#  [('puce', 'ou', 'sur', 'vinted'), ['NOM', 'KON', 'PRP', 'NOM']],
#  [('puce', 'ou', 'sur', 'vinted', 'ça', 'revient'),
#   ['NOM', 'KON', 'PRP', 'NOM', 'PRO:DEM', 'VER:pres']],
#  [('puce', 'ou', 'sur', 'vinted', 'ça', 'revient', 'bcp'),
#   ['NOM', 'KON', 'PRP', 'NOM', 'PRO:DEM', 'VER:pres', 'NOM']],
#  [('vinted', 'ça', 'revient'), ['NOM', 'PRO:DEM', 'VER:pres']],
#  [('vinted', 'ça', 'revient', 'bcp'), ['NOM', 'PRO:DEM', 'VER:pres', 'NOM']],
#  [('revient', 'bcp'), ['VER:pres', 'NOM']],
#  [('gwayn', 'super'), ['NOM', 'ADJ']],
#  [('gwayn', 'super', 'pour', 'la', 'liste'),
#   ['NOM', 'ADJ', 'PRP', 'DET:ART', 'NOM']],
#  [('gwayn', 'super', 'pour', 'la', 'liste', 'de', 'naissance'),
#   ['NOM', 'ADJ', 'PRP', 'DET:ART', 'NOM', 'PRP', 'NOM']],
#  [('super', 'pour', 'la', 'liste'), ['ADJ', 'PRP', 'DET:ART', 'NOM']],
#  [('super', 'pour', 'la', 'liste', 'de', 'naissance'),
#   ['ADJ', 'PRP', 'DET:ART', 'NOM', 'PRP', 'NOM']],
#  [('liste', 'de', 'naissance'), ['NOM', 'PRP', 'NOM']],
#  [('dispo', 'après', 'notre', 'mariage'), ['NOM', 'PRP', 'DET:POS', 'NOM']],
#  [('cap', 'et', 'diffuser'), ['NOM', 'KON', 'VER:infi']],
#  [('cap', 'et', 'diffuser', 'la', 'liste'),
#   ['NOM', 'KON', 'VER:infi', 'DET:ART', 'NOM']],
#  [('cap', 'et', 'diffuser', 'la', 'liste', 'de', 'naissance'),
#   ['NOM', 'KON', 'VER:infi', 'DET:ART', 'NOM', 'PRP', 'NOM']],
#  [('diffuser', 'la', 'liste'), ['VER:infi', 'DET:ART', 'NOM']],
#  [('diffuser', 'la', 'liste', 'de', 'naissance'),
#   ['VER:infi', 'DET:ART', 'NOM', 'PRP', 'NOM']],
#  [('liste', 'de', 'naissance'), ['NOM', 'PRP', 'NOM']],
#  [('liste', 'de', 'naissance', 'et', "j'", 'ai', 'également'),
#   ['NOM', 'PRP', 'NOM', 'KON', 'PRO:PER', 'VER:pres', 'ADV']],
#  [('liste', 'de', 'naissance', 'et', "j'", 'ai', 'également', 'acheté'),
#   ['NOM', 'PRP', 'NOM', 'KON', 'PRO:PER', 'VER:pres', 'ADV', 'VER:pper']],
#  [('naissance', 'et', "j'", 'ai', 'également'),
#   ['NOM', 'KON', 'PRO:PER', 'VER:pres', 'ADV']],
#  [('naissance', 'et', "j'", 'ai', 'également', 'acheté'),
#   ['NOM', 'KON', 'PRO:PER', 'VER:pres', 'ADV', 'VER:pper']],
#  [('naissance', 'et', "j'", 'ai', 'également', 'acheté', 'des', 'packs'),
#   ['NOM', 'KON', 'PRO:PER', 'VER:pres', 'ADV', 'VER:pper', 'PRP:det', 'NOM']],
#  [('également', 'acheté'), ['ADV', 'VER:pper']],
#  [('également', 'acheté', 'des', 'packs'),
#   ['ADV', 'VER:pper', 'PRP:det', 'NOM']],
#  [('également', 'acheté', 'des', 'packs', 'de', 'couches'),
#   ['ADV', 'VER:pper', 'PRP:det', 'NOM', 'PRP', 'NOM']],
#  [('également', 'acheté', 'des', 'packs', 'de', 'couches', 'pampers'),
#   ['ADV', 'VER:pper', 'PRP:det', 'NOM', 'PRP', 'NOM', 'ADJ']],
#  [('également',
#    'acheté',
#    'des',
#    'packs',
#    'de',
#    'couches',
#    'pampers',
#    'harmonie'),
#   ['ADV', 'VER:pper', 'PRP:det', 'NOM', 'PRP', 'NOM', 'ADJ', 'NOM']],
#  [('acheté', 'des', 'packs'), ['VER:pper', 'PRP:det', 'NOM']],
#  [('acheté', 'des', 'packs', 'de', 'couches'),
#   ['VER:pper', 'PRP:det', 'NOM', 'PRP', 'NOM']],
#  [('acheté', 'des', 'packs', 'de', 'couches', 'pampers'),
#   ['VER:pper', 'PRP:det', 'NOM', 'PRP', 'NOM', 'ADJ']],
#  [('acheté', 'des', 'packs', 'de', 'couches', 'pampers', 'harmonie'),
#   ['VER:pper', 'PRP:det', 'NOM', 'PRP', 'NOM', 'ADJ', 'NOM']],
#  [('packs', 'de', 'couches'), ['NOM', 'PRP', 'NOM']],
#  [('packs', 'de', 'couches', 'pampers'), ['NOM', 'PRP', 'NOM', 'ADJ']],
#  [('packs', 'de', 'couches', 'pampers', 'harmonie'),
#   ['NOM', 'PRP', 'NOM', 'ADJ', 'NOM']],
#  [('packs', 'de', 'couches', 'pampers', 'harmonie', 'en', 'promo'),
#   ['NOM', 'PRP', 'NOM', 'ADJ', 'NOM', 'PRP', 'NOM']],
#  [('couches', 'pampers'), ['NOM', 'ADJ']],
#  [('couches', 'pampers', 'harmonie'), ['NOM', 'ADJ', 'NOM']],
#  [('couches', 'pampers', 'harmonie', 'en', 'promo'),
#   ['NOM', 'ADJ', 'NOM', 'PRP', 'NOM']],
#  [('couches', 'pampers', 'harmonie', 'en', 'promo', 'sur', 'amazon'),
#   ['NOM', 'ADJ', 'NOM', 'PRP', 'NOM', 'PRP', 'NOM']],
#  [('pampers', 'harmonie'), ['ADJ', 'NOM']],
#  [('pampers', 'harmonie', 'en', 'promo'), ['ADJ', 'NOM', 'PRP', 'NOM']],
#  [('pampers', 'harmonie', 'en', 'promo', 'sur', 'amazon'),
#   ['ADJ', 'NOM', 'PRP', 'NOM', 'PRP', 'NOM']],
#  [('harmonie', 'en', 'promo'), ['NOM', 'PRP', 'NOM']],
#  [('harmonie', 'en', 'promo', 'sur', 'amazon'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'NOM']],
#  [('promo', 'sur', 'amazon'), ['NOM', 'PRP', 'NOM']],
#  [('oui', 'pareil'), ['INT', 'ADJ']],
#  [('oui', 'pareil', 'que', 'toi', 'arliaje'),
#   ['INT', 'ADJ', 'KON', 'PRO:PER', 'VER:subp']],
#  [('oui', 'pareil', 'que', 'toi', 'arliaje', 'les', 'garde'),
#   ['INT', 'ADJ', 'KON', 'PRO:PER', 'VER:subp', 'DET:ART', 'NOM']],
#  [('pareil', 'que', 'toi', 'arliaje'), ['ADJ', 'KON', 'PRO:PER', 'VER:subp']],
#  [('pareil', 'que', 'toi', 'arliaje', 'les', 'garde'),
#   ['ADJ', 'KON', 'PRO:PER', 'VER:subp', 'DET:ART', 'NOM']],
#  [('pareil', 'que', 'toi', 'arliaje', 'les', 'garde', 'au', 'minimum'),
#   ['ADJ', 'KON', 'PRO:PER', 'VER:subp', 'DET:ART', 'NOM', 'PRP:det', 'NOM']],
#  [('arliaje', 'les', 'garde'), ['VER:subp', 'DET:ART', 'NOM']],
#  [('arliaje', 'les', 'garde', 'au', 'minimum'),
#   ['VER:subp', 'DET:ART', 'NOM', 'PRP:det', 'NOM']],
#  [('garde', 'au', 'minimum'), ['NOM', 'PRP:det', 'NOM']],
#  [('mois', 'mais', "j'", 'ai', 'de', 'la', 'chance'),
#   ['NOM', 'KON', 'PRO:PER', 'VER:pres', 'PRP', 'DET:ART', 'NOM']],
#  [('nuit', 'rapidement'), ['NOM', 'ADV']],
#  [('nuit', 'rapidement', '...'), ['NOM', 'ADV', 'PUN']],
#  [('nuit', 'rapidement', '...', 'pour', 'la', 'construction'),
#   ['NOM', 'ADV', 'PUN', 'PRP', 'DET:ART', 'NOM']],
#  [('nuit', 'rapidement', '...', 'pour', 'la', 'construction', 'bin'),
#   ['NOM', 'ADV', 'PUN', 'PRP', 'DET:ART', 'NOM', 'ADJ']],
#  [('rapidement', '...'), ['ADV', 'PUN']],
#  [('rapidement', '...', 'pour', 'la', 'construction'),
#   ['ADV', 'PUN', 'PRP', 'DET:ART', 'NOM']],
#  [('rapidement', '...', 'pour', 'la', 'construction', 'bin'),
#   ['ADV', 'PUN', 'PRP', 'DET:ART', 'NOM', 'ADJ']],
#  [('rapidement', '...', 'pour', 'la', 'construction', 'bin', 'on', 'attend'),
#   ['ADV', 'PUN', 'PRP', 'DET:ART', 'NOM', 'ADJ', 'PRO:PER', 'VER:pres']],
#  [('...', 'pour', 'la', 'construction'), ['PUN', 'PRP', 'DET:ART', 'NOM']],
#  [('...', 'pour', 'la', 'construction', 'bin'),
#   ['PUN', 'PRP', 'DET:ART', 'NOM', 'ADJ']],
#  [('...', 'pour', 'la', 'construction', 'bin', 'on', 'attend'),
#   ['PUN', 'PRP', 'DET:ART', 'NOM', 'ADJ', 'PRO:PER', 'VER:pres']],
#  [('...', 'pour', 'la', 'construction', 'bin', 'on', 'attend', 'tjrs'),
#   ['PUN', 'PRP', 'DET:ART', 'NOM', 'ADJ', 'PRO:PER', 'VER:pres', 'NOM']],
#  [('construction', 'bin'), ['NOM', 'ADJ']],
#  [('construction', 'bin', 'on', 'attend'),
#   ['NOM', 'ADJ', 'PRO:PER', 'VER:pres']],
#  [('construction', 'bin', 'on', 'attend', 'tjrs'),
#   ['NOM', 'ADJ', 'PRO:PER', 'VER:pres', 'NOM']],
#  [('construction', 'bin', 'on', 'attend', 'tjrs', 'le', 'permis'),
#   ['NOM', 'ADJ', 'PRO:PER', 'VER:pres', 'NOM', 'DET:ART', 'NOM']],
#  [('bin', 'on', 'attend'), ['ADJ', 'PRO:PER', 'VER:pres']],
#  [('bin', 'on', 'attend', 'tjrs'), ['ADJ', 'PRO:PER', 'VER:pres', 'NOM']],
#  [('bin', 'on', 'attend', 'tjrs', 'le', 'permis'),
#   ['ADJ', 'PRO:PER', 'VER:pres', 'NOM', 'DET:ART', 'NOM']],
#  [('bin', 'on', 'attend', 'tjrs', 'le', 'permis', 'de', 'construire'),
#   ['ADJ', 'PRO:PER', 'VER:pres', 'NOM', 'DET:ART', 'NOM', 'PRP', 'VER:infi']],
#  [('attend', 'tjrs'), ['VER:pres', 'NOM']],
#  [('attend', 'tjrs', 'le', 'permis'), ['VER:pres', 'NOM', 'DET:ART', 'NOM']],
#  [('attend', 'tjrs', 'le', 'permis', 'de', 'construire'),
#   ['VER:pres', 'NOM', 'DET:ART', 'NOM', 'PRP', 'VER:infi']],
#  [('tjrs', 'le', 'permis'), ['NOM', 'DET:ART', 'NOM']],
#  [('tjrs', 'le', 'permis', 'de', 'construire'),
#   ['NOM', 'DET:ART', 'NOM', 'PRP', 'VER:infi']],
#  [('permis', 'de', 'construire'), ['NOM', 'PRP', 'VER:infi']],
#  [('permis', 'de', 'construire', 'mais', 'on', 'se', 'prend'),
#   ['NOM', 'PRP', 'VER:infi', 'KON', 'PRO:PER', 'PRO:PER', 'VER:pres']],
#  [('permis', 'de', 'construire', 'mais', 'on', 'se', 'prend', 'déjà'),
#   ['NOM', 'PRP', 'VER:infi', 'KON', 'PRO:PER', 'PRO:PER', 'VER:pres', 'ADV']],
#  [('construire', 'mais', 'on', 'se', 'prend'),
#   ['VER:infi', 'KON', 'PRO:PER', 'PRO:PER', 'VER:pres']],
#  [('construire', 'mais', 'on', 'se', 'prend', 'déjà'),
#   ['VER:infi', 'KON', 'PRO:PER', 'PRO:PER', 'VER:pres', 'ADV']],
#  [('construire', 'mais', 'on', 'se', 'prend', 'déjà', 'la', 'tête'),
#   ['VER:infi',
#    'KON',
#    'PRO:PER',
#    'PRO:PER',
#    'VER:pres',
#    'ADV',
#    'DET:ART',
#    'NOM']],
#  [('prend', 'déjà'), ['VER:pres', 'ADV']],
#  [('prend', 'déjà', 'la', 'tête'), ['VER:pres', 'ADV', 'DET:ART', 'NOM']],
#  [('prend', 'déjà', 'la', 'tête', 'pour', 'savoir'),
#   ['VER:pres', 'ADV', 'DET:ART', 'NOM', 'PRP', 'VER:infi']],
#  [('déjà', 'la', 'tête'), ['ADV', 'DET:ART', 'NOM']],
#  [('déjà', 'la', 'tête', 'pour', 'savoir'),
#   ['ADV', 'DET:ART', 'NOM', 'PRP', 'VER:infi']],
#  [('déjà', 'la', 'tête', 'pour', 'savoir', 'comment', 'il', 'faut'),
#   ['ADV', 'DET:ART', 'NOM', 'PRP', 'VER:infi', 'ADV', 'PRO:PER', 'VER:pres']],
#  [('tête', 'pour', 'savoir'), ['NOM', 'PRP', 'VER:infi']],
#  [('tête', 'pour', 'savoir', 'comment', 'il', 'faut'),
#   ['NOM', 'PRP', 'VER:infi', 'ADV', 'PRO:PER', 'VER:pres']],
#  [('tête', 'pour', 'savoir', 'comment', 'il', 'faut', 'aménager'),
#   ['NOM', 'PRP', 'VER:infi', 'ADV', 'PRO:PER', 'VER:pres', 'VER:infi']],
#  [('tête', 'pour', 'savoir', 'comment', 'il', 'faut', 'aménager', '...'),
#   ['NOM', 'PRP', 'VER:infi', 'ADV', 'PRO:PER', 'VER:pres', 'VER:infi', 'PUN']],
#  [('savoir', 'comment', 'il', 'faut'),
#   ['VER:infi', 'ADV', 'PRO:PER', 'VER:pres']],
#  [('savoir', 'comment', 'il', 'faut', 'aménager'),
#   ['VER:infi', 'ADV', 'PRO:PER', 'VER:pres', 'VER:infi']],
#  [('savoir', 'comment', 'il', 'faut', 'aménager', '...'),
#   ['VER:infi', 'ADV', 'PRO:PER', 'VER:pres', 'VER:infi', 'PUN']],
#  [('savoir', 'comment', 'il', 'faut', 'aménager', '...', 'achat'),
#   ['VER:infi', 'ADV', 'PRO:PER', 'VER:pres', 'VER:infi', 'PUN', 'NOM']],
#  [('savoir', 'comment', 'il', 'faut', 'aménager', '...', 'achat', 'cuisine'),
#   ['VER:infi', 'ADV', 'PRO:PER', 'VER:pres', 'VER:infi', 'PUN', 'NOM', 'NOM']],
#  [('faut', 'aménager'), ['VER:pres', 'VER:infi']],
#  [('faut', 'aménager', '...'), ['VER:pres', 'VER:infi', 'PUN']],
#  [('faut', 'aménager', '...', 'achat'),
#   ['VER:pres', 'VER:infi', 'PUN', 'NOM']],
#  [('faut', 'aménager', '...', 'achat', 'cuisine'),
#   ['VER:pres', 'VER:infi', 'PUN', 'NOM', 'NOM']],
#  [('faut', 'aménager', '...', 'achat', 'cuisine', 'salle'),
#   ['VER:pres', 'VER:infi', 'PUN', 'NOM', 'NOM', 'NOM']],
#  [('faut', 'aménager', '...', 'achat', 'cuisine', 'salle', 'de', 'bain'),
#   ['VER:pres', 'VER:infi', 'PUN', 'NOM', 'NOM', 'NOM', 'PRP', 'NOM']],
#  [('aménager', '...'), ['VER:infi', 'PUN']],
#  [('aménager', '...', 'achat'), ['VER:infi', 'PUN', 'NOM']],
#  [('aménager', '...', 'achat', 'cuisine'), ['VER:infi', 'PUN', 'NOM', 'NOM']],
#  [('aménager', '...', 'achat', 'cuisine', 'salle'),
#   ['VER:infi', 'PUN', 'NOM', 'NOM', 'NOM']],
#  [('aménager', '...', 'achat', 'cuisine', 'salle', 'de', 'bain'),
#   ['VER:infi', 'PUN', 'NOM', 'NOM', 'NOM', 'PRP', 'NOM']],
#  [('aménager', '...', 'achat', 'cuisine', 'salle', 'de', 'bain', 'sol'),
#   ['VER:infi', 'PUN', 'NOM', 'NOM', 'NOM', 'PRP', 'NOM', 'NOM']],
#  [('...', 'achat'), ['PUN', 'NOM']],
#  [('...', 'achat', 'cuisine'), ['PUN', 'NOM', 'NOM']],
#  [('...', 'achat', 'cuisine', 'salle'), ['PUN', 'NOM', 'NOM', 'NOM']],
#  [('...', 'achat', 'cuisine', 'salle', 'de', 'bain'),
#   ['PUN', 'NOM', 'NOM', 'NOM', 'PRP', 'NOM']],
#  [('...', 'achat', 'cuisine', 'salle', 'de', 'bain', 'sol'),
#   ['PUN', 'NOM', 'NOM', 'NOM', 'PRP', 'NOM', 'NOM']],
#  [('...', 'achat', 'cuisine', 'salle', 'de', 'bain', 'sol', '...'),
#   ['PUN', 'NOM', 'NOM', 'NOM', 'PRP', 'NOM', 'NOM', 'PUN']],
#  [('achat', 'cuisine'), ['NOM', 'NOM']],
#  [('achat', 'cuisine', 'salle'), ['NOM', 'NOM', 'NOM']],
#  [('achat', 'cuisine', 'salle', 'de', 'bain'),
#   ['NOM', 'NOM', 'NOM', 'PRP', 'NOM']],
#  [('achat', 'cuisine', 'salle', 'de', 'bain', 'sol'),
#   ['NOM', 'NOM', 'NOM', 'PRP', 'NOM', 'NOM']],
#  [('achat', 'cuisine', 'salle', 'de', 'bain', 'sol', '...'),
#   ['NOM', 'NOM', 'NOM', 'PRP', 'NOM', 'NOM', 'PUN']],
#  [('achat', 'cuisine', 'salle', 'de', 'bain', 'sol', '...', 'peinture'),
#   ['NOM', 'NOM', 'NOM', 'PRP', 'NOM', 'NOM', 'PUN', 'NOM']],
#  [('cuisine', 'salle'), ['NOM', 'NOM']],
#  [('cuisine', 'salle', 'de', 'bain'), ['NOM', 'NOM', 'PRP', 'NOM']],
#  [('cuisine', 'salle', 'de', 'bain', 'sol'),
#   ['NOM', 'NOM', 'PRP', 'NOM', 'NOM']],
#  [('cuisine', 'salle', 'de', 'bain', 'sol', '...'),
#   ['NOM', 'NOM', 'PRP', 'NOM', 'NOM', 'PUN']],
#  [('cuisine', 'salle', 'de', 'bain', 'sol', '...', 'peinture'),
#   ['NOM', 'NOM', 'PRP', 'NOM', 'NOM', 'PUN', 'NOM']],
#  [('cuisine', 'salle', 'de', 'bain', 'sol', '...', 'peinture', '...'),
#   ['NOM', 'NOM', 'PRP', 'NOM', 'NOM', 'PUN', 'NOM', 'PUN']],
#  [('salle', 'de', 'bain'), ['NOM', 'PRP', 'NOM']],
#  [('salle', 'de', 'bain', 'sol'), ['NOM', 'PRP', 'NOM', 'NOM']],
#  [('salle', 'de', 'bain', 'sol', '...'), ['NOM', 'PRP', 'NOM', 'NOM', 'PUN']],
#  [('salle', 'de', 'bain', 'sol', '...', 'peinture'),
#   ['NOM', 'PRP', 'NOM', 'NOM', 'PUN', 'NOM']],
#  [('salle', 'de', 'bain', 'sol', '...', 'peinture', '...'),
#   ['NOM', 'PRP', 'NOM', 'NOM', 'PUN', 'NOM', 'PUN']],
#  [('bain', 'sol'), ['NOM', 'NOM']],
#  [('bain', 'sol', '...'), ['NOM', 'NOM', 'PUN']],
#  [('bain', 'sol', '...', 'peinture'), ['NOM', 'NOM', 'PUN', 'NOM']],
#  [('bain', 'sol', '...', 'peinture', '...'),
#   ['NOM', 'NOM', 'PUN', 'NOM', 'PUN']],
#  [('bain', 'sol', '...', 'peinture', '...', 'on', 'achète'),
#   ['NOM', 'NOM', 'PUN', 'NOM', 'PUN', 'PRO:PER', 'VER:pres']],
#  [('sol', '...'), ['NOM', 'PUN']],
#  [('sol', '...', 'peinture'), ['NOM', 'PUN', 'NOM']],
#  [('sol', '...', 'peinture', '...'), ['NOM', 'PUN', 'NOM', 'PUN']],
#  [('sol', '...', 'peinture', '...', 'on', 'achète'),
#   ['NOM', 'PUN', 'NOM', 'PUN', 'PRO:PER', 'VER:pres']],
#  [('...', 'peinture'), ['PUN', 'NOM']],
#  [('...', 'peinture', '...'), ['PUN', 'NOM', 'PUN']],
#  [('...', 'peinture', '...', 'on', 'achète'),
#   ['PUN', 'NOM', 'PUN', 'PRO:PER', 'VER:pres']],
#  [('peinture', '...'), ['NOM', 'PUN']],
#  [('peinture', '...', 'on', 'achète'), ['NOM', 'PUN', 'PRO:PER', 'VER:pres']],
#  [('...', 'on', 'achète'), ['PUN', 'PRO:PER', 'VER:pres']],
#  [('...', 'on', 'achète', 'tout', 'quand', 'c', 'en', 'promo'),
#   ['PUN', 'PRO:PER', 'VER:pres', 'ADV', 'KON', 'NOM', 'PRP', 'NOM']],
#  [('achète', 'tout', 'quand', 'c', 'en', 'promo'),
#   ['VER:pres', 'ADV', 'KON', 'NOM', 'PRP', 'NOM']],
#  [('promo', 'ou', 'en', 'solde'), ['NOM', 'KON', 'PRP', 'NOM']],
#  [('promo', 'ou', 'en', 'solde', 'pour', 'faire'),
#   ['NOM', 'KON', 'PRP', 'NOM', 'PRP', 'VER:infi']],
#  [('solde', 'pour', 'faire'), ['NOM', 'PRP', 'VER:infi']],
#  [('solde', 'pour', 'faire', 'les', 'plus', "d'", 'économie'),
#   ['NOM', 'PRP', 'VER:infi', 'DET:ART', 'ADV', 'PRP', 'NOM']],
#  [('faire', 'les', 'plus', "d'", 'économie'),
#   ['VER:infi', 'DET:ART', 'ADV', 'PRP', 'NOM']],
#  [('faire', 'les', 'plus', "d'", 'économie', 'possible', '...'),
#   ['VER:infi', 'DET:ART', 'ADV', 'PRP', 'NOM', 'ADJ', 'PUN']],
#  [('économie', 'possible', '...'), ['NOM', 'ADJ', 'PUN']],
#  [('économie', 'possible', '...', 'pour', 'cette', 'grossesse'),
#   ['NOM', 'ADJ', 'PUN', 'PRP', 'PRO:DEM', 'NOM']],
#  [('...', 'pour', 'cette', 'grossesse'), ['PUN', 'PRP', 'PRO:DEM', 'NOM']],
#  [('douleur', 'plus', 'de', 'fatigue'), ['NOM', 'ADV', 'PRP', 'NOM']],
#  [('angoisses', 'des', 'que', 'je', 'ne', 'sens'),
#   ['NOM', 'PRP:det', 'ADV', 'PRO:PER', 'ADV', 'VER:pres']],
#  [('sens', 'pas', 'bb', 'bougé'), ['VER:pres', 'ADV', 'NOM', 'VER:pper']],
#  [('sens', 'pas', 'bb', 'bougé', "'", 'c', 'sûrement'),
#   ['VER:pres', 'ADV', 'NOM', 'VER:pper', 'PUN', 'NOM', 'ADV']],
#  [('bougé', "'", 'c', 'sûrement'), ['VER:pper', 'PUN', 'NOM', 'ADV']],
#  [('...', 'alors', 'je', 'me', 'rassure'),
#   ['PUN', 'ADV', 'PRO:PER', 'PRO:PER', 'VER:pres']],
#  [('rassure', 'toute', 'seule', 'en', 'me', 'disant'),
#   ['VER:pres', 'PRO:IND', 'ADJ', 'PRP', 'PRO:PER', 'VER:ppre']],
#  [('semaines', '...'), ['NOM', 'PUN']],
#  [('semaines', '...', 'même', 'si', 'c', 'long'),
#   ['NOM', 'PUN', 'ADJ', 'KON', 'NOM', 'ADJ']],
#  [('semaines', '...', 'même', 'si', 'c', 'long', '...'),
#   ['NOM', 'PUN', 'ADJ', 'KON', 'NOM', 'ADJ', 'PUN']],
#  [('...', 'même', 'si', 'c', 'long'), ['PUN', 'ADJ', 'KON', 'NOM', 'ADJ']],
#  [('...', 'même', 'si', 'c', 'long', '...'),
#   ['PUN', 'ADJ', 'KON', 'NOM', 'ADJ', 'PUN']],
#  [('long', '...'), ['ADJ', 'PUN']],
#  [('fausse', 'couche'), ['ADJ', 'NOM']],
#  [('debut', 'de', 'grossesse'), ['NOM', 'PRP', 'NOM']],
#  [('bcp', 'de', 'saignement'), ['NOM', 'PRP', 'NOM']],
#  [('bcp', 'de', 'saignement', 'mais', 'bébé'),
#   ['NOM', 'PRP', 'NOM', 'KON', 'NOM']],
#  [('saignement', 'mais', 'bébé'), ['NOM', 'KON', 'NOM']],
#  [('sens', 'super'), ['NOM', 'ADJ']],
#  [('arrêté', 'de', 'stressé.ici'), ['VER:pper', 'PRP', 'NOM']],
#  [('semaine', 'prochaine'), ['NOM', 'ADJ']],
#  [('parrait', 'encore', 'loin'), ['VER:cond', 'ADV', 'ADV']],
#  [('parrait', 'encore', 'loin', '...'), ['VER:cond', 'ADV', 'ADV', 'PUN']],
#  [('parrait', 'encore', 'loin', '...', 'je', 'le', 'sens'),
#   ['VER:cond', 'ADV', 'ADV', 'PUN', 'PRO:PER', 'PRO:PER', 'VER:pres']],
#  [('parrait', 'encore', 'loin', '...', 'je', 'le', 'sens', 'bouger'),
#   ['VER:cond',
#    'ADV',
#    'ADV',
#    'PUN',
#    'PRO:PER',
#    'PRO:PER',
#    'VER:pres',
#    'VER:infi']],
#  [('loin', '...'), ['ADV', 'PUN']],
#  [('loin', '...', 'je', 'le', 'sens'),
#   ['ADV', 'PUN', 'PRO:PER', 'PRO:PER', 'VER:pres']],
#  [('loin', '...', 'je', 'le', 'sens', 'bouger'),
#   ['ADV', 'PUN', 'PRO:PER', 'PRO:PER', 'VER:pres', 'VER:infi']],
#  [('...', 'je', 'le', 'sens'), ['PUN', 'PRO:PER', 'PRO:PER', 'VER:pres']],
#  [('...', 'je', 'le', 'sens', 'bouger'),
#   ['PUN', 'PRO:PER', 'PRO:PER', 'VER:pres', 'VER:infi']],
#  [('sens', 'bouger'), ['VER:pres', 'VER:infi']],
#  [('sens', 'bouger', 'aussi', 'tous', 'les', 'jours'),
#   ['VER:pres', 'VER:infi', 'ADV', 'PRO:IND', 'DET:ART', 'NOM']],
#  [('bouger', 'aussi', 'tous', 'les', 'jours'),
#   ['VER:infi', 'ADV', 'PRO:IND', 'DET:ART', 'NOM']],
#  [('bouger', 'aussi', 'tous', 'les', 'jours', 'mais', 'je', 'sais'),
#   ['VER:infi',
#    'ADV',
#    'PRO:IND',
#    'DET:ART',
#    'NOM',
#    'KON',
#    'PRO:PER',
#    'VER:pres']],
#  [('jours', 'mais', 'je', 'sais'), ['NOM', 'KON', 'PRO:PER', 'VER:pres']],
#  [('sais', 'pas', "j'", 'ai', 'des', "angoisses.c'est"),
#   ['VER:pres', 'ADV', 'PRO:PER', 'VER:pres', 'PRP:det', 'NOM']],
#  [('sais', 'pas', "j'", 'ai', 'des', "angoisses.c'est", 'surement'),
#   ['VER:pres', 'ADV', 'PRO:PER', 'VER:pres', 'PRP:det', 'NOM', 'NOM']],
#  [("angoisses.c'est", 'surement'), ['NOM', 'NOM']],
#  [("angoisses.c'est", 'surement', 'les', 'hormones'),
#   ['NOM', 'NOM', 'DET:ART', 'NOM']],
#  [("angoisses.c'est", 'surement', 'les', 'hormones', "lolj'ai"),
#   ['NOM', 'NOM', 'DET:ART', 'NOM', 'VER:simp']],
#  [("angoisses.c'est", 'surement', 'les', 'hormones', "lolj'ai", 'hâte'),
#   ['NOM', 'NOM', 'DET:ART', 'NOM', 'VER:simp', 'NOM']],
#  [('surement', 'les', 'hormones'), ['NOM', 'DET:ART', 'NOM']],
#  [('surement', 'les', 'hormones', "lolj'ai"),
#   ['NOM', 'DET:ART', 'NOM', 'VER:simp']],
#  [('surement', 'les', 'hormones', "lolj'ai", 'hâte'),
#   ['NOM', 'DET:ART', 'NOM', 'VER:simp', 'NOM']],
#  [('hormones', "lolj'ai"), ['NOM', 'VER:simp']],
#  [('hormones', "lolj'ai", 'hâte'), ['NOM', 'VER:simp', 'NOM']],
#  [('hormones', "lolj'ai", 'hâte', "d'", 'être', 'dans', 'un', 'mois'),
#   ['NOM', 'VER:simp', 'NOM', 'PRP', 'VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [("lolj'ai", 'hâte'), ['VER:simp', 'NOM']],
#  [("lolj'ai", 'hâte', "d'", 'être', 'dans', 'un', 'mois'),
#   ['VER:simp', 'NOM', 'PRP', 'VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('hâte', "d'", 'être', 'dans', 'un', 'mois'),
#   ['NOM', 'PRP', 'VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('hâte', "d'", 'être', 'dans', 'un', 'mois', 'du', 'coup'),
#   ['NOM', 'PRP', 'VER:infi', 'PRP', 'DET:ART', 'NOM', 'PRP:det', 'NOM']],
#  [('mois', 'du', 'coup'), ['NOM', 'PRP:det', 'NOM']],
#  [('grand', 'mère'), ['ADJ', 'NOM']],
#  [('belle', 'mère'), ['ADJ', 'NOM']],
#  [('belle', 'mère', 'et', 'ma', 'mère'),
#   ['ADJ', 'NOM', 'KON', 'DET:POS', 'NOM']],
#  [('belle', 'mère', 'et', 'ma', 'mère', 'ont', 'déjà'),
#   ['ADJ', 'NOM', 'KON', 'DET:POS', 'NOM', 'VER:pres', 'ADV']],
#  [('belle', 'mère', 'et', 'ma', 'mère', 'ont', 'déjà', 'commencé'),
#   ['ADJ', 'NOM', 'KON', 'DET:POS', 'NOM', 'VER:pres', 'ADV', 'VER:pper']],
#  [('mère', 'et', 'ma', 'mère'), ['NOM', 'KON', 'DET:POS', 'NOM']],
#  [('mère', 'et', 'ma', 'mère', 'ont', 'déjà'),
#   ['NOM', 'KON', 'DET:POS', 'NOM', 'VER:pres', 'ADV']],
#  [('mère', 'et', 'ma', 'mère', 'ont', 'déjà', 'commencé'),
#   ['NOM', 'KON', 'DET:POS', 'NOM', 'VER:pres', 'ADV', 'VER:pper']],
#  [('mère', 'ont', 'déjà'), ['NOM', 'VER:pres', 'ADV']],
#  [('mère', 'ont', 'déjà', 'commencé'), ['NOM', 'VER:pres', 'ADV', 'VER:pper']],
#  [('mère', 'ont', 'déjà', 'commencé', 'à', 'acheter'),
#   ['NOM', 'VER:pres', 'ADV', 'VER:pper', 'PRP', 'VER:infi']],
#  [('déjà', 'commencé'), ['ADV', 'VER:pper']],
#  [('déjà', 'commencé', 'à', 'acheter'),
#   ['ADV', 'VER:pper', 'PRP', 'VER:infi']],
#  [('déjà', 'commencé', 'à', 'acheter', 'et', 'à', 'préparer'),
#   ['ADV', 'VER:pper', 'PRP', 'VER:infi', 'KON', 'PRP', 'VER:infi']],
#  [('commencé', 'à', 'acheter'), ['VER:pper', 'PRP', 'VER:infi']],
#  [('commencé', 'à', 'acheter', 'et', 'à', 'préparer'),
#   ['VER:pper', 'PRP', 'VER:infi', 'KON', 'PRP', 'VER:infi']],
#  [('acheter', 'et', 'à', 'préparer'), ['VER:infi', 'KON', 'PRP', 'VER:infi']],
#  [('doucement', 'lol'), ['ADV', 'NOM']],
#  [('piticlaire', 'difficile'), ['NOM', 'ADJ']],
#  [('piticlaire', 'difficile', "d'", 'etre', 'sereine'),
#   ['NOM', 'ADJ', 'PRP', 'NOM', 'ADJ']],
#  [('difficile', "d'", 'etre', 'sereine'), ['ADJ', 'PRP', 'NOM', 'ADJ']],
#  [('sentir', 'bébé'), ['VER:infi', 'NOM']],
#  [('sentir', 'bébé', 'bouger'), ['VER:infi', 'NOM', 'VER:infi']],
#  [('sentir', 'bébé', 'bouger', 'tous', 'les', 'jours'),
#   ['VER:infi', 'NOM', 'VER:infi', 'PRO:IND', 'DET:ART', 'NOM']],
#  [('bébé', 'bouger'), ['NOM', 'VER:infi']],
#  [('bébé', 'bouger', 'tous', 'les', 'jours'),
#   ['NOM', 'VER:infi', 'PRO:IND', 'DET:ART', 'NOM']],
#  [('bouger', 'tous', 'les', 'jours'),
#   ['VER:infi', 'PRO:IND', 'DET:ART', 'NOM']],
#  [('bouge', 'pendant', 'nos', 'phase'), ['VER:pres', 'PRP', 'DET:POS', 'NOM']],
#  [('craque', 'toujours', 'en', 'magasin'), ['VER:pres', 'ADV', 'PRP', 'NOM']],
#  [('craque', 'toujours', 'en', 'magasin', 'pour', 'quelque', 'trucs'),
#   ['VER:pres', 'ADV', 'PRP', 'NOM', 'PRP', 'PRO:IND', 'NOM']],
#  [('magasin', 'pour', 'quelque', 'trucs'), ['NOM', 'PRP', 'PRO:IND', 'NOM']],
#  [('coucou', 'à', 'toutesest'), ['NOM', 'PRP', 'NOM']],
#  [('coucou', 'à', 'toutesest', '-ce'), ['NOM', 'PRP', 'NOM', 'PRO:DEM']],
#  [('toutesest', '-ce'), ['NOM', 'PRO:DEM']],
#  [('toutesest', '-ce', 'que', 'parmi', 'vous', 'certaines', 'ont', 'déjà'),
#   ['NOM',
#    'PRO:DEM',
#    'PRO:REL',
#    'PRP',
#    'PRO:PER',
#    'PRO:IND',
#    'VER:pres',
#    'ADV']],
#  [('-ce', 'que', 'parmi', 'vous', 'certaines', 'ont', 'déjà'),
#   ['PRO:DEM', 'PRO:REL', 'PRP', 'PRO:PER', 'PRO:IND', 'VER:pres', 'ADV']],
#  [('-ce', 'que', 'parmi', 'vous', 'certaines', 'ont', 'déjà', 'essayé'),
#   ['PRO:DEM',
#    'PRO:REL',
#    'PRP',
#    'PRO:PER',
#    'PRO:IND',
#    'VER:pres',
#    'ADV',
#    'VER:pper']],
#  [('déjà', 'essayé'), ['ADV', 'VER:pper']],
#  [('déjà', 'essayé', 'les', 'couches'), ['ADV', 'VER:pper', 'DET:ART', 'NOM']],
#  [('déjà', 'essayé', 'les', 'couches', 'lavables'),
#   ['ADV', 'VER:pper', 'DET:ART', 'NOM', 'ADJ']],
#  [('essayé', 'les', 'couches'), ['VER:pper', 'DET:ART', 'NOM']],
#  [('essayé', 'les', 'couches', 'lavables'),
#   ['VER:pper', 'DET:ART', 'NOM', 'ADJ']],
#  [('couches', 'lavables'), ['NOM', 'ADJ']],
#  [("qu'", 'en', 'pensez'), ['PRO:REL', 'PRO:PER', 'VER:pres']],
#  [("qu'", 'en', 'pensez', '-vous'),
#   ['PRO:REL', 'PRO:PER', 'VER:pres', 'PRO:PER']],
#  [('pensez', '-vous'), ['VER:pres', 'PRO:PER']],
#  [('courage', 'à', 'vous', 'pour', 'les', 'travaux'),
#   ['NOM', 'PRP', 'PRO:PER', 'PRP', 'DET:ART', 'NOM']],
#  [('acheter', 'mais', 'en', 'fait', 'on', 'ne', 'veut'),
#   ['VER:infi', 'KON', 'PRO:PER', 'VER:pres', 'PRO:PER', 'ADV', 'VER:pres']],
#  [('veut', 'pas', 'grand'), ['VER:pres', 'ADV', 'ADJ']],
#  [('veut', 'pas', 'grand', 'chose'), ['VER:pres', 'ADV', 'ADJ', 'NOM']],
#  [('grand', 'chose'), ['ADJ', 'NOM']],
#  [('vêtementsun', 'matelas'), ['ADJ', 'NOM']],
#  [('couches', 'lavables'), ['NOM', 'ADJ']],
#  [('couches', 'lavables', 'et', 'ce', 'bébé'),
#   ['NOM', 'ADJ', 'KON', 'PRO:DEM', 'NOM']],
#  [('lavables', 'et', 'ce', 'bébé'), ['ADJ', 'KON', 'PRO:DEM', 'NOM']],
#  [('voudrais', 'tu', 'savoir'), ['VER:cond', 'PRO:PER', 'VER:infi']],
#  [('voudrais', 'savoir'), ['VER:cond', 'VER:infi']],
#  [('voudrais', 'savoir', 'un', 'peu', 'les', 'achats'),
#   ['VER:cond', 'VER:infi', 'DET:ART', 'ADV', 'DET:ART', 'NOM']],
#  [('voudrais', 'savoir', 'un', 'peu', 'les', 'achats', 'nécessaires'),
#   ['VER:cond', 'VER:infi', 'DET:ART', 'ADV', 'DET:ART', 'NOM', 'ADJ']],
#  [('savoir', 'un', 'peu', 'les', 'achats'),
#   ['VER:infi', 'DET:ART', 'ADV', 'DET:ART', 'NOM']],
#  [('savoir', 'un', 'peu', 'les', 'achats', 'nécessaires'),
#   ['VER:infi', 'DET:ART', 'ADV', 'DET:ART', 'NOM', 'ADJ']],
#  [('achats', 'nécessaires'), ['NOM', 'ADJ']],
#  [('achats', 'nécessaires', 'pour', 'un', 'enfant'),
#   ['NOM', 'ADJ', 'PRP', 'DET:ART', 'NOM']],
#  [('nécessaires', 'pour', 'un', 'enfant'), ['ADJ', 'PRP', 'DET:ART', 'NOM']],
#  [('regardé', 'quelques', 'vidéos', 'comment', 'ça', 'fonctionnait'),
#   ['VER:pper', 'PRO:IND', 'NOM', 'ADV', 'PRO:DEM', 'VER:impf']],
#  [('achètes', 'combien', 'de', 'couches'), ['VER:pres', 'ADV', 'PRP', 'NOM']],
#  [('inserts', 'et', 'de', 'langes'), ['NOM', 'KON', 'PRP', 'NOM']],
#  [('inserts', 'et', 'de', 'langes', '(', 'environ', ')'),
#   ['NOM', 'KON', 'PRP', 'NOM', 'PUN', 'ADV', 'PUN']],
#  [('langes', '(', 'environ', ')'), ['NOM', 'PUN', 'ADV', 'PUN']],
#  [('(', 'environ', ')'), ['PUN', 'ADV', 'PUN']],
#  [('-ce', 'que', "d'", 'un', 'point'),
#   ['PRO:DEM', 'PRO:REL', 'PRP', 'DET:ART', 'NOM']],
#  [('-ce', 'que', "d'", 'un', 'point', 'de', 'vue'),
#   ['PRO:DEM', 'PRO:REL', 'PRP', 'DET:ART', 'NOM', 'PRP', 'NOM']],
#  [('-ce', 'que', "d'", 'un', 'point', 'de', 'vue', 'économique'),
#   ['PRO:DEM', 'PRO:REL', 'PRP', 'DET:ART', 'NOM', 'PRP', 'NOM', 'ADJ']],
#  [('point', 'de', 'vue'), ['NOM', 'PRP', 'NOM']],
#  [('point', 'de', 'vue', 'économique'), ['NOM', 'PRP', 'NOM', 'ADJ']],
#  [('point', 'de', 'vue', 'économique', "c'", 'est', 'une', 'grosse'),
#   ['NOM', 'PRP', 'NOM', 'ADJ', 'PRO:DEM', 'VER:pres', 'DET:ART', 'ADJ']],
#  [('vue', 'économique'), ['NOM', 'ADJ']],
#  [('vue', 'économique', "c'", 'est', 'une', 'grosse'),
#   ['NOM', 'ADJ', 'PRO:DEM', 'VER:pres', 'DET:ART', 'ADJ']],
#  [('vue', 'économique', "c'", 'est', 'une', 'grosse', 'différence'),
#   ['NOM', 'ADJ', 'PRO:DEM', 'VER:pres', 'DET:ART', 'ADJ', 'NOM']],
#  [('économique', "c'", 'est', 'une', 'grosse'),
#   ['ADJ', 'PRO:DEM', 'VER:pres', 'DET:ART', 'ADJ']],
#  [('économique', "c'", 'est', 'une', 'grosse', 'différence'),
#   ['ADJ', 'PRO:DEM', 'VER:pres', 'DET:ART', 'ADJ', 'NOM']],
#  [('grosse', 'différence'), ['ADJ', 'NOM']],
#  [('attends', 'des', 'jumelles'), ['VER:pres', 'PRP:det', 'ADJ']],
#  [('peur', "d'", 'être', 'un', 'peu', 'débordée'),
#   ['NOM', 'PRP', 'VER:infi', 'DET:ART', 'ADV', 'VER:pper']],
#  [('débordée', 'par', 'les', 'machines'),
#   ['VER:pper', 'PRP', 'DET:ART', 'NOM']],
#  [('débordée', 'par', 'les', 'machines', 'si', "j'", 'opte'),
#   ['VER:pper', 'PRP', 'DET:ART', 'NOM', 'KON', 'PRO:PER', 'VER:pres']],
#  [('machines', 'si', "j'", 'opte'), ['NOM', 'KON', 'PRO:PER', 'VER:pres']],
#  [('machines', 'si', "j'", 'opte', 'pour', 'ce', 'choix'),
#   ['NOM', 'KON', 'PRO:PER', 'VER:pres', 'PRP', 'PRO:DEM', 'NOM']],
#  [('opte', 'pour', 'ce', 'choix'), ['VER:pres', 'PRP', 'PRO:DEM', 'NOM']],
#  [('vois', "qu'"), ['VER:pres', 'KON']],
#  [("qu'", 'il', "n'", 'y', 'a', 'pas', 'de', 'post'),
#   ['KON', 'PRO:PER', 'ADV', 'PRO:PER', 'VER:pres', 'ADV', 'PRP', 'NOM']],
#  [('post', 'afin', 'de', 'partagé'), ['NOM', 'KON', 'PRP', 'ADJ']],
#  [('post', 'afin', 'de', 'partagé', 'nos', 'achats'),
#   ['NOM', 'KON', 'PRP', 'ADJ', 'DET:POS', 'NOM']],
#  [('partagé', 'nos', 'achats'), ['ADJ', 'DET:POS', 'NOM']],
#  [('coup', 'de', 'cœur'), ['NOM', 'PRP', 'NOM']],
#  [('coup', 'de', 'cœur', 'ou', 'coup'), ['NOM', 'PRP', 'NOM', 'KON', 'NOM']],
#  [('coup', 'de', 'cœur', 'ou', 'coup', 'de', 'gueule'),
#   ['NOM', 'PRP', 'NOM', 'KON', 'NOM', 'PRP', 'NOM']],
#  [('cœur', 'ou', 'coup'), ['NOM', 'KON', 'NOM']],
#  [('cœur', 'ou', 'coup', 'de', 'gueule'), ['NOM', 'KON', 'NOM', 'PRP', 'NOM']],
#  [('cœur', 'ou', 'coup', 'de', 'gueule', 'sur', 'les', 'produits'),
#   ['NOM', 'KON', 'NOM', 'PRP', 'NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('coup', 'de', 'gueule'), ['NOM', 'PRP', 'NOM']],
#  [('coup', 'de', 'gueule', 'sur', 'les', 'produits'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('coup', 'de', 'gueule', 'sur', 'les', 'produits', 'pour', 'bébé.avez'),
#   ['NOM', 'PRP', 'NOM', 'PRP', 'DET:ART', 'NOM', 'KON', 'VER:pres']],
#  [('gueule', 'sur', 'les', 'produits'), ['NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('gueule', 'sur', 'les', 'produits', 'pour', 'bébé.avez'),
#   ['NOM', 'PRP', 'DET:ART', 'NOM', 'KON', 'VER:pres']],
#  [('gueule', 'sur', 'les', 'produits', 'pour', 'bébé.avez', 'vous', 'déjà'),
#   ['NOM', 'PRP', 'DET:ART', 'NOM', 'KON', 'VER:pres', 'PRO:PER', 'ADV']],
#  [('produits', 'pour', 'bébé.avez'), ['NOM', 'KON', 'VER:pres']],
#  [('produits', 'pour', 'bébé.avez', 'vous', 'déjà'),
#   ['NOM', 'KON', 'VER:pres', 'PRO:PER', 'ADV']],
#  [('produits', 'pour', 'bébé.avez', 'vous', 'déjà', 'commencé'),
#   ['NOM', 'KON', 'VER:pres', 'PRO:PER', 'ADV', 'VER:pper']],
#  [('bébé.avez', 'vous', 'déjà'), ['VER:pres', 'PRO:PER', 'ADV']],
#  [('bébé.avez', 'vous', 'déjà', 'commencé'),
#   ['VER:pres', 'PRO:PER', 'ADV', 'VER:pper']],
#  [('déjà', 'commencé'), ['ADV', 'VER:pper']],
#  [('doudou', 'à', 'été', 'choisi'), ['NOM', 'PRP', 'NOM', 'VER:pper']],
#  [('doudou', 'à', 'été', 'choisi', 'par', "l'", 'aînée'),
#   ['NOM', 'PRP', 'NOM', 'VER:pper', 'PRP', 'DET:ART', 'ADJ']],
#  [('choisi', 'par', "l'", 'aînée'), ['VER:pper', 'PRP', 'DET:ART', 'ADJ']],
#  [('tour', 'de', 'lit'), ['NOM', 'PRP', 'NOM']],
#  [('tour', 'de', 'lit', 'gigoteuse'), ['NOM', 'PRP', 'NOM', 'NOM']],
#  [('tour', 'de', 'lit', 'gigoteuse', 'et', 'poussette'),
#   ['NOM', 'PRP', 'NOM', 'NOM', 'KON', 'NOM']],
#  [('tour', 'de', 'lit', 'gigoteuse', 'et', 'poussette', 'acheté'),
#   ['NOM', 'PRP', 'NOM', 'NOM', 'KON', 'NOM', 'VER:pper']],
#  [('lit', 'gigoteuse'), ['NOM', 'NOM']],
#  [('lit', 'gigoteuse', 'et', 'poussette'), ['NOM', 'NOM', 'KON', 'NOM']],
#  [('lit', 'gigoteuse', 'et', 'poussette', 'acheté'),
#   ['NOM', 'NOM', 'KON', 'NOM', 'VER:pper']],
#  [('gigoteuse', 'et', 'poussette'), ['NOM', 'KON', 'NOM']],
#  [('gigoteuse', 'et', 'poussette', 'acheté'),
#   ['NOM', 'KON', 'NOM', 'VER:pper']],
#  [('poussette', 'acheté'), ['NOM', 'VER:pper']],
#  [('commencer', 'la', 'peinture'), ['VER:infi', 'DET:ART', 'NOM']],
#  [('commencer', 'la', 'peinture', 'dans', 'la', 'chambre'),
#   ['VER:infi', 'DET:ART', 'NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('commencer', 'la', 'peinture', 'dans', 'la', 'chambre', 'du', 'futur'),
#   ['VER:infi', 'DET:ART', 'NOM', 'PRP', 'DET:ART', 'NOM', 'PRP:det', 'ADJ']],
#  [('peinture', 'dans', 'la', 'chambre'), ['NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('peinture', 'dans', 'la', 'chambre', 'du', 'futur'),
#   ['NOM', 'PRP', 'DET:ART', 'NOM', 'PRP:det', 'ADJ']],
#  [('peinture', 'dans', 'la', 'chambre', 'du', 'futur', 'bébé'),
#   ['NOM', 'PRP', 'DET:ART', 'NOM', 'PRP:det', 'ADJ', 'NOM']],
#  [('chambre', 'du', 'futur'), ['NOM', 'PRP:det', 'ADJ']],
#  [('chambre', 'du', 'futur', 'bébé'), ['NOM', 'PRP:det', 'ADJ', 'NOM']],
#  [('futur', 'bébé'), ['ADJ', 'NOM']],
#  [('...', 'c', 'des', 'acheteuses'), ['PUN', 'NOM', 'PRP:det', 'NOM']],
#  [('...', 'c', 'des', 'acheteuses', 'compulsives'),
#   ['PUN', 'NOM', 'PRP:det', 'NOM', 'ADJ']],
#  [('...', 'c', 'des', 'acheteuses', 'compulsives', 'lol'),
#   ['PUN', 'NOM', 'PRP:det', 'NOM', 'ADJ', 'ADJ']],
#  [('acheteuses', 'compulsives'), ['NOM', 'ADJ']],
#  [('acheteuses', 'compulsives', 'lol'), ['NOM', 'ADJ', 'ADJ']],
#  [('acheteuses', 'compulsives', 'lol', 'c', 'pour', 'ça', "j'", 'achète'),
#   ['NOM', 'ADJ', 'ADJ', 'NOM', 'PRP', 'PRO:DEM', 'PRO:PER', 'VER:pres']],
#  [('compulsives', 'lol'), ['ADJ', 'ADJ']],
#  [('compulsives', 'lol', 'c', 'pour', 'ça', "j'", 'achète'),
#   ['ADJ', 'ADJ', 'NOM', 'PRP', 'PRO:DEM', 'PRO:PER', 'VER:pres']],
#  [('lol', 'c', 'pour', 'ça', "j'", 'achète'),
#   ['ADJ', 'NOM', 'PRP', 'PRO:DEM', 'PRO:PER', 'VER:pres']],
#  [('pagaille', 'lol'), ['NOM', 'ADJ']],
#  [('haha', 'autant', 'en', 'profiter'), ['NOM', 'ADV', 'PRP', 'VER:infi']],
#  [('piticlaire', 'excellent'), ['NOM', 'ADJ']],
#  [('elleso', 'ont', 'hâte'), ['ADJ', 'VER:pres', 'NOM']],
#  [('browser', 'cannot', 'play'), ['VER:simp', 'NOM', 'INT']],
#  [('browser', 'cannot', 'play'), ['VER:simp', 'NOM', 'INT']],
#  [("m\\'a", 'retiré'), ['VER:simp', 'VER:pper']],
#  [("m\\'a", 'retiré', 'la', 'glande'),
#   ['VER:simp', 'VER:pper', 'DET:ART', 'NOM']],
#  [("m\\'a", 'retiré', 'la', 'glande', 'thyroïde'),
#   ['VER:simp', 'VER:pper', 'DET:ART', 'NOM', 'ADJ']],
#  [('retiré', 'la', 'glande'), ['VER:pper', 'DET:ART', 'NOM']],
#  [('retiré', 'la', 'glande', 'thyroïde'),
#   ['VER:pper', 'DET:ART', 'NOM', 'ADJ']],
#  [('glande', 'thyroïde'), ['NOM', 'ADJ']],
#  [('ans', 'pour', 'des', 'nodules'), ['NOM', 'KON', 'PRP:det', 'NOM']],
#  [('ans', 'pour', 'des', 'nodules', 'non', 'cancéreux'),
#   ['NOM', 'KON', 'PRP:det', 'NOM', 'ADV', 'ADJ']],
#  [('ans', 'pour', 'des', 'nodules', 'non', 'cancéreux', 'qui', 'accéléraient'),
#   ['NOM', 'KON', 'PRP:det', 'NOM', 'ADV', 'ADJ', 'PRO:REL', 'VER:impf']],
#  [('nodules', 'non', 'cancéreux'), ['NOM', 'ADV', 'ADJ']],
#  [('nodules', 'non', 'cancéreux', 'qui', 'accéléraient'),
#   ['NOM', 'ADV', 'ADJ', 'PRO:REL', 'VER:impf']],
#  [('nodules', 'non', 'cancéreux', 'qui', 'accéléraient', 'les', 'battements'),
#   ['NOM', 'ADV', 'ADJ', 'PRO:REL', 'VER:impf', 'DET:ART', 'NOM']],
#  [('cancéreux', 'qui', 'accéléraient'), ['ADJ', 'PRO:REL', 'VER:impf']],
#  [('cancéreux', 'qui', 'accéléraient', 'les', 'battements'),
#   ['ADJ', 'PRO:REL', 'VER:impf', 'DET:ART', 'NOM']],
#  [('cancéreux',
#    'qui',
#    'accéléraient',
#    'les',
#    'battements',
#    'de',
#    'mon',
#    'cœur'),
#   ['ADJ', 'PRO:REL', 'VER:impf', 'DET:ART', 'NOM', 'PRP', 'DET:POS', 'NOM']],
#  [('accéléraient', 'les', 'battements'), ['VER:impf', 'DET:ART', 'NOM']],
#  [('accéléraient', 'les', 'battements', 'de', 'mon', 'cœur'),
#   ['VER:impf', 'DET:ART', 'NOM', 'PRP', 'DET:POS', 'NOM']],
#  [('battements', 'de', 'mon', 'cœur'), ['NOM', 'PRP', 'DET:POS', 'NOM']],
#  [('prend', 'du', 'lévothyrox'), ['VER:pres', 'PRP:det', 'NOM']],
#  [('molécule', 'est', 'une', 'hormone'),
#   ['NOM', 'VER:pres', 'DET:ART', 'NOM']],
#  [('molécule', 'est', 'une', 'hormone', 'enrobée'),
#   ['NOM', 'VER:pres', 'DET:ART', 'NOM', 'VER:pper']],
#  [('molécule', 'est', 'une', 'hormone', 'enrobée', "d\\'une"),
#   ['NOM', 'VER:pres', 'DET:ART', 'NOM', 'VER:pper', 'ADJ']],
#  [('molécule', 'est', 'une', 'hormone', 'enrobée', "d\\'une", 'substance'),
#   ['NOM', 'VER:pres', 'DET:ART', 'NOM', 'VER:pper', 'ADJ', 'NOM']],
#  [('molécule',
#    'est',
#    'une',
#    'hormone',
#    'enrobée',
#    "d\\'une",
#    'substance',
#    'permettant'),
#   ['NOM', 'VER:pres', 'DET:ART', 'NOM', 'VER:pper', 'ADJ', 'NOM', 'VER:ppre']],
#  [('hormone', 'enrobée'), ['NOM', 'VER:pper']],
#  [('hormone', 'enrobée', "d\\'une"), ['NOM', 'VER:pper', 'ADJ']],
#  [('hormone', 'enrobée', "d\\'une", 'substance'),
#   ['NOM', 'VER:pper', 'ADJ', 'NOM']],
#  [('hormone', 'enrobée', "d\\'une", 'substance', 'permettant'),
#   ['NOM', 'VER:pper', 'ADJ', 'NOM', 'VER:ppre']],
#  [('hormone',
#    'enrobée',
#    "d\\'une",
#    'substance',
#    'permettant',
#    'de',
#    "l\\'avaler"),
#   ['NOM', 'VER:pper', 'ADJ', 'NOM', 'VER:ppre', 'PRP', 'VER:infi']],
#  [('enrobée', "d\\'une"), ['VER:pper', 'ADJ']],
#  [('enrobée', "d\\'une", 'substance'), ['VER:pper', 'ADJ', 'NOM']],
#  [('enrobée', "d\\'une", 'substance', 'permettant'),
#   ['VER:pper', 'ADJ', 'NOM', 'VER:ppre']],
#  [('enrobée', "d\\'une", 'substance', 'permettant', 'de', "l\\'avaler"),
#   ['VER:pper', 'ADJ', 'NOM', 'VER:ppre', 'PRP', 'VER:infi']],
#  [("d\\'une", 'substance'), ['ADJ', 'NOM']],
#  [("d\\'une", 'substance', 'permettant'), ['ADJ', 'NOM', 'VER:ppre']],
#  [("d\\'une", 'substance', 'permettant', 'de', "l\\'avaler"),
#   ['ADJ', 'NOM', 'VER:ppre', 'PRP', 'VER:infi']],
#  [('substance', 'permettant'), ['NOM', 'VER:ppre']],
#  [('substance', 'permettant', 'de', "l\\'avaler"),
#   ['NOM', 'VER:ppre', 'PRP', 'VER:infi']],
#  [('substance', 'permettant', 'de', "l\\'avaler", 'et', 'de', 'la', 'faire'),
#   ['NOM', 'VER:ppre', 'PRP', 'VER:infi', 'KON', 'PRP', 'PRO:PER', 'VER:infi']],
#  [('permettant', 'de', "l\\'avaler"), ['VER:ppre', 'PRP', 'VER:infi']],
#  [('permettant', 'de', "l\\'avaler", 'et', 'de', 'la', 'faire'),
#   ['VER:ppre', 'PRP', 'VER:infi', 'KON', 'PRP', 'PRO:PER', 'VER:infi']],
#  [('permettant', 'de', "l\\'avaler", 'et', 'de', 'la', 'faire', 'passer'),
#   ['VER:ppre',
#    'PRP',
#    'VER:infi',
#    'KON',
#    'PRP',
#    'PRO:PER',
#    'VER:infi',
#    'VER:infi']],
#  [("l\\'avaler", 'et', 'de', 'la', 'faire'),
#   ['VER:infi', 'KON', 'PRP', 'PRO:PER', 'VER:infi']],
#  [("l\\'avaler", 'et', 'de', 'la', 'faire', 'passer'),
#   ['VER:infi', 'KON', 'PRP', 'PRO:PER', 'VER:infi', 'VER:infi']],
#  [('faire', 'passer'), ['VER:infi', 'VER:infi']],
#  [('faire', 'passer', 'dans', 'le', 'sang'),
#   ['VER:infi', 'VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('faire', 'passer', 'dans', 'le', 'sang', 'afin', 'de', 'produire'),
#   ['VER:infi', 'VER:infi', 'PRP', 'DET:ART', 'NOM', 'KON', 'PRP', 'VER:infi']],
#  [('passer', 'dans', 'le', 'sang'), ['VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('passer', 'dans', 'le', 'sang', 'afin', 'de', 'produire'),
#   ['VER:infi', 'PRP', 'DET:ART', 'NOM', 'KON', 'PRP', 'VER:infi']],
#  [('sang', 'afin', 'de', 'produire'), ['NOM', 'KON', 'PRP', 'VER:infi']],
#  [('sang', 'afin', 'de', 'produire', 'les', 'mêmes', 'effets'),
#   ['NOM', 'KON', 'PRP', 'VER:infi', 'DET:ART', 'ADJ', 'NOM']],
#  [('produire', 'les', 'mêmes', 'effets'),
#   ['VER:infi', 'DET:ART', 'ADJ', 'NOM']],
#  [('produire', 'les', 'mêmes', 'effets', 'que', 'la', 'vrai'),
#   ['VER:infi', 'DET:ART', 'ADJ', 'NOM', 'KON', 'DET:ART', 'ADJ']],
#  [('produire', 'les', 'mêmes', 'effets', 'que', 'la', 'vrai', 'glande'),
#   ['VER:infi', 'DET:ART', 'ADJ', 'NOM', 'KON', 'DET:ART', 'ADJ', 'NOM']],
#  [('effets', 'que', 'la', 'vrai'), ['NOM', 'KON', 'DET:ART', 'ADJ']],
#  [('effets', 'que', 'la', 'vrai', 'glande'),
#   ['NOM', 'KON', 'DET:ART', 'ADJ', 'NOM']],
#  [('effets', 'que', 'la', 'vrai', 'glande', 'thyroïde'),
#   ['NOM', 'KON', 'DET:ART', 'ADJ', 'NOM', 'ADJ']],
#  [('effets', 'que', 'la', 'vrai', 'glande', 'thyroïde', "qu\\'on"),
#   ['NOM', 'KON', 'DET:ART', 'ADJ', 'NOM', 'ADJ', 'NOM']],
#  [('effets', 'que', 'la', 'vrai', 'glande', 'thyroïde', "qu\\'on", "m\\'a"),
#   ['NOM', 'KON', 'DET:ART', 'ADJ', 'NOM', 'ADJ', 'NOM', 'VER:simp']],
#  [('vrai', 'glande'), ['ADJ', 'NOM']],
#  [('vrai', 'glande', 'thyroïde'), ['ADJ', 'NOM', 'ADJ']],
#  [('vrai', 'glande', 'thyroïde', "qu\\'on"), ['ADJ', 'NOM', 'ADJ', 'NOM']],
#  [('vrai', 'glande', 'thyroïde', "qu\\'on", "m\\'a"),
#   ['ADJ', 'NOM', 'ADJ', 'NOM', 'VER:simp']],
#  [('vrai', 'glande', 'thyroïde', "qu\\'on", "m\\'a", "retirée.c\\'est"),
#   ['ADJ', 'NOM', 'ADJ', 'NOM', 'VER:simp', 'NOM']],
#  [('vrai',
#    'glande',
#    'thyroïde',
#    "qu\\'on",
#    "m\\'a",
#    "retirée.c\\'est",
#    'très',
#    'difficile'),
#   ['ADJ', 'NOM', 'ADJ', 'NOM', 'VER:simp', 'NOM', 'ADV', 'ADJ']],
#  [('glande', 'thyroïde'), ['NOM', 'ADJ']],
#  [('glande', 'thyroïde', "qu\\'on"), ['NOM', 'ADJ', 'NOM']],
#  [('glande', 'thyroïde', "qu\\'on", "m\\'a"),
#   ['NOM', 'ADJ', 'NOM', 'VER:simp']],
#  [('glande', 'thyroïde', "qu\\'on", "m\\'a", "retirée.c\\'est"),
#   ['NOM', 'ADJ', 'NOM', 'VER:simp', 'NOM']],
#  [('glande',
#    'thyroïde',
#    "qu\\'on",
#    "m\\'a",
#    "retirée.c\\'est",
#    'très',
#    'difficile'),
#   ['NOM', 'ADJ', 'NOM', 'VER:simp', 'NOM', 'ADV', 'ADJ']],
#  [('thyroïde', "qu\\'on"), ['ADJ', 'NOM']],
#  [('thyroïde', "qu\\'on", "m\\'a"), ['ADJ', 'NOM', 'VER:simp']],
#  [('thyroïde', "qu\\'on", "m\\'a", "retirée.c\\'est"),
#   ['ADJ', 'NOM', 'VER:simp', 'NOM']],
#  [('thyroïde', "qu\\'on", "m\\'a", "retirée.c\\'est", 'très', 'difficile'),
#   ['ADJ', 'NOM', 'VER:simp', 'NOM', 'ADV', 'ADJ']],
#  [('thyroïde',
#    "qu\\'on",
#    "m\\'a",
#    "retirée.c\\'est",
#    'très',
#    'difficile',
#    'a',
#    'doser'),
#   ['ADJ', 'NOM', 'VER:simp', 'NOM', 'ADV', 'ADJ', 'VER:pres', 'VER:infi']],
#  [("qu\\'on", "m\\'a"), ['NOM', 'VER:simp']],
#  [("qu\\'on", "m\\'a", "retirée.c\\'est"), ['NOM', 'VER:simp', 'NOM']],
#  [("qu\\'on", "m\\'a", "retirée.c\\'est", 'très', 'difficile'),
#   ['NOM', 'VER:simp', 'NOM', 'ADV', 'ADJ']],
#  [("qu\\'on", "m\\'a", "retirée.c\\'est", 'très', 'difficile', 'a', 'doser'),
#   ['NOM', 'VER:simp', 'NOM', 'ADV', 'ADJ', 'VER:pres', 'VER:infi']],
#  [("qu\\'on",
#    "m\\'a",
#    "retirée.c\\'est",
#    'très',
#    'difficile',
#    'a',
#    'doser',
#    'sachant'),
#   ['NOM',
#    'VER:simp',
#    'NOM',
#    'ADV',
#    'ADJ',
#    'VER:pres',
#    'VER:infi',
#    'VER:ppre']],
#  [("m\\'a", "retirée.c\\'est"), ['VER:simp', 'NOM']],
#  [("m\\'a", "retirée.c\\'est", 'très', 'difficile'),
#   ['VER:simp', 'NOM', 'ADV', 'ADJ']],
#  [("m\\'a", "retirée.c\\'est", 'très', 'difficile', 'a', 'doser'),
#   ['VER:simp', 'NOM', 'ADV', 'ADJ', 'VER:pres', 'VER:infi']],
#  [("m\\'a", "retirée.c\\'est", 'très', 'difficile', 'a', 'doser', 'sachant'),
#   ['VER:simp', 'NOM', 'ADV', 'ADJ', 'VER:pres', 'VER:infi', 'VER:ppre']],
#  [("retirée.c\\'est", 'très', 'difficile'), ['NOM', 'ADV', 'ADJ']],
#  [("retirée.c\\'est", 'très', 'difficile', 'a', 'doser'),
#   ['NOM', 'ADV', 'ADJ', 'VER:pres', 'VER:infi']],
#  [("retirée.c\\'est", 'très', 'difficile', 'a', 'doser', 'sachant'),
#   ['NOM', 'ADV', 'ADJ', 'VER:pres', 'VER:infi', 'VER:ppre']],
#  [('difficile', 'a', 'doser'), ['ADJ', 'VER:pres', 'VER:infi']],
#  [('difficile', 'a', 'doser', 'sachant'),
#   ['ADJ', 'VER:pres', 'VER:infi', 'VER:ppre']],
#  [('difficile', 'a', 'doser', 'sachant', 'que', 'nous', 'ne', 'réagissant'),
#   ['ADJ',
#    'VER:pres',
#    'VER:infi',
#    'VER:ppre',
#    'KON',
#    'PRO:PER',
#    'ADV',
#    'VER:ppre']],
#  [('doser', 'sachant'), ['VER:infi', 'VER:ppre']],
#  [('doser', 'sachant', 'que', 'nous', 'ne', 'réagissant'),
#   ['VER:infi', 'VER:ppre', 'KON', 'PRO:PER', 'ADV', 'VER:ppre']],
#  [('sachant', 'que', 'nous', 'ne', 'réagissant'),
#   ['VER:ppre', 'KON', 'PRO:PER', 'ADV', 'VER:ppre']],
#  [('réagissant', 'pas', 'toutes', 'de', 'la', 'même', 'faç'),
#   ['VER:ppre', 'ADV', 'PRO:IND', 'PRP', 'DET:ART', 'ADJ', 'NOM']],
#  [('allant', 'sur', 'le', 'site', '"', 'vivre'),
#   ['VER:ppre', 'PRP', 'DET:ART', 'NOM', 'PUN:cit', 'VER:infi']],
#  [('allant', 'sur', 'le', 'site', '"', 'vivre', 'sans', 'thyroïde'),
#   ['VER:ppre', 'PRP', 'DET:ART', 'NOM', 'PUN:cit', 'VER:infi', 'PRP', 'NOM']],
#  [('vivre', 'sans', 'thyroïde'), ['VER:infi', 'PRP', 'NOM']],
#  [('vivre', 'sans', 'thyroïde', '"', "j\\'ai"),
#   ['VER:infi', 'PRP', 'NOM', 'PUN:cit', 'VER:simp']],
#  [('vivre', 'sans', 'thyroïde', '"', "j\\'ai", 'appris'),
#   ['VER:infi', 'PRP', 'NOM', 'PUN:cit', 'VER:simp', 'VER:pper']],
#  [('vivre', 'sans', 'thyroïde', '"', "j\\'ai", 'appris', 'de', 'choses'),
#   ['VER:infi', 'PRP', 'NOM', 'PUN:cit', 'VER:simp', 'VER:pper', 'PRP', 'NOM']],
#  [('thyroïde', '"', "j\\'ai"), ['NOM', 'PUN:cit', 'VER:simp']],
#  [('thyroïde', '"', "j\\'ai", 'appris'),
#   ['NOM', 'PUN:cit', 'VER:simp', 'VER:pper']],
#  [('thyroïde', '"', "j\\'ai", 'appris', 'de', 'choses'),
#   ['NOM', 'PUN:cit', 'VER:simp', 'VER:pper', 'PRP', 'NOM']],
#  [('thyroïde', '"', "j\\'ai", 'appris', 'de', 'choses', 'intéressantes'),
#   ['NOM', 'PUN:cit', 'VER:simp', 'VER:pper', 'PRP', 'NOM', 'ADJ']],
#  [("j\\'ai", 'appris'), ['VER:simp', 'VER:pper']],
#  [("j\\'ai", 'appris', 'de', 'choses'),
#   ['VER:simp', 'VER:pper', 'PRP', 'NOM']],
#  [("j\\'ai", 'appris', 'de', 'choses', 'intéressantes'),
#   ['VER:simp', 'VER:pper', 'PRP', 'NOM', 'ADJ']],
#  [('appris', 'de', 'choses'), ['VER:pper', 'PRP', 'NOM']],
#  [('appris', 'de', 'choses', 'intéressantes'),
#   ['VER:pper', 'PRP', 'NOM', 'ADJ']],
#  [('choses', 'intéressantes'), ['NOM', 'ADJ']],
#  [('choses', 'intéressantes', 'de', 'la', 'part', 'des', 'membres'),
#   ['NOM', 'ADJ', 'PRP', 'DET:ART', 'NOM', 'PRP:det', 'NOM']],
#  [('intéressantes', 'de', 'la', 'part', 'des', 'membres'),
#   ['ADJ', 'PRP', 'DET:ART', 'NOM', 'PRP:det', 'NOM']],
#  [('membres', 'de', 'ce', 'groupe'), ['NOM', 'PRP', 'PRO:DEM', 'NOM']],
#  [('groupe', 'qui', 'ont', 'encore', 'ou', 'non', 'leur', 'thyroï'),
#   ['NOM', 'PRO:REL', 'VER:pres', 'ADV', 'KON', 'ADV', 'DET:POS', 'NOM']],
#  [("l\\'on", 'change'), ['NOM', 'VER:pres']],
#  [("l\\'on", 'change', 'de', 'dosage'), ['NOM', 'VER:pres', 'PRP', 'NOM']],
#  [("l\\'on", 'change', 'de', 'dosage', 'les', 'effets'),
#   ['NOM', 'VER:pres', 'PRP', 'NOM', 'DET:ART', 'NOM']],
#  [('change', 'de', 'dosage'), ['VER:pres', 'PRP', 'NOM']],
#  [('change', 'de', 'dosage', 'les', 'effets'),
#   ['VER:pres', 'PRP', 'NOM', 'DET:ART', 'NOM']],
#  [('dosage', 'les', 'effets'), ['NOM', 'DET:ART', 'NOM']],
#  [('dosage', 'les', 'effets', 'ne', 'se', 'font', 'sentir'),
#   ['NOM', 'DET:ART', 'NOM', 'ADV', 'PRO:PER', 'VER:pres', 'VER:infi']],
#  [('effets', 'ne', 'se', 'font', 'sentir'),
#   ['NOM', 'ADV', 'PRO:PER', 'VER:pres', 'VER:infi']],
#  [('semaines', 'plus', 'tard'), ['NOM', 'ADV', 'ADV']],
#  [('prenez', 'donc', 'votre', 'dosage'),
#   ['VER:pres', 'ADV', 'DET:POS', 'NOM']],
#  [('prenez', 'donc', 'votre', 'dosage', 'mais', 'vos', 'symptômes'),
#   ['VER:pres', 'ADV', 'DET:POS', 'NOM', 'KON', 'DET:POS', 'NOM']],
#  [('dosage', 'mais', 'vos', 'symptômes'), ['NOM', 'KON', 'DET:POS', 'NOM']],
#  [('dosage', 'mais', 'vos', 'symptômes', 'ne', 'diminuent'),
#   ['NOM', 'KON', 'DET:POS', 'NOM', 'ADV', 'VER:pres']],
# ...
#    'une',
#    'pharmacie',
#    'très',
#    'frequentée'),
#   ['VER:pres', 'VER:infi', 'VER:infi', 'PRP', 'DET:ART', 'NOM', 'ADV', 'ADJ']],
#  [('essayer', "d\\'aller"), ['VER:infi', 'VER:infi']],
#  [('essayer', "d\\'aller", 'dans', 'une', 'pharmacie'),
#   ['VER:infi', 'VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('essayer', "d\\'aller", 'dans', 'une', 'pharmacie', 'très', 'frequentée'),
#   ['VER:infi', 'VER:infi', 'PRP', 'DET:ART', 'NOM', 'ADV', 'ADJ']],
#  [("d\\'aller", 'dans', 'une', 'pharmacie'),
#   ['VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [("d\\'aller", 'dans', 'une', 'pharmacie', 'très', 'frequentée'),
#   ['VER:infi', 'PRP', 'DET:ART', 'NOM', 'ADV', 'ADJ']],
#  [('pharmacie', 'très', 'frequentée'), ['NOM', 'ADV', 'ADJ']],
#  [('chance', 'de', 'tomber'), ['NOM', 'PRP', 'VER:infi']],
#  [('chance', 'de', 'tomber', 'sur', 'le', 'vismed'),
#   ['NOM', 'PRP', 'VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('chance', 'de', 'tomber', 'sur', 'le', 'vismed', 'nouveau', 'flacon'),
#   ['NOM', 'PRP', 'VER:infi', 'PRP', 'DET:ART', 'NOM', 'ADJ', 'NOM']],
#  [('tomber', 'sur', 'le', 'vismed'), ['VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('tomber', 'sur', 'le', 'vismed', 'nouveau', 'flacon'),
#   ['VER:infi', 'PRP', 'DET:ART', 'NOM', 'ADJ', 'NOM']],
#  [('vismed', 'nouveau', 'flacon'), ['NOM', 'ADJ', 'NOM']],
#  [('demander', 'avant', "d\\'acheter"), ['VER:infi', 'PRP', 'NOM']],
#  [('demander', 'avant', "d\\'acheter", 'quel', 'est', 'leur', 'modele'),
#   ['VER:infi', 'PRP', 'NOM', 'PRO:REL', 'VER:pres', 'DET:POS', 'NOM']],
#  [("d\\'acheter", 'quel', 'est', 'leur', 'modele'),
#   ['NOM', 'PRO:REL', 'VER:pres', 'DET:POS', 'NOM']],
#  [("d\\'acheter", 'quel', 'est', 'leur', 'modele', 'de', 'flaconparceque'),
#   ['NOM', 'PRO:REL', 'VER:pres', 'DET:POS', 'NOM', 'PRP', 'NOM']],
#  [('modele', 'de', 'flaconparceque'), ['NOM', 'PRP', 'NOM']],
#  [('flacon', 'sans', 'ordo'), ['NOM', 'PRP', 'NOM']],
#  [('flacon', 'sans', 'ordo', "c\\'est"), ['NOM', 'PRP', 'NOM', 'NOM']],
#  [('ordo', "c\\'est"), ['NOM', 'NOM']],
#  [('vismed', 'unidose'), ['NOM', 'ADJ']],
#  [('vismed', 'unidose', "c\\'est"), ['NOM', 'ADJ', 'NOM']],
#  [('vismed', 'unidose', "c\\'est", 'pareil'), ['NOM', 'ADJ', 'NOM', 'ADJ']],
#  [('unidose', "c\\'est"), ['ADJ', 'NOM']],
#  [('unidose', "c\\'est", 'pareil'), ['ADJ', 'NOM', 'ADJ']],
#  [("c\\'est", 'pareil'), ['NOM', 'ADJ']],
#  [('remboursé', 'ou', 'tres', 'mal'), ['VER:pper', 'KON', 'VER:subi', 'ADV']],
#  [('ulcère', 'cornéen'), ['NOM', 'ADJ']],
#  [('appel', 'vos', 'gouttes'), ['NOM', 'DET:POS', 'NOM']],
#  [('appel', 'vos', 'gouttes', 'à', 'la', 'vitamine'),
#   ['NOM', 'DET:POS', 'NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('appel', 'vos', 'gouttes', 'à', 'la', 'vitamine', 'a', 'svp'),
#   ['NOM', 'DET:POS', 'NOM', 'PRP', 'DET:ART', 'NOM', 'VER:pres', 'NOM']],
#  [('gouttes', 'à', 'la', 'vitamine'), ['NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('gouttes', 'à', 'la', 'vitamine', 'a', 'svp'),
#   ['NOM', 'PRP', 'DET:ART', 'NOM', 'VER:pres', 'NOM']],
#  [('vitamine', 'a', 'svp'), ['NOM', 'VER:pres', 'NOM']],
#  [('remboursé', 'par', 'la', 'sécu'), ['VER:pper', 'PRP', 'DET:ART', 'NOM']],
#  [('pomede', 'dulcis'), ['ADJ', 'NOM']],
#  [('pomede', 'dulcis', 'à', 'la', 'vitamine'),
#   ['ADJ', 'NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('dulcis', 'à', 'la', 'vitamine'), ['NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('savais', 'pas', 'que', 'ca', 'existé'),
#   ['VER:impf', 'ADV', 'KON', 'VER:simp', 'VER:pper']],
#  [('savais', 'pas', 'que', 'ca', 'existé', 'en', 'goutteje'),
#   ['VER:impf', 'ADV', 'KON', 'VER:simp', 'VER:pper', 'PRP', 'NOM']],
#  [('savais', 'pas', 'que', 'ca', 'existé', 'en', 'goutteje', 'souffre'),
#   ['VER:impf',
#    'ADV',
#    'KON',
#    'VER:simp',
#    'VER:pper',
#    'PRP',
#    'NOM',
#    'VER:pres']],
#  [('existé', 'en', 'goutteje'), ['VER:pper', 'PRP', 'NOM']],
#  [('existé', 'en', 'goutteje', 'souffre'),
#   ['VER:pper', 'PRP', 'NOM', 'VER:pres']],
#  [('existé', 'en', 'goutteje', 'souffre', 'moi', 'aussi', 'mes', 'yeux'),
#   ['VER:pper', 'PRP', 'NOM', 'VER:pres', 'PRO:PER', 'ADV', 'DET:POS', 'NOM']],
#  [('goutteje', 'souffre'), ['NOM', 'VER:pres']],
#  [('goutteje', 'souffre', 'moi', 'aussi', 'mes', 'yeux'),
#   ['NOM', 'VER:pres', 'PRO:PER', 'ADV', 'DET:POS', 'NOM']],
#  [('goutteje', 'souffre', 'moi', 'aussi', 'mes', 'yeux', 'sont', 'irrité'),
#   ['NOM',
#    'VER:pres',
#    'PRO:PER',
#    'ADV',
#    'DET:POS',
#    'NOM',
#    'VER:pres',
#    'VER:pper']],
#  [('souffre', 'moi', 'aussi', 'mes', 'yeux'),
#   ['VER:pres', 'PRO:PER', 'ADV', 'DET:POS', 'NOM']],
#  [('souffre', 'moi', 'aussi', 'mes', 'yeux', 'sont', 'irrité'),
#   ['VER:pres', 'PRO:PER', 'ADV', 'DET:POS', 'NOM', 'VER:pres', 'VER:pper']],
#  [('yeux', 'sont', 'irrité'), ['NOM', 'VER:pres', 'VER:pper']],
#  [('yeux', 'sont', 'irrité', 'et', 'me', 'generaliste'),
#   ['NOM', 'VER:pres', 'VER:pper', 'KON', 'PRO:PER', 'NOM']],
#  [('yeux', 'sont', 'irrité', 'et', 'me', 'generaliste', 'ne', 'veut'),
#   ['NOM', 'VER:pres', 'VER:pper', 'KON', 'PRO:PER', 'NOM', 'ADV', 'VER:pres']],
#  [('irrité', 'et', 'me', 'generaliste'),
#   ['VER:pper', 'KON', 'PRO:PER', 'NOM']],
#  [('irrité', 'et', 'me', 'generaliste', 'ne', 'veut'),
#   ['VER:pper', 'KON', 'PRO:PER', 'NOM', 'ADV', 'VER:pres']],
#  [('generaliste', 'ne', 'veut'), ['NOM', 'ADV', 'VER:pres']],
#  [('generaliste', 'ne', 'veut', 'pas', "m'", 'envoyer'),
#   ['NOM', 'ADV', 'VER:pres', 'ADV', 'PRO:PER', 'VER:infi']],
#  [('veut', 'pas', "m'", 'envoyer'),
#   ['VER:pres', 'ADV', 'PRO:PER', 'VER:infi']],
#  [('veut', 'pas', "m'", 'envoyer', 'chez', 'un', 'bon', 'opthalmo'),
#   ['VER:pres', 'ADV', 'PRO:PER', 'VER:infi', 'PRP', 'DET:ART', 'ADJ', 'NOM']],
#  [('envoyer', 'chez', 'un', 'bon', 'opthalmo'),
#   ['VER:infi', 'PRP', 'DET:ART', 'ADJ', 'NOM']],
#  [('aller', 'consulter', 'à', "l'", 'hopital'),
#   ['VER:infi', 'VER:infi', 'PRP', 'DET:ART', 'NOM']],
#  [('allé', 'en', 'aout'), ['VER:pper', 'PRP', 'NOM']],
#  [('allé', 'en', 'aout', 'dernier', 'et', 'je', 'suis', 'tombé'),
#   ['VER:pper', 'PRP', 'NOM', 'ADJ', 'KON', 'PRO:PER', 'VER:pres', 'VER:pper']],
#  [('aout', 'dernier', 'et', 'je', 'suis', 'tombé'),
#   ['NOM', 'ADJ', 'KON', 'PRO:PER', 'VER:pres', 'VER:pper']],
#  [('tombé', 'sur', 'des', 'étudients'), ['VER:pper', 'PRP', 'PRP:det', 'ADJ']],
#  [('sûrs', "qu'"), ['ADJ', 'KON']],
#  [('sûrs', "qu'", 'ils', 'ai', 'etaient'),
#   ['ADJ', 'KON', 'PRO:PER', 'VER:pres', 'NOM']],
#  [('sûrs', "qu'", 'ils', 'ai', 'etaient', 'compétants'),
#   ['ADJ', 'KON', 'PRO:PER', 'VER:pres', 'NOM', 'ADJ']],
#  [("qu'", 'ils', 'ai', 'etaient'), ['KON', 'PRO:PER', 'VER:pres', 'NOM']],
#  [("qu'", 'ils', 'ai', 'etaient', 'compétants'),
#   ['KON', 'PRO:PER', 'VER:pres', 'NOM', 'ADJ']],
#  [('etaient', 'compétants'), ['NOM', 'ADJ']],
#  [('bref', 'je', 'suis', 'dépitée'),
#   ['ADV', 'PRO:PER', 'VER:pres', 'VER:pper']],
#  [('clous', 'je', "n'", 'ose'), ['NOM', 'PRO:PER', 'ADV', 'VER:pres']],
#  [('clous', 'je', "n'", 'ose', 'pas', "m'", 'y', 'avanturer'),
#   ['NOM',
#    'PRO:PER',
#    'ADV',
#    'VER:pres',
#    'ADV',
#    'PRO:PER',
#    'PRO:PER',
#    'VER:infi']],
#  [('ose', 'pas', "m'", 'y', 'avanturer'),
#   ['VER:pres', 'ADV', 'PRO:PER', 'PRO:PER', 'VER:infi']],
#  [('effrais', 'un', 'peu', 'peu', 'trop', "j'", 'avoue'),
#   ['VER:cond', 'DET:ART', 'ADV', 'ADV', 'ADV', 'PRO:PER', 'VER:pres']],
#  [('ophtalmo', "m'", 'avait', 'prescrit'),
#   ['NOM', 'PRO:PER', 'VER:impf', 'VER:pper']],
#  [('ophtalmo', "m'", 'avait', 'prescrit', 'du', 'lacrifluid'),
#   ['NOM', 'PRO:PER', 'VER:impf', 'VER:pper', 'PRP:det', 'NOM']],
#  [('prescrit', 'du', 'lacrifluid'), ['VER:pper', 'PRP:det', 'NOM']],
#  [('prescrit', 'du', 'lacrifluid', 'pour', 'ma', 'sécheresse'),
#   ['VER:pper', 'PRP:det', 'NOM', 'PRP', 'DET:POS', 'NOM']],
#  [('prescrit', 'du', 'lacrifluid', 'pour', 'ma', 'sécheresse', 'oculaire'),
#   ['VER:pper', 'PRP:det', 'NOM', 'PRP', 'DET:POS', 'NOM', 'ADJ']],
#  [('lacrifluid', 'pour', 'ma', 'sécheresse'),
#   ['NOM', 'PRP', 'DET:POS', 'NOM']],
#  [('lacrifluid', 'pour', 'ma', 'sécheresse', 'oculaire'),
#   ['NOM', 'PRP', 'DET:POS', 'NOM', 'ADJ']],
#  [('sécheresse', 'oculaire'), ['NOM', 'ADJ']],
#  [('piquait', 'quand', 'je', 'les', 'mettais'),
#   ['VER:impf', 'KON', 'PRO:PER', 'PRO:PER', 'VER:impf']],
#  [('yeux', 'encore', 'plus', 'rouges'), ['NOM', 'ADV', 'ADV', 'ADJ']],
#  [('yeux', 'encore', 'plus', 'rouges', 'et', "j'", 'ai', 'vraiment'),
#   ['NOM', 'ADV', 'ADV', 'ADJ', 'KON', 'PRO:PER', 'VER:pres', 'ADV']],
#  [('rouges', 'et', "j'", 'ai', 'vraiment'),
#   ['ADJ', 'KON', 'PRO:PER', 'VER:pres', 'ADV']],
#  [('rouges', 'et', "j'", 'ai', 'vraiment', 'eu', 'la', 'sensation'),
#   ['ADJ', 'KON', 'PRO:PER', 'VER:pres', 'ADV', 'VER:pper', 'DET:ART', 'NOM']],
#  [('vraiment', 'eu', 'la', 'sensation'),
#   ['ADV', 'VER:pper', 'DET:ART', 'NOM']],
#  [('vraiment', 'eu', 'la', 'sensation', 'que', 'la', 'sécheresse'),
#   ['ADV', 'VER:pper', 'DET:ART', 'NOM', 'KON', 'DET:ART', 'NOM']],
#  [('vraiment',
#    'eu',
#    'la',
#    'sensation',
#    'que',
#    'la',
#    'sécheresse',
#    'augmentait'),
#   ['ADV', 'VER:pper', 'DET:ART', 'NOM', 'KON', 'DET:ART', 'NOM', 'VER:impf']],
#  [('sensation', 'que', 'la', 'sécheresse'), ['NOM', 'KON', 'DET:ART', 'NOM']],
#  [('sensation', 'que', 'la', 'sécheresse', 'augmentait'),
#   ['NOM', 'KON', 'DET:ART', 'NOM', 'VER:impf']],
#  [('sensation', 'que', 'la', 'sécheresse', 'augmentait', 'au', 'lieu'),
#   ['NOM', 'KON', 'DET:ART', 'NOM', 'VER:impf', 'PRP:det', 'NOM']],
#  [('sécheresse', 'augmentait'), ['NOM', 'VER:impf']],
#  [('sécheresse', 'augmentait', 'au', 'lieu'),
#   ['NOM', 'VER:impf', 'PRP:det', 'NOM']],
#  [('sécheresse', 'augmentait', 'au', 'lieu', 'de', 'diminuer'),
#   ['NOM', 'VER:impf', 'PRP:det', 'NOM', 'PRP', 'VER:infi']],
#  [('augmentait', 'au', 'lieu'), ['VER:impf', 'PRP:det', 'NOM']],
#  [('augmentait', 'au', 'lieu', 'de', 'diminuer'),
#   ['VER:impf', 'PRP:det', 'NOM', 'PRP', 'VER:infi']],
#  [('lieu', 'de', 'diminuer'), ['NOM', 'PRP', 'VER:infi']],
#  [('coup', "j'", 'ai', 'acheté'), ['NOM', 'PRO:PER', 'VER:pres', 'VER:pper']],
#  [('coup', "j'", 'ai', 'acheté', 'en', 'pharmacie'),
#   ['NOM', 'PRO:PER', 'VER:pres', 'VER:pper', 'PRP', 'NOM']],
#  [('acheté', 'en', 'pharmacie'), ['VER:pper', 'PRP', 'NOM']],
#  [('acheté', 'en', 'pharmacie', 'un', 'autre', 'produit'),
#   ['VER:pper', 'PRP', 'NOM', 'DET:ART', 'ADJ', 'NOM']],
#  [('pharmacie', 'un', 'autre', 'produit'), ['NOM', 'DET:ART', 'ADJ', 'NOM']],
#  [('pharmacie', 'un', 'autre', 'produit', '(', 'refresh', ')'),
#   ['NOM', 'DET:ART', 'ADJ', 'NOM', 'PUN', 'NOM', 'PUN']],
#  [('produit', '(', 'refresh', ')'), ['NOM', 'PUN', 'NOM', 'PUN']],
#  [('(', 'refresh', ')'), ['PUN', 'NOM', 'PUN']],
#  [('mets', 'plusieurs', 'fois', 'par', 'jours'),
#   ['VER:pres', 'PRO:IND', 'NOM', 'PRP', 'NOM']],
#  [('sais', 'pas', 'si', 'ça', 'améliore'),
#   ['VER:pres', 'ADV', 'KON', 'PRO:DEM', 'VER:pres']],
#  [('sais', 'pas', 'si', 'ça', 'améliore', 'la', 'sécheresse'),
#   ['VER:pres', 'ADV', 'KON', 'PRO:DEM', 'VER:pres', 'DET:ART', 'NOM']],
#  [('améliore', 'la', 'sécheresse'), ['VER:pres', 'DET:ART', 'NOM']],
#  [('sécheresse', 'mais', 'au', 'moins', 'ça', 'ne', 'me', 'pique'),
#   ['NOM', 'KON', 'PRP:det', 'ADV', 'PRO:DEM', 'ADV', 'PRO:PER', 'VER:pres']],
#  [('essayer', 'les', 'goutes'), ['VER:infi', 'DET:ART', 'NOM']],
#  [('essayer', 'les', 'goutes', 'aquarest'),
#   ['VER:infi', 'DET:ART', 'NOM', 'ADJ']],
#  [('goutes', 'aquarest'), ['NOM', 'ADJ']],
#  [('mal', 'hydratantes'), ['ADV', 'ADJ']],
#  [('mal', 'hydratantes', 'et', 'ne', 'pique'),
#   ['ADV', 'ADJ', 'KON', 'ADV', 'VER:pres']],
#  [('mal', 'hydratantes', 'et', 'ne', 'pique', 'pas', 'les', 'yeux'),
#   ['ADV', 'ADJ', 'KON', 'ADV', 'VER:pres', 'ADV', 'DET:ART', 'NOM']],
#  [('hydratantes', 'et', 'ne', 'pique'), ['ADJ', 'KON', 'ADV', 'VER:pres']],
#  [('hydratantes', 'et', 'ne', 'pique', 'pas', 'les', 'yeux'),
#   ['ADJ', 'KON', 'ADV', 'VER:pres', 'ADV', 'DET:ART', 'NOM']],
#  [('pique', 'pas', 'les', 'yeux'), ['VER:pres', 'ADV', 'DET:ART', 'NOM']],
#  [('acheter', 'des', 'larmes'), ['VER:infi', 'PRP:det', 'NOM']],
#  [('acheter', 'des', 'larmes', 'artificielles'),
#   ['VER:infi', 'PRP:det', 'NOM', 'ADJ']],
#  [('acheter', 'des', 'larmes', 'artificielles', 'en', 'pharmacie'),
#   ['VER:infi', 'PRP:det', 'NOM', 'ADJ', 'PRP', 'NOM']],
#  [('larmes', 'artificielles'), ['NOM', 'ADJ']],
#  [('larmes', 'artificielles', 'en', 'pharmacie'),
#   ['NOM', 'ADJ', 'PRP', 'NOM']],
#  [('artificielles', 'en', 'pharmacie'), ['ADJ', 'PRP', 'NOM']],
#  [('durée', 'indiquée'), ['NOM', 'VER:pper']],
#  [('durée', 'indiquée', 'après', 'tu', 'devrais'),
#   ['NOM', 'VER:pper', 'PRP', 'PRO:PER', 'VER:cond']],
#  [('indiquée', 'après', 'tu', 'devrais'),
#   ['VER:pper', 'PRP', 'PRO:PER', 'VER:cond']],
#  [('indiquée', 'après', 'tu', 'devrais', 'plus', 'avoir', 'de', 'souçis'),
#   ['VER:pper', 'PRP', 'PRO:PER', 'VER:cond', 'ADV', 'VER:infi', 'PRP', 'NOM']],
#  [('devrais', 'plus', 'avoir', 'de', 'souçis'),
#   ['VER:cond', 'ADV', 'VER:infi', 'PRP', 'NOM']],
#  [('monde', 'sur', 'ce', 'forum'), ['NOM', 'PRP', 'PRO:DEM', 'NOM']],
#  [('monde', 'sur', 'ce', 'forum', 'mais', 'je', 'viens'),
#   ['NOM', 'PRP', 'PRO:DEM', 'NOM', 'KON', 'PRO:PER', 'VER:pres']],
#  [('monde', 'sur', 'ce', 'forum', 'mais', 'je', 'viens', 'parmis'),
#   ['NOM', 'PRP', 'PRO:DEM', 'NOM', 'KON', 'PRO:PER', 'VER:pres', 'NOM']],
#  [('forum', 'mais', 'je', 'viens'), ['NOM', 'KON', 'PRO:PER', 'VER:pres']],
#  [('forum', 'mais', 'je', 'viens', 'parmis'),
#   ['NOM', 'KON', 'PRO:PER', 'VER:pres', 'NOM']],
#  [('viens', 'parmis'), ['VER:pres', 'NOM']],
#  [('viens', 'parmis', 'vous', 'pour', 'rechercher', 'des', 'conseils'),
#   ['VER:pres', 'NOM', 'PRO:PER', 'PRP', 'VER:infi', 'PRP:det', 'NOM']],
#  [('parmis', 'vous', 'pour', 'rechercher', 'des', 'conseils'),
#   ['NOM', 'PRO:PER', 'PRP', 'VER:infi', 'PRP:det', 'NOM']],
#  [('conseils', 'et', 'me', 'rassurer'), ['NOM', 'KON', 'PRO:PER', 'VER:infi']],
#  [('commencé', 'après', 'une', 'rhinopharyngite'),
#   ['VER:pper', 'PRP', 'DET:ART', 'NOM']],
#  [('commencé', 'a', 'avoir', "l'", 'interieur'),
#   ['VER:pper', 'VER:pres', 'VER:infi', 'DET:ART', 'NOM']],
#  [('commencé', 'a', 'avoir', "l'", 'interieur', 'de', 'la', 'paupiere'),
#   ['VER:pper',
#    'VER:pres',
#    'VER:infi',
#    'DET:ART',
#    'NOM',
#    'PRP',
#    'DET:ART',
#    'NOM']],
#  [('interieur', 'de', 'la', 'paupiere'), ['NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('interieur', 'de', 'la', 'paupiere', 'inferieure'),
#   ['NOM', 'PRP', 'DET:ART', 'NOM', 'ADJ']],
#  [('interieur', 'de', 'la', 'paupiere', 'inferieure', 'rouge'),
#   ['NOM', 'PRP', 'DET:ART', 'NOM', 'ADJ', 'ADJ']],
#  [('paupiere', 'inferieure'), ['NOM', 'ADJ']],
#  [('paupiere', 'inferieure', 'rouge'), ['NOM', 'ADJ', 'ADJ']],
#  [('paupiere', 'inferieure', 'rouge', 'ainsi', 'que', 'le', 'coin'),
#   ['NOM', 'ADJ', 'ADJ', 'KON', 'KON', 'DET:ART', 'NOM']],
#  [('inferieure', 'rouge'), ['ADJ', 'ADJ']],
#  [('inferieure', 'rouge', 'ainsi', 'que', 'le', 'coin'),
#   ['ADJ', 'ADJ', 'KON', 'KON', 'DET:ART', 'NOM']],
#  [('rouge', 'ainsi', 'que', 'le', 'coin'),
#   ['ADJ', 'KON', 'KON', 'DET:ART', 'NOM']],
#  [('rouge', 'ainsi', 'que', 'le', 'coin', 'de', "l'", 'oeil'),
#   ['ADJ', 'KON', 'KON', 'DET:ART', 'NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('coin', 'de', "l'", 'oeil'), ['NOM', 'PRP', 'DET:ART', 'NOM']],
#  [('pensant', 'a', 'une', 'conjonctivite'),
#   ['VER:ppre', 'VER:pres', 'DET:ART', 'NOM']],
#  [('pensant', 'a', 'une', 'conjonctivite', 'je', 'suis', 'allée'),
#   ['VER:ppre',
#    'VER:pres',
#    'DET:ART',
#    'NOM',
#    'PRO:PER',
#    'VER:pres',
#    'VER:pper']],
#  [('conjonctivite', 'je', 'suis', 'allée'),
#   ['NOM', 'PRO:PER', 'VER:pres', 'VER:pper']],
#  [('conjonctivite', 'je', 'suis', 'allée', 'chez', 'le', 'medecin'),
#   ['NOM', 'PRO:PER', 'VER:pres', 'VER:pper', 'PRP', 'DET:ART', 'NOM']],
#  [('allée', 'chez', 'le', 'medecin'), ['VER:pper', 'PRP', 'DET:ART', 'NOM']],
#  [('allée', 'chez', 'le', 'medecin', 'qui', 'ma', 'donné'),
#   ['VER:pper', 'PRP', 'DET:ART', 'NOM', 'PRO:REL', 'DET:POS', 'NOM']],
#  [('medecin', 'qui', 'ma', 'donné'), ['NOM', 'PRO:REL', 'DET:POS', 'NOM']],
#  [('medecin', 'qui', 'ma', 'donné', 'des', 'antibios'),
#   ['NOM', 'PRO:REL', 'DET:POS', 'NOM', 'PRP:det', 'NOM']],
#  [('donné', 'des', 'antibios'), ['NOM', 'PRP:det', 'NOM']],
#  [('paupiere', 'étant', 'de', 'plus', 'en', 'plus', 'rouge'),
#   ['NOM', 'VER:ppre', 'PRP', 'ADV', 'PRP', 'ADV', 'ADJ']],
#  [('rouge', "j'", 'ai', 'decidé'), ['ADJ', 'PRO:PER', 'VER:pres', 'VER:pper']],
#  ...]

# %%
phrases = [[term[0], " ".join(term[1])] for term in phrases]

# %%
for phrase in phrases:
    phrase.append(frequencies[tuple(phrase[0])])

# %% [markdown]
# ### **Filtrage (Patrons syntaxiques)**
# Lossio-Ventura, J. A., Jonquet, C., Roche, M., & Teisseire, M. (2014). *Biomedical Terminology Extraction : A new combination of Statistical and Web Mining Approaches*. 421. https://hal-lirmm.ccsd.cnrs.fr/lirmm-01056598
#
# On veut aller extraire les structures syntaxiques les plus courantes dans les MeSH pour filtrer notre corpus selon celles-ci (inspiré de la méthodologie de l'article ci-dessus ; voir le Notebook *Mesh_extract.ipynb*). Pour ce faire, nous allons donc ne sélectionner que les ngrammes qui y correspondent.

# %%
file_patterns = '../02-filtrage/MeSH/mesh_patterns-fr.csv'

with open (file_patterns, 'r') as f:
    patterns = pd.read_csv(f)
    patterns = patterns['Structure'].tolist() # Pour prendre les structures syntaxiques attestées dans les MeSH

# %%
def filter_patterns(phrases):
    return [t for t in phrases if t[1] in patterns and not 'NUM' in t[1]] # and not 'NOM NOM' in t[1]

# %%
terms = filter_patterns(phrases)

# %%
print("Le filtrage syntaxique élimine environ {} % des termes".format(round((len(phrases) - len(terms)) / len(phrases) * 100)))
print("On avait {} ngrammes, ".format(len(phrases)) + "on en a maintenant {}.".format(len(terms)))
# Out:
# Le filtrage syntaxique élimine environ 72 % des termes
# On avait 3128573 ngrammes, on en a maintenant 865578.

# %%
for phrase in terms:
    phrase[0] = tuple(phrase[0])


terms_patterns = pd.DataFrame(terms, columns = ["Expression", "Structure syntaxique", "Fréquence"])
terms_patterns = terms_patterns.to_dict('records')
dict_patterns = {}
for term in terms_patterns:
     exp = term['Expression']
     pattern = term['Structure syntaxique']
     dict_patterns[exp] = pattern

# %%
terms_patterns = [t for t in terms_patterns if t['Fréquence'] > 2]
for x in terms_patterns :
    x['Expression'] = " ".join(x['Expression']).replace("' ", "'").replace("( ", "(").replace(" )", ")").replace(' -', '-')

# %% [markdown]
# ### **Extraction de termes MeSH**

# %%
df = pd.DataFrame(terms_patterns).drop_duplicates

# %%
df['isMeSHTerm']= False # On set à False puis on va changer pour True si on trouve le terme
df['MeSHID'] = None
df['MesH_prefLabel_fr'] = None
df['MesH_prefLabel_en'] = None

# %%
from nltk.tokenize import MWETokenizer
file_path = '../02-filtrage/MeSH/mesh-fr.txt'

with open (file_path, 'r', encoding='utf-8') as f:
    mesh = [tuple(tokenizer_re.tokenize(w)) for w in f.readlines()]
    tokenizer_mesh = MWETokenizer(mesh, separator= ' ')
    mesh = [tokenizer_mesh.tokenize(w)[0].lower() for w in mesh]
    mesh = [w for w in mesh if len(w.split()) > 1] # On ne retient que les termes complexes
    #mesh = [tuple(t.strip('.').lower().split()) for t in f.readlines()]

# %%
df
# Out:
#                    Expression  Structure syntaxique  Fréquence  isMeSHTerm  \
# 0                   temps qu'           NOM PRO:REL         83       False
# 1          liste de naissance           NOM PRP NOM         26       False
# 2          liste de naissance           NOM PRP NOM         26       False
# 3            également acheté          ADV VER:pper          7       False
# 4                 attend tjrs          VER:pres NOM          3       False
# ...                       ...                   ...        ...         ...
# 202043      vinaigre de cidre           NOM PRP NOM         34       False
# 202044  prendre un traitement  VER:infi DET:ART NOM         28       False
# 202045         bonne érection               ADJ NOM          3       False
# 202046       quasi impossible               ADV ADJ         15       False
# 202047            belle femme               ADJ NOM          5       False
#
#        MeSHID MesH_prefLabel_fr MesH_prefLabel_en
# 0        None              None              None
# 1        None              None              None
# 2        None              None              None
# 3        None              None              None
# 4        None              None              None
# ...       ...               ...               ...
# 202043   None              None              None
# 202044   None              None              None
# 202045   None              None              None
# 202046   None              None              None
# 202047   None              None              None
#
# [202048 rows x 7 columns]

# %%
list_terms = df['Expression'].tolist()
extr_mesh = tokenizer_mesh.tokenize(list_terms)

# %%
for t in extr_mesh:
    if t in mesh:
        df.loc[df['Expression'] == t, 'isMeSHTerm'] = True

df = df.drop_duplicates(subset = "Expression")
df
# Out:
#                   Expression  Structure syntaxique  Fréquence  isMeSHTerm  \
# 0                  temps qu'           NOM PRO:REL         83       False
# 1         liste de naissance           NOM PRP NOM         26       False
# 3           également acheté          ADV VER:pper          7       False
# 4                attend tjrs          VER:pres NOM          3       False
# 5       permis de construire      NOM PRP VER:infi          4       False
# ...                      ...                   ...        ...         ...
# 201464      alcaline ionisée          ADJ VER:pper          3       False
# 201560     droits de l'homme   NOM PRP DET:ART NOM          4       False
# 201568         nations unies               NOM ADJ          4        True
# 201741   promenade privative               NOM ADJ          3       False
# 201876      super les filles  VER:infi DET:ART NOM          9       False
#
#        MeSHID MesH_prefLabel_fr MesH_prefLabel_en
# 0        None              None              None
# 1        None              None              None
# 3        None              None              None
# 4        None              None              None
# 5        None              None              None
# ...       ...               ...               ...
# 201464   None              None              None
# 201560   None              None              None
# 201568   None              None              None
# 201741   None              None              None
# 201876   None              None              None
#
# [27736 rows x 7 columns]

# %%
# Termes MeSH présents dans notre corpus 
df[df['isMeSHTerm'] == True]
# Out:
#                         Expression Structure syntaxique  Fréquence  \
# 7                    fausse couche              ADJ NOM        474
# 12                      grand mère              ADJ NOM         82
# 22                    point de vue          NOM PRP NOM        187
# 57                  ulcère cornéen              NOM ADJ          4
# 61            larmes artificielles              NOM ADJ         18
# ...                            ...                  ...        ...
# 189566            candida glabrata         NOM VER:simp          6
# 190285  syndrome des ongles jaunes  NOM PRP:det NOM ADJ          6
# 192198            marqueur tumoral              NOM ADJ          3
# 193558    carence en acide folique      NOM PRP NOM ADJ          3
# 201568               nations unies              NOM ADJ          4
#
#         isMeSHTerm MeSHID MesH_prefLabel_fr MesH_prefLabel_en
# 7             True   None              None              None
# 12            True   None              None              None
# 22            True   None              None              None
# 57            True   None              None              None
# 61            True   None              None              None
# ...            ...    ...               ...               ...
# 189566        True   None              None              None
# 190285        True   None              None              None
# 192198        True   None              None              None
# 193558        True   None              None              None
# 201568        True   None              None              None
#
# [946 rows x 7 columns]

# %% [markdown]
# ### **Extraction de termes existant dans la taxonomie**

# %%
df['isTaxoTerm']= 'False' # On set à False puis on va changer pour True si on trouve le terme
# Out:
# /var/folders/99/r0skp4wd6dx1rrw6kjr2nmz00000gq/T/ipykernel_16078/2422679389.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['isTaxoTerm']= 'False' # On set à False puis on va changer pour True si on trouve le terme

# %%
file_path = '../02-filtrage/default_taxo_labels.csv'

default = pd.read_csv(file_path)
taxo_terms = list(dict.fromkeys([str(t).strip().lower() for t in default['label'].tolist()]))

taxo_terms
# Out:
# ['neurochirurgie stereotaxique et fonctionnelle',
#  'stereotactic and functional neurosurgery',
#  'neurosurgery',
#  'neurochirurgie',
#  'deep brain stimulation',
#  'stimulation cérébrale profonde',
#  'poly polymerase inhibitors',
#  'other antineoplastic agents',
#  'lifestylemodifications',
#  'familymedicineinterventions',
#  'healthpromotionprevention',
#  'psychologicalbehavioralti',
#  'alliedhealthfacility',
#  'établissement de soins ambulatoires',
#  'ambulatorycaremedicalfacility',
#  'ambulatory care facility',
#  'medicalfacilitytype',
#  'languagecognitionfacility',
#  'prostesisorthesisfacility',
#  'earauditionfacility',
#  'nutritiondietfacility',
#  'eyevisionfacility',
#  'mobilitymusculoskeletalfacility',
#  'garderie',
#  'nursery',
#  'parietal lobe',
#  'lobe pariétal',
#  'cortex cérébral',
#  'cerebral cortex',
#  'cognitive dissonance',
#  'dissonance cognitive',
#  'cognition',
#  'manometry',
#  'manométrie',
#  'digestivefonctiontests',
#  'manométrie anorectale',
#  'anorectal manometry',
#  'esophageal manometry',
#  'manométrie oesophagienne',
#  'barostat',
#  'arm',
#  'bras',
#  'membre supérieur',
#  'upper extremity',
#  'upper limb',
#  'aisselle',
#  'armpit',
#  'coude',
#  'elbow',
#  'avant-bras',
#  'forearm',
#  'arminjury',
#  'traumatisme du bras',
#  'arm injury',
#  'lymphoedème après cancer du sein',
#  'breast cancer lymphedema',
#  'programme de prévention',
#  'prevention program',
#  'intervention de prévention',
#  'preventive measure',
#  'volonteeringresources',
#  'volonteeringcentres',
#  'centre de bénévolat',
#  "centre d'action bénévole",
#  'volonteer center',
#  'système digestif',
#  'digestive system',
#  'digestive tract',
#  'tube digestif',
#  'digestive secretions',
#  'sécrétions digestives',
#  'pancreas',
#  'pancréas',
#  'liver',
#  'foie',
#  'biliary tract',
#  'voies biliaires',
#  'rectum',
#  'denture',
#  'dentition',
#  'digestivesignssymptoms',
#  'digestive sign',
#  'sémiologie digestive',
#  'chirurgiedigestivesi',
#  'digestivesystemsi',
#  'procédure de chirurgie digestive',
#  'digestive system surgical procedure',
#  'digestiveostomies',
#  'digestiveabdominalimaging',
#  'digestivesystemendoscopies',
#  'nutrition',
#  'digestive biopsy',
#  'biopsie digestive',
#  'gastroentérologie',
#  'gastroenterology',
#  'gastro-entérologie',
#  'child–parent psychotherapy',
#  "thérapie d'interaction parent-enfant",
#  'child-parent psychotherapy',
#  "thérapie de l'attachement",
#  'attachment-based therapy',
#  'child',
#  'enfant',
#  'adolescent',
#  'infancy',
#  'enterovirus',
#  'picornaviridae',
#  'entérovirus humain c',
#  'human enterovirus c',
#  'enterovirus infection',
#  'infection à entérovirus',
#  'granulome inguinal',
#  'granuloma inguinale',
#  'bacterialsti',
#  'genitalsymptomaticstds',
#  'enfant prématuré',
#  'premature infant',
#  'jeunesse',
#  'youth',
#  'neonatal seizure disorder',
#  'convulsion néonatale',
#  'neonatal',
#  'cyanobacteria toxin',
#  'toxine de cyanobactérie',
#  'bacterial toxin',
#  'toxine bactérienne',
#  'ostéo-intégration',
#  'osseointegration',
#  'régénération osseuse',
#  'bone regeneration',
#  'reflexology',
#  'réflexologie',
#  'chinesemedecineti',
#  'massage',
#  'médecine légale',
#  'forensic medicine',
#  'medicaldisciplines',
#  'forensic science',
#  'science légale',
#  'forensic pathology',
#  'pathologie judiciaire',
#  'toxicologie médicolégale',
#  'forensic toxicology',
#  'odontology',
#  'odontologie',
#  'responsabilité criminelle',
#  'criminal responsability',
#  'mort suspicieuse',
#  'suspicious death',
#  'endoflifedeath',
#  'death',
#  'mort',
#  'crimeviolenceemergencyfacility',
#  'morgue',
#  'médecin légiste',
#  'forensic pathologist',
#  'détermination du sexe à partir du squelette',
#  'sex determination by skeleton',
#  'autopsie',
#  'autopsy',
#  'age determination by skeleton',
#  "détermination de l'âge à partir du squelette",
#  'japanesemedecineti',
#  'alternativemedicineti',
#  'massage amma',
#  'amma massage',
#  'massage lomi-atsu',
#  'lomi-atsu massage',
#  'massage ashiatsu',
#  'ashiatsu massage',
#  'shiatsu massage',
#  'massage shiatsu',
#  'maldigestion du glucose',
#  'glucose maldigestion',
#  'urological manifestations',
#  'manifestations urologiques',
#  'signsymptombysite',
#  'pollakiurie',
#  'frequent urination',
#  'dysurie',
#  'dysuria',
#  'urine sombre',
#  'dark urine',
#  'protéinurie',
#  'proteinuria',
#  'urinary tract',
#  'voies urinaires',
#  "test d'urine",
#  'urinalysis',
#  'urologie',
#  'urology',
#  'hormone',
#  'drugschemicals',
#  'drugfoodchemicalbiomedicalmaterial',
#  'hormone peptidique',
#  'peptide hormone',
#  'desmopressine',
#  'desmopressin',
#  'adrenal cortex hormone',
#  'hormone corticosurrénalienne',
#  'sex hormone',
#  'hormone stéroïdienne',
#  'melatonin',
#  'mélatonine',
#  'human insulin',
#  'insuline humaine',
#  'cortisol',
#  'hormone therapy',
#  'hormonothérapie',
#  'lifting fessier',
#  'buttock lift',
#  'plasticsurgerybodysi',
#  'radioligand assay',
#  'dosage radiorécepteur',
#  'techniques de laboratoire clinique',
#  'clinical laboratory techniques',
#  'radioisotope diagnostic techniques',
#  'techniques de diagnostic radioisotopique',
#  'endocrinediagnostictechniques',
#  'dosage radio-immunologique',
#  'radioimmunoassay',
#  'test de liaison de ligands',
#  'radiobinding assay',
#  'verbal behavior',
#  'comportement verbal',
#  'communication',
#  'parole',
#  'speech',
#  'services de mieux-être',
#  'wellness services',
#  'programmes de bien-être',
#  'wellness programs',
#  'mobile massotherapy',
#  'massothérapie mobile',
#  'employee assistance program',
#  "programme d'aide aux employés",
#  'réadaptation sensorielle',
#  'sensory integration therapy',
#  'occupationaltherapycognitiveti',
#  'brain tissue transplantation',
#  'transplantation de tissu cérébral',
#  'neurosp',
#  'tissue transplantation',
#  'transplantation de tissu',
#  'phantom limb',
#  'membre fantôme',
#  'troubles de la perception',
#  'perceptual disorders',
#  'endodontie régénératrice',
#  'regenerative endodontics',
#  'endodonticsti',
#  'endodontics surgery',
#  'regeneration of immature teeth',
#  'régénération des dents immatures',
#  'labyrinthitis',
#  'labyrinthite',
#  'otite',
#  'otitis',
#  'maladie labyrinthique',
#  'labyrinth disease',
#  'industrial rehabilitation',
#  'réadaptation industrielle',
#  'occupationaltherapyrehabilitationti',
#  'functional rehabilitation',
#  'réadaptation fonctionnelle',
#  'évaluation du potentiel de réadaptation',
#  'functional capacity evaluation',
#  'couronne en composite',
#  'composite crown',
#  'dental crown',
#  'couronne dentaire',
#  'maladies rénales',
#  'kidney diseases',
#  'kidney disease',
#  'maladie rénale',
#  'urologicconditions',
#  'maladie des voies urinaires',
#  'urologic disease',
#  'néphrosclérose',
#  'nephrosclerosis',
#  'néphropathie associée au sida',
#  'hiv-associated nephropathy',
#  'kidney cortex necrosis',
#  'nécrose du cortex rénal',
#  'hyperoxalurie',
#  'hyperoxaluria',
#  'diabetic nephropathy',
#  'néphropathie diabétique',
#  'perinephritis',
#  'périnéphrite',
#  'néphrite',
#  'nephritis',
#  'zellweger syndrome',
#  'syndrome de zellweger',
#  'kidney cancer',
#  'cancer du rein',
#  'reins fusionnés',
#  'fused kidney',
#  'urémie',
#  'uremia',
#  'hydronéphrose',
#  'hydronephrosis',
#  'anurie',
#  'anuria',
#  'diabète insipide',
#  'diabetes insipidus',
#  'insuffisance rénale',
#  'renal insufficiency',
#  'hypertension rénale',
#  'renal hypertension',
#  'syndrome du casse-noisette',
#  'renal nutcracker syndrome',
#  'calculs rénaux',
#  'kidney calculi',
#  'kidney',
#  'rein',
#  'nephrology',
#  'néphrologie',
#  'blood urea nitrogen',
#  'azote uréique sanguin',
#  'biopsie rénale',
#  'kidney biopsy',
#  'test de créatinine sanguine',
#  'creatinine in blood test',
#  "inhibition de l'ovulation",
#  'ovulation inhibition',
#  'ovulation',
#  'audiométrie vocale',
#  'speech audiometry',
#  'audiometry',
#  'audiométrie',
#  'speech discrimination test',
#  'tests de discrimination de la parole',
#  'synthetic sentence identification test',
#  'score de reconnaissance de mots',
#  'word recognition score',
#  'blood vessel prosthesis implantation',
#  'implantation de prothèses vasculaires',
#  'vascular grafting',
#  'greffe vasculaire',
#  'prosthesis implantation',
#  'implantation de prothèse',
#  'ostéonécrose mandibulaire',
#  'mandible osteonecrosis',
#  'mandibulardiseases',
#  'mandibular disease',
#  'ostéonécrose',
#  'osteonecrosis',
#  'communicationmethods',
#  'thérapeutiques',
#  'therapeutics',
#  'hearingreadaptationtherapies',
#  'speechreadaptationmethods',
#  'meningeal tuberculosis',
#  'méningite tuberculeuse',
#  'bacterial meningitis',
#  'méningite bactérienne',
#  'mycobacterium tuberculosis',
#  'rate',
#  'spleen',
#  'système lymphatique',
#  'lymphatic system',
#  'lissu lymphoïde',
#  'lymphoid tissue',
#  'splénomégalie',
#  'splenomegaly',
#  'maladie splénique',
#  'spleen disease',
#  'maladie de la rate',
#  'photobiomodulation',
#  'laser technology',
#  'technologie laser',
#  'chiropratique',
#  'chiropractic',
#  'arthralgia',
#  'arthralgie',
#  'back pain',
#  'dorsalgie',
#  "ventriculographie isotopique à l'équilibre",
#  'muga scan',
#  'ventriculographie isotopique',
#  'radionuclide ventriculography',
#  'assessmenttools',
#  'diagnostictechniques',
#  'audiologyassessmenttools',
#  'évaluation des capacités parentales',
#  'custody access evaluation',
#  'respiratoryassessmenttools',
#  'disabilityassessmenttools',
#  'speechassessmenttools',
#  'évaluation de réinsertion sociale',
#  'social reintegration assessment',
#  'évaluation psychologique',
#  'psychological assessment',
#  'patient post avc',
#  'stroke patient',
#  'vaginal secretions culture',
#  'culture des sécrétions vaginales',
#  'gynecologicalcultures',
#  'vaginitis',
#  'vaginite',
#  'bacterial vaginosis',
#  'vaginite bactérienne',
#  'lunettes de soleil sur ordonnance',
#  'prescription sunglasses',
#  'lunettes',
#  'eyeglasses',
#  'joue',
#  'cheek',
#  'faceparts',
#  'système stomatognathique',
#  'stomatognatic system',
#  'stomatognathic system',
#  'sexologue',
#  'sexologist',
#  'behavioralsciencepsychologyprofessionals',
#  'sexology',
#  'sexologie',
#  'association des sexologues du québec',
#  'musculoskeletalimaging',
#  'imagingbysystemsite',
#  'spinal imaging',
#  'imagerie rachidienne',
#  'bones imaging',
#  'imagerie des os',
#  'pelvic imaging',
#  'imagerie pelvienne',
#  'muscles imaging',
#  'imagerie des muscles',
#  'lowerextremityimaging',
#  'jointstendonsimaging',
#  'cranialneckimaging',
#  'upperextremityimaging',
#  'soins infirmiers gériatriques',
#  'geriatric nursing',
#  'nursing',
#  'soins infirmiers',
#  'chsld',
#  'unité de gériatrie',
#  'geriatric unit',
#  'agedrelateddiseases',
#  'maladie du vieillissement',
#  'aging-associated disease',
#  'elderly',
#  'âgé',
#  'pitch pattern sequence test',
#  'frequency pattern test',
#  'auditory perceptual disorder',
#  'trouble de la perception auditive',
#  'pure-tone audiometry',
#  'audiométrie tonale',
#  'agedevelopmentlifestage',
#  'age groups',
#  'demographicgroups',
#  'demographic groups',
#  'sujet âgé',
#  'aged',
#  'personne âgée',
#  'âge adulte',
#  'adulthood',
#  'end of life',
#  'fin de vie',
#  'fracture vertébrale par compression',
#  'vertebral compression fracture',
#  'fracture osseuse',
#  'bone fracture',
#  'spine injury',
#  'blessure à la colonne vertebrale',
#  'blessure à la colonne vertébrale',
#  'tachycardie ventriculaire',
#  'ventricular tachycardia',
#  'tachycardie',
#  'tachycardia',
#  'eye injury',
#  "lésions traumatiques de l'oeil",
#  "maladies de l'oeil",
#  'eye diseases',
#  'injurybysite',
#  'corps étranger oculaire',
#  'eye foreign body',
#  'penetrating eye injury',
#  "plaie pénétrante de l'oeil",
#  'retinal injury',
#  'lésion rétinienne',
#  'brûlure oculaire',
#  'eye burn',
#  'lésion de la cornée',
#  'corneal injury',
#  'abrasions cornéennes',
#  'suppurative uveitis',
#  'uvéite purulente',
#  'laser à diode',
#  'diode laser',
#  'aide médicale à mourir',
#  'medical aid in dying',
#  'hospicepalliativecareti',
#  'minerals',
#  'minéraux',
#  'médicaments',
#  'drugs',
#  'médicament',
#  'lithium',
#  'dysenterie bacillaire',
#  'bacillary dysentery',
#  'dysenterie',
#  'dysentery',
#  'shigella dysenteriae',
#  'boisson fermentée',
#  'fermented beverage',
#  'aliments fermentés',
#  'fermented food',
#  'boisson',
#  'beverage',
#  'wine',
#  'vin',
#  'bière',
#  'beer',
#  'ovarian follicle',
#  'follicule ovarique',
#  'ovary',
#  'ovaire',
#  'follicular fluid',
#  'liquide folliculaire',
#  'cellules de la granulosa',
#  'granulosa cells',
#  'teca folicular',
#  'cellules thécales',
#  'theca cells',
#  'oestrogènes',
#  'estrogens',
#  'cil',
#  'eyelash',
#  'eyelid',
#  'paupière',
#  'hair',
#  'cheveux',
#  'pédiculose',
#  'lice infestation',
#  'hippocampe',
#  'hippocampus',
#  'système limbique',
#  'limbic system',
#  'chronic pelvic pain',
#  'douleur chronique pelvienne',
#  'pelvicinflammatoryconditions',
#  'pelvic inflammatory disease',
#  'maladie inflammatoire pelvienne',
#  'manipulation vertébrale',
#  'spinal manipulation',
#  'spinerehabilitationti',
#  'chiropracticti',
#  'gonstead technique',
#  'technique gonstead',
#  'thompson technique',
#  'technique thompson',
#  'technique sacro-occipitale',
#  'sacro occipital technique',
#  'technique cox',
#  'cox technique',
#  'network spinal analysis',
#  'analyse spinale network',
#  'torque release technique',
#  'méthode torque release',
#  'décompression neuro-vertébrale',
#  'spinal decompression',
#  'toggle recoil',
#  'ajustement hio',
#  'diversified technique',
#  'technique diversifiée',
#  'activator method chiropractic technique',
#  'méthode activator technique',
#  'technique atlas orthogonal',
#  'atlas orthogonal technique',
#  'dermatitis',
#  'dermatite',
#  'maladie de la peau',
#  'skin disease',
#  'eczéma atopique',
#  'atopic dermatitis',
#  'contact dermatitis',
#  'dermatite de contact',
#  'dermite périorale',
#  'perioral dermatitis',
#  'dandruff',
#  'pellicules',
#  'acrodermatite',
#  'acrodermatosis',
#  'drug eruptions',
#  'toxidermie',
#  'eczema',
#  'eczéma',
#  'dermite séborrhéique',
#  'seborrheic dermatitis',
#  'glycerol',
#  'glycérol',
#  'betamethasone',
#  'bétaméthasone',
#  'doxycycline',
#  'béclométasone',
#  'beclometasone',
#  'specializedtherapist',
#  'wellnessoccupations',
#  'thérapeute spirituel',
#  'spiritual therapist',
#  'dance therapist',
#  'danse-thérapeute',
#  'système nerveux parasympathique',
#  'parasympathetic nervous system',
#  'peripheral nervous system',
#  'système nerveux périphérique',
#  'nerf oculomoteur',
#  'oculomotor nerve',
#  'glossopharyngeal nerve',
#  'nerf glossopharyngien',
#  'nerf facial',
#  'facial nerve',
#  'nerf vague',
#  'vagus nerve',
#  'chronic fatigue syndrome',
#  'syndrome de fatigue chronique',
#  'neuromuscular disease',
#  'maladies neuromusculaires',
#  'centralnervoussystemdisease',
#  'central nervous system disease',
#  'maladie du système nerveux central',
#  'maladie virale',
#  'viral infection',
#  'marital therapy',
#  'thérapie conjugale',
#  'couple therapy',
#  'thérapie de couple',
#  'polypes coliques',
#  'colonic polyp',
#  'polype intestinale',
#  'intestinal polyps',
#  'spinalconditions',
#  'maladie de la colonne vertébrale',
#  'spinal disease',
#  'musculoskeletalconditions',
#  'conditionostéomusculaires',
#  'musculoskeletal disease',
#  'maladie ostéomusculaire',
#  'lordose',
#  'lordosis',
#  'spondylolisthesis',
#  'spondylolisthésis',
#  'spinal deformity',
#  'déformation spinale',
#  'cauda equina syndrome',
#  'syndrome de la queue de cheval',
#  'kyphosis',
#  'cyphose',
#  'scoliosis',
#  'scoliose',
#  'sténose spinale',
#  'spinal stenosis',
#  'syndrome de marfan',
#  'marfan syndrome',
#  'hernie discale',
#  'herniated disc',
#  'maladie du rachis',
#  'degenerativespinediseases',
#  'sciatica',
#  'sciatalgie',
#  'spondylolyse',
#  'spondylolysis',
#  'moelle spinale',
#  'spinal cord',
#  'chirurgie du rachis',
#  'spine surgery',
#  'surveillance hémodynamique',
#  'hemodynamic monitoring',
#  'physiologic monitoring',
#  'monitorage physiologique',
#  'cardiovasculardiagnostictechniques',
#  'hemodynamics',
#  'hémodynamique',
#  'critical care',
#  'soins intensifs',
#  "médecine d'urgence",
#  'emergency medicine',
#  'cardiologydi',
#  'swan-ganz catheterization',
#  'cathétérisme par sonde de swan-ganz',
#  'allergènes',
#  'allergen',
#  'antigen',
#  'antigène',
#  'allergène alimentaire',
#  'food allergen',
#  'hypersensibilité',
#  'hypersensitivity',
#  'splanchnic nerves',
#  'nerfs splanchniques',
#  'sympathetic nervous system',
#  'système nerveux sympathique',
#  'autonomic pathways',
#  'voies nerveuses autonomes',
#  'gouttière de blanchiment',
#  'bleach gutter',
#  'dentalproducts',
#  'anti-psychiatry',
#  'antipsychiatrie',
#  'alternaltivetherapy',
#  'eyevisionalliedhealthdi',
#  'alliedhealthdisciplinesdi',
#  'optometrydi',
#  'unité de chirurgie générale',
#  'general surgery unit',
#  'surgeryunit',
#  'surgery unit',
#  'general surgery',
#  'chirurgie générale',
#  'obstetricalgynecologicaldevices',
#  'medicaldevice',
#  'on-reserve income assistance program',
#  "programme d'aide au revenu dans les réserves",
#  'indigenous services',
#  'services aux autochtones',
#  'povertysupportservices',
#  'indigenous peoples',
#  'peuples autochtones',
#  'bordetellainfections',
#  'bordetellose',
#  'bordetella infection',
#  'gramnegativeinfections',
#  'gram negative infection',
#  'pertussis',
#  'coqueluche',
#  'bordetella',
#  'romanticrelation',
#  'romantic relationship',
#  'relation amoureuse',
#  'socialphenomena',
#  'facteur sociologique',
#  'sociological factor',
#  'codépendance',
#  'codependancy',
#  'rupture',
#  'breakup',
#  'infidélité',
#  'infidelity',
#  'divorce',
#  'coaching',
#  'psychology',
#  'psychologie',
#  'coaching de relation de couple',
#  'relationship coaching',
#  'angiographie aortique',
#  'aortography',
#  'cardiac radiography',
#  'radiographie cardiaque',
#  'angiographie',
#  'angiography',
#  'root resection',
#  'résection radiculaire',
#  'speech in noise test',
#  'hematemesis',
#  'hématémèse',
#  'vomissement',
#  'vomiting',
#  'gastrointestinal hemorrhage',
#  'hémorragie gastrointestinale',
#  'gingivitis',
#  'gingivite',
#  'bacterial infection',
#  'infection bactérienne',
#  'maladie de la gencive',
#  'gingival disease',
#  'metronidazole',
#  'métronidazole',
#  'chronic kidney failure',
#  'défaillance rénale chronique',
#  'chronic renal insufficiency',
#  'insuffisance rénale chronique',
#  'erythrocyte count',
#  'numération des érythrocytes',
#  'genetic risk assessment for children',
#  "évaluation du risque génétique chez l'enfant",
#  'genetic risk assessment',
#  'évaluation du risque génétique',
#  'personnalité histrionique',
#  'histrionic personality disorder',
#  'troubles de la personnalité',
#  'personality disorder',
#  'intimidation',
#  'bullying',
#  'agressivité',
#  'aggressiveness',
#  'youngpopulationpsychologicalphenomena',
#  'clothingproducts',
#  'dailylivingaidproducts',
#  'aids to daily living',
#  'aides à la vie quotidienne',
#  'shoehorn',
#  'chausse-pied',
#  'urethra',
#  'urètre',
#  'penis',
#  'pénis',
#  'dépistage de la chlamydia',
#  'chlamydia screening',
#  'hallux varus',
#  'déformation du pied',
#  'foot deformity',
#  'prothèse capillaire',
#  'hair prosthesis',
#  'greffe de cheveux',
#  'hair transplant',
#  'test de clairance mucociliaire',
#  'measurement of mucociliary clearance',
#  'respiratory system diagnostic techniques',
#  'techniques de diagnostic respiratoire',
#  'clairance mucociliaire',
#  'mucociliary clearance',
#  'seafood allergy',
#  'allergie aux fruits de mer',
#  'hypersensibilité alimentaire',
#  'food allergy',
#  "test d'allergie aux fruits de mer",
#  'seafood allergy test',
#  'metabolic diseases',
#  'maladies métaboliques',
#  'metabolic disease',
#  'maladie métabolique',
#  'nutritionalmetaboliccondition',
#  'maladies métaboliques et nutritionnelles',
#  'nutritional and metabolic diseases',
#  'metabolic syndrome',
#  'syndrome métabolique',
#  'spinocerebellar degeneration',
#  'dégénérescences spinocérébelleuses',
#  'lipidmetabolismdisorders',
#  'lipid metabolism disorder',
#  'trouble du métabolisme lipidique',
#  'metabolicskindiseases',
#  'metabolic skin disease',
#  'waterelectrolyteimbalance',
#  'calciummetabolismdisorders',
#  'calcium metabolism disorder',
#  'trouble du métabolisme du calcium',
#  'metabolic brain diseases',
#  'encéphalopathies métaboliques',
#  'lactation disorder',
#  'malabsorption syndrome',
#  'syndrome de malabsorption',
#  'metabolic bone  diseases',
#  'maladies osseuses métaboliques',
#  'phosphorusmetabolismdisorders',
#  'phosphorus metabolism disorder',
#  'trouble du métabolisme du phosphore',
#  'acidbaseimbalance',
#  'acid-base imbalance',
#  "trouble de l'équilibre acidobasique",
#  'glucosemetabolismdisorders',
#  'trouble du métabolisme du glucose',
#  'glucose metabolism disorder',
#  'mitochondrialdiseases',
#  'mitochondrial disease',
#  'maladie mitochondriale',
#  'ironmetabolismdisorders',
#  'biopsie intestinale',
#  'intestinal biopsy',
#  'celiac disease',
#  'maladie céliaque',
#  'intestinal cancer',
#  "cancer de l'intestin",
#  'corneal perforation',
#  'perforation de la cornée',
#  'auditory hair cell',
#  'cellules ciliées auditives',
#  'organ of corti',
#  'organe spiral',
#  'lowerextremityendoscopies',
#  'endoscopie osseuse',
#  'bones endoscopies',
#  'polysomnographie',
#  'polysomnography',
#  'sleepmedicinedi',
#  'polysomnographie ambulatoire',
#  'ambulatory polysomnography',
#  'obstructive sleep apnea',
#  'apnée obstructive du sommeil',
#  'sleep laboratory technology',
#  'technique en polysomnographie',
#  'pulmonology',
#  'pneumologie',
#  'respiratory therapist',
#  'inhalothérapeuthe',
#  'intra-deep hearing aid',
#  'appareil intra auriculaire complètement dans le canal',
#  'appareil intra auriculaire',
#  'in-ear hearing aid',
#  'periodonticsp',
#  'dentistrysi',
#  'échographie interventionnelle',
#  'interventional ultrasound',
#  'ecografía',
#  'ultrasonography',
#  'ultrasonographie',
#  'cytoponction sous échoendoscopie',
#  'endoscopic ultrasound guided fine needle aspiration',
#  'musculoskeletal injury prevention',
#  'prévention des blessures musculosquelettiques',
#  'sportsmedicineprevention',
#  'electrodesiccation',
#  'électrodessiccation',
#  'électrochirurgie',
#  'electrosurgery',
#  'skin cancer',
#  'cancer de la peau',
#  'skinlesionremoval',
#  'clinique de gestion de la douleur',
#  'pain management clinic',
#  'outpatient medical centre',
#  'centre de services médicaux ambulatoires',
#  'unité de soins en anesthésiologie',
#  'anesthesiology unit',
#  'specialized clinic',
#  'clinique médicale spécialisée',
#  "clinique d'accès rapide en gestion de la douleur",
#  'rapid access pain clinic',
#  'chronic pain management',
#  'gestion de la douleur chronique',
#  'postgastrectomy syndrome',
#  'syndrome post-gastrectomie',
#  'stomachdiseases',
#  "maladie de l'estomac",
#  'stomach disease',
#  'dumping syndrome',
#  'genericinterventions',
#  'intervention',
#  'exam',
#  'examen',
#  'management',
#  'gestion',
#  'rehabilitation',
#  'réadaptation',
#  'scan',
#  'reconstruction',
#  'medical consultation',
#  'consultation médicale',
#  'consultation',
#  'replacement',
#  'remplacement',
#  'care',
#  'soin',
#  'prise en charge',
#  'follow-up',
#  'removal',
#  'retrait',
#  'support',
#  'soutien',
#  'mesure',
#  'measurement',
#  'therapy',
#  'thérapie',
#  'humeur aqueuse',
#  'aqueous humor',
#  'extracellular fluid',
#  'liquide extracellulaire',
#  'liquide extra-cellulaire',
#  'anterior chamber',
#  "chambre antérieure de l'oeil",
#  'accouchement',
#  'obstetric delivery',
#  'obstetric surgery',
#  'chirurgie obstétrique',
#  'épisiotomie',
#  'episiotomy',
#  'umbilical cord clamping',
#  'clampage du cordon ombilical',
#  'cesarean section',
#  'césarienne',
#  'induced labor',
#  'accouchement provoqué',
#  'extraction obstétricale',
#  'obstetrical extraction',
#  'foetus',
#  'fetus',
#  'placenta',
#  'résorption osseuse',
#  'bone resorption',
#  'bone remodeling',
#  'remodelage osseux',
#  'middle ear ventilation',
#  "ventilation de l'oreille moyenne",
#  'otologicsp',
#  'pedorthicti',
#  'prostheticsortheticsdisciplinesti',
#  'pedorthics',
#  'podo-orthèse',
#  '3d echocardiography',
#  'échocardiographie 3d',
#  '3d imaging',
#  'imagerie 3d',
#  'echocardiogram',
#  'échocardiographie',
#  '4d echocardiography',
#  'échocardiographie 4d',
#  ...]

# %%
for t in df['Expression'].tolist():
    if t in taxo_terms:
        df.loc[df['Expression'] == t, 'isTaxoTerm'] = True
df[df['isTaxoTerm'] == True]
# Out:
#                         Expression Structure syntaxique  Fréquence  \
# 7                    fausse couche              ADJ NOM        474
# 18                couches lavables              NOM ADJ         69
# 61            larmes artificielles              NOM ADJ         18
# 100                      yeux secs              NOM ADJ         12
# 105              test de grossesse          NOM PRP NOM        170
# ...                            ...                  ...        ...
# 163139      capacités d'adaptation          NOM PRP NOM          3
# 163146   prévention des infections      NOM PRP:det NOM          3
# 166704            pompe à insuline          NOM PRP NOM          3
# 190285  syndrome des ongles jaunes  NOM PRP:det NOM ADJ          6
# 201560           droits de l'homme  NOM PRP DET:ART NOM          4
#
#         isMeSHTerm MeSHID MesH_prefLabel_fr MesH_prefLabel_en isTaxoTerm
# 7             True   None              None              None       True
# 18           False   None              None              None       True
# 61            True   None              None              None       True
# 100          False   None              None              None       True
# 105           True   None              None              None       True
# ...            ...    ...               ...               ...        ...
# 163139       False   None              None              None       True
# 163146        True   None              None              None       True
# 166704       False   None              None              None       True
# 190285        True   None              None              None       True
# 201560       False   None              None              None       True
#
# [688 rows x 8 columns]

# %% [markdown]
# ### **Mapping to MeSH IDs**

# %% [markdown]
# Lire le fichier XML contenant le MeSH Bilingue
#
# Le MeSH 2019 comprend 29 351 descripteurs
# https://mesh.inserm.fr/FrenchMesh/presentation.htm

# %%
import xml.etree.ElementTree as ET
import re
import pandas as pd
base_path = '../02-filtrage/MeSH/'

tree = ET.parse(base_path + 'fredesc2019.xml')
root = tree.getroot()

def flatten(l):
    return [item for sublist in l for item in sublist]

data_mesh = [{'mesh_id' : x.find('DescriptorUI').text.strip('\n'), \
         'label_fr' : x.find('DescriptorName').find('String').text.split('[')[0], \
         'label_en' : x.find('DescriptorName').find('String').text.split('[')[1].strip(']'), \
         'synonymes (en/fr)' : flatten([[term.find('String').text for term in concept.find('TermList').findall('Term')] for concept in x.find('ConceptList').findall('Concept')]) \
         } for x in root.findall('DescriptorRecord')]

# %%
for t in df[df['isMeSHTerm'] == True]['Expression'].tolist():
    for d in data_mesh:
        if t in [str(x).lower() for x in d['synonymes (en/fr)']]:
            df.loc[df['Expression'] == t, 'MeSHID'] = d['mesh_id']
            df.loc[df['Expression'] == t, 'MesH_prefLabel_fr'] = d['label_fr']
            df.loc[df['Expression'] == t, 'MesH_prefLabel_en'] = d['label_en']

df
# Out:
#                   Expression  Structure syntaxique  Fréquence  isMeSHTerm  \
# 0                  temps qu'           NOM PRO:REL         83       False
# 1         liste de naissance           NOM PRP NOM         26       False
# 3           également acheté          ADV VER:pper          7       False
# 4                attend tjrs          VER:pres NOM          3       False
# 5       permis de construire      NOM PRP VER:infi          4       False
# ...                      ...                   ...        ...         ...
# 201464      alcaline ionisée          ADJ VER:pper          3       False
# 201560     droits de l'homme   NOM PRP DET:ART NOM          4       False
# 201568         nations unies               NOM ADJ          4        True
# 201741   promenade privative               NOM ADJ          3       False
# 201876      super les filles  VER:infi DET:ART NOM          9       False
#
#          MeSHID MesH_prefLabel_fr MesH_prefLabel_en isTaxoTerm
# 0          None              None              None      False
# 1          None              None              None      False
# 3          None              None              None      False
# 4          None              None              None      False
# 5          None              None              None      False
# ...         ...               ...               ...        ...
# 201464     None              None              None      False
# 201560     None              None              None       True
# 201568  D014480     Nations Unies    United Nations      False
# 201741     None              None              None      False
# 201876     None              None              None      False
#
# [27736 rows x 8 columns]

# %%
df.insert(0, 'Corpus', acteur)
df
# Out:
#             Corpus            Expression  Structure syntaxique  Fréquence  \
# 0       doctissimo             temps qu'           NOM PRO:REL         83
# 1       doctissimo    liste de naissance           NOM PRP NOM         26
# 3       doctissimo      également acheté          ADV VER:pper          7
# 4       doctissimo           attend tjrs          VER:pres NOM          3
# 5       doctissimo  permis de construire      NOM PRP VER:infi          4
# ...            ...                   ...                   ...        ...
# 201464  doctissimo      alcaline ionisée          ADJ VER:pper          3
# 201560  doctissimo     droits de l'homme   NOM PRP DET:ART NOM          4
# 201568  doctissimo         nations unies               NOM ADJ          4
# 201741  doctissimo   promenade privative               NOM ADJ          3
# 201876  doctissimo      super les filles  VER:infi DET:ART NOM          9
#
#         isMeSHTerm   MeSHID MesH_prefLabel_fr MesH_prefLabel_en isTaxoTerm
# 0            False     None              None              None      False
# 1            False     None              None              None      False
# 3            False     None              None              None      False
# 4            False     None              None              None      False
# 5            False     None              None              None      False
# ...            ...      ...               ...               ...        ...
# 201464       False     None              None              None      False
# 201560       False     None              None              None       True
# 201568        True  D014480     Nations Unies    United Nations      False
# 201741       False     None              None              None      False
# 201876       False     None              None              None      False
#
# [27736 rows x 9 columns]

# %%
df.to_csv('../' + acteur + '_candidate-terms.csv')
