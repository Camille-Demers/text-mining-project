# %% [markdown]
# # 2. **Extract Most Frequent Syntactic Structures from MeSH**

# %% [markdown]
# Extraire les structures syntaxiques les plus courantes dans les MeSH pour filtrer notre corpus selon celles-ci (inspiré de la méthodologie de l'article ci-dessous).
#
# Lossio-Ventura, J. A., Jonquet, C., Roche, M., & Teisseire, M. (2014). Biomedical Terminology Extraction : A new combination of Statistical and Web Mining Approaches. 421. https://hal-lirmm.ccsd.cnrs.fr/lirmm-01056598

# %%
import pandas
path = '../02-filtrage/MeSH/'

with open(path + 'mesh-fr.txt', 'r', encoding = "UTF-8") as f:
    mesh = f.read().split("\n")

# %% [markdown]
# ### POS tagging
# TreeTagger

# %%
import treetaggerwrapper
tagger = treetaggerwrapper.TreeTagger(TAGLANG='fr')

# %%
mesh_txt = [tagger.tag_text(term) for term in mesh]

# %%
"""
0 - Token
1 - POS
2 - Lemme
"""

structures = []
tuples = []
for terme in mesh_txt:
    exp = " ".join([(t.split("\t")[0]) for t in terme])
    chunk = " ".join([(t.split('\t')[1]) for t in terme])
    tuples.append((exp, chunk))
    structures.append(chunk)

# %%
tuples
# Out:
# [('Pneumonie nécrosante', 'NOM ADJ'),
#  ('A-23187', 'NAM'),
#  ('Téméfos', 'NOM'),
#  ('Abattoirs', 'NOM'),
#  ('Abattoir', 'NOM'),
#  ('Abréviations comme sujet', 'NOM ADV ADJ'),
#  ('Acronymes comme sujet', 'NOM ADV ADJ'),
#  ('Abdomen', 'NOM'),
#  ('Ventre', 'NOM'),
#  ('Abdomen aigu', 'NOM ADJ'),
#  ('Abdomen chirurgical', 'NOM ADJ'),
#  ('Abdomen urgent', 'NOM ADJ'),
#  ("Traumatismes de l' abdomen", 'NOM PRP DET:ART NOM'),
#  ('Blessures abdominales', 'NOM ADJ'),
#  ("Blessures de l' abdomen", 'NOM PRP DET:ART NOM'),
#  ('Lésions abdominales', 'NOM ADJ'),
#  ("Lésions de l' abdomen", 'NOM PRP DET:ART NOM'),
#  ('Lésions traumatiques abdominales', 'NOM ADJ ADJ'),
#  ("Lésions traumatiques de l' abdomen", 'NOM ADJ PRP DET:ART NOM'),
#  ('Traumatisme abdominal', 'NOM ADJ'),
#  ('Traumatismes abdominaux', 'NOM ADJ'),
#  ("Tumeurs de l' abdomen", 'NOM PRP DET:ART NOM'),
#  ('Tumeurs abdominales', 'NOM ADJ'),
#  ('Muscles abdominaux', 'NOM ADJ'),
#  ('Muscle abdominal', 'NOM ADJ'),
#  ("Muscles de l' abdomen", 'NOM PRP DET:ART NOM'),
#  ('Sangle abdominale', 'NOM ADJ'),
#  ('Nerf abducens', 'NOM ADJ'),
#  ('Nerf crânien 6', 'NOM ADJ NUM'),
#  ('Nerf crânien VI', 'NOM ADJ NUM'),
#  ('Nerf moteur oculaire externe', 'NOM ADJ ADJ NOM'),
#  ('Sixième nerf crânien', 'NUM NOM ADJ'),
#  ('Sixième paire crânienne', 'NUM NOM ADJ'),
#  ("Virus de la leucémie murine d' Abelson", 'NOM PRP DET:ART NOM ADJ PRP NAM'),
#  ('A-MuLV', 'NAM'),
#  ('Abelson leukemia virus', 'NAM VER:simp NOM'),
#  ('Abelson murine leukemia virus', 'NOM ADJ VER:simp NOM'),
#  ("Virus de la leucémie d' Abelson", 'NOM PRP DET:ART NOM PRP NAM'),
#  ('Abêtalipoprotéinémie', 'NOM'),
#  ('Acanthocytose', 'NOM'),
#  ('Déficit en MTP', 'NOM PRP NAM'),
#  ('Déficit en protéine microsomale de transfert des triglycérides',
#   'NOM PRP NOM ADJ PRP NOM PRP:det NOM'),
#  ('Déficit en protéine microsomique de transfert de triglycérides',
#   'NOM PRP NOM ADJ PRP NOM PRP NOM'),
#  ('Déficit en transporteur microsomal des triglycérides',
#   'NOM PRP NOM ADJ PRP:det NOM'),
#  ('Déficit en transporteur microsomique des triglycérides',
#   'NOM PRP NOM ADJ PRP:det NOM'),
#  ('Maladie de Bassen-Kornzweig', 'NOM PRP NAM'),
#  ('Maladie du déficit en protéine microsomale de transfert des triglycérides',
#   'NOM PRP:det NOM PRP NOM ADJ PRP NOM PRP:det NOM'),
#  ('Syndrome de Bassen-Kornzweig', 'NOM PRP NAM'),
#  ('Malformations', 'NOM'),
#  ('Anomalie congénitale', 'NOM ADJ'),
#  ('Anomalie morphologique congénitale', 'NOM ADJ ADJ'),
#  ('Anomalies congénitales', 'NOM ADJ'),
#  ('Anomalies morphologiques congénitales', 'NOM ADJ ADJ'),
#  ('Difformités congénitales', 'NOM ADJ'),
#  ('Malformation', 'NOM'),
#  ('Malformations congénitales', 'NOM ADJ'),
#  ('Malformations dues aux médicaments et aux drogues',
#   'NOM VER:pper PRP:det NOM KON PRP:det NOM'),
#  ('Anomalies congénitales dues aux médicaments et aux drogues',
#   'NOM ADJ VER:pper PRP:det NOM KON PRP:det NOM'),
#  ('Anomalies congénitales provoquées par les médicaments et les drogues',
#   'NOM ADJ VER:pper PRP DET:ART NOM KON DET:ART NOM'),
#  ("Malformations d' origine médicamenteuse", 'NOM PRP NOM ADJ'),
#  ('Malformations dues aux médicaments', 'NOM VER:pper PRP:det NOM'),
#  ('Malformations induites par les médicaments et les drogues',
#   'NOM VER:pper PRP DET:ART NOM KON DET:ART NOM'),
#  ('Malformations tératogènes dues aux médicaments et aux drogues',
#   'NOM ADJ VER:pper PRP:det NOM KON PRP:det NOM'),
#  ('Malformations multiples', 'NOM ADJ'),
#  ('Anomalies congénitales multiples', 'NOM ADJ ADJ'),
#  ('Anomalies multiples congénitales', 'NOM ADJ ADJ'),
#  ('Malformations radio-induites', 'NOM ADJ'),
#  ('Malformations dues aux radiations', 'NOM VER:pper PRP:det NOM'),
#  ('Malformations dues aux rayonnements', 'NOM VER:pper PRP:det NOM'),
#  ('Malformations induites par les radiations', 'NOM VER:pper PRP DET:ART NOM'),
#  ('Malformations induites par les rayonnements',
#   'NOM VER:pper PRP DET:ART NOM'),
#  ('Malformations provoquées par les radiations',
#   'NOM VER:pper PRP DET:ART NOM'),
#  ('Malformations provoquées par les rayonnements',
#   'NOM VER:pper PRP DET:ART NOM'),
#  ('Système ABO de groupes sanguins', 'NOM ADJ PRP NOM ADJ'),
#  ('Groupe sanguin H', 'NOM ADJ ABR'),
#  ('Groupes sanguins ABH', 'NOM ADJ NAM'),
#  ('Système ABO', 'NOM ADJ'),
#  ('Système de groupe sanguin H', 'NOM PRP NOM ADJ ABR'),
#  ('Antigène H de type I ( groupe sanguin )',
#   'NOM ABR PRP NOM NUM PUN NOM ADJ PUN'),
#  ('Antigène H de type 1 ( groupe sanguin )',
#   'NOM ABR PRP NOM NUM PUN NOM ADJ PUN'),
#  ('Antigène O de type 1 ( groupe sanguin )',
#   'NOM NOM PRP NOM NUM PUN NOM ADJ PUN'),
#  ('Antigène O de type I ( groupe sanguin )',
#   'NOM NOM PRP NOM NUM PUN NOM ADJ PUN'),
#  ('Antigène de groupe sanguin H de type 1', 'NOM PRP NOM ADJ ABR PRP NOM NUM'),
#  ('Antigène de groupe sanguin H de type I', 'NOM PRP NOM ADJ ABR PRP NOM NUM'),
#  ('Facteurs ABO', 'NOM ADJ'),
#  ('Abomasum', 'NOM'),
#  ('Caillette', 'NOM'),
#  ('Abortifs', 'ADJ'),
#  ('Abortifs post-conceptionnels', 'ADJ NOM'),
#  ('Abortifs postconceptionnels', 'ADJ NOM'),
#  ('Agents abortifs', 'NOM ADJ'),
#  ('Médicaments abortifs', 'NOM ADJ'),
#  ('Abortifs non stéroïdiens', 'ADJ ADV ADJ'),
#  ('Agents abortifs non stéroïdiens', 'NOM ADJ ADV ADJ'),
#  ('Médicaments abortifs non stéroïdiens', 'NOM ADJ ADV ADJ'),
#  ('Abortifs stéroïdiens', 'ADJ ADJ'),
#  ('Agents abortifs stéroïdiens', 'NOM ADJ ADJ'),
#  ('Médicaments abortifs stéroïdiens', 'NOM ADJ ADJ'),
#  ('Avortement spontané', 'NOM ADJ'),
#  ('Fausse couche', 'ADJ NOM'),
#  ('Avortement spontané précoce', 'NOM ADJ ADJ'),
#  ('Fausse couche précoce', 'ADJ NOM ADJ'),
#  ('Avortement tubaire', 'NOM ADJ'),
#  ("Femmes demandant l' avortement", 'NOM VER:ppre DET:ART NOM'),
#  ("Candidates à l' avortement", 'NOM PRP DET:ART NOM'),
#  ('Femmes demandant des avortements répétés',
#   'NOM VER:ppre PRP:det NOM VER:pper'),
#  ('Candidates à des avortements répétitifs', 'NOM PRP PRP:det NOM ADJ'),
#  ('Candidates à des avortements répétés', 'NOM PRP PRP:det NOM VER:pper'),
#  ('Femmes demandant des avortements répétitifs',
#   'NOM VER:ppre PRP:det NOM ADJ'),
#  ("Femmes se voyant refuser l' avortement",
#   'NOM PRO:PER VER:ppre VER:infi DET:ART NOM'),
#  ("Candidates à l' avortement se heurtant à des refus",
#   'NOM PRP DET:ART NOM PRO:PER VER:ppre PRP PRP:det NOM'),
#  ('Avortement illégal', 'NOM ADJ'),
#  ('Avortement eugénique', 'NOM ADJ'),
#  ('Avortement sélectif', 'NOM ADJ'),
#  ('Avortements à répétition', 'NOM PRP NOM'),
#  ('Avortements habituels', 'NOM ADJ'),
#  ('Avortements récidivants', 'NOM ADJ'),
#  ('Avortements spontanés précoces à répétition', 'NOM ADJ ADJ PRP NOM'),
#  ('Fausses couches précoces à répétition', 'ADJ NOM ADJ PRP NOM'),
#  ('Fausses couches à répétition', 'ADJ NOM PRP NOM'),
#  ('Maladie abortive', 'NOM ADJ'),
#  ('Avortement incomplet', 'NOM ADJ'),
#  ('Avortement provoqué', 'NOM VER:pper'),
#  ("Taux d' avortement", 'NOM PRP NOM'),
#  ('Techniques abortives', 'NOM ADJ'),
#  ("Techniques d' avortement", 'ADJ PRP NOM'),
#  ('Interruption volontaire de grossesse par voie médicamenteuse',
#   'NOM ADJ PRP NOM PRP NOM ADJ'),
#  ('IVG médicamenteuse', 'ABR ADJ'),
#  ('IVGm', 'NOM'),
#  ('Avortement antérieur', 'NOM ADJ'),
#  ("Antécédent d' avortement", 'NOM PRP NOM'),
#  ('Avortement par injection de solution saline', 'NOM PRP NOM PRP NOM ADJ'),
#  ('Avortement provoqué par solution saline', 'NOM VER:pper PRP NOM ADJ'),
#  ('Avortement par injection de solution savonneuse',
#   'NOM PRP NOM PRP NOM ADJ'),
#  ('Avortement provoqué par solution savonneuse', 'NOM VER:pper PRP NOM ADJ'),
#  ('Groupes anti-avortement', 'NOM NOM'),
#  ('Embryotomie', 'NOM'),
#  ('Contrôle postconception de la fécondité', 'NOM NOM PRP DET:ART NOM'),
#  ('Contrôle post-conception de la fertilité', 'NOM NOM PRP DET:ART NOM'),
#  ('Contrôle post-conception de la fécondité', 'NOM NOM PRP DET:ART NOM'),
#  ('Contrôle postconception de la fertilité', 'NOM NOM PRP DET:ART NOM'),
#  ('Contrôle postconceptionnel de la fertilité', 'NOM ADJ PRP DET:ART NOM'),
#  ('Contrôle postconceptionnel de la fécondité', 'NOM ADJ PRP DET:ART NOM'),
#  ("Échec de tentative d' avortement", 'NOM PRP NOM PRP NOM'),
#  ('Avortement provoqué par rivanol', 'NOM VER:pper PRP NOM'),
#  ('Interruption légale de grossesse', 'NOM ADJ PRP NOM'),
#  ('Avortement provoqué légal', 'NOM VER:pper ADJ'),
#  ('Interruption volontaire de grossesse', 'NOM ADJ PRP NOM'),
#  ('IVG ( Interruption Volontaire de Grossesse )',
#   'ABR PUN NOM ADJ PRP NOM PUN'),
#  ('Interruption de grossesse sur demande', 'NOM PRP NOM PRP NOM'),
#  ('Rétention foetale', 'NOM ADJ'),
#  ('Avortement septique', 'NOM ADJ'),
#  ('Avortement thérapeutique', 'NOM ADJ'),
#  ('IMG ( Interruption Médicale de Grossesse )', 'NAM PUN NOM ADJ PRP NOM PUN'),
#  ('Interruption de grossesse pour motif médical', 'NOM PRP NOM PRP NOM ADJ'),
#  ('Interruption médicale de grossesse', 'NOM ADJ PRP NOM'),
#  ("Menace d' avortement", 'NOM PRP NOM'),
#  ('Menace de fausse couche', 'VER:pres PRP ADJ NOM'),
#  ('Avortement chez les animaux', 'NOM PRP DET:ART NOM'),
#  ('Avortement animal', 'NOM ADJ'),
#  ("Avortement chez l' animal", 'NOM PRP DET:ART NOM'),
#  ('Avortement des animaux', 'NOM PRP:det NOM'),
#  ('Abréaction', 'NOM'),
#  ('Abrine', 'NAM'),
#  ('Jéquiritine', 'NOM'),
#  ('Hématome rétroplacentaire', 'NOM ADJ'),
#  ('Décollement placentaire', 'NOM ADJ'),
#  ('Hématome rétro-placentaire', 'NOM ADJ'),
#  ('Abcès', 'NOM'),
#  ('Abcès périamygdalien', 'NOM ADJ'),
#  ('Abcès péri-amygdalien', 'NOM ADJ'),
#  ('Abcès péritonsillaire', 'NOM ADJ'),
#  ('Phlegmon amygdalien', 'NOM ADJ'),
#  ('Acide abscissique', 'NOM ADJ'),
#  ('Abscissine II', 'NOM NUM'),
#  ('Acide abscisique', 'NOM ADJ'),
#  ('Dormine', 'NAM'),
#  ('Absentéisme', 'NOM'),
#  ('Absorption', 'NOM'),
#  ('Indexation et rédaction du résumé comme sujet',
#   'NOM KON NOM PRP:det NOM ADV ADJ'),
#  ('Indexation et rédaction du résumé', 'NOM KON NOM PRP:det NOM'),
#  ('Rédaction du résumé et indexation', 'NOM PRP:det NOM KON NOM'),
#  ('Rédaction du résumé et indexation comme sujet',
#   'NOM PRP:det NOM KON NOM ADV ADJ'),
#  ('Indexation', 'NOM'),
#  ('Indexation comme sujet', 'NOM ADV ADJ'),
#  ('Index comme sujet', 'NOM ADV ADJ'),
#  ('Liste comme sujet', 'NOM ADV ADJ'),
#  ('Rédaction du résumé comme sujet', 'NOM PRP:det NOM ADV ADJ'),
#  ('Rédaction du résumé', 'NOM PRP:det NOM'),
#  ('Piliers dentaires', 'NOM ADJ'),
#  ('Butée dentaire', 'NOM ADJ'),
#  ("Dents d' ancrage", 'NOM PRP NOM'),
#  ('Dents piliers', 'NOM NOM'),
#  ('Piliers implantaires', 'NOM ADJ'),
#  ('Acacia', 'NOM'),
#  ('Acacia catechu', 'NOM NOM'),
#  ('Acacia à cachou', 'NOM PRP NOM'),
#  ('Cachoutier', 'NAM'),
#  ('Centres hospitaliers universitaires', 'NOM ADJ ADJ'),
#  ('CHU ( Centre Hospitalier Universitaire )', 'VER:pper PUN NOM ADJ ADJ PUN'),
#  ('CHU ( Centre Hospitalo-Universitaire )', 'VER:pper PUN NOM ADJ PUN'),
#  ('Centre médical universitaire', 'NOM ADJ ADJ'),
#  ('Centres hospitalo-universitaires', 'NOM ADJ'),
#  ('Centres médicaux universitaires', 'NOM ADJ ADJ'),
#  ('Centres médico-universitaires', 'NOM ADJ'),
#  ('Académies et instituts', 'NOM KON NOM'),
#  ('Instituts et Academies', 'NOM KON NOM'),
#  ('Instituts et écoles', 'NOM KON NOM'),
#  ('Écoles et instituts', 'NOM KON NOM'),
#  ('Instituts', 'NOM'),
#  ('Instituts de recherche', 'NOM PRP NOM'),
#  ('Centres de recherche', 'NOM PRP NOM'),
#  ('Académies', 'NOM'),
#  ('Acanthamoeba', 'NAM'),
#  ('Acanthocephala', 'NOM'),
#  ('Acanthocéphales', 'NOM'),
#  ('Vers à tête épineuse', 'PRP PRP NOM ADJ'),
#  ('Acanthocytes', 'NOM'),
#  ('Acanthocyte', 'NAM'),
#  ('Érythrocytes en anneaux', 'NOM PRP NOM'),
#  ('Acantholyse', 'NAM'),
#  ('Acanthosis nigricans', 'NOM NOM'),
#  ('Dystrophie papillaire et pigmentaire', 'NOM ADJ KON ADJ'),
#  ('Acari', 'NAM'),
#  ('Acariens', 'ADJ'),
#  ('Accélération', 'NOM'),
#  ('Nerf accessoire', 'NOM ADJ'),
#  ('Nerf accessoire de Willis', 'NOM ADJ PRP NAM'),
#  ('Nerf crânien 11', 'NOM ADJ NUM'),
#  ('Nerf crânien XI', 'NOM ADJ NUM'),
#  ('Nerf spinal accessoire', 'NOM ADJ ADJ'),
#  ('Onzième nerf crânien', 'ADJ NOM ADJ'),
#  ('Onzième paire crânienne', 'ADJ NOM ADJ'),
#  ('Prévention des accidents', 'NOM PRP:det NOM'),
#  ('Prédisposition aux accidents', 'NOM PRP:det NOM'),
#  ('Propension aux accidents', 'NOM PRP:det NOM'),
#  ('Tendance aux accidents', 'NOM PRP:det NOM'),
#  ('Chutes accidentelles', 'NOM ADJ'),
#  ('Chutes', 'NOM'),
#  ('Glissade et chute', 'NOM KON NOM'),
#  ('Accidents', 'NOM'),
#  ("Accidents d' aviation", 'NOM PRP NOM'),
#  ('Accidents aéronautiques', 'NOM ADJ'),
#  ("Accidents d' avions", 'NOM PRP NOM'),
#  ('Accidents domestiques', 'NOM ADJ'),
#  ('Accidents au domicile', 'NOM PRP:det NOM'),
#  ('Accidents du travail', 'NOM PRP:det NOM'),
#  ('Accidents de travail', 'NOM PRP NOM'),
#  ('Accidents en milieu professionnel', 'NOM PRP NOM ADJ'),
#  ('Accidents professionnels', 'NOM ADJ'),
#  ('Accidents sur le lieu de travail', 'NOM PRP DET:ART NOM PRP NOM'),
#  ('Accidents industriels', 'NOM ADJ'),
#  ('Accidents en milieu industriel', 'NOM PRP NOM ADJ'),
#  ('Accidents de la route', 'NOM PRP DET:ART NOM'),
#  ('Accidents de la circulation', 'NOM PRP DET:ART NOM'),
#  ('Acclimatation', 'NOM'),
#  ('Accommodation oculaire', 'NOM ADJ'),
#  ("Accommodation de l' oeil", 'NOM PRP DET:ART NOM'),
#  ('Accommodation des yeux', 'NOM PRP:det NOM'),
#  ('Accommodation du cristallin', 'NOM PRP:det NOM'),
#  ('Accommodation cristallinienne', 'NOM ADJ'),
#  ('Comptabilité', 'NOM'),
#  ('Industrie pétrolière et gazière', 'NOM ADJ KON ADJ'),
#  ('Industrie du gaz et du pétrole', 'NOM PRP:det NOM KON PRP:det NOM'),
#  ('Industrie du pétrole et du gaz', 'NOM PRP:det NOM KON PRP:det NOM'),
#  ('Industrie gazière et pétrolière', 'NOM ADJ KON ADJ'),
#  ('Industrie pétrolière', 'NOM ADJ'),
#  ('Industrie du pétrole', 'NOM PRP:det NOM'),
#  ('Industrie du pétrole brut', 'NOM PRP:det NOM ADJ'),
#  ('Industrie du gaz naturel', 'NOM PRP:det NOM ADJ'),
#  ('Industrie du charbon', 'NOM PRP:det NOM'),
#  ('Charbonnages', 'NOM'),
#  ('Industrie charbonnière', 'NOM ADJ'),
#  ('Industrie houillère', 'NOM ADJ'),
#  ('Conduite avec facultés affaiblies', 'NOM PRP NOM VER:pper'),
#  ('Alcool et conduite', 'NOM KON NOM'),
#  ('Conduite avec capacités affaiblies', 'NOM PRP NOM VER:pper'),
#  ("Conduite en état d' ivresse", 'NOM PRP NOM PRP NOM'),
#  ("Conduite en état d' ébriété", 'NOM PRP NOM PRP NOM'),
#  ("Conduite sous influence d' alcool , de drogues ou de médicaments",
#   'NOM PRP NOM PRP NOM PUN PRP NOM KON PRP NOM'),
#  ("Conduite sous l' influence d' alcool , de drogues ou de médicaments",
#   'NOM PRP DET:ART NOM PRP NOM PUN PRP NOM KON PRP NOM'),
#  ("L' alcool au volant", 'DET:ART NOM PRP:det NOM'),
#  ("L' alcool et la conduite", 'DET:ART NOM KON DET:ART NOM'),
#  ('Cellules souches embryonnaires humaines', 'NOM NOM ADJ ADJ'),
#  ('CSEh', 'NAM'),
#  ('Cellule souche embryonnaire humaine', 'NOM NOM ADJ ADJ'),
#  ('Cellules souches embryonnaires de souris', 'NOM NOM ADJ PRP NOM'),
#  ('CSEm', 'NAM'),
#  ('CSEs', 'NOM'),
#  ('Cellule souche embryonnaire de souris', 'NOM NOM ADJ PRP NOM'),
#  ('Cellule souche embryonnaire murine', 'NOM NOM ADJ ADJ'),
#  ('Cellules souches embryonnaires murines', 'NOM NOM ADJ ADJ'),
#  ('Cellules germinales embryonnaires', 'NOM ADJ ADJ'),
#  ('Cellule germinale embryonnaire', 'NOM ADJ ADJ'),
#  ('Cellules embryonnaires germinales', 'NOM ADJ ADJ'),
#  ('Efficacité au travail', 'NOM PRP:det NOM'),
#  ('Rendement au travail', 'NOM PRP:det NOM'),
#  ('Efficacité professionnelle', 'NOM ADJ'),
#  ('Rendement professionnel', 'NOM ADJ'),
#  ('Comportement criminel', 'NOM ADJ'),
#  ('Comportement contraire à la loi', 'NOM ADJ PRP DET:ART NOM'),
#  ('Comportement illicite', 'NOM ADJ'),
#  ('Comportement illégal', 'NOM ADJ'),
#  ('Comportements illégaux', 'NOM ADJ'),
#  ('Conduite contraire à la loi', 'NOM ADJ PRP DET:ART NOM'),
#  ('Conduite criminelle', 'NOM ADJ'),
#  ('Conduite illicite', 'NOM ADJ'),
#  ('Conduite illégale', 'NOM ADJ'),
#  ('Intention criminelle', 'NOM ADJ'),
#  ('Prise de décision clinique', 'NOM PRP NOM ADJ'),
#  ('Prise de décision médicale', 'NOM PRP NOM ADJ'),
#  ('Vieillissement cognitif', 'NOM ADJ'),
#  ('Neurosciences cognitives', 'NOM ADJ'),
#  ('Ajustement émotionnel', 'NOM ADJ'),
#  ('Adaptation émotionnelle', 'NOM ADJ'),
#  ('Reconnaissance faciale', 'NOM ADJ'),
#  ('Reconnaissance de visage', 'NOM PRP NOM'),
#  ("Reconnaissance d' identité", 'NOM PRP NOM'),
#  ('Grands-parents', 'NOM'),
#  ('Grand-parent', 'NAM'),
#  ('Grand-mère', 'NOM'),
#  ('Grands-mères', 'NOM'),
#  ('Grand-père', 'NOM'),
#  ('Grands-pères', 'NOM'),
#  ("Comportement de recherche d' aide", 'NOM PRP NOM PRP NOM'),
#  ('Heuristique', 'ADJ'),
#  ('Méthode empirique', 'NOM ADJ'),
#  ('Règle empirique', 'NOM ADJ'),
#  ('Règle générale', 'NOM ADJ'),
#  ('Violence envers le partenaire intime', 'NOM PRP DET:ART NOM ADJ'),
#  ('Violence envers la conjointe', 'NOM PRP DET:ART NOM'),
#  ('Violence envers la partenaire intime', 'NOM PRP DET:ART NOM ADJ'),
#  ('Violence envers le conjoint', 'NOM PRP DET:ART NOM'),
#  ("Violence à l' égard de la conjointe",
#   'NOM PRP DET:ART NOM PRP DET:ART NOM'),
#  ("Violence à l' égard de la partenaire intime",
#   'NOM PRP DET:ART NOM PRP DET:ART NOM ADJ'),
#  ("Violence à l' égard du conjoint", 'NOM PRP DET:ART NOM PRP:det NOM'),
#  ("Violence à l' égard du partenaire intime",
#   'NOM PRP DET:ART NOM PRP:det NOM ADJ'),
#  ('Violence dans les fréquentations', 'NOM PRP DET:ART NOM'),
#  ('Violence dans les fréquentations amoureuses', 'NOM PRP DET:ART NOM ADJ'),
#  ('Rééducation neurologique', 'NOM ADJ'),
#  ('Neuroréadaptation', 'NOM'),
#  ('Neurorééducation', 'NOM'),
#  ('Réadaptation neurologique', 'NOM ADJ'),
#  ('Sévices', 'NOM'),
#  ('Violence physique', 'NOM ADJ'),
#  ('Comportement déviant', 'NOM ADJ'),
#  ('Conduite déviante', 'NOM ADJ'),
#  ('Problème comportemental', 'NOM ADJ'),
#  ('Problème de comportement', 'NOM PRP NOM'),
#  ('Problèmes comportementaux', 'NOM ADJ'),
#  ('Comportement dysfonctionnel ( psychologie )', 'NOM ADJ PUN NOM PUN'),
#  ('Psychologie du comportement dysfonctionnel', 'NOM PRP:det NOM ADJ'),
#  ('Comportement perturbateur', 'NOM ADJ'),
#  ("Consommation d' alcool par les mineurs", 'NOM PRP NOM PRP DET:ART ADJ'),
#  ("Consommation d' alcool chez les adolescentes",
#   'NOM PRP NOM PRP DET:ART NOM'),
#  ("Consommation d' alcool chez les adolescents",
#   'NOM PRP NOM PRP DET:ART NOM'),
#  ("Consommation d' alcool chez les jeunes", 'NOM PRP NOM PRP DET:ART NOM'),
#  ("Consommation d' alcool chez les mineures", 'NOM PRP NOM PRP DET:ART NOM'),
#  ("Consommation d' alcool chez les mineurs", 'NOM PRP NOM PRP DET:ART ADJ'),
#  ("Consommation d' alcool par les adolescentes",
#   'NOM PRP NOM PRP DET:ART NOM'),
#  ("Consommation d' alcool par les adolescents", 'NOM PRP NOM PRP DET:ART NOM'),
#  ("Consommation d' alcool par les jeunes", 'NOM PRP NOM PRP DET:ART NOM'),
#  ("Consommation d' alcool par les mineures", 'NOM PRP NOM PRP DET:ART NOM'),
#  ("L' alcool chez les adolescentes", 'DET:ART NOM PRP DET:ART NOM'),
#  ("L' alcool chez les adolescents", 'DET:ART NOM PRP DET:ART NOM'),
#  ("L' alcool chez les jeunes", 'DET:ART NOM PRP DET:ART NOM'),
#  ("L' alcool chez les mineures", 'DET:ART NOM PRP DET:ART NOM'),
#  ("L' alcool chez les mineurs", 'DET:ART NOM PRP DET:ART ADJ'),
#  ('Âge légal pour boire', 'NOM ADJ PRP VER:infi'),
#  ("Âge légal pour boire de l' alcool", 'NOM ADJ PRP VER:infi PRP DET:ART NOM'),
#  ("Âge légal pour consommer de l' alcool",
#   'NOM ADJ PRP VER:infi PRP DET:ART NOM'),
#  ('Âge minimum légal pour boire', 'NOM NOM ADJ PRP VER:infi'),
#  ("Âge minimum légal pour boire de l' alcool",
#   'NOM NOM ADJ PRP VER:infi PRP DET:ART NOM'),
#  ("Âge minimum légal pour consommer de l' alcool",
#   'NOM NOM ADJ PRP VER:infi PRP DET:ART NOM'),
#  ('Âge minimum pour boire', 'NOM NOM PRP VER:infi'),
#  ("Âge minimum pour boire de l' alcool",
#   'NOM NOM PRP VER:infi PRP DET:ART NOM'),
#  ("Âge minimum pour consommer de l' alcool",
#   'NOM NOM PRP VER:infi PRP DET:ART NOM'),
#  ('Expression génique ectopique', 'NOM ADJ ADJ'),
#  ('Expression ectopique', 'NOM ADJ'),
#  ("Expression ectopique d' un gène", 'NOM ADJ PRP DET:ART NOM'),
#  ('Expression ectopique de gènes', 'NOM ADJ PRP NOM'),
#  ('Plasticité cellulaire', 'NOM ADJ'),
#  ('Plasticité de la cellule', 'NOM PRP DET:ART NOM'),
#  ('Plasticité des cellules', 'NOM PRP:det NOM'),
#  ('Auto-renouvellement cellulaire', 'NOM ADJ'),
#  ('Auto-renouvellement des cellules', 'NOM PRP:det NOM'),
#  ('Autorenouvellement cellulaire', 'NOM ADJ'),
#  ('Auto-renouvellement des cellules souches', 'NOM PRP:det NOM NOM'),
#  ('Autorenouvellement des cellules souches', 'NOM PRP:det NOM NOM'),
#  ('Renouvellement des cellules souches', 'NOM PRP:det NOM NOM'),
#  ('Recherche en réadaptation', 'NOM PRP NOM'),
#  ('Recherche en réhabilitation', 'NOM PRP NOM'),
#  ('Orthodontistes', 'NOM'),
#  ('Orthopédistes dento-faciaux', 'NOM ADJ'),
#  ('Orthopédiste dento-facial', 'ADJ NOM'),
#  ('Orthopédistes dentofaciaux', 'NOM ADJ'),
#  ('Chirurgiens buccaux et maxillo-faciaux', 'NOM ADJ KON ADJ'),
#  ('Chirurgien buccal', 'NOM ADJ'),
#  ('Chirurgien buccal et maxillo-facial', 'NOM ADJ KON ADJ'),
#  ('Chirurgien maxillo-facial', 'NOM ADJ'),
#  ('Chirurgiens buccaux', 'NOM ADJ'),
#  ('Chirurgiens maxillo-faciaux', 'NOM ADJ'),
#  ('Exodontistes', 'NOM'),
#  ('Neuroprotection', 'NOM'),
#  ('Protection des neurones', 'NOM PRP:det NOM'),
#  ('Protection neuronale', 'NOM ADJ'),
#  ('Alimentation et nutrition', 'NOM KON NOM'),
#  ('Régime alimentaire et nutrition', 'NOM ADJ KON NOM'),
#  ('Régime alimentaire , aliments et nutrition', 'NOM ADJ PUN NOM KON NOM'),
#  ('Triticale', 'NOM'),
#  ('Résultats des soins intensifs', 'NOM PRP:det NOM ADJ'),
#  ('Résultats des soins aux malades en phase critique',
#   'NOM PRP:det NOM PRP:det NOM PRP NOM ADJ'),
#  ('Résultats des soins aux patientes en phase critique',
#   'NOM PRP:det NOM PRP:det NOM PRP NOM ADJ'),
#  ('Résultats des soins aux patients en phase critique',
#   'NOM PRP:det NOM PRP:det NOM PRP NOM ADJ'),
#  ('Formation par simulation', 'NOM PRP NOM'),
#  ('Formation par la simulation', 'NOM PRP DET:ART NOM'),
#  ('Apprentissage interactif', 'NOM ADJ'),
#  ('Apprentissage par interaction', 'NOM PRP NOM'),
#  ("Apprentissage par l' interaction", 'NOM PRP DET:ART NOM'),
#  ('Millets', 'NOM'),
#  ('Sciences biocomportementales', 'NOM ADJ'),
#  ('Approche biocomportementale', 'NOM ADJ'),
#  ('Modèle biocomportemental', 'NOM ADJ'),
#  ('Modèles biocomportementaux', 'NOM ADJ'),
#  ('Sciences bio-comportementales', 'NOM ADJ'),
#  ('Couronne de protéines', 'NOM PRP NOM'),
#  ('Végétariens', 'ADJ'),
#  ('Végétariennes', 'ADJ'),
#  ('Végétariens ovo-lacto', 'ADJ NOM'),
#  ('Lacto-ovo végétariennes', 'NOM ADJ'),
#  ('Lacto-ovo végétariens', 'NOM ADJ'),
#  ('Ovo-lacto végétariennes', 'NOM ADJ'),
#  ('Ovo-lacto végétariens', 'NOM ADJ'),
#  ('Ovolactovégétariennes', 'NOM'),
#  ('Ovolactovégétariens', 'NOM'),
#  ('Végétariennes ovo-lacto', 'ADJ NOM'),
#  ('Végétaliens', 'NAM'),
#  ('Végétaliennes', 'NAM'),
#  ('Dettes actives et passives', 'NOM ADJ KON ADJ'),
#  ('Dettes et créances', 'NOM KON NOM'),
#  ('Dettes et créances commerciales', 'NOM KON NOM ADJ'),
#  ('Dettes passives', 'NOM ADJ'),
#  ('Dettes commerciales', 'NOM ADJ'),
#  ('Dettes fournisseurs', 'NOM NOM'),
#  ('Sports pour les jeunes', 'NOM PRP DET:ART NOM'),
#  ('Activités sportives pour la jeunesse', 'NOM ADJ PRP DET:ART NOM'),
#  ('Activités sportives pour les adolescentes', 'NOM ADJ PRP DET:ART NOM'),
#  ('Activités sportives pour les adolescents', 'NOM ADJ PRP DET:ART NOM'),
#  ('Activités sportives pour les enfants', 'NOM ADJ PRP DET:ART NOM'),
#  ('Activités sportives pour les jeunes', 'NOM ADJ PRP DET:ART NOM'),
#  ('Sports pour la jeunesse', 'NOM PRP DET:ART NOM'),
#  ('Sports pour les adolescentes', 'NOM PRP DET:ART NOM'),
#  ('Sports pour les adolescents', 'NOM PRP DET:ART NOM'),
#  ('Sports pour les enfants', 'NOM PRP DET:ART NOM'),
#  ('Activités sportives organisées pour les jeunes',
#   'NOM ADJ VER:pper PRP DET:ART NOM'),
#  ('Activités sportives organisées pour la jeunesse',
#   'NOM ADJ VER:pper PRP DET:ART NOM'),
#  ("Activités sportives organisées à l' intention de la jeunesse",
#   'NOM ADJ VER:pper PRP DET:ART NOM PRP DET:ART NOM'),
#  ("Activités sportives organisées à l' intention des jeunes",
#   'NOM ADJ VER:pper PRP DET:ART NOM PRP:det NOM'),
#  ('Lettrisme', 'NOM'),
#  ('Alphabétisme', 'NOM'),
#  ("Capacité de lire et d' écrire", 'NOM PRP VER:infi KON PRP VER:infi'),
#  ('Littéracie', 'NAM'),
#  ('Littératie', 'NOM'),
#  ('Littérisme', 'NOM'),
#  ('Illettrisme', 'NOM'),
#  ('Analphabétisme', 'NOM'),
#  ('Malnutrition aigüe sévère', 'NOM NOM ADJ'),
#  ('Malnutrition aiguë sévère', 'NOM ADJ ADJ'),
#  ('Malnutrition sévère aigüe', 'NOM ADJ NOM'),
#  ('Services bancaires aux particuliers', 'NOM ADJ PRP:det NOM'),
#  ('Comptes bancaires', 'NOM ADJ'),
#  ('Comptes en banque', 'NOM PRP NOM'),
#  ('Opérations bancaires des particuliers', 'NOM ADJ PRP:det NOM'),
#  ('Opérations bancaires personnelles', 'NOM ADJ ADJ'),
#  ('Opérations de banque commerciale', 'NOM PRP NOM ADJ'),
#  ('Opérations de banque financière', 'NOM PRP NOM ADJ'),
#  ('Services bancaires commerciaux', 'NOM ADJ ADJ'),
#  ('Services bancaires personnels', 'NOM ADJ ADJ'),
#  ("Comptes d' épargne", 'NOM PRP NOM'),
#  ('Comptes courants', 'NOM ADJ'),
#  ('Comptes chèques', 'NOM NOM'),
#  ('Comptes de chèques', 'NOM PRP NOM'),
#  ('Comptes-chèques', 'NAM'),
#  ("Conception d' installations fondée sur des données probantes",
#   'NOM PRP NOM VER:pper PRP PRP:det NOM ADJ'),
#  ('Conception des installations fondée sur des données probantes',
#   'NOM PRP:det NOM ADJ PRP PRP:det NOM ADJ'),
#  ('Apparence corporelle', 'NOM ADJ'),
#  ('Apparence du corps', 'NOM PRP:det NOM'),
#  ('Apparence extérieure', 'NOM ADJ'),
#  ('Apparence physique', 'NOM ADJ'),
#  ('Aspect physique', 'NOM ADJ'),
#  ('Jus de fruits et de légumes', 'NOM PRP NOM KON PRP NOM'),
#  ('Jus de fruit et de légume', 'NOM PRP NOM KON PRP NOM'),
#  ('Jus de légumes', 'NOM PRP NOM'),
#  ('Jus de légume', 'NOM PRP NOM'),
#  ('Jus de fruits', 'NOM PRP NOM'),
#  ('Jus de fruit', 'NOM PRP NOM'),
#  ('Beurre clarifié', 'NOM VER:pper'),
#  ('Ghee', 'NOM'),
#  ('Ghi', 'NAM'),
#  ('Ghî', 'NOM'),
#  ('Huile de beurre', 'NOM PRP NOM'),
#  ('Matière grasse anhydre du beurre', 'NOM ADJ ADJ PRP:det NOM'),
#  ('Fracturation hydraulique', 'NOM ADJ'),
#  ('Fracturation hydrosiliceuse', 'NOM ADJ'),
#  ('Hydrofracturation', 'NAM'),
#  ('Traumatisme psychologique', 'NOM ADJ'),
#  ('Choc psychotraumatique', 'NOM ADJ'),
#  ('Psychotraumatisme', 'NOM'),
#  ('Trauma psychologique', 'NOM ADJ'),
#  ('Traumatisme psychique', 'NOM ADJ'),
#  ('Influence du groupe', 'NOM PRP:det NOM'),
#  ('Influence des pairs', 'NOM PRP:det NOM'),
#  ('Pression du groupe', 'NOM PRP:det NOM'),
#  ('Pression des pairs', 'NOM PRP:det NOM'),
#  ('Produits à base de légumes', 'NOM PRP NOM PRP NOM'),
#  ('Produit végétal', 'NOM ADJ'),
#  ("Produits d' origine végétale", 'NOM PRP NOM ADJ'),
#  ('Produits de légumes', 'NOM PRP NOM'),
#  ('Produits végétaux', 'NOM ADJ'),
#  ("Publicité s' adressant directement au consommateur",
#   'NOM PRO:PER VER:ppre ADV PRP:det NOM'),
#  ('Commercialisation destinée directement au consommateur',
#   'NOM VER:pper ADV PRP:det NOM'),
#  ('Commercialisation directe au consommateur', 'NOM ADJ PRP:det NOM'),
#  ('Marketing destiné directement au consommateur',
#   'NOM VER:pper ADV PRP:det NOM'),
#  ('Marketing direct au consommateur', 'NOM ADJ PRP:det NOM'),
#  ('Publicité directe au consommateur', 'NOM ADJ PRP:det NOM'),
#  ('Dépistage et analyse proposés directement au consommateur',
#   'NOM KON VER:pres VER:pper ADV PRP:det NOM'),
#  ('Analyse proposée directement au consommateur',
#   'VER:pres VER:pper ADV PRP:det NOM'),
#  ('Dépistage proposé directement au consommateur',
#   'NOM VER:pper ADV PRP:det NOM'),
#  ('Vésicules extracellulaires', 'NOM ADJ'),
#  ('Exovésicules', 'NOM'),
#  ('Corps apoptotiques', 'NOM ADJ'),
#  ('Corps apoptotique', 'NOM ADJ'),
#  ('Virus fongiques', 'NOM ADJ'),
#  ('Mycovirus', 'NOM'),
#  ('Virus des champignons', 'NOM PRP:det NOM'),
#  ('Virus fongique', 'NOM ADJ'),
#  ('Télocytes', 'NOM'),
#  ('Cellule de type cellule interstitielle de Cajal',
#   'NOM PRP NOM NOM ADJ PRP NAM'),
#  ('Cellule interstitielle de type Cajal', 'NOM ADJ PRP NOM NAM'),
#  ('Cellules de type cellules interstitielles de Cajal',
#   'NOM PRP NOM NOM ADJ PRP NAM'),
#  ('Cellules interstitielles de type Cajal', 'NOM ADJ PRP NOM NAM'),
#  ('Télocyte', 'NAM'),
#  ("Dispositif d' exosquelette", 'NOM PRP NOM'),
#  ('Exosquelette robotisé', 'NOM VER:pper'),
#  ('Hypersensibilité aux fruits de mer', 'NOM PRP:det NOM PRP NOM'),
#  ('Allergie aux fruits de mer', 'NOM PRP:det NOM PRP NOM'),
#  ('Échec des secours ( soins de santé )',
#   'NOM PRP:det NOM PUN NOM PRP NOM PUN'),
#  ('Non-sauvetage ( soins de santé )', 'NOM PUN NOM PRP NOM PUN'),
#  ('Réadaptation psychiatrique', 'NOM ADJ'),
#  ('Réadaptation en santé mentale', 'NOM PRP NOM ADJ'),
#  ('Réadaptation psychosociale', 'NOM ADJ'),
#  ('Réhabilitation en santé mentale', 'NOM PRP NOM ADJ'),
#  ('Réhabilitation psychiatrique', 'NOM ADJ'),
#  ('Réhabilitation psychosociale', 'NOM ADJ'),
#  ('Aggravation transitoire des symptômes', 'NOM ADJ PRP:det NOM'),
#  ('Aggravation passagère des symptômes', 'NOM ADJ PRP:det NOM'),
#  ('Exacerbation passagère des symptômes', 'NOM ADJ PRP:det NOM'),
#  ('Exacerbation transitoire des symptômes', 'NOM ADJ PRP:det NOM'),
#  ('Préparation de coeur isolé', 'NOM PRP NOM ADJ'),
#  ('Modèle de cœur isolé et perfusé', 'NOM PRP NOM VER:pper KON VER:pper'),
#  ('Modèle de cœur isolé perfusé', 'NOM PRP NOM VER:pper VER:pper'),
#  ('Coeur perfusé de Langendorff', 'NOM VER:pper PRP NAM'),
#  ('Coeur perfusé selon Langendorff', 'NOM VER:pper PRP NAM'),
#  ('Préparation de cœur isolé perfusé de Langendorff',
#   'NOM PRP NOM ADJ VER:pper PRP NAM'),
#  ('Préparation de cœur isolé perfusé selon Langendorff',
#   'NOM PRP NOM ADJ VER:pper PRP NAM'),
#  ('Technique de préparation de coeur travaillant', 'NOM PRP NOM PRP NOM ADJ'),
#  ('Préparation de coeur travaillant', 'NOM PRP NOM ADJ'),
#  ('Préparation de coeur au travail', 'NOM PRP NOM PRP:det NOM'),
#  ('Technique de préparation de coeur isolé', 'NOM PRP NOM PRP NOM ADJ'),
#  ('Régime végétalien', 'NOM ADJ'),
#  ('Régime alimentaire végétalien', 'NOM ADJ ADJ'),
#  ('Végétalisme', 'NOM'),
#  ("Techniques d' observation du comportement", 'ADJ PRP NOM PRP:det NOM'),
#  ('Observation comportementale', 'NOM ADJ'),
#  ('Observation du comportement', 'NOM PRP:det NOM'),
#  ("Techniques d' observation comportementale", 'ADJ PRP NOM ADJ'),
#  ("Échelle d' évaluation du comportement", 'NOM PRP NOM PRP:det NOM'),
#  ('Échelle comportementale', 'NOM ADJ'),
#  ("Échelle d' évaluation comportementale", 'NOM PRP NOM ADJ'),
#  ('Échelle de comportement', 'NOM PRP NOM'),
#  ('Test de comportement', 'NOM PRP NOM'),
#  ('Test comportemental', 'NOM ADJ'),
#  ('Tests comportementaux', 'NOM ADJ'),
#  ("Consommation d' alcool dans les universités",
#   'NOM PRP NOM PRP DET:ART NOM'),
#  ("Consommation d' alcool chez les étudiantes", 'NOM PRP NOM PRP DET:ART NOM'),
#  ("Consommation d' alcool chez les étudiants", 'NOM PRP NOM PRP DET:ART NOM'),
#  ("Consommation d' alcool dans les établissements d' enseignement supérieur",
#   'NOM PRP NOM PRP DET:ART NOM PRP NOM ADJ'),
#  ("Consommation d' alcool des étudiantes", 'NOM PRP NOM PRP:det NOM'),
#  ("Consommation d' alcool des étudiants", 'NOM PRP NOM PRP:det NOM'),
#  ('Obésité métaboliquement bénigne', 'NOM NOM ADJ'),
#  ('Obésité métaboliquement normale', 'NOM NOM ADJ'),
#  ('Obésité métaboliquement saine', 'NOM NOM ADJ'),
#  ('Obésité sans anomalie métabolique', 'NOM PRP NOM ADJ'),
#  ('Grains complets', 'NOM ADJ'),
#  ('Grains entiers', 'NOM ADJ'),
#  ('Céréales complètes', 'NOM ADJ'),
#  ('Chirurgie endoscopique transanale', 'NOM ADJ ADJ'),
#  ('Chirurgie transanale endoscopique', 'NOM ADJ ADJ'),
#  ('Interventions de chirurgie endoscopique transanale', 'NOM PRP NOM ADJ ADJ'),
#  ('Microchirurgie endoscopique transanale', 'NOM ADJ ADJ'),
#  ('Microchirurgie transanale endoscopique', 'NOM ADJ ADJ'),
#  ('Lésion due au froid', 'NOM VER:pper PRP:det NOM'),
#  ('Accident dû au froid', 'NOM VER:pper PRP:det NOM'),
#  ('Équipement de protection individuelle', 'NOM PRP NOM ADJ'),
#  ('EPI ( Équipement de Protection Individuelle )',
#   'NAM PUN NOM PRP NOM ADJ PUN'),
#  ('Matériel de protection individuel', 'ADJ PRP NOM ADJ'),
#  ('Matériel de protection individuelle', 'ADJ PRP NOM ADJ'),
#  ('Matériel individuel de protection', 'ADJ NOM PRP NOM'),
#  ('Équipement de protection individuel', 'NOM PRP NOM ADJ'),
#  ('Équipement individuel de protection', 'NOM ADJ PRP NOM'),
#  ('Agents neurotoxiques', 'NOM ADJ'),
#  ('Agents innervants', 'NOM ADJ'),
#  ('Gaz innervant', 'NOM VER:ppre'),
#  ('Gaz innervants', 'NOM ADJ'),
#  ('Gaz neurotoxique', 'NOM ADJ'),
#  ('Gaz neurotoxiques', 'NOM ADJ'),
#  ('Blessures de guerre', 'NOM PRP NOM'),
#  ('Blessures liées à la guerre', 'NOM VER:pper PRP DET:ART NOM'),
#  ('Traumatisme de guerre', 'NOM PRP NOM'),
#  ('Traumatisme lié à la guerre', 'NOM VER:pper PRP DET:ART NOM'),
#  ('Échelle de mesure des mouvements involontaires anormaux',
#   'NOM PRP NOM PRP:det NOM ADJ ADJ'),
#  ('AIMS', 'NOM'),
#  ('Abnormal involuntary movement scale', 'ADJ NOM NOM ADJ'),
#  ('Échelle des mouvements involontaires anormaux', 'NOM PRP:det NOM ADJ ADJ'),
#  ('Alcoolémie', 'NOM'),
#  ("Taux d' alcool dans le sang", 'NOM PRP NOM PRP DET:ART NOM'),
#  ("Taux d' alcool sanguin", 'NOM PRP NOM ADJ'),
#  ("Taux d' alcoolémie", 'NOM PRP NOM'),
#  ('Trouble de la communication sociale', 'NOM PRP DET:ART NOM ADJ'),
#  ('Trouble de la communication pragmatique', 'NOM PRP DET:ART NOM ADJ'),
#  ('Services juridiques', 'NOM ADJ'),
#  ('Diffamation', 'NOM'),
#  ('Calomnie', 'NOM'),
#  ('Diffamation verbale', 'NOM ADJ'),
#  ('Diffamation orale', 'NOM ADJ'),
#  ('Propos diffamatoire', 'NOM ADJ'),
#  ('Propos diffamatoires', 'NOM ADJ'),
#  ('Libelle', 'NOM'),
#  ('Diffamation par écrit', 'NOM PRP NOM'),
#  ('Diffamation écrite', 'NOM VER:pper'),
#  ('Écrit diffamatoire', 'VER:pres ADJ'),
#  ('Thérapie de maitrise de la colère', 'NOM PRP VER:pres PRP DET:ART NOM'),
#  ('Formation en maitrise de la colère',
#   'NOM PRO:PER VER:pres PRP DET:ART NOM'),
#  ('Maitrise de la colère', 'VER:pres PRP DET:ART NOM'),
#  ('Thérapie de maîtrise de la colère', 'NOM PRP NOM PRP DET:ART NOM'),
#  ('Psychologie du sport', 'NOM PRP:det NOM'),
#  ('Psychologie des sports', 'NOM PRP:det NOM'),
#  ('Psychologie sportive', 'NOM ADJ'),
#  ('Exposition à la guerre', 'NOM PRP DET:ART NOM'),
#  ("Trouble de la fluence verbale débutant dans l' enfance",
#   'NOM PRP DET:ART NOM ADJ VER:ppre PRP DET:ART NOM'),
#  ('Patients ne se présentant pas à leurs rendez -vous',
#   'ADJ ADV PRO:PER VER:ppre ADV PRP DET:POS VER:pres PRO:PER'),
#  ('Absence des patients', 'NOM PRP:det NOM'),
#  ('Absentéisme des patients', 'NOM PRP:det NOM'),
#  ('Malades ne se présentant pas à leurs rendez -vous',
#   'ADJ ADV PRO:PER VER:ppre ADV PRP DET:POS VER:pres PRO:PER'),
#  ('Non-présentation des patients', 'NOM PRP:det NOM'),
#  ('Patient ne se présentant pas à ses rendez -vous',
#   'ADJ ADV PRO:PER VER:ppre ADV PRP DET:POS VER:pres PRO:PER'),
#  ('Patient ne se présentant pas à son rendez -vous',
#   'ADJ ADV PRO:PER VER:ppre ADV PRP DET:POS VER:pres PRO:PER'),
#  ('Patientes ne se présentant pas à leurs rendez -vous',
#   'ADJ ADV PRO:PER VER:ppre ADV PRP DET:POS VER:pres PRO:PER'),
#  ('Patients ne se présentant pas à leur rendez -vous',
#   'ADJ ADV PRO:PER VER:ppre ADV PRP PRO:PER VER:pres PRO:PER'),
#  ('Techniques de reprogrammation cellulaire', 'ADJ PRP NOM ADJ'),
#  ('Techniques de programmation cellulaire', 'ADJ PRP NOM ADJ'),
#  ('Techniques de programmation de cellules', 'ADJ PRP NOM PRP NOM'),
#  ('Techniques de reprogrammation de cellules', 'ADJ PRP NOM PRP NOM'),
#  ('Techniques de différenciation dirigée', 'ADJ PRP NOM VER:pper'),
#  ('Techniques de reprogrammation cellulaire directe', 'ADJ PRP NOM ADJ ADJ'),
#  ('Techniques de reprogrammation directe de cellules',
#   'ADJ PRP NOM ADJ PRP NOM'),
#  ('Métacognition', 'NOM'),
#  ('Conscience métacognitive', 'NOM ADJ'),
#  ('Surveillance métacognitive', 'NOM ADJ'),
#  ('Contrôle métacognitif', 'NOM ADJ'),
#  ('Métamémoire', 'NOM'),
#  ('Compétence métacognitive', 'NOM ADJ'),
#  ('Connaissance métacognitive', 'NOM ADJ'),
#  ('Savoir métacognitif', 'NOM ADJ'),
#  ('Abus de médicaments sur ordonnance', 'NOM PRP NOM PRP NOM'),
#  ("Abus de médicaments d' ordonnance", 'NOM PRP NOM PRP NOM'),
#  ('Abus de médicaments délivrés sur ordonnance',
#   'NOM PRP NOM VER:pper PRP NOM'),
#  ('Surutilisation de médicaments sur ordonnance', 'NOM PRP NOM PRP NOM'),
#  ('Utilisation excessive de médicaments sur ordonnance',
#   'NOM ADJ PRP NOM PRP NOM'),
#  ('Incident critique en soins de santé', 'NOM ADJ PRP NOM PRP NOM'),
#  ('Accident évité de justesse en soins de santé',
#   'NOM VER:pper PRP NOM PRP NOM PRP NOM'),
#  ("Presqu'accident en soins de santé", 'NOM PRP NOM PRP NOM'),
#  ('Presque-accident en soins de santé', 'NOM PRP NOM PRP NOM'),
#  ('Quasi-accident en soins de santé', 'NOM PRP NOM PRP NOM'),
#  ("Thérapie par l' interférence par ARN", 'NOM PRP DET:ART NOM PRP NAM'),
#  ("Thérapeutique basée sur l' interférence par ARN",
#   'NOM VER:pper PRP DET:ART NOM PRP NAM'),
#  ("Thérapeutique par l' interférence par ARN", 'NOM PRP DET:ART NOM PRP NAM'),
#  ("Thérapie basée sur l' interférence par ARN",
#   'NOM VER:pper PRP DET:ART NOM PRP NAM'),
#  ("Traitement basé sur l' interférence par ARN",
#   'NOM VER:pper PRP DET:ART NOM PRP NAM'),
#  ("Traitement par l' interférence par ARN", 'NOM PRP DET:ART NOM PRP NAM'),
#  ('Diffusion dynamique de la lumière', 'NOM ADJ PRP DET:ART NOM'),
#  ('DDL ( Diffusion Dynamique de la Lumière )',
#   'NAM PUN NOM ADJ PRP DET:ART NOM PUN'),
#  ('Diffusion quasi élastique de la lumière', 'NOM ADV ADJ PRP DET:ART NOM'),
#  ('DQEL', 'NAM'),
#  ('Temps de pause en soins de santé', 'NOM PRP NOM PRP NOM PRP NOM'),
#  ('Time out en soins de santé', 'VER:cond ADV PRP NOM PRP NOM'),
#  ('Temps de pause en chirurgie', 'NOM PRP NOM PRP NOM'),
#  ('Time out en chirurgie', 'VER:cond ADV PRP NOM'),
#  ('Analyse des modes de défaillance et de leurs effets en soins de santé',
#   'NOM PRP:det NOM PRP NOM KON PRP DET:POS NOM PRP NOM PRP NOM'),
#  ('HFMEA', 'NAM'),
#  ('Healthcare failure mode and effect analysis',
#   'NAM VER:pres NOM ADJ ADJ NOM'),
#  ('Analyse des modes de défaillance et de leurs effets',
#   'NOM PRP:det NOM PRP NOM KON PRP DET:POS NOM'),
#  ('AMDC', 'NAM'),
#  ('AMDE', 'NAM'),
#  ('Analyse des modes de défaillance et de leurs conséquences',
#   'NOM PRP:det NOM PRP NOM KON PRP DET:POS NOM'),
#  ('FMEA', 'NAM'),
#  ('Failure mode and effect analysis', 'NOM NOM ADJ ADJ NOM'),
#  ('Possession ( anthropologie )', 'NOM PUN NOM PUN'),
#  ('Idées de possession', 'NOM PRP NOM'),
#  ('Possession démoniaque', 'NOM ADJ'),
#  ('Possession par un démon', 'NOM PRP DET:ART NOM'),
#  ('Possession par un esprit', 'NOM PRP DET:ART NOM'),
#  ('Gestion des ressources en équipe en soins de santé',
#   'NOM PRP:det NOM PRP NOM PRP NOM PRP NOM'),
#  ('CRM santé', 'NAM NOM'),
#  ('Gestion des ressources en équipe dans le domaine de la santé',
#   'NOM PRP:det NOM PRP NOM PRP DET:ART NOM PRP DET:ART NOM'),
#  ('Gestion des ressources en équipe dans le secteur de la santé',
#   'NOM PRP:det NOM PRP NOM PRP DET:ART NOM PRP DET:ART NOM'),
#  ('Gestion des risques en équipe en soins de santé',
#   'NOM PRP:det NOM PRP NOM PRP NOM PRP NOM'),
#  ('Gestion du travail en équipe dans le domaine de la santé',
#   'NOM PRP:det NOM PRP NOM PRP DET:ART NOM PRP DET:ART NOM'),
#  ('Gestion du travail en équipe dans le secteur de la santé',
#   'NOM PRP:det NOM PRP NOM PRP DET:ART NOM PRP DET:ART NOM'),
#  ('Gestion du travail en équipe en soins de santé',
#   'NOM PRP:det NOM PRP NOM PRP NOM PRP NOM'),
#  ('Heuristique informatique', 'NOM ADJ'),
#  ('Ataxines', 'NOM'),
#  ('Protéines des ataxies spinocérébelleuses', 'NOM PRP:det NOM ADJ'),
#  ('Alarmines', 'NOM'),
#  ('Alarmine', 'NAM'),
#  ('Protéines alarmine', 'NOM ADJ'),
#  ('Produits de comblement dermique', 'NOM PRP NOM ADJ'),
#  ('Agents de comblement cutané', 'NOM PRP NOM ADJ'),
#  ('Agents de comblement dermique', 'NOM PRP NOM ADJ'),
#  ('Produit de comblement cutané', 'NOM PRP NOM ADJ'),
#  ('Produit de comblement dermique', 'NOM PRP NOM ADJ'),
#  ('Produits de comblement cutané', 'NOM PRP NOM ADJ'),
#  ("Spectre d' action", 'NOM PRP NOM'),
#  ('Diplomatie', 'NOM'),
#  ('Accumulation de mutations', 'NOM PRP NOM'),
#  ('Accumulation de mutations spontanées', 'NOM PRP NOM ADJ'),
#  ("Sites internes d' entrée des ribosomes", 'NOM ADJ PRP NOM PRP:det NOM'),
#  ('IRES', 'NOM'),
#  ('Internal ribosome entry site', 'ADJ NOM ADJ NOM'),
#  ("Site d' entrée interne du ribosome", 'NOM PRP NOM ADJ PRP:det NOM'),
#  ("Site interne d' entrée du ribosome", 'NOM ADJ PRP NOM PRP:det NOM'),
#  ("Sites d' entrée interne des ribosomes", 'NOM PRP NOM ADJ PRP:det NOM'),
#  ('Mimétisme biologique', 'NOM ADJ'),
#  ('Aposématisme', 'NOM'),
#  ('Cryptisme', 'NOM'),
#  ('Mimétisme batésien', 'NOM ADJ'),
#  ('Mimétisme mullérien', 'NOM ADJ'),
#  ('Camouflage biologique', 'NOM ADJ'),
#  ("Trouble spécifique d' apprentissage", 'NOM ADJ PRP NOM'),
#  ("Trouble spécifique de l' apprentissage", 'NOM ADJ PRP DET:ART NOM'),
#  ('Liste de médicaments potentiellement inappropriés', 'NOM PRP NOM ADV ADJ'),
#  ('Liste de MPI', 'NOM PRP NAM'),
#  ('MPI ( Médicament Potentiellement Inapproprié )',
#   'NAM PUN NOM ADV VER:pper PUN'),
#  ('Médicaments potentiellement inappropriés', 'NOM ADV ADJ'),
#  ('Critères de Beers', 'NOM PRP NAM'),
#  ('Critères de de Beers', 'NOM PRP PRP NAM'),
#  ('Médicaments potentiellement inappropriés selon Beers',
#   'NOM ADV ADJ PRP NAM'),
#  ('Médicaments potentiellement inappropriés selon les critères de Beers',
#   'NOM ADV ADJ PRP DET:ART NOM PRP NAM'),
#  ("Screening tool of older person's potentially inappropriate prescriptions",
#   'NOM NOM ADJ NOM ADJ NOM ADJ NOM'),
#  ('Critères STOPP-START', 'NOM NAM'),
#  ('Outil de dépistage des prescriptions médicamenteuses potentiellement inappropriées chez la personne âgée',
#   'NOM PRP NOM PRP:det NOM ADJ ADV ADJ PRP DET:ART NOM ADJ'),
#  ('Outil de dépistage des prescriptions potentiellement inappropriées chez la personne âgée',
#   'NOM PRP NOM PRP:det NOM ADV ADJ PRP DET:ART NOM ADJ'),
#  ('Outil de détection des prescriptions médicamenteuses potentiellement inappropriées chez la personne âgée',
#   'NOM PRP NOM PRP:det NOM ADJ ADV ADJ PRP DET:ART NOM ADJ'),
#  ('Outil de détection des prescriptions potentiellement inappropriées chez la personne âgée',
#   'NOM PRP NOM PRP:det NOM ADV ADJ PRP DET:ART NOM ADJ'),
#  ('STOPP', 'NOM'),
#  ('Indice de pertinence des médicaments', 'NOM PRP NOM PRP:det NOM'),
#  ('Troubles tardifs', 'NOM ADJ'),
#  ("Maladies d' apparition tardive", 'NOM PRP NOM ADJ'),
#  ('Maladies plus tardives', 'NOM ADV ADJ'),
#  ('Maladies tardives', 'NOM ADJ'),
#  ('Maladies ultérieures', 'NOM ADJ'),
#  ('Maladies à début tardif', 'NOM PRP NOM ADJ'),
#  ("Troubles d' apparition tardive", 'NOM PRP NOM ADJ'),
#  ('Troubles plus tardifs', 'NOM ADV ADJ'),
#  ('Troubles ultérieurs', 'NOM ADJ'),
#  ('Troubles à début tardif', 'NOM PRP NOM ADJ'),
#  ('Phakopsora pachyrhizi', 'NOM ADJ'),
#  ('Rouille asiatique du soja', 'NOM ADJ PRP:det NOM'),
#  ('Rouille asiatique du soya', 'NOM ADJ PRP:det NOM'),
#  ('Agriculteurs', 'NOM'),
#  ('Agricultrices', 'NOM'),
#  ('Fermiers', 'NOM'),
#  ('Fermières', 'NOM'),
#  ('Ouvriers agricoles', 'NOM ADJ'),
#  ('Ouvrières agricoles', 'NOM ADJ'),
#  ('Éleveurs', 'NOM'),
#  ('Éleveuses', 'NOM'),
#  ('Technologie culturellement adaptée', 'NOM ADV VER:pper'),
#  ('Technologie adaptée culturellement', 'NOM VER:pper ADV'),
#  ('Technologie appropriée', 'NOM ADJ'),
#  ('Technologie intermédiaire', 'NOM ADJ'),
#  ('Technologie douce', 'NOM ADJ'),
#  ('Technique douce', 'NOM ADJ'),
#  ('Apprentissage social', 'NOM ADJ'),
#  ('Apprentissages sociaux', 'NOM ADJ'),
#  ('États financiers', 'NAM ADJ'),
#  ('Tableaux comptables', 'NOM ADJ'),
#  ('Actifs financiers', 'ADJ NOM'),
#  ('Avoirs financiers', 'NOM ADJ'),
#  ('État des flux de trésorerie', 'NOM PRP:det NOM PRP NOM'),
#  ('Avoir net', 'VER:infi ADJ'),
#  ('Tableau de trésorerie', 'NOM PRP NOM'),
#  ('Tableau des flux de trésorerie', 'NOM PRP:det NOM PRP NOM'),
#  ('Valeur nette', 'NOM ADJ'),
#  ('Bilan', 'NOM'),
#  ('Bilan financier', 'NOM ADJ'),
#  ('Relevé des dépenses', 'VER:pper PRP:det NOM'),
#  ('État des dépenses', 'NOM PRP:det NOM'),
#  ('Compte de résultats', 'NOM PRP NOM'),
#  ('Compte de résultat', 'NOM PRP NOM'),
#  ('Compte des résultats', 'NOM PRP:det NOM'),
#  ('État des résultats', 'NOM PRP:det NOM'),
#  ('Capitaux propres', 'NOM ADJ'),
#  ('Fonds propres', 'NOM ADJ'),
#  ('Passif financier', 'NOM ADJ'),
#  ('Dettes', 'NOM'),
#  ('Passif', 'ADJ'),
#  ('Mineurs ( métier )', 'ADJ PUN NOM PUN'),
#  ('Mineuses ( métier )', 'NOM PUN NOM PUN'),
#  ('Travailleurs de la mine', 'NOM PRP DET:ART NOM'),
#  ('Travailleurs miniers', 'NOM ADJ'),
#  ('Travailleuses de la mine', 'NOM PRP DET:ART NOM'),
#  ('Travailleuses minières', 'NOM ADJ'),
#  ('Chronopharmacocinétique', 'NAM'),
#  ('Données administratives des demandes de remboursement des soins de santé',
#   'NOM ADJ PRP:det NOM PRP NOM PRP:det NOM PRP NOM'),
#  ("Santé de l' enfant", 'NOM PRP DET:ART NOM'),
#  ('Santé des enfants', 'NOM PRP:det NOM'),
#  ('Interleukine-33', 'NAM'),
#  ('IL-33', 'NAM'),
#  ('IL33', 'NAM'),
#  ('Protéine S100A12', 'NOM NAM'),
#  ('Calgranuline C', 'NOM NUM'),
#  ('Protéine CAAF1', 'NOM NAM'),
#  ('Protéine EN-RAGE', 'NOM NOM'),
#  ('Protéine ENRAGE', 'NOM VER:pres'),
#  ('Protéine MRP-6', 'NOM NAM'),
#  ('Protéine S100 A12', 'NOM NAM NAM'),
#  ('S100A12', 'NOM'),
#  ('Télopodes', 'NAM'),
#  ('Drosophila simulans', 'VER:simp NOM'),
#  ('Optimisme', 'NOM'),
#  ('Pessimisme', 'NOM'),
#  ('Ataxine-1', 'NAM'),
#  ('Protéine Atxn-1', 'NOM NAM'),
#  ('Protéine Atxn1', 'NOM NAM'),
#  ('Protéine SCA1', 'NOM NAM'),
#  ('Protéine ataxine-1', 'NOM ADJ'),
#  ("Protéine de l' ataxie spinocérébelleuse de type 1",
#   'NOM PRP DET:ART NOM ADJ PRP NOM NUM'),
#  ("Santé de l' adolescent", 'NOM PRP DET:ART NOM'),
#  ("Santé de l' adolescente", 'NOM PRP DET:ART NOM'),
#  ('Santé des adolescentes', 'NOM PRP:det NOM'),
#  ('Santé des adolescents', 'NOM PRP:det NOM'),
#  ('Ataxine-2', 'NAM'),
#  ('Protéine ATXN2', 'NOM NAM'),
#  ('Protéine Atx-2', 'NOM NAM'),
#  ('Protéine SCA2', 'NOM NAM'),
#  ('Protéine ataxine-2', 'NOM ADJ'),
#  ("Protéine de l' ataxie spinocérébelleuse de type 2",
#   'NOM PRP DET:ART NOM ADJ PRP NOM NUM'),
#  ('Ataxine-3', 'NAM'),
#  ('Protéine ATXN3', 'NOM NAM'),
#  ('Protéine SCA3', 'NOM NAM'),
#  ('Protéine ataxine-3', 'NOM ADJ'),
#  ("Protéine de l' ataxie spinocérébelleuse de type 3",
#   'NOM PRP DET:ART NOM ADJ PRP NOM NUM'),
#  ('Protéine de la maladie de Machado-Joseph', 'NOM PRP DET:ART NOM PRP NAM'),
#  ("Analyse sur le lieu d' intervention", 'NOM PRP DET:ART NOM PRP NOM'),
#  ('Analyse délocalisée', 'VER:pres VER:pper'),
#  ('Analyse hors laboratoire', 'NOM PRP NOM'),
#  ('POCT', 'NOM'),
#  ('Point-of-care testing', 'ADJ NOM'),
#  ("Test sur le lieu d' intervention", 'NOM PRP DET:ART NOM PRP NOM'),
#  ('Analyse au chevet du patient', 'NOM PRP:det NOM PRP:det ADJ'),
#  ('Test au chevet du patient', 'NOM PRP:det NOM PRP:det ADJ'),
#  ('Ataxine-7', 'NAM'),
#  ('Protéine ATXN7', 'NOM NAM'),
#  ('Protéine Atxn-7', 'NOM NAM'),
#  ('Protéine SCA7', 'NOM NAM'),
#  ("Protéine de l' ataxie spinocérébelleuse de type 7",
#   'NOM PRP DET:ART NOM ADJ PRP NOM NUM'),
#  ('Ataxine-10', 'NAM'),
#  ('Protéine ATXN10', 'NOM NAM'),
#  ('Protéine Atxn-10', 'NOM NAM'),
#  ('Protéine SCA10', 'NOM NAM'),
#  ("Protéine de l' ataxie spinocérébelleuse de type 10",
#   'NOM PRP DET:ART NOM ADJ PRP NOM NUM'),
#  ('Récepteurs des peptides similaires au glucagon',
#   'NOM PRP:det NOM ADJ PRP:det NOM'),
#  ('GLPR', 'NAM'),
#  ('Glucagon-like peptide receptor', 'ADJ NOM ADJ'),
#  ('Protéines GLPR', 'NOM NAM'),
#  ('Récepteurs des peptides de type glucagon', 'NOM PRP:det NOM PRP NOM NOM'),
#  ('Récepteurs des peptides semblables au glucagon',
#   'NOM PRP:det NOM ADJ PRP:det NOM'),
#  ('Récepteur du peptide-1 similaire au glucagon',
#   'NOM PRP:det NOM ADJ PRP:det NOM'),
#  ('GLP-1R', 'NAM'),
#  ('GLP1R', 'NAM'),
#  ('Glucagon-like peptide-1 receptor', 'NOM ADJ NOM'),
#  ('Protéine GLP1R', 'NOM NAM'),
#  ('Récepteur GLP-1R', 'NOM NAM'),
#  ('Récepteur GLP1R', 'NOM NAM'),
#  ('Récepteur du GLP-1', 'NOM PRP:det NAM'),
#  ('Récepteur du peptide-1 de type glucagon', 'NOM PRP:det NOM PRP NOM NOM'),
#  ('Récepteur du peptide-1 semblable au glucagon',
#   'NOM PRP:det NOM ADJ PRP:det NOM'),
#  ('Récepteur du peptide-2 similaire au glucagon',
#   'NOM PRP:det NOM ADJ PRP:det NOM'),
#  ('GLP-2R', 'NAM'),
#  ('GLP2R', 'NAM'),
#  ('Glucagon-like peptide-2 receptor', 'NOM ADJ NOM'),
#  ('Protéine GLP2R', 'NOM NAM'),
#  ('Récepteur GLP-2R', 'NOM NAM'),
#  ('Récepteur GLP2R', 'NOM NAM'),
#  ('Récepteur du GLP-2', 'NOM PRP:det NAM'),
#  ('Récepteur du peptide-2 de type glucagon', 'NOM PRP:det NOM PRP NOM NOM'),
#  ('Récepteur du peptide-2 semblable au glucagon',
#   'NOM PRP:det NOM ADJ PRP:det NOM'),
#  ('Récepteur spécifique des produits finaux de glycosylation avancée',
#   'NOM ADJ PRP:det NOM ADJ PRP NOM VER:pper'),
#  ('Protéine AGER', 'NOM NOM'),
#  ('RAGE', 'NOM'),
#  ('Receptor for advanced glycation end products',
#   'NAM NOM ADJ NOM VER:pres NOM'),
#  ('Récepteur AGE', 'ADJ NOM'),
#  ("Récepteur de l' amphotérine", 'NOM PRP DET:ART NOM'),
#  ('Récepteur des AGE', 'NOM PRP:det NOM'),
#  ('Récepteur des produits finaux de glycation avancée',
#   'NOM PRP:det NOM ADJ PRP NOM VER:pper'),
#  ('Récepteur des produits finaux de glycosylation avancée',
#   'NOM PRP:det NOM ADJ PRP NOM VER:pper'),
#  ('Récepteur des produits terminaux de glycation avancée',
#   'NOM PRP:det NOM ADJ PRP NOM VER:pper'),
#  ('Récepteur des produits terminaux de glycosylation avancée',
#   'NOM PRP:det NOM ADJ PRP NOM VER:pper'),
#  ('Récepteur spécifique des produits terminaux de glycosylation avancée',
#   'NOM ADJ PRP:det NOM ADJ PRP NOM VER:pper'),
#  ('Récepteurs des produits finaux de glycosylation avancée',
#   'NOM PRP:det NOM ADJ PRP NOM VER:pper'),
#  ("Protéines à motif de reconnaissance de l' ARN",
#   'NOM PRP NOM PRP NOM PRP DET:ART NAM'),
#  ("Protéines à domaine de liaison à l' ARN",
#   'NOM PRP NOM PRP NOM PRP DET:ART NAM'),
#  ('Protéines à domaine ribonucléoprotéique', 'NOM PRP NOM ADJ'),
#  ('Protéine-2 similaire à ELAV', 'NOM ADJ PRP NAM'),
#  ('Antigène HuB', 'NOM NAM'),
#  ("Antigène HuB de l' encéphalomyélite paranéoplasique",
#   'NOM NAM PRP DET:ART NOM ADJ'),
#  ('Protéine HuB', 'NOM NAM'),
#  ('Protéine-2 semblable à ELAV', 'NOM ADJ PRP NAM'),
#  ('Protéine-3 similaire à ELAV', 'NOM ADJ PRP NAM'),
#  ('Antigène HuC', 'NOM NAM'),
#  ("Antigène HuC de l' encéphalomyélite paranéoplasique",
#   'NOM NAM PRP DET:ART NOM ADJ'),
#  ('Protéine HuC', 'NOM NAM'),
#  ('Protéine-3 semblable à ELAV', 'NOM ADJ PRP NAM'),
#  ('Protéine-4 similaire à ELAV', 'NOM ADJ PRP NAM'),
#  ('Antigène HuD', 'NOM NAM'),
#  ("Antigène HuD de l' encéphalomyélite paranéoplasique",
#   'NOM NAM PRP DET:ART NOM ADJ'),
#  ('Protéine HuD', 'NOM NAM'),
#  ('Protéine-4 semblable à ELAV', 'NOM ADJ PRP NAM'),
#  ('Protéine-1 similaire à ELAV', 'NOM ADJ PRP NAM'),
#  ('Antigène HuR', 'NOM NAM'),
#  ("Antigène HuR de l' encéphalomyélite paranéoplasique",
#   'NOM NAM PRP DET:ART NOM ADJ'),
#  ('Protéine HuR', 'NOM NAM'),
#  ('Protéine-1 semblable à ELAV', 'NOM ADJ PRP NAM'),
#  ('Lactosérum', 'NOM'),
#  ('Petit-lait', 'NOM'),
#  ('Protéines de lactosérum', 'NOM PRP NOM'),
#  ('Protéine de lactosérum', 'NOM PRP NOM'),
#  ('Protéine de petit-lait', 'NOM PRP NOM'),
#  ('Protéines de petit-lait', 'NOM PRP NOM'),
#  ('Syllogomanie', 'NOM'),
#  ("Trouble d' accumulation", 'NOM PRP NOM'),
#  ("Trouble d' accumulation compulsive", 'NOM PRP NOM ADJ'),
#  ('Accumulation obsessionnelle', 'NOM ADJ'),
#  ('Accumulation compulsive', 'NOM ADJ'),
#  ('Stockage obsessionnel', 'NOM ADJ'),
#  ('Thésaurisation obsessionnelle', 'NOM ADJ'),
#  ('Inhibiteurs de poly ( ADP-ribose ) polymérases',
#   'NOM PRP NOM PUN NAM PUN NOM'),
#  ('Inhibiteurs de PARP', 'NOM PRP NAM'),
#  ('Inhibiteurs de la poly ( ADP-ribose ) polymérase',
#   'NOM PRP DET:ART NOM PUN NAM PUN NOM'),
#  ('Inhibiteurs de la poly ( ADP-ribosylation )',
#   'NOM PRP DET:ART NOM PUN NAM PUN'),
#  ('Inhibiteurs de poly ( ADP-ribose ) polymérase',
#   'NOM PRP NOM PUN NAM PUN NOM'),
#  ('Inhibiteurs des poly ( ADP-ribose ) polymérases',
#   'NOM PRP:det NOM PUN NAM PUN NOM'),
#  ('Trouble du spectre autistique', 'NOM PRP:det NOM ADJ'),
#  ('TSA ( Trouble du Spectre Autistique )', 'NAM PUN NOM PRP:det NOM ADJ PUN'),
#  ("Trouble du spectre de l' autisme", 'NOM PRP:det NOM PRP DET:ART NOM'),
#  ('Troubles du spectre autistique', 'NOM PRP:det NOM ADJ'),
#  ('Protéines CELF', 'NOM NAM'),
#  ('Protéines BRUNOL', 'NOM NAM'),
#  ('Protéines CUG-BP', 'NOM NAM'),
#  ('Protéines CUGBP', 'NOM NAM'),
#  ('Protéines de liaison aux répétitions CUG', 'NOM PRP NOM PRP:det NOM NAM'),
#  ('Protéine CELF1', 'NOM NAM'),
#  ('Protéine BRUNOL2', 'NOM NAM'),
#  ('Protéine CUGBP1', 'NOM NAM'),
#  ('Protéine-2 semblable à Bruno', 'NOM ADJ PRP NAM'),
#  ('Protéine-2 similaire à Bruno', 'NOM ADJ PRP NAM'),
#  ('Développement industriel', 'NOM ADJ'),
#  ("Développement de l' industrie", 'NOM PRP DET:ART NOM'),
#  ("Expansion de l' industrie", 'NOM PRP DET:ART NOM'),
#  ('Expansion industrielle', 'NOM ADJ'),
#  ('Développement technologique', 'NOM ADJ'),
#  ('Développement de la technologie', 'NOM PRP DET:ART NOM'),
#  ('Industrialisation', 'NOM'),
#  ('Informatique en nuage', 'NOM PRP NOM'),
#  ('Infonuagique', 'NOM'),
#  ('Informatique dématérialisée', 'NOM VER:pper'),
#  ("Service d' infonuagique", 'NOM PRP NOM'),
#  ("Service d' informatique en nuage", 'NOM PRP NOM PRP NOM'),
#  ('Service infonuagique', 'NOM ADJ'),
#  ('Stockage de données en ligne', 'NOM PRP NOM PRP NOM'),
#  ('Stockage en ligne', 'NOM PRP NOM'),
#  ('Stockage en nuage', 'NOM PRP NOM'),
#  ('Stockage infonuagique', 'NOM ADJ'),
#  ('Traitement de données en ligne', 'NOM PRP NOM PRP NOM'),
#  ('Traitement en ligne', 'NOM PRP NOM'),
#  ('Traitement en nuage', 'NOM PRP NOM'),
#  ('Traitement infonuagique', 'NOM ADJ'),
#  ('Ressources naturelles', 'NOM ADJ'),
#  ('Richesses naturelles', 'NOM ADJ'),
#  ...]

# %% [markdown]
# ### Frequency distribution

# %%
from nltk.probability import FreqDist
freq = FreqDist(structures)
tab = pandas.DataFrame(list(freq.items()), columns= ["Structure", "Fréquence"])
tab.sort_values(["Fréquence"], 
                    axis=0,
                    ascending=[False], 
                    inplace=True)
tab.to_csv(path+'mesh_patterns-fr.csv')
tab
# Out:
#                                               Structure  Fréquence
# 0                                               NOM ADJ      20116
# 2                                                   NOM      15475
# 1                                                   NAM       9906
# 46                                          NOM PRP NOM       6086
# 179                                             NOM NAM       4916
# ...                                                 ...        ...
# 3111  NOM PRP NOM PRP:det NOM PRP DET:ART NOM ADJ PR...          1
# 3113                   NOM VER:pper PRP:det NOM NAM NUM          1
# 3115                NOM PRP NOM PRP NOM NUM PRP ADJ NOM          1
# 3117                            NOM PRP:det ADJ PRP NOM          1
# 6180                                   ADJ VER:pper NOM          1
#
# [6181 rows x 2 columns]
